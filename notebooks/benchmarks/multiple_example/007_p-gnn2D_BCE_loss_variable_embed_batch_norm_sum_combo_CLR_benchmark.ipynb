# %% [markdown]
# # Benchmark position-aware graph neural network/2D CNN architecture
#
# This notebook contains all of the code to overfit a P-GNN/2D CNN to four contact channels of a single structure (6E6O).
#
# ## Setup

# %% [markdown]
# ### Dataloader code

# %%
import torch
from torch.utils.data import Dataset
import numpy as np
import periodictable as pt
import pandas as pd
import os
import matplotlib.pyplot as plt
import networkx as nx
import itertools as it


def read_files(acc, model, graph_dir, contacts_dir):
    """
    Read graph and contacts files.

    Args:
    - acc (str) - String of the PDB ID (lowercese).
    - model (int) - Model number of the desired bioassembly.
    - graph_dir (str) - Directory containing the nodes, edges,
        and mask files.
    - contacts_dir (str) - Directory containing the .contacts
        files from get_contacts.py.

    Returns:
    - Dictionary of DataFrames and lists corresponding to
        graph nodes, edges, mask, and contacts.
    """

    # Get the file names for the graph files
    node_file = os.path.join(graph_dir, '{}-{}_nodes.csv'.format(acc, model))
    edge_file = os.path.join(graph_dir, '{}-{}_edges.csv'.format(acc, model))
    mask_file = os.path.join(graph_dir, '{}-{}_mask.csv'.format(acc, model))

    # Get the contacts file
    contacts_file = os.path.join(contacts_dir, '{}-{}.contacts'.format(acc, model))

    # Read the nodes and edges
    nodes = pd.read_csv(node_file)
    edges = pd.read_csv(edge_file)

    # Check if the mask is empty
    if os.path.getsize(mask_file) > 0:
        with open(mask_file) as f:
            mask = f.read().split('\n')
    else:
        mask = []

    # Read the contacts
    contacts = pd.read_table(contacts_file, sep='\t',
                             header=None, names=['type', 'start', 'end'])

    # Return the data
    data = {
        'nodes': nodes,
        'edges': edges,
        'mask': mask,
        'contacts': contacts
    }

    return data


def process_res_data(data):
    """
    Process residue-level data from atom-level data.

    Args:
    - data (dict) - Dictionary of graph data output from `read_files`.

    Returns:
    - Dictionary of atom and residue graph and contact data.
    """

    # Extract data form dict
    nodes = data['nodes']
    edges = data['edges']
    mask = data['mask']
    contacts = data['contacts']

    # Get residue nodes
    res_nodes = pd.DataFrame()
    res_nodes['res'] = [':'.join(atom.split(':')[:3]) for atom in nodes['atom']]
    res_nodes = res_nodes.drop_duplicates().reset_index(drop=True)

    # Get residue edges
    res_edges = edges.copy()
    res_edges['start'] = [':'.join(atom.split(':')[:3]) for atom in res_edges['start']]
    res_edges['end'] = [':'.join(atom.split(':')[:3]) for atom in res_edges['end']]
    res_edges = res_edges[res_edges['start'] != res_edges['end']].drop_duplicates().reset_index(drop=True)

    # Get residue contacts
    res_contacts = contacts.copy()
    res_contacts['start'] = [':'.join(atom.split(':')[:3]) for atom in res_contacts['start']]
    res_contacts['end'] = [':'.join(atom.split(':')[:3]) for atom in res_contacts['end']]
    res_contacts = res_contacts[res_contacts['start'] != res_contacts['end']].drop_duplicates().reset_index(drop=True)

    # Get residue mask
    res_mask = list(set([':'.join(atom.split(':')[:3]) for atom in mask]))

    # Return data dict
    data = {
        'atom_nodes': nodes,
        'atom_edges': edges,
        'atom_contact': contacts,
        'atom_mask': mask,
        'res_nodes': res_nodes,
        'res_edges': res_edges,
        'res_contact': res_contacts,
        'res_mask': res_mask
    }

    return data


def get_map_dicts(entity_list):
    """
    Map identifiers to indices and vice versa.

    Args:
    - entity_list (list) - List of entities (atoms, residues, etc.)
        to index.

    Returns:
    - Tuple of the entity to index and index to entity dicts, respectively.
    """

    # Create the entity:index dictionary
    ent2idx_dict = {entity: idx for idx, entity in enumerate(entity_list)}

    # Create the index:entity dictionary
    idx2ent_dict = {idx: entity for entity, idx in ent2idx_dict.items()}

    return (ent2idx_dict, idx2ent_dict)


def create_adj_mat(data, dict_map, mat_type):
    """
    Creates an adjacency matrix.

    Args:
    - data (DataFrame) - Dataframe with 'start' and 'end' column
        for each interaction. For atom-level adjacency, 'order'
        column is also required. For atom or residue conatcts,
        'type' column is also required.

    Returns:
    - Coordinate format matrix (numpy). For atom adjacency, third column
        corresponds to bond order. For contacts, third column
        corresponds to channel.

    Channel mappings (shorthand from get_contacts.py source):

        0:
            hp             hydrophobic interactions
        1:
            hb             hydrogen bonds
            lhb            ligand hydrogen bonds
            hbbb           backbone-backbone hydrogen bonds
            hbsb           backbone-sidechain hydrogen bonds
            hbss           sidechain-sidechain hydrogen bonds
            hbls           ligand-sidechain residue hydrogen bonds
            hblb           ligand-backbone residue hydrogen bonds
        2:
            vdw            van der Waals
        3:
            wb             water bridges
            wb2            extended water bridges
            lwb            ligand water bridges
            lwb2           extended ligand water bridges
        4:
            sb             salt bridges
        5:
            ps             pi-stacking
        6:
            pc             pi-cation
        7:
            ts             t-stacking
    """

    # Initialize the coordinate list
    coord_mat = []

    # Map channel names to numeric channels
    channel = {
        # Hydrophobic interactions in first channel
        'hp': 0,
        'hplp': 0,
        'hpll': 0,

        # Hydrogen bonds in second channel
        'hb': 1,
        'lhb': 1,
        'hbbb': 1,
        'hbsb': 1,
        'hbss': 1,
        'hbls': 1,
        'hblb': 1,

        # VdW in third channel
        'vdw': 2,

        # Water bridges
        'wb': 3,
        'wb2': 3,
        'lwb': 3,
        'lwb2': 3,

        # Salt bridges
        'sb': 4,
        'sbpl': 4,
        'sbll': 4,

        # Other interactions
        'ps': 5,
        'pc': 6,
        'ts': 7,
    }

    # Assemble the contacts
    for idx, row in data.iterrows():

        if row['start'] in dict_map and row['end'] in dict_map:

            entry = [dict_map[row['start']], dict_map[row['end']]]

            # Add order or type if necessary
            if mat_type == 'atom_graph':
                entry.append(row['order'])
            elif mat_type == 'atom_contact':
                entry.append(channel[row['type']])
            elif mat_type == 'res_contact':
                entry.append(channel[row['type']])

            coord_mat.append(entry)

    return np.array(coord_mat)


def create_conn_adj_mat(adj):
    """
    Create connection adjacency matrix
    """

    conn_map = {(a, b): idx for idx, (a, b) in enumerate(zip(*np.triu_indices_from(adj)))}

    one_hop_neighbors = {idx: np.argwhere(row > 0).squeeze().tolist() for idx, row in enumerate(adj)}

    conns = []

    for i, j in it.combinations_with_replacement(one_hop_neighbors, 2):
        row = conn_map[(i, j)]
        adj_conn_coords = set([(m, n) if m <= n else (n, m)
                               for m, n in it.product(one_hop_neighbors[i],
                                                      one_hop_neighbors[j])])
        adj_conns = [conn_map[x] for x in adj_conn_coords]

        conns.append(np.array(list(it.product([row], adj_conns))))

    conn_adj = np.concatenate(conns, axis=0).T

    return conn_adj


def create_mem_mat(atom_dict, res_dict):
    """
    Create a membership matrix mapping atoms to residues.

    Args:
    - atom_dict (dict) - Dictionary mapping atoms to indices.
    - res_dict (dict) - Dictionary mapping residues to indices.

    Returns:
    - Coordinate format membership matrix (numpy) with first
        row being residue number and the second column being
        atom number.
    """

    # Initialize the coordinate list
    mem_coord = []

    # Map atoms to residues
    for atom, atom_idx in atom_dict.items():
        res_idx = res_dict[':'.join(atom.split(':')[:3])]

        mem_coord.append([res_idx, atom_idx])

    mem_coord = np.array(mem_coord)

    return mem_coord


def create_idx_list(id_list, dict_map):
    """
    Create list of indices.

    Args:
    - id_list (list) - List of masked atom or residue identifiers.
    - dict_map (dict) - Dictionary mapping entities to indices.

    Returns:
    - A numpy array of the masked indices.
    """

    # Generate the numpy index array
    idx_array = np.array([dict_map[iden] for iden in id_list])

    return idx_array


class TesselateDataset(Dataset):
    """
    Dataset class for structural data.

    Args:
    - accession_list (str) - File path from which to read PDB IDs for dataset.
    - graph_dir (str) - Directory containing the nodes, edges, and mask files.
    - contacts_dir (str) - Directory containing the .contacts files from
        get_contacts.py.
    - return_data (list) - List of datasets to return. Value must be 'all' or
        a subset of the following list:
            - pdb_id
            - model
            - atom_nodes
            - atom_adj
            - atom_contact
            - atom_mask
            - res_adj
            - res_dist
            - res_contact
            - res_mask
            - mem_mat
            - idx2atom_dict
            - idx2res_dict
    """

    def __init__(self, accession_list, graph_dir, contacts_dir, add_covalent=False, return_data='all', in_memory=False):

        if return_data == 'all':
            self.return_data = [
                'pdb_id',
                'model',
                'atom_nodes',
                'atom_adj',
                'atom_contact',
                'atom_mask',
                'res_adj',
                'res_dist',
                'conn_adj',
                'res_contact',
                'res_mask',
                'mem_mat',
                'idx2atom_dict',
                'idx2res_dict'
            ]

        else:
            self.return_data = return_data

        # Store reference to accession list file
        self.accession_list = accession_list

        # Store references to the necessary directories
        self.graph_dir = graph_dir
        self.contacts_dir = contacts_dir

        # Whether to add covalent bonds to prediction task and
        # remove sequence non-deterministic covalent bonds from the adjacency matrix
        self.add_covalent=add_covalent

        # Read in and store a list of accession IDs
        with open(accession_list, 'r') as handle:
            self.accessions = np.array([acc.strip().lower().split() for acc in handle.readlines()])

        self.data = {}


    def __len__(self):
        """
        Return the length of the dataset.

        Returns:
        - Integer count of number of examples.
        """
        return len(self.accessions)


    def __getitem__(self, idx):
        """
        Get an item with a particular index value.

        Args:
        - idx (int) - Index of desired sample.

        Returns:
        - Dictionary of dataset example. All tensors are sparse when possible.
        """

        try:
            if idx in self.data:
                return self.data[idx]

            # initialize the return dictionary
            return_dict = {}

            acc_entry = self.accessions[idx]

            # Get the PDB ID
            acc = acc_entry[0]

            # Get the model number if one exists
            if len(acc_entry) == 1:
                model = 1
            else:
                model = acc_entry[1]

            # Read and process the files
            data = read_files(acc, model, self.graph_dir, self.contacts_dir)
            data = process_res_data(data)

            # Generate the mapping dictionaries
            atom2idx_dict, idx2atom_dict = get_map_dicts(data['atom_nodes']['atom'].unique())
            res2idx_dict, idx2res_dict = get_map_dicts(data['res_nodes']['res'].unique())

            # Get numbers of atoms and residues per sample
            n_atoms = len(atom2idx_dict)
            n_res = len(res2idx_dict)

            # Handle all of the possible returned datasets
            if 'pdb_id' in self.return_data:
                return_dict['pdb_id'] = acc

            if 'model' in self.return_data:
                return_dict['model'] = model

            if 'atom_nodes' in self.return_data:
                ele_nums = [pt.elements.symbol(element).number for element in data['atom_nodes']['element']]
                return_dict['atom_nodes'] = torch.LongTensor(ele_nums)
                assert not torch.isnan(return_dict['atom_nodes']).any()

            if 'atom_adj' in self.return_data:

                adj = create_adj_mat(data['atom_edges'], atom2idx_dict, mat_type='atom_graph').T

                x = torch.LongTensor(adj[0, :]).squeeze()
                y = torch.LongTensor(adj[1, :]).squeeze()
                val = torch.FloatTensor(adj[2, :]).squeeze()

                atom_adj = torch.zeros([n_atoms, n_atoms]).index_put_((x, y), val, accumulate=False)

                atom_adj = atom_adj.index_put_((y, x), val, accumulate=False)

                atom_adj[range(n_atoms), range(n_atoms)] = 1

                atom_adj = (atom_adj > 0).float()

                return_dict['atom_adj'] = atom_adj

                assert not torch.isnan(return_dict['atom_adj']).any()

            if 'atom_contact' in self.return_data:
                atom_contact = create_adj_mat(data['atom_contact'], atom2idx_dict, mat_type='atom_contact').T

                x = torch.LongTensor(atom_contact[0, :]).squeeze()
                y = torch.LongTensor(atom_contact[1, :]).squeeze()
                z = torch.LongTensor(atom_contact[2, :]).squeeze()

                atom_contact = torch.zeros([n_atoms, n_atoms, 8]).index_put_((x, y, z),
                                                                        torch.ones(len(x)))
                atom_contact = atom_contact.index_put_((y, x, z),
                                                       torch.ones(len(x)))

                return_dict['atom_contact'] = atom_contact

                assert not torch.isnan(return_dict['atom_contact']).any()

            if 'atom_mask' in self.return_data:
                atom_mask = create_idx_list(data['atom_mask'], atom2idx_dict)

                masked_pos = torch.from_numpy(atom_mask)

                if self.add_covalent:
                    channels = 9
                else:
                    channels = 8

                mask = torch.ones([n_atoms, n_atoms, channels])

                if len(masked_pos) > 0:
                    mask[masked_pos, :, :] = 0
                    mask[:, masked_pos, :] = 0

                return_dict['atom_mask'] = mask

                assert not torch.isnan(return_dict['atom_mask']).any()

            if 'res_adj' in self.return_data:
                adj = create_adj_mat(data['res_edges'], res2idx_dict, mat_type='res_graph').T

                x = torch.LongTensor(adj[0, :]).squeeze()
                y = torch.LongTensor(adj[1, :]).squeeze()

                res_adj = torch.zeros([n_res, n_res]).index_put_((x, y), torch.ones(len(x)))

                res_adj = res_adj.index_put_((y, x), torch.ones(len(x)))

                res_adj[range(n_res), range(n_res)] = 1

                return_dict['res_adj'] = res_adj

                assert not torch.isnan(return_dict['res_adj']).any()

                if 'res_dist' in self.return_data:
                    G = nx.from_numpy_matrix(return_dict['res_adj'].numpy())
                    res_dist = torch.from_numpy(nx.floyd_warshall_numpy(G)).float()

                    res_dist[torch.isinf(res_dist)] = -1

                    return_dict['res_dist'] = res_dist

                    chain_mem = torch.zeros(res_dist.shape)
                    chain_mem[~torch.isinf(return_dict['res_dist'])] = 1

                    return_dict['chain_mem'] = chain_mem

                    assert not torch.isnan(return_dict['res_dist']).any()
                    assert not torch.isinf(return_dict['res_dist']).any()
                    assert not torch.isnan(return_dict['chain_mem']).any()
                    assert not torch.isinf(return_dict['chain_mem']).any()

                if 'conn_adj' in self.return_data:

                    conn_adj = create_conn_adj_mat(return_dict['res_adj'].numpy())

                    return_dict['conn_adj'] = torch.from_numpy(conn_adj)

            if 'res_contact' in self.return_data:
                res_contact = create_adj_mat(data['res_contact'], res2idx_dict, mat_type='res_contact').T

                x = torch.LongTensor(res_contact[0, :]).squeeze()
                y = torch.LongTensor(res_contact[1, :]).squeeze()
                z = torch.LongTensor(res_contact[2, :]).squeeze()

                res_contact = torch.zeros([n_res, n_res, 8]).index_put_((x, y, z),
                                                                        torch.ones(len(x)))

                res_contact = res_contact.index_put_((y, x, z),
                                                     torch.ones(len(x)))

                return_dict['res_contact'] = res_contact

                assert not torch.isnan(return_dict['res_contact']).any()

            if 'res_mask' in self.return_data:
                res_mask = create_idx_list(data['res_mask'], res2idx_dict)

                masked_pos = torch.from_numpy(res_mask)

                if self.add_covalent:
                    channels = 9
                else:
                    channels = 8

                mask = torch.ones([n_res, n_res, channels])

                if len(masked_pos) > 0:
                    mask[masked_pos, :, :] = 0
                    mask[:, masked_pos, :] = 0

                return_dict['res_mask'] = mask

                assert not torch.isnan(return_dict['res_mask']).any()

            if 'mem_mat' in self.return_data:
                mem_mat = create_mem_mat(atom2idx_dict, res2idx_dict).T

                x = torch.LongTensor(mem_mat[0, :]).squeeze()
                y = torch.LongTensor(mem_mat[1, :]).squeeze()

                mem_mat = torch.zeros([n_res, n_atoms]).index_put_((x, y),
                                                                   torch.ones(len(x)))

                return_dict['mem_mat'] = mem_mat

                assert not torch.isnan(return_dict['mem_mat']).any()

            if 'idx2atom_dict' in self.return_data:
                return_dict['idx2atom_dict'] = idx2atom_dict

            if 'idx2res_dict' in self.return_data:
                return_dict['idx2res_dict'] = idx2res_dict

            self.data[idx] = return_dict

            # Return the processed data
            return return_dict

        except Exception as e:
            print("Error:", acc, str(e))
            return np.array([0])

# %% [markdown]
# ### Modules

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np


####################
# Embedding layers #
####################

class AtomEmbed(nn.Module):
    """
    Embed the atoms to fixed-length input vectors.

    Args:
    - num_features (int) - Size of the returned embedding vectors.
    - scale_grad_by_freq (bool) - Scale gradients by the inverse of
        frequency (default=True).
    """

    def __init__(self, n_features, scale_grad_by_freq=True):
        super(AtomEmbed, self).__init__()
        self.embedding = nn.Embedding(118,
                                      n_features,
                                      scale_grad_by_freq=scale_grad_by_freq)

    def forward(self, atomic_numbers):
        """
        Return the embeddings for each atom in the graph.

        Args:
        - atoms (torch.LongTensor) - Tensor (n_atoms) containing atomic numbers.

        Returns:
        - torch.FloatTensor of dimension (n_atoms, n_features) containing
            the embedding vectors.
        """

        # Get and return the embeddings for each atom
        embedded_atoms = self.embedding(atomic_numbers)
        return embedded_atoms


#########################
# Position-aware layers #
#########################

# # PGNN layer, only pick closest node for message passing
class PGNN_layer(nn.Module):
    def __init__(self, input_dim, output_dim,dist_trainable=False):
        super(PGNN_layer, self).__init__()
        self.input_dim = input_dim
        self.dist_trainable = dist_trainable

        if self.dist_trainable:
            self.dist_compute = Nonlinear(1, output_dim, 1)

        self.linear_hidden = nn.Linear(input_dim*2, output_dim)
        self.linear_out_position = nn.Linear(output_dim,1)
        self.act = nn.ReLU()

        for m in self.modules():
            if isinstance(m, nn.Linear):
                m.weight.data = nn.init.xavier_uniform_(m.weight.data, gain=nn.init.calculate_gain('relu'))
                if m.bias is not None:
                    m.bias.data = nn.init.constant_(m.bias.data, 0.0)

    def forward(self, feature, dists_max, dists_argmax):
        if self.dist_trainable:
            dists_max = self.dist_compute(dists_max.unsqueeze(-1)).squeeze()

        subset_features = feature[dists_argmax.flatten(), :]
        subset_features = subset_features.reshape((dists_argmax.shape[0], dists_argmax.shape[1],
                                                   feature.shape[1]))

        messages = (subset_features * dists_max.unsqueeze(-1))

        self_feature = feature.unsqueeze(1).repeat(1, dists_max.shape[1], 1)
        messages = torch.cat((messages, self_feature), dim=-1)

        messages = self.linear_hidden(messages).squeeze()
        messages = self.act(messages) # n*m*d

        out_position = self.linear_out_position(messages).squeeze(-1)  # n*m_out
        out_structure = torch.mean(messages, dim=1)  # n*d

        return out_position, out_structure


### Non linearity
class Nonlinear(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super(Nonlinear, self).__init__()

        self.linear1 = nn.Linear(input_dim, hidden_dim)
        self.linear2 = nn.Linear(hidden_dim, output_dim)

        self.act = nn.ReLU()

        for m in self.modules():
            if isinstance(m, nn.Linear):
                m.weight.data = nn.init.xavier_uniform_(m.weight.data, gain=nn.init.calculate_gain('relu'))
                if m.bias is not None:
                    m.bias.data = nn.init.constant_(m.bias.data, 0.0)

    def forward(self, x):
        x = self.linear1(x)
        x = self.act(x)
        x = self.linear2(x)
        return x

# %% [markdown]
# # Functions

# %%
import numpy as np
import torch

########################################
# Pairwise matrix generation functions #
########################################

def pairwise_mat(nodes, method='mean'):
    """
    Generate matrix for pairwise determination of interactions.

    Args:
    - nodes (torch.FloatTensor) - Tensor of node (n_nodes, n_features) features.
    - method (str) - One of 'sum' or 'mean' for combination startegy for
        pairwise combination matrix (default = 'mean').

    Returns:
    - torch.FloatTensor of shape (n_pairwise, n_nodes) than can be used used to
        combine feature vectors. Values are 1 if method == "sum" and 0.5 if
        method == "mean".
    """

    # Get the upper triangle indices
    triu = np.vstack(np.triu_indices(nodes.shape[0]))

    # Loop through all indices and add to list with
    idxs = torch.from_numpy(triu).T

    # Convert to tensor
    combos = torch.zeros([idxs.shape[0], nodes.shape[0]]).scatter(1, idxs, 1)

    # Set to 0.5 if method is 'mean'
    if method == 'mean':
        combos *= 0.5

    return combos.to(nodes.device)


def pairwise_3d(nodes):
    # Get the upper triangle indices
    repeated_nodes = nodes.unsqueeze(0).expand(nodes.shape[0], -1, -1)
    repeated_nodes2 = repeated_nodes.permute(1, 0, 2)

    return torch.cat((repeated_nodes, repeated_nodes2), dim=-1)


############################
# Upper triangle functions #
############################

def triu_condense(input_tensor):
    """
    Condense the upper triangle of a tensor into a 2d dense representation.

    Args:
    - input_tensor (torch.Tensor) - Tensor of shape (n, n, m).

    Returns:
    - Tensor of shape (n(n+1)/2, m) where elements along the third dimension in
        the original tensor are packed row-wise according to the upper
        triangular indices.
    """

    # Get upper triangle index info
    row_idx, col_idx = np.triu_indices(input_tensor.shape[0])
    row_idx = torch.LongTensor(row_idx)
    col_idx = torch.LongTensor(col_idx)

    # Return the packed matrix
    output = input_tensor[row_idx, col_idx, :]

    return output


def triu_expand(input_matrix):
    """
    Expand a dense representation of the upper triangle of a tensor into
    a 3D squareform representation.

    Args:
    - input_matrix (torch.Tensor) - Tensor of shape (n(n+1)/2, m).

    Returns:
    - Tensor of shape (n, n, m) where elements along the third dimension in the
        original tensor are packed row-wise according to the upper triangular
        indices.
    """
    # Get the edge size n of the tensor
    n_elements = input_matrix.shape[0]
    n_chan = input_matrix.shape[1]
    n_res = int((-1 + np.sqrt(1 + 4 * 2 * (n_elements))) / 2)

    # Get upper triangle index info
    row_idx, col_idx = np.triu_indices(n_res)
    row_idx = torch.LongTensor(row_idx)
    col_idx = torch.LongTensor(col_idx)

    # Generate the output tensor
    output = torch.zeros((n_res, n_res, n_chan), device=input_matrix.device)

    # Input the triu values
    for i in range(n_chan):
        i_tens = torch.full((len(row_idx),), i, dtype=torch.long)
        output.index_put_((row_idx, col_idx, i_tens), input_matrix[:, i])

    # Input the tril values
    for i in range(n_chan):
        i_tens = torch.full((len(row_idx),), i, dtype=torch.long)
        output.index_put_((col_idx, row_idx, i_tens), input_matrix[:, i])

    return output


###################
# P-GNN functions #
###################

def generate_dists(adj_mat):
    adj_mask = adj_mat == 0

    dist = adj_mat - torch.eye(adj_mat.shape[0], device=adj_mat.device)
    dist = 1 / (dist + 1)
    dist[adj_mask] = 0

    return dist.squeeze()


def get_dist_max(anchorset_id, dist):
    dist_max = torch.zeros((dist.shape[0],len(anchorset_id)),
                           device=dist.device)
    dist_argmax = torch.zeros((dist.shape[0],len(anchorset_id)),
                              device=dist.device).long()
    for i in range(len(anchorset_id)):
        temp_id = anchorset_id[i]
        dist_temp = dist[:, temp_id]
        dist_max_temp, dist_argmax_temp = torch.max(dist_temp, dim=-1)
        dist_max[:,i] = dist_max_temp
        dist_argmax[:,i] = dist_argmax_temp
    return dist_max, dist_argmax


def get_random_anchorset(n,c=0.5):
    m = int(np.log2(n))
    copy = int(c*m)
    anchorset_id = []
    for i in range(m):
        anchor_size = int(n/np.exp2(i + 1))
        for j in range(copy):
            anchorset_id.append(np.random.choice(n,size=anchor_size,replace=False))
    return anchorset_id


def preselect_anchor(n_nodes, dists):
    anchorset_id = get_random_anchorset(n_nodes, c=1)
    return get_dist_max(anchorset_id, dists)

##############################
# Leak adjacency information #
##############################

def adj_adjust(adj, contact, p):
    dev = adj.device
    adj = adj.squeeze().cpu()
    contact = contact.squeeze().cpu()
    keep = torch.full(adj.shape, p)
    out = torch.bernoulli(keep).bool()
    mask = (torch.triu(out) + torch.triu(out).T) > 0
    adj_out = (((mask.unsqueeze(-1) * contact).sum(dim=-1) 
                + adj) > 0).float()
    return adj_out.to(dev)

# %% [markdown]
# ### Model

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F
import pytorch_lightning as pl
from torch.utils.data import DataLoader
import wandb


class PGNN2D(pl.LightningModule):
    def __init__(self, input_dim, hidden_dim, output_dim,
                 n_contact_channels,
                 layer_num=2, train_data=None,
                 val_data=None, test_data=None):
        super(PGNN2D, self).__init__()

        # Parameters
        self.n_contact_channels = n_contact_channels
        self.layer_num = layer_num

        # Datasets
        self.train_data = train_data
        self.val_data = val_data
        self.test_data = test_data

        # Embedding
        self.embed = AtomEmbed(input_dim)

        # First P-GNN layer
        self.conv_atom_first = PGNN_layer(input_dim, hidden_dim)

        self.batch_norm_first = nn.BatchNorm1d(hidden_dim)

        # All other P-GNN layers
        if layer_num>1:
            self.conv_atom_hidden = nn.ModuleList([PGNN_layer(hidden_dim,
                                                              hidden_dim)
                                                  for i in range(layer_num - 1)])

            self.batch_norm_hidden = nn.ModuleList([nn.BatchNorm1d(hidden_dim)
                                                   for i in range(layer_num - 1)])

        # RNN to condense position-aware embeddings
        self.embed_condense = torch.nn.GRU(input_size=1, hidden_size=25, batch_first=True)
        self.batch_norm_condense = nn.BatchNorm1d(25)

        self.batch_norm_pairwise = nn.BatchNorm1d(25)

        # 2D convolutional layers
        self.conv1 = nn.Conv2d(25,
                               25, 3, stride=1, padding=1)
        self.batch_norm_conv1 = nn.BatchNorm2d(25)
        self.conv2 = nn.Conv2d(25,
                               25, 3, stride=1, padding=1)
        self.batch_norm_conv2 = nn.BatchNorm2d(25)

        self.conv3 = nn.Conv2d(25,
                               25, 3, stride=1, padding=1)
        self.batch_norm_conv3 = nn.BatchNorm2d(25)

        # Final 2D CNN
        self.conv_final = nn.Conv2d(25, n_contact_channels, 3, stride=1, padding=1)

        # Focal loss
        self.loss = nn.BCEWithLogitsLoss()

        # Validation information
        self.reset_epoch_metrics()
        
        self.p = 0.9

        
    def forward(self, data):

        data['atom_dist'] = generate_dists(data['atom_adj'])

        data['atom_dist_max'], data['atom_dist_argmax'] = preselect_anchor(data['atom_adj'].squeeze().shape[0], data['atom_dist'])

        x = self.embed(data['atom_nodes'].squeeze())

        atom_embed = x.detach().cpu().numpy()

        x_position, x = self.conv_atom_first(x, data['atom_dist_max'], data['atom_dist_argmax'])
        x = F.relu(x)
        x = self.batch_norm_first(x)

        for i in range(self.layer_num-1):

            data['atom_dist'] = generate_dists(data['atom_adj'])

            data['atom_dist_max'], data['atom_dist_argmax'] = preselect_anchor(data['atom_adj'].squeeze().shape[0], data['atom_dist'])

            x_position, x = self.conv_atom_hidden[i](x, data['atom_dist_max'], data['atom_dist_argmax'])
            x = self.batch_norm_hidden[i](x)
            x = F.relu(x)

        x_position = data['mem_mat'].squeeze().matmul(x_position)

        _, x_position = self.embed_condense(x_position.unsqueeze(-1))

        x_position = x_position.squeeze()
        x_position = self.batch_norm_condense(x_position)

        pairwise = pairwise_mat(x_position, method='sum').matmul(x_position)
        pairwise = triu_expand(self.batch_norm_pairwise(pairwise)).permute(2, 0, 1).unsqueeze(0)

        conv1_out = F.relu(self.conv1(pairwise))
        conv1_out = self.batch_norm_conv1(conv1_out)
        conv2_out = F.relu(self.conv2(conv1_out))
        conv2_out = self.batch_norm_conv2(conv2_out)
        conv3_out = F.relu(self.conv3(conv2_out))
        conv3_out = self.batch_norm_conv3(conv3_out)
        square_preds = self.conv_final(conv3_out)

        square_preds = square_preds + square_preds.permute(0, 1, 3, 2)

        preds = triu_condense(square_preds.squeeze().permute(1, 2, 0))

        return preds

    def configure_optimizers(self):
        parameters = filter(lambda p: p.requires_grad, self.parameters())
        optimizer = torch.optim.SGD(parameters, lr=.1, momentum=0.9)
#         scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer)
        scheduler = torch.optim.lr_scheduler.CyclicLR(optimizer,
                                                      1e-4,
                                                      0.5,
                                                      step_size_up=16)

        return [optimizer], [scheduler]
    
    def training_step(self, batch, batch_nb):
        # REQUIRED
        batch['atom_adj'] = adj_adjust(batch['atom_adj'], batch['atom_contact'], self.p)
        
        y_hat = self.forward(batch).squeeze()
        y = triu_condense(batch['res_contact'].squeeze())
        weights = triu_condense(batch['res_mask'].squeeze())

        loss = F.binary_cross_entropy_with_logits(y_hat, y, weight=weights)

        self.train_losses.append(loss.item())

        return {'loss': loss}

    def validation_step(self, batch, batch_nb):
        # OPTIONAL
        batch['atom_adj'] = adj_adjust(batch['atom_adj'], batch['atom_contact'], self.p)
        
        y_hat = self.forward(batch).squeeze()
        y = triu_condense(batch['res_contact'].squeeze())
        weights = triu_condense(batch['res_mask'].squeeze())

        loss = F.binary_cross_entropy_with_logits(y_hat, y, weight=weights)

        self.val_losses.append(loss.item())

        _, _, auroc = calc_metric_curve(y_hat.sigmoid().cpu(), y.cpu(), 'ROC', squareform=False)
        _, _, auprc = calc_metric_curve(y_hat.sigmoid().cpu(), y.cpu(), 'PRC', squareform=False)

        self.auroc['Hydrophobic'].append(auroc[0])
        self.auroc['Hydrogen bond'].append(auroc[1])
        self.auroc['Van der Waals'].append(auroc[2])
        self.auroc['Water bridges'].append(auroc[3])
        self.auroc['Salt bridges'].append(auroc[4])
        self.auroc['Pi-stacking'].append(auroc[5])
        self.auroc['Pi-cation'].append(auroc[6])
        self.auroc['T-stacking'].append(auroc[7])

        self.auprc['Hydrophobic'].append(auprc[0])
        self.auprc['Hydrogen bond'].append(auprc[1])
        self.auprc['Van der Waals'].append(auprc[2])
        self.auprc['Water bridges'].append(auprc[3])
        self.auprc['Salt bridges'].append(auprc[4])
        self.auprc['Pi-stacking'].append(auprc[5])
        self.auprc['Pi-cation'].append(auprc[6])
        self.auprc['T-stacking'].append(auprc[7])
        
        self.pred_example.append(wandb.Image(plot_channels(triu_expand(y_hat.detach().cpu()))))
        
    def validation_end(self, outputs):
        self.p = 0.95 * self.p
        
        avg_loss = torch.tensor(self.val_losses).mean().item()
        return {'val_loss': avg_loss}

    def on_post_performance_check(self):

        epoch_metrics = {}
        all_metrics = {}

        for key in self.auroc:
            values = np.asarray(self.auroc[key])
            all_metrics[f'AUROC - {key}'] = values

            values = values[~np.isnan(values)]
            epoch_metrics[f'AUROC - {key}'] = wandb.Histogram(values)


        for key in self.auprc:
            values = np.asarray(self.auprc[key])
            all_metrics[f'AUPRC - {key}'] = values

            values = values[~np.isnan(values)]
            epoch_metrics[f'AUPRC - {key}'] = wandb.Histogram(values)

        epoch_metrics['Train Losses'] = wandb.Histogram(self.train_losses)

        epoch_metrics['Val Losses'] = wandb.Histogram(self.val_losses)
        all_metrics['Val Losses'] = np.asarray(self.val_losses)

        all_metrics = pd.DataFrame(all_metrics)
        cor_mat = all_metrics.corr()

        corr_plot = metric_corr_plot(cor_mat)
        epoch_metrics['Metric Corr Plot'] = wandb.Image(corr_plot)

        epoch_metrics['train_loss'] = np.asarray(self.train_losses).mean()
        epoch_metrics['val_loss'] = np.asarray(self.val_losses).mean()

        epoch_metrics['Example Prediction'] = self.pred_example

        self.logger.experiment.log(epoch_metrics)

        self.reset_epoch_metrics()

    def reset_epoch_metrics(self):

        # Validation information
        self.auroc = {
            'Hydrophobic': [],
            'Hydrogen bond': [],
            'Van der Waals': [],
            'Water bridges': [],
            'Salt bridges': [],
            'Pi-stacking': [],
            'Pi-cation': [],
            'T-stacking': []
        }

        self.auprc = {
            'Hydrophobic': [],
            'Hydrogen bond': [],
            'Van der Waals': [],
            'Water bridges': [],
            'Salt bridges': [],
            'Pi-stacking': [],
            'Pi-cation': [],
            'T-stacking': []
        }

        self.val_losses = []
        self.train_losses = []
        self.pred_example = []


#     def validation_end(self, outputs):
#         # OPTIONAL
# #         avg_loss = torch.stack([x['val_loss'] for x in outputs]).mean()
# #         return {'avg_val_loss': avg_loss}
#         pass

    @pl.data_loader
    def train_dataloader(self):
        # REQUIRED
        return DataLoader(self.train_data, shuffle=True, num_workers=30, pin_memory=True)

    @pl.data_loader
    def val_dataloader(self):
        # OPTIONAL
        return DataLoader(self.val_data, shuffle=False, num_workers=20, pin_memory=True)

# %% [markdown]
# ### Analysis functions

# %%
import seaborn as sns

def plot_channels(values):
    fig, ax = plt.subplots(nrows=2, ncols=4, figsize=(20, 10))

    ax = ax.flatten()

    channel_names = [
        'Hydrophobic',
        'Hydrogen bond',
        'Van der Waals',
        'Water bridges',
        'Salt bridges',
        'Pi-stacking',
        'Pi-cation',
        'T-stacking'
    ]

    for channel in range(values.shape[-1]):
        ax[channel].imshow(values[:, :, channel].squeeze(), vmin=0, vmax=1)
        ax[channel].set(title=channel_names[channel], xlabel='Residue #', ylabel='Residue #')

    plt.close()
    return fig


######################
# ROC and PRC curves #
######################
from sklearn.metrics import precision_recall_curve, roc_curve, auc

def calc_metric_curve(preds, target, curve_type, squareform=False):
    """
    Calculate ROC or PRC curves and area for the predicted contact channels.

    Args:
    - preds (np.ndarray) - Numpy array of model predictions either of form
        (n_res, n_res, n_chan) or (n_res * [n_res - 1] / 2, n_chan).
    - target (np.ndarray) - Numpy array of target values either of form
        (n_res, n_res, n_chan) or (n_res * [n_res - 1] / 2, n_chan),
        must match form of preds.
    - curve_type (str) - One of 'ROC' or 'PRC' to denote type of curve.
    - squareform (bool) - True if tensors are of shape (n_res, n_res, n_chan),
        False if they are of shape (n_res * [n_res - 1] / 2, n_chan)
        (default = True).

    Returns:
    - Tuple of x, y, and AUC values to be used for plotting the curves
        using plot_curve metric.
    """

    # Get correct curve function
    if curve_type.upper() == 'ROC':
        curve_func = roc_curve
    elif curve_type.upper() == 'PRC':
        curve_func = precision_recall_curve

    # Generate dicts to hold outputs from curve generation functions
    x = dict()
    y = dict()
    auc_ = dict()

    # Handle case of squareform matrix (only get non-redundant triu indices)
    if squareform:
        indices = np.triu_indices(target.shape[0])

    # For each channel
    for i in range(target.shape[-1]):

        # Handle case of squareform
        if squareform:
            var1, var2, _ = curve_func(target[:, :, i][indices],
                                       preds[:, :, i][indices])

        # Handle case of pairwise
        else:
            var1, var2, _ = curve_func(target[:, i], preds[:, i])

        # Assign outputs to correct dict for plotting
        if curve_type.upper() == 'ROC':
            x[i] = var1
            y[i] = var2
        elif curve_type.upper() == 'PRC':
            x[i] = var2
            y[i] = var1

        # Calc AUC
        auc_[i] = auc(x[i], y[i])

    return (x, y, auc_)


def plot_curve_metric(x, y, auc, curve_type, title=None, labels=None):
    """
    Plot ROC or PRC curves per output channel.

    Args:
    - x (dict) - Dict of numpy arrays for values to plot on x axis.
    - y (dict) - Dict of numpy arrays for values to plot on x axis.
    - auc (dict) - Dict of numpy arrays for areas under each curve.
    - curve_type (str) - One of 'ROC' or 'PRC' to denote type of curve.
    - title
    - labels

    Returns:
    - pyplot object of curves.
    """

    # Generate figure
    plt.figure()

    # Linetype spec
    lw = 2
    curve_type = curve_type.upper()

    # Get the number of channels being plotted
    n_chan = len(x)

    # Make labels numeric if not provided
    if labels is None:
        labels = list(range(n_chan))

    # Check to make sure the labels are the right length
    if len(labels) != n_chan:
        raise ValueError('Number of labels ({}) does not match number of prediction channels ({}).'.format(len(labels), n_chan))

    # Get a lit of colors for all the channels
    color_list = plt.cm.Set1(np.linspace(0, 1, n_chan))

    # Plot each line
    for i, color in enumerate(color_list):
        plt.plot(x[i], y[i], color=color,
                 lw=lw, label='{} (area = {:0.2f})'.format(labels[i], auc[i]))

    # Add labels and diagonal line for ROC
    if curve_type == 'ROC':
        xlab = 'FPR'
        ylab = 'TPR'
        plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
        plt.legend(loc="lower right")

    # Add labels for PRC
    elif curve_type == 'PRC':
        xlab = 'Recall'
        ylab = 'Precision'
        plt.legend(loc="lower left")

    # Extend limits, add labels and title
    plt.xlim([-0.05, 1.05])
    plt.ylim([-0.05, 1.05])
    plt.xlabel(xlab)
    plt.ylabel(ylab)

    if title is not None:
        plt.title('{} for {}'.format(curve_type, title))
    else:
        plt.title('{}'.format(curve_type))

    plt.show()

def plot_curve(preds, target, curve_type, title=None, labels=None,
               squareform=False):
    """
    Wrapper to directly plot curves from model output and target.

    Args:
    - preds (np array-like) - Array or tensor of predicted values output by
        model.
    - target (np array-like) - Array or tensor of target values.
    - curve_type (str) - One of 'ROC' or 'PRC'.
    - title (str) - Title of plot (default = None).
    - labels (list) - List of labels for each channel on the plot
        (default = None).
    - squareform (bool) - Whether the predictions and targets are in square form
        (default = False).
    """
    x, y, auc_ = calc_metric_curve(preds, target, curve_type, squareform)
    return plot_curve_metric(x, y, auc_, curve_type, title, labels)


################################
# Correlations between metrics #
################################

def metric_corr_plot(corr):
    mask = np.triu(np.ones_like(corr, dtype=np.bool))

    fig, ax = plt.subplots(figsize=(11, 9))
    cmap = sns.diverging_palette(220, 10, as_cmap=True)

    sns.heatmap(corr, mask=mask, cmap=cmap, vmax=1.0, vmin = -1.0, center=0,
                square=True, linewidths=.5, cbar_kws={"shrink": .5}, ax=ax)

    plt.tight_layout()
    plt.close()
    return fig

# %% [markdown]
# ## Training
#
# ### Instantiate dataloader and model

# %%
from pytorch_lightning.callbacks import ModelCheckpoint

data_base = '/home/tshimko/tesselate/'

torch.manual_seed(10)


data_load = [
#                 'pdb_id',
#                 'model',
                'atom_nodes',
                'atom_adj',
                'atom_contact',
#                 'atom_mask',
                'res_adj',
                'res_dist',
                'chain_mem',
                'res_contact',
                'conn_adj',
                'res_mask',
                'mem_mat',
#                 'idx2atom_dict',
#                 'idx2res_dict'
            ]

# train_data = TesselateDataset(data_base + 'id_lists/ligand_free_monomers/small_train.txt',
#                               graph_dir=data_base + 'data/graphs',
#                               contacts_dir=data_base + 'data/contacts',
#                               return_data='all', in_memory=False)

train_data = TesselateDataset(data_base + 'test4.txt',
                              graph_dir=data_base + 'data/graphs',
                              contacts_dir=data_base + 'data/contacts',
                              return_data=data_load, in_memory=False)

val_data = TesselateDataset(data_base + 'id_lists/ligand_free_monomers/small_val.txt',
                            graph_dir=data_base + 'data/graphs',
                            contacts_dir=data_base + 'data/contacts',
                            return_data='all', in_memory=False)


checkpoint_callback = ModelCheckpoint(
    filepath=os.getcwd() + '/checkpoints',
    save_top_k=0,
    verbose=False,
    monitor='val_loss',
    mode='min',
    prefix=''
)

model = PGNN2D(input_dim=10, hidden_dim=10, output_dim=10,
               n_contact_channels=8,
               layer_num=4,
               train_data=train_data,
               val_data=val_data, test_data=None)

# %%
# %%capture --no-stdout
import logging
logging.getLogger().setLevel(logging.CRITICAL)

from pytorch_lightning import Trainer
from pytorch_lightning.logging import WandbLogger

logger = WandbLogger(project='tesselate')

trainer = Trainer(max_nb_epochs=10000,
                  accumulate_grad_batches=8,
                  checkpoint_callback=checkpoint_callback,
                  early_stop_callback=False,
                  gpus=[1],
#                   distributed_backend='dp',
                  logger=logger,
                  fast_dev_run=False)
#                   amp_level='O2', use_amp=True) # Needed for 16-bit training
trainer.fit(model)
# Out:
# Epoch 1:  51%|█████▏    | 55/107 [00:43<00:25,  2.01batch/s, batch_idx=54, gpu=0, loss=0.576, v_num=3drc8ka5]
# Validating:   0%|          | 0/52 [00:00<?, ?batch/s]
# Epoch 1:  52%|█████▏    | 56/107 [00:48<01:34,  1.86s/batch, batch_idx=54, gpu=0, loss=0.576, v_num=3drc8ka5]
# Epoch 1:  53%|█████▎    | 57/107 [00:51<01:54,  2.30s/batch, batch_idx=54, gpu=0, loss=0.576, v_num=3drc8ka5]
# Epoch 1:  54%|█████▍    | 58/107 [00:54<01:51,  2.27s/batch, batch_idx=54, gpu=0, loss=0.576, v_num=3drc8ka5]
# Epoch 1:  55%|█████▌    | 59/107 [00:56<01:56,  2.43s/batch, batch_idx=54, gpu=0, loss=0.576, v_num=3drc8ka5]
# Epoch 1:  56%|█████▌    | 60/107 [00:58<01:45,  2.24s/batch, batch_idx=54, gpu=0, loss=0.576, v_num=3drc8ka5]
# Epoch 1:  57%|█████▋    | 61/107 [01:00<01:31,  1.99s/batch, batch_idx=54, gpu=0, loss=0.576, v_num=3drc8ka5]
# Epoch 1:  58%|█████▊    | 62/107 [01:04<01:55,  2.57s/batch, batch_idx=54, gpu=0, loss=0.576, v_num=3drc8ka5]
# Epoch 1:  59%|█████▉    | 63/107 [01:05<01:38,  2.23s/batch, batch_idx=54, gpu=0, loss=0.576, v_num=3drc8ka5]
# Epoch 1:  60%|█████▉    | 64/107 [01:09<01:55,  2.68s/batch, batch_idx=54, gpu=0, loss=0.576, v_num=3drc8ka5]
# Epoch 1:  61%|██████    | 65/107 [01:10<01:37,  2.32s/batch, batch_idx=54, gpu=0, loss=0.576, v_num=3drc8ka5]
# Epoch 1:  62%|██████▏   | 66/107 [01:14<01:52,  2.73s/batch, batch_idx=54, gpu=0, loss=0.576, v_num=3drc8ka5]
# Epoch 1:  63%|██████▎   | 67/107 [01:16<01:39,  2.49s/batch, batch_idx=54, gpu=0, loss=0.576, v_num=3drc8ka5]
# Epoch 1:  64%|██████▎   | 68/107 [01:17<01:23,  2.13s/batch, batch_idx=54, gpu=0, loss=0.576, v_num=3drc8ka5]
# Epoch 1:  64%|██████▍   | 69/107 [01:19<01:20,  2.12s/batch, batch_idx=54, gpu=0, loss=0.576, v_num=3drc8ka5]
# Epoch 1:  65%|██████▌   | 70/107 [01:21<01:13,  1.98s/batch, batch_idx=54, gpu=0, loss=0.576, v_num=3drc8ka5]
# Epoch 1:  66%|██████▋   | 71/107 [01:24<01:20,  2.22s/batch, batch_idx=54, gpu=0, loss=0.576, v_num=3drc8ka5]
# Epoch 1:  67%|██████▋   | 72/107 [01:26<01:15,  2.15s/batch, batch_idx=54, gpu=0, loss=0.576, v_num=3drc8ka5]
# Epoch 1:  68%|██████▊   | 73/107 [01:26<00:58,  1.73s/batch, batch_idx=54, gpu=0, loss=0.576, v_num=3drc8ka5]
# Epoch 1:  69%|██████▉   | 74/107 [01:28<00:58,  1.77s/batch, batch_idx=54, gpu=0, loss=0.576, v_num=3drc8ka5]
# Epoch 1:  70%|███████   | 75/107 [01:29<00:49,  1.56s/batch, batch_idx=54, gpu=0, loss=0.576, v_num=3drc8ka5]
# Epoch 1:  71%|███████   | 76/107 [01:31<00:44,  1.44s/batch, batch_idx=54, gpu=0, loss=0.576, v_num=3drc8ka5]
# Epoch 1:  72%|███████▏  | 77/107 [01:32<00:43,  1.45s/batch, batch_idx=54, gpu=0, loss=0.576, v_num=3drc8ka5]
# Epoch 1:  73%|███████▎  | 78/107 [01:35<00:58,  2.03s/batch, batch_idx=54, gpu=0, loss=0.576, v_num=3drc8ka5]
# Epoch 1:  74%|███████▍  | 79/107 [01:36<00:48,  1.73s/batch, batch_idx=54, gpu=0, loss=0.576, v_num=3drc8ka5]
# Epoch 1:  75%|███████▍  | 80/107 [01:38<00:46,  1.70s/batch, batch_idx=54, gpu=0, loss=0.576, v_num=3drc8ka5]
# Epoch 1:  76%|███████▌  | 81/107 [01:39<00:36,  1.39s/batch, batch_idx=54, gpu=0, loss=0.576, v_num=3drc8ka5]
# Epoch 1:  77%|███████▋  | 82/107 [01:40<00:32,  1.30s/batch, batch_idx=54, gpu=0, loss=0.576, v_num=3drc8ka5]
# Epoch 1:  78%|███████▊  | 83/107 [01:41<00:33,  1.39s/batch, batch_idx=54, gpu=0, loss=0.576, v_num=3drc8ka5]
# Epoch 1:  79%|███████▊  | 84/107 [01:42<00:29,  1.26s/batch, batch_idx=54, gpu=0, loss=0.576, v_num=3drc8ka5]
# Epoch 1:  79%|███████▉  | 85/107 [01:43<00:26,  1.20s/batch, batch_idx=54, gpu=0, loss=0.576, v_num=3drc8ka5]
# Epoch 1:  80%|████████  | 86/107 [01:45<00:25,  1.24s/batch, batch_idx=54, gpu=0, loss=0.576, v_num=3drc8ka5]
# Epoch 1:  81%|████████▏ | 87/107 [01:46<00:23,  1.19s/batch, batch_idx=54, gpu=0, loss=0.576, v_num=3drc8ka5]
# Epoch 1:  82%|████████▏ | 88/107 [01:47<00:21,  1.11s/batch, batch_idx=54, gpu=0, loss=0.576, v_num=3drc8ka5]
# Epoch 1:  83%|████████▎ | 89/107 [01:49<00:24,  1.33s/batch, batch_idx=54, gpu=0, loss=0.576, v_num=3drc8ka5]
# Epoch 1:  84%|████████▍ | 90/107 [01:51<00:26,  1.53s/batch, batch_idx=54, gpu=0, loss=0.576, v_num=3drc8ka5]
# Epoch 1:  85%|████████▌ | 91/107 [01:52<00:22,  1.38s/batch, batch_idx=54, gpu=0, loss=0.576, v_num=3drc8ka5]
# Epoch 1:  86%|████████▌ | 92/107 [01:55<00:28,  1.88s/batch, batch_idx=54, gpu=0, loss=0.576, v_num=3drc8ka5]
# Epoch 1:  87%|████████▋ | 93/107 [01:56<00:22,  1.63s/batch, batch_idx=54, gpu=0, loss=0.576, v_num=3drc8ka5]
# Epoch 1:  88%|████████▊ | 94/107 [01:58<00:24,  1.88s/batch, batch_idx=54, gpu=0, loss=0.576, v_num=3drc8ka5]
# Epoch 1:  89%|████████▉ | 95/107 [02:06<00:42,  3.54s/batch, batch_idx=54, gpu=0, loss=0.576, v_num=3drc8ka5]
# Epoch 1:  90%|████████▉ | 96/107 [02:07<00:32,  2.97s/batch, batch_idx=54, gpu=0, loss=0.576, v_num=3drc8ka5]
# Epoch 1:  91%|█████████ | 97/107 [02:11<00:31,  3.15s/batch, batch_idx=54, gpu=0, loss=0.576, v_num=3drc8ka5]
# Epoch 1:  92%|█████████▏| 98/107 [02:12<00:23,  2.57s/batch, batch_idx=54, gpu=0, loss=0.576, v_num=3drc8ka5]
# Epoch 1:  93%|█████████▎| 99/107 [02:13<00:17,  2.19s/batch, batch_idx=54, gpu=0, loss=0.576, v_num=3drc8ka5]
# Epoch 1:  93%|█████████▎| 100/107 [02:14<00:12,  1.79s/batch, batch_idx=54, gpu=0, loss=0.576, v_num=3drc8ka5]
# Epoch 1:  94%|█████████▍| 101/107 [02:15<00:09,  1.52s/batch, batch_idx=54, gpu=0, loss=0.576, v_num=3drc8ka5]
# Epoch 1:  95%|█████████▌| 102/107 [02:17<00:08,  1.70s/batch, batch_idx=54, gpu=0, loss=0.576, v_num=3drc8ka5]
# Epoch 1:  96%|█████████▋| 103/107 [02:19<00:06,  1.68s/batch, batch_idx=54, gpu=0, loss=0.576, v_num=3drc8ka5]
# Epoch 1:  97%|█████████▋| 104/107 [02:20<00:04,  1.51s/batch, batch_idx=54, gpu=0, loss=0.576, v_num=3drc8ka5]
# Epoch 1:  98%|█████████▊| 105/107 [02:21<00:02,  1.44s/batch, batch_idx=54, gpu=0, loss=0.576, v_num=3drc8ka5]
# Epoch 1:  99%|█████████▉| 106/107 [02:23<00:01,  1.55s/batch, batch_idx=54, gpu=0, loss=0.576, v_num=3drc8ka5]
# Epoch 1: 100%|██████████| 107/107 [02:30<00:00,  1.34s/batch, batch_idx=54, gpu=0, loss=0.576, v_num=3drc8ka5]
# Epoch 2:  51%|█████▏    | 55/107 [00:40<00:29,  1.74batch/s, batch_idx=54, gpu=0, loss=0.570, v_num=3drc8ka5]
# Validating:   0%|          | 0/52 [00:00<?, ?batch/s]
# Epoch 2:  52%|█████▏    | 56/107 [00:45<01:36,  1.89s/batch, batch_idx=54, gpu=0, loss=0.570, v_num=3drc8ka5]
# Epoch 2:  53%|█████▎    | 57/107 [00:50<02:21,  2.83s/batch, batch_idx=54, gpu=0, loss=0.570, v_num=3drc8ka5]
# Epoch 2:  54%|█████▍    | 58/107 [00:53<02:10,  2.67s/batch, batch_idx=54, gpu=0, loss=0.570, v_num=3drc8ka5]
# Epoch 2:  55%|█████▌    | 59/107 [00:56<02:22,  2.97s/batch, batch_idx=54, gpu=0, loss=0.570, v_num=3drc8ka5]
# Epoch 2:  56%|█████▌    | 60/107 [00:59<02:11,  2.79s/batch, batch_idx=54, gpu=0, loss=0.570, v_num=3drc8ka5]
# Epoch 2:  57%|█████▋    | 61/107 [01:00<01:47,  2.35s/batch, batch_idx=54, gpu=0, loss=0.570, v_num=3drc8ka5]
# Epoch 2:  58%|█████▊    | 62/107 [01:03<01:56,  2.59s/batch, batch_idx=54, gpu=0, loss=0.570, v_num=3drc8ka5]
# Epoch 2:  59%|█████▉    | 63/107 [01:04<01:32,  2.11s/batch, batch_idx=54, gpu=0, loss=0.570, v_num=3drc8ka5]
# Epoch 2:  60%|█████▉    | 64/107 [01:06<01:25,  1.99s/batch, batch_idx=54, gpu=0, loss=0.570, v_num=3drc8ka5]
# Epoch 2:  61%|██████    | 65/107 [01:07<01:12,  1.74s/batch, batch_idx=54, gpu=0, loss=0.570, v_num=3drc8ka5]
# Epoch 2:  62%|██████▏   | 66/107 [01:09<01:14,  1.83s/batch, batch_idx=54, gpu=0, loss=0.570, v_num=3drc8ka5]
# Epoch 2:  63%|██████▎   | 67/107 [01:12<01:32,  2.31s/batch, batch_idx=54, gpu=0, loss=0.570, v_num=3drc8ka5]
# Epoch 2:  64%|██████▎   | 68/107 [01:14<01:18,  2.01s/batch, batch_idx=54, gpu=0, loss=0.570, v_num=3drc8ka5]
# Epoch 2:  64%|██████▍   | 69/107 [01:15<01:13,  1.94s/batch, batch_idx=54, gpu=0, loss=0.570, v_num=3drc8ka5]
# Epoch 2:  65%|██████▌   | 70/107 [01:17<01:08,  1.84s/batch, batch_idx=54, gpu=0, loss=0.570, v_num=3drc8ka5]
# Epoch 2:  66%|██████▋   | 71/107 [01:20<01:16,  2.11s/batch, batch_idx=54, gpu=0, loss=0.570, v_num=3drc8ka5]
# Epoch 2:  67%|██████▋   | 72/107 [01:23<01:21,  2.34s/batch, batch_idx=54, gpu=0, loss=0.570, v_num=3drc8ka5]
# Epoch 2:  68%|██████▊   | 73/107 [01:23<01:03,  1.86s/batch, batch_idx=54, gpu=0, loss=0.570, v_num=3drc8ka5]
# Epoch 2:  69%|██████▉   | 74/107 [01:25<01:01,  1.86s/batch, batch_idx=54, gpu=0, loss=0.570, v_num=3drc8ka5]
# Epoch 2:  70%|███████   | 75/107 [01:26<00:51,  1.62s/batch, batch_idx=54, gpu=0, loss=0.570, v_num=3drc8ka5]
# Epoch 2:  71%|███████   | 76/107 [01:28<00:46,  1.49s/batch, batch_idx=54, gpu=0, loss=0.570, v_num=3drc8ka5]
# Epoch 2:  72%|███████▏  | 77/107 [01:29<00:44,  1.49s/batch, batch_idx=54, gpu=0, loss=0.570, v_num=3drc8ka5]
# Epoch 2:  73%|███████▎  | 78/107 [01:32<00:55,  1.93s/batch, batch_idx=54, gpu=0, loss=0.570, v_num=3drc8ka5]
# Epoch 2:  74%|███████▍  | 79/107 [01:33<00:46,  1.67s/batch, batch_idx=54, gpu=0, loss=0.570, v_num=3drc8ka5]
# Epoch 2:  75%|███████▍  | 80/107 [01:35<00:45,  1.67s/batch, batch_idx=54, gpu=0, loss=0.570, v_num=3drc8ka5]
# Epoch 2:  76%|███████▌  | 81/107 [01:35<00:35,  1.37s/batch, batch_idx=54, gpu=0, loss=0.570, v_num=3drc8ka5]
# Epoch 2:  77%|███████▋  | 82/107 [01:36<00:31,  1.28s/batch, batch_idx=54, gpu=0, loss=0.570, v_num=3drc8ka5]
# Epoch 2:  78%|███████▊  | 83/107 [01:38<00:33,  1.38s/batch, batch_idx=54, gpu=0, loss=0.570, v_num=3drc8ka5]
# Epoch 2:  79%|███████▊  | 84/107 [01:39<00:28,  1.24s/batch, batch_idx=54, gpu=0, loss=0.570, v_num=3drc8ka5]
# Epoch 2:  79%|███████▉  | 85/107 [01:40<00:26,  1.18s/batch, batch_idx=54, gpu=0, loss=0.570, v_num=3drc8ka5]
# Epoch 2:  80%|████████  | 86/107 [01:41<00:25,  1.24s/batch, batch_idx=54, gpu=0, loss=0.570, v_num=3drc8ka5]
# Epoch 2:  81%|████████▏ | 87/107 [01:43<00:23,  1.20s/batch, batch_idx=54, gpu=0, loss=0.570, v_num=3drc8ka5]
# Epoch 2:  82%|████████▏ | 88/107 [01:43<00:21,  1.12s/batch, batch_idx=54, gpu=0, loss=0.570, v_num=3drc8ka5]
# Epoch 2:  83%|████████▎ | 89/107 [01:45<00:21,  1.22s/batch, batch_idx=54, gpu=0, loss=0.570, v_num=3drc8ka5]
# Epoch 2:  84%|████████▍ | 90/107 [01:47<00:24,  1.44s/batch, batch_idx=54, gpu=0, loss=0.570, v_num=3drc8ka5]
# Epoch 2:  85%|████████▌ | 91/107 [01:48<00:21,  1.32s/batch, batch_idx=54, gpu=0, loss=0.570, v_num=3drc8ka5]
# Epoch 2:  86%|████████▌ | 92/107 [01:51<00:27,  1.81s/batch, batch_idx=54, gpu=0, loss=0.570, v_num=3drc8ka5]
# Epoch 2:  87%|████████▋ | 93/107 [01:52<00:22,  1.58s/batch, batch_idx=54, gpu=0, loss=0.570, v_num=3drc8ka5]
# Epoch 2:  88%|████████▊ | 94/107 [01:55<00:27,  2.15s/batch, batch_idx=54, gpu=0, loss=0.570, v_num=3drc8ka5]
# Epoch 2:  89%|████████▉ | 95/107 [02:03<00:44,  3.69s/batch, batch_idx=54, gpu=0, loss=0.570, v_num=3drc8ka5]
# Epoch 2:  90%|████████▉ | 96/107 [02:04<00:33,  3.07s/batch, batch_idx=54, gpu=0, loss=0.570, v_num=3drc8ka5]
# Epoch 2:  91%|█████████ | 97/107 [02:08<00:32,  3.22s/batch, batch_idx=54, gpu=0, loss=0.570, v_num=3drc8ka5]
# Epoch 2:  92%|█████████▏| 98/107 [02:09<00:23,  2.62s/batch, batch_idx=54, gpu=0, loss=0.570, v_num=3drc8ka5]
# Epoch 2:  93%|█████████▎| 99/107 [02:10<00:17,  2.23s/batch, batch_idx=54, gpu=0, loss=0.570, v_num=3drc8ka5]
# Epoch 2:  93%|█████████▎| 100/107 [02:11<00:12,  1.83s/batch, batch_idx=54, gpu=0, loss=0.570, v_num=3drc8ka5]
# Epoch 2:  94%|█████████▍| 101/107 [02:12<00:09,  1.55s/batch, batch_idx=54, gpu=0, loss=0.570, v_num=3drc8ka5]
# Epoch 2:  95%|█████████▌| 102/107 [02:14<00:08,  1.72s/batch, batch_idx=54, gpu=0, loss=0.570, v_num=3drc8ka5]
# Epoch 2:  96%|█████████▋| 103/107 [02:15<00:06,  1.52s/batch, batch_idx=54, gpu=0, loss=0.570, v_num=3drc8ka5]
# Epoch 2:  97%|█████████▋| 104/107 [02:16<00:04,  1.39s/batch, batch_idx=54, gpu=0, loss=0.570, v_num=3drc8ka5]
# Epoch 2:  98%|█████████▊| 105/107 [02:18<00:02,  1.36s/batch, batch_idx=54, gpu=0, loss=0.570, v_num=3drc8ka5]
# Epoch 2:  99%|█████████▉| 106/107 [02:20<00:01,  1.48s/batch, batch_idx=54, gpu=0, loss=0.570, v_num=3drc8ka5]
# Epoch 2: 100%|██████████| 107/107 [02:27<00:00,  1.29s/batch, batch_idx=54, gpu=0, loss=0.570, v_num=3drc8ka5]
# Epoch 3:  51%|█████▏    | 55/107 [00:41<00:26,  1.94batch/s, batch_idx=54, gpu=0, loss=0.545, v_num=3drc8ka5]
# Validating:   0%|          | 0/52 [00:00<?, ?batch/s]
# Epoch 3:  52%|█████▏    | 56/107 [00:46<01:34,  1.86s/batch, batch_idx=54, gpu=0, loss=0.545, v_num=3drc8ka5]
# Epoch 3:  53%|█████▎    | 57/107 [00:50<01:55,  2.31s/batch, batch_idx=54, gpu=0, loss=0.545, v_num=3drc8ka5]
# Epoch 3:  54%|█████▍    | 58/107 [00:51<01:43,  2.11s/batch, batch_idx=54, gpu=0, loss=0.545, v_num=3drc8ka5]
# Epoch 3:  55%|█████▌    | 59/107 [00:55<02:09,  2.70s/batch, batch_idx=54, gpu=0, loss=0.545, v_num=3drc8ka5]
# Epoch 3:  56%|█████▌    | 60/107 [00:57<01:53,  2.41s/batch, batch_idx=54, gpu=0, loss=0.545, v_num=3drc8ka5]
# Epoch 3:  57%|█████▋    | 61/107 [00:58<01:31,  1.99s/batch, batch_idx=54, gpu=0, loss=0.545, v_num=3drc8ka5]
# Epoch 3:  58%|█████▊    | 62/107 [01:04<02:18,  3.07s/batch, batch_idx=54, gpu=0, loss=0.545, v_num=3drc8ka5]
# Epoch 3:  59%|█████▉    | 63/107 [01:05<01:55,  2.62s/batch, batch_idx=54, gpu=0, loss=0.545, v_num=3drc8ka5]
# Epoch 3:  60%|█████▉    | 64/107 [01:07<01:48,  2.52s/batch, batch_idx=54, gpu=0, loss=0.545, v_num=3drc8ka5]
# Epoch 3:  61%|██████    | 65/107 [01:08<01:25,  2.04s/batch, batch_idx=54, gpu=0, loss=0.545, v_num=3drc8ka5]
# Epoch 3:  62%|██████▏   | 66/107 [01:10<01:22,  2.01s/batch, batch_idx=54, gpu=0, loss=0.545, v_num=3drc8ka5]
# Epoch 3:  63%|██████▎   | 67/107 [01:12<01:13,  1.85s/batch, batch_idx=54, gpu=0, loss=0.545, v_num=3drc8ka5]
# Epoch 3:  64%|██████▎   | 68/107 [01:14<01:11,  1.85s/batch, batch_idx=54, gpu=0, loss=0.545, v_num=3drc8ka5]
# Epoch 3:  64%|██████▍   | 69/107 [01:15<01:08,  1.80s/batch, batch_idx=54, gpu=0, loss=0.545, v_num=3drc8ka5]
# Epoch 3:  65%|██████▌   | 70/107 [01:17<01:03,  1.71s/batch, batch_idx=54, gpu=0, loss=0.545, v_num=3drc8ka5]
# Epoch 3:  66%|██████▋   | 71/107 [01:19<01:11,  1.98s/batch, batch_idx=54, gpu=0, loss=0.545, v_num=3drc8ka5]
# Epoch 3:  67%|██████▋   | 72/107 [01:21<01:08,  1.96s/batch, batch_idx=54, gpu=0, loss=0.545, v_num=3drc8ka5]
# Epoch 3:  68%|██████▊   | 73/107 [01:22<00:53,  1.59s/batch, batch_idx=54, gpu=0, loss=0.545, v_num=3drc8ka5]
# Epoch 3:  69%|██████▉   | 74/107 [01:24<00:54,  1.64s/batch, batch_idx=54, gpu=0, loss=0.545, v_num=3drc8ka5]
# Epoch 3:  70%|███████   | 75/107 [01:25<00:46,  1.46s/batch, batch_idx=54, gpu=0, loss=0.545, v_num=3drc8ka5]
# Epoch 3:  71%|███████   | 76/107 [01:26<00:42,  1.38s/batch, batch_idx=54, gpu=0, loss=0.545, v_num=3drc8ka5]
# Epoch 3:  72%|███████▏  | 77/107 [01:27<00:41,  1.38s/batch, batch_idx=54, gpu=0, loss=0.545, v_num=3drc8ka5]
# Epoch 3:  73%|███████▎  | 78/107 [01:30<00:52,  1.82s/batch, batch_idx=54, gpu=0, loss=0.545, v_num=3drc8ka5]
# Epoch 3:  74%|███████▍  | 79/107 [01:31<00:44,  1.59s/batch, batch_idx=54, gpu=0, loss=0.545, v_num=3drc8ka5]
# Epoch 3:  75%|███████▍  | 80/107 [01:33<00:42,  1.59s/batch, batch_idx=54, gpu=0, loss=0.545, v_num=3drc8ka5]
# Epoch 3:  76%|███████▌  | 81/107 [01:34<00:34,  1.32s/batch, batch_idx=54, gpu=0, loss=0.545, v_num=3drc8ka5]
# Epoch 3:  77%|███████▋  | 82/107 [01:35<00:30,  1.24s/batch, batch_idx=54, gpu=0, loss=0.545, v_num=3drc8ka5]
# Epoch 3:  78%|███████▊  | 83/107 [01:36<00:32,  1.34s/batch, batch_idx=54, gpu=0, loss=0.545, v_num=3drc8ka5]
# Epoch 3:  79%|███████▊  | 84/107 [01:37<00:27,  1.21s/batch, batch_idx=54, gpu=0, loss=0.545, v_num=3drc8ka5]
# Epoch 3:  79%|███████▉  | 85/107 [01:38<00:25,  1.17s/batch, batch_idx=54, gpu=0, loss=0.545, v_num=3drc8ka5]
# Epoch 3:  80%|████████  | 86/107 [01:39<00:24,  1.19s/batch, batch_idx=54, gpu=0, loss=0.545, v_num=3drc8ka5]
# Epoch 3:  81%|████████▏ | 87/107 [01:41<00:23,  1.17s/batch, batch_idx=54, gpu=0, loss=0.545, v_num=3drc8ka5]
# Epoch 3:  82%|████████▏ | 88/107 [01:43<00:29,  1.56s/batch, batch_idx=54, gpu=0, loss=0.545, v_num=3drc8ka5]
# Epoch 3:  83%|████████▎ | 89/107 [01:44<00:26,  1.50s/batch, batch_idx=54, gpu=0, loss=0.545, v_num=3drc8ka5]
# Epoch 3:  84%|████████▍ | 90/107 [01:46<00:27,  1.63s/batch, batch_idx=54, gpu=0, loss=0.545, v_num=3drc8ka5]
# Epoch 3:  85%|████████▌ | 91/107 [01:47<00:23,  1.44s/batch, batch_idx=54, gpu=0, loss=0.545, v_num=3drc8ka5]
# Epoch 3:  86%|████████▌ | 92/107 [01:50<00:28,  1.88s/batch, batch_idx=54, gpu=0, loss=0.545, v_num=3drc8ka5]
# Epoch 3:  87%|████████▋ | 93/107 [01:51<00:22,  1.64s/batch, batch_idx=54, gpu=0, loss=0.545, v_num=3drc8ka5]
# Epoch 3:  88%|████████▊ | 94/107 [01:54<00:24,  1.87s/batch, batch_idx=54, gpu=0, loss=0.545, v_num=3drc8ka5]
# Epoch 3:  89%|████████▉ | 95/107 [02:01<00:42,  3.51s/batch, batch_idx=54, gpu=0, loss=0.545, v_num=3drc8ka5]
# Epoch 3:  90%|████████▉ | 96/107 [02:03<00:32,  2.93s/batch, batch_idx=54, gpu=0, loss=0.545, v_num=3drc8ka5]
# Epoch 3:  91%|█████████ | 97/107 [02:06<00:31,  3.14s/batch, batch_idx=54, gpu=0, loss=0.545, v_num=3drc8ka5]
# Epoch 3:  92%|█████████▏| 98/107 [02:07<00:22,  2.55s/batch, batch_idx=54, gpu=0, loss=0.545, v_num=3drc8ka5]
# Epoch 3:  93%|█████████▎| 99/107 [02:09<00:17,  2.17s/batch, batch_idx=54, gpu=0, loss=0.545, v_num=3drc8ka5]
# Epoch 3:  93%|█████████▎| 100/107 [02:10<00:12,  1.79s/batch, batch_idx=54, gpu=0, loss=0.545, v_num=3drc8ka5]
# Epoch 3:  94%|█████████▍| 101/107 [02:11<00:09,  1.52s/batch, batch_idx=54, gpu=0, loss=0.545, v_num=3drc8ka5]
# Epoch 3:  95%|█████████▌| 102/107 [02:13<00:08,  1.69s/batch, batch_idx=54, gpu=0, loss=0.545, v_num=3drc8ka5]
# Epoch 3:  96%|█████████▋| 103/107 [02:14<00:06,  1.50s/batch, batch_idx=54, gpu=0, loss=0.545, v_num=3drc8ka5]
# Epoch 3:  97%|█████████▋| 104/107 [02:15<00:04,  1.37s/batch, batch_idx=54, gpu=0, loss=0.545, v_num=3drc8ka5]
# Epoch 3:  98%|█████████▊| 105/107 [02:16<00:02,  1.33s/batch, batch_idx=54, gpu=0, loss=0.545, v_num=3drc8ka5]
# Epoch 3:  99%|█████████▉| 106/107 [02:18<00:01,  1.44s/batch, batch_idx=54, gpu=0, loss=0.545, v_num=3drc8ka5]
# Epoch 3: 100%|██████████| 107/107 [02:24<00:00,  1.25s/batch, batch_idx=54, gpu=0, loss=0.545, v_num=3drc8ka5]
# Epoch 4:  51%|█████▏    | 55/107 [00:41<00:22,  2.28batch/s, batch_idx=54, gpu=0, loss=0.492, v_num=3drc8ka5]
# Validating:   0%|          | 0/52 [00:00<?, ?batch/s]
# Epoch 4:  52%|█████▏    | 56/107 [00:46<01:29,  1.75s/batch, batch_idx=54, gpu=0, loss=0.492, v_num=3drc8ka5]
# Epoch 4:  53%|█████▎    | 57/107 [00:49<01:58,  2.37s/batch, batch_idx=54, gpu=0, loss=0.492, v_num=3drc8ka5]
# Epoch 4:  54%|█████▍    | 58/107 [00:51<01:45,  2.15s/batch, batch_idx=54, gpu=0, loss=0.492, v_num=3drc8ka5]
# Epoch 4:  55%|█████▌    | 59/107 [00:54<01:50,  2.30s/batch, batch_idx=54, gpu=0, loss=0.492, v_num=3drc8ka5]
# Epoch 4:  56%|█████▌    | 60/107 [00:55<01:37,  2.08s/batch, batch_idx=54, gpu=0, loss=0.492, v_num=3drc8ka5]
# Epoch 4:  57%|█████▋    | 61/107 [00:56<01:21,  1.77s/batch, batch_idx=54, gpu=0, loss=0.492, v_num=3drc8ka5]
# Epoch 4:  58%|█████▊    | 62/107 [01:02<02:05,  2.80s/batch, batch_idx=54, gpu=0, loss=0.492, v_num=3drc8ka5]
# Epoch 4:  59%|█████▉    | 63/107 [01:02<01:38,  2.23s/batch, batch_idx=54, gpu=0, loss=0.492, v_num=3drc8ka5]
# Epoch 4:  60%|█████▉    | 64/107 [01:07<02:00,  2.81s/batch, batch_idx=54, gpu=0, loss=0.492, v_num=3drc8ka5]
# Epoch 4:  61%|██████    | 65/107 [01:08<01:37,  2.32s/batch, batch_idx=54, gpu=0, loss=0.492, v_num=3drc8ka5]
# Epoch 4:  62%|██████▏   | 66/107 [01:10<01:39,  2.42s/batch, batch_idx=54, gpu=0, loss=0.492, v_num=3drc8ka5]
# Epoch 4:  63%|██████▎   | 67/107 [01:13<01:33,  2.34s/batch, batch_idx=54, gpu=0, loss=0.492, v_num=3drc8ka5]
# Epoch 4:  64%|██████▎   | 68/107 [01:14<01:16,  1.97s/batch, batch_idx=54, gpu=0, loss=0.492, v_num=3drc8ka5]
# Epoch 4:  64%|██████▍   | 69/107 [01:15<01:10,  1.85s/batch, batch_idx=54, gpu=0, loss=0.492, v_num=3drc8ka5]
# Epoch 4:  65%|██████▌   | 70/107 [01:17<01:03,  1.71s/batch, batch_idx=54, gpu=0, loss=0.492, v_num=3drc8ka5]
# Epoch 4:  66%|██████▋   | 71/107 [01:19<01:10,  1.95s/batch, batch_idx=54, gpu=0, loss=0.492, v_num=3drc8ka5]
# Epoch 4:  67%|██████▋   | 72/107 [01:21<01:06,  1.91s/batch, batch_idx=54, gpu=0, loss=0.492, v_num=3drc8ka5]
# Epoch 4:  68%|██████▊   | 73/107 [01:22<00:52,  1.55s/batch, batch_idx=54, gpu=0, loss=0.492, v_num=3drc8ka5]
# Epoch 4:  69%|██████▉   | 74/107 [01:23<00:51,  1.58s/batch, batch_idx=54, gpu=0, loss=0.492, v_num=3drc8ka5]
# Epoch 4:  70%|███████   | 75/107 [01:24<00:43,  1.37s/batch, batch_idx=54, gpu=0, loss=0.492, v_num=3drc8ka5]
# Epoch 4:  71%|███████   | 76/107 [01:25<00:38,  1.25s/batch, batch_idx=54, gpu=0, loss=0.492, v_num=3drc8ka5]
# Epoch 4:  72%|███████▏  | 77/107 [01:26<00:37,  1.25s/batch, batch_idx=54, gpu=0, loss=0.492, v_num=3drc8ka5]
# Epoch 4:  73%|███████▎  | 78/107 [01:29<00:49,  1.69s/batch, batch_idx=54, gpu=0, loss=0.492, v_num=3drc8ka5]
# Epoch 4:  74%|███████▍  | 79/107 [01:30<00:40,  1.44s/batch, batch_idx=54, gpu=0, loss=0.492, v_num=3drc8ka5]
# Epoch 4:  75%|███████▍  | 80/107 [01:31<00:39,  1.45s/batch, batch_idx=54, gpu=0, loss=0.492, v_num=3drc8ka5]
# Epoch 4:  76%|███████▌  | 81/107 [01:32<00:31,  1.20s/batch, batch_idx=54, gpu=0, loss=0.492, v_num=3drc8ka5]
# Epoch 4:  77%|███████▋  | 82/107 [01:33<00:27,  1.11s/batch, batch_idx=54, gpu=0, loss=0.492, v_num=3drc8ka5]
# Epoch 4:  78%|███████▊  | 83/107 [01:34<00:28,  1.20s/batch, batch_idx=54, gpu=0, loss=0.492, v_num=3drc8ka5]
# Epoch 4:  79%|███████▊  | 84/107 [01:35<00:24,  1.08s/batch, batch_idx=54, gpu=0, loss=0.492, v_num=3drc8ka5]
# Epoch 4:  79%|███████▉  | 85/107 [01:36<00:22,  1.01s/batch, batch_idx=54, gpu=0, loss=0.492, v_num=3drc8ka5]
# Epoch 4:  80%|████████  | 86/107 [01:37<00:21,  1.05s/batch, batch_idx=54, gpu=0, loss=0.492, v_num=3drc8ka5]
# Epoch 4:  81%|████████▏ | 87/107 [01:38<00:20,  1.00s/batch, batch_idx=54, gpu=0, loss=0.492, v_num=3drc8ka5]
# Epoch 4:  82%|████████▏ | 88/107 [01:39<00:17,  1.06batch/s, batch_idx=54, gpu=0, loss=0.492, v_num=3drc8ka5]
# Epoch 4:  83%|████████▎ | 89/107 [01:40<00:18,  1.01s/batch, batch_idx=54, gpu=0, loss=0.492, v_num=3drc8ka5]
# Epoch 4:  84%|████████▍ | 90/107 [01:42<00:21,  1.24s/batch, batch_idx=54, gpu=0, loss=0.492, v_num=3drc8ka5]
# Epoch 4:  85%|████████▌ | 91/107 [01:43<00:18,  1.13s/batch, batch_idx=54, gpu=0, loss=0.492, v_num=3drc8ka5]
# Epoch 4:  86%|████████▌ | 92/107 [01:46<00:24,  1.64s/batch, batch_idx=54, gpu=0, loss=0.492, v_num=3drc8ka5]
# Epoch 4:  87%|████████▋ | 93/107 [01:46<00:19,  1.42s/batch, batch_idx=54, gpu=0, loss=0.492, v_num=3drc8ka5]
# Epoch 4:  88%|████████▊ | 94/107 [01:49<00:21,  1.67s/batch, batch_idx=54, gpu=0, loss=0.492, v_num=3drc8ka5]
# Epoch 4:  89%|████████▉ | 95/107 [01:56<00:39,  3.33s/batch, batch_idx=54, gpu=0, loss=0.492, v_num=3drc8ka5]
# Epoch 4:  90%|████████▉ | 96/107 [01:57<00:30,  2.76s/batch, batch_idx=54, gpu=0, loss=0.492, v_num=3drc8ka5]
# Epoch 4:  91%|█████████ | 97/107 [02:01<00:29,  2.97s/batch, batch_idx=54, gpu=0, loss=0.492, v_num=3drc8ka5]
# Epoch 4:  92%|█████████▏| 98/107 [02:02<00:21,  2.38s/batch, batch_idx=54, gpu=0, loss=0.492, v_num=3drc8ka5]
# Epoch 4:  93%|█████████▎| 99/107 [02:03<00:15,  1.99s/batch, batch_idx=54, gpu=0, loss=0.492, v_num=3drc8ka5]
# Epoch 4:  93%|█████████▎| 100/107 [02:04<00:11,  1.64s/batch, batch_idx=54, gpu=0, loss=0.492, v_num=3drc8ka5]
# Epoch 4:  94%|█████████▍| 101/107 [02:05<00:08,  1.39s/batch, batch_idx=54, gpu=0, loss=0.492, v_num=3drc8ka5]
# Epoch 4:  95%|█████████▌| 102/107 [02:06<00:07,  1.54s/batch, batch_idx=54, gpu=0, loss=0.492, v_num=3drc8ka5]
# Epoch 4:  96%|█████████▋| 103/107 [02:07<00:05,  1.34s/batch, batch_idx=54, gpu=0, loss=0.492, v_num=3drc8ka5]
# Epoch 4:  97%|█████████▋| 104/107 [02:08<00:03,  1.20s/batch, batch_idx=54, gpu=0, loss=0.492, v_num=3drc8ka5]
# Epoch 4:  98%|█████████▊| 105/107 [02:09<00:02,  1.16s/batch, batch_idx=54, gpu=0, loss=0.492, v_num=3drc8ka5]
# Epoch 4:  99%|█████████▉| 106/107 [02:11<00:01,  1.27s/batch, batch_idx=54, gpu=0, loss=0.492, v_num=3drc8ka5]
# Epoch 4: 100%|██████████| 107/107 [02:17<00:00,  1.79s/batch, batch_idx=54, gpu=0, loss=0.492, v_num=3drc8ka5]
# Epoch 5:  51%|█████▏    | 55/107 [00:41<00:36,  1.42batch/s, batch_idx=54, gpu=0, loss=0.417, v_num=3drc8ka5]
# Validating:   0%|          | 0/52 [00:00<?, ?batch/s]
# Epoch 5:  52%|█████▏    | 56/107 [00:47<01:47,  2.11s/batch, batch_idx=54, gpu=0, loss=0.417, v_num=3drc8ka5]
# Epoch 5:  53%|█████▎    | 57/107 [00:52<02:24,  2.90s/batch, batch_idx=54, gpu=0, loss=0.417, v_num=3drc8ka5]
# Epoch 5:  54%|█████▍    | 58/107 [00:53<02:05,  2.56s/batch, batch_idx=54, gpu=0, loss=0.417, v_num=3drc8ka5]
# Epoch 5:  55%|█████▌    | 59/107 [00:55<01:56,  2.43s/batch, batch_idx=54, gpu=0, loss=0.417, v_num=3drc8ka5]
# Epoch 5:  56%|█████▌    | 60/107 [00:57<01:41,  2.16s/batch, batch_idx=54, gpu=0, loss=0.417, v_num=3drc8ka5]
# Epoch 5:  57%|█████▋    | 61/107 [00:58<01:23,  1.82s/batch, batch_idx=54, gpu=0, loss=0.417, v_num=3drc8ka5]
# Epoch 5:  58%|█████▊    | 62/107 [01:03<02:10,  2.89s/batch, batch_idx=54, gpu=0, loss=0.417, v_num=3drc8ka5]
# Epoch 5:  59%|█████▉    | 63/107 [01:04<01:41,  2.30s/batch, batch_idx=54, gpu=0, loss=0.417, v_num=3drc8ka5]
# Epoch 5:  60%|█████▉    | 64/107 [01:06<01:33,  2.18s/batch, batch_idx=54, gpu=0, loss=0.417, v_num=3drc8ka5]
# Epoch 5:  61%|██████    | 65/107 [01:07<01:19,  1.88s/batch, batch_idx=54, gpu=0, loss=0.417, v_num=3drc8ka5]
# Epoch 5:  62%|██████▏   | 66/107 [01:09<01:18,  1.93s/batch, batch_idx=54, gpu=0, loss=0.417, v_num=3drc8ka5]
# Epoch 5:  63%|██████▎   | 67/107 [01:11<01:10,  1.76s/batch, batch_idx=54, gpu=0, loss=0.417, v_num=3drc8ka5]
# Epoch 5:  64%|██████▎   | 68/107 [01:12<01:02,  1.60s/batch, batch_idx=54, gpu=0, loss=0.417, v_num=3drc8ka5]
# Epoch 5:  64%|██████▍   | 69/107 [01:15<01:15,  1.99s/batch, batch_idx=54, gpu=0, loss=0.417, v_num=3drc8ka5]
# Epoch 5:  65%|██████▌   | 70/107 [01:17<01:12,  1.97s/batch, batch_idx=54, gpu=0, loss=0.417, v_num=3drc8ka5]
# Epoch 5:  66%|██████▋   | 71/107 [01:19<01:16,  2.13s/batch, batch_idx=54, gpu=0, loss=0.417, v_num=3drc8ka5]
# Epoch 5:  67%|██████▋   | 72/107 [01:21<01:10,  2.00s/batch, batch_idx=54, gpu=0, loss=0.417, v_num=3drc8ka5]
# Epoch 5:  68%|██████▊   | 73/107 [01:22<00:54,  1.60s/batch, batch_idx=54, gpu=0, loss=0.417, v_num=3drc8ka5]
# Epoch 5:  69%|██████▉   | 74/107 [01:23<00:52,  1.59s/batch, batch_idx=54, gpu=0, loss=0.417, v_num=3drc8ka5]
# Epoch 5:  70%|███████   | 75/107 [01:24<00:44,  1.38s/batch, batch_idx=54, gpu=0, loss=0.417, v_num=3drc8ka5]
# Epoch 5:  71%|███████   | 76/107 [01:25<00:39,  1.26s/batch, batch_idx=54, gpu=0, loss=0.417, v_num=3drc8ka5]
# Epoch 5:  72%|███████▏  | 77/107 [01:26<00:37,  1.25s/batch, batch_idx=54, gpu=0, loss=0.417, v_num=3drc8ka5]
# Epoch 5:  73%|███████▎  | 78/107 [01:29<00:48,  1.69s/batch, batch_idx=54, gpu=0, loss=0.417, v_num=3drc8ka5]
# Epoch 5:  74%|███████▍  | 79/107 [01:30<00:40,  1.44s/batch, batch_idx=54, gpu=0, loss=0.417, v_num=3drc8ka5]
# Epoch 5:  75%|███████▍  | 80/107 [01:31<00:38,  1.44s/batch, batch_idx=54, gpu=0, loss=0.417, v_num=3drc8ka5]
# Epoch 5:  76%|███████▌  | 81/107 [01:32<00:31,  1.20s/batch, batch_idx=54, gpu=0, loss=0.417, v_num=3drc8ka5]
# Epoch 5:  77%|███████▋  | 82/107 [01:33<00:27,  1.10s/batch, batch_idx=54, gpu=0, loss=0.417, v_num=3drc8ka5]
# Epoch 5:  78%|███████▊  | 83/107 [01:34<00:28,  1.20s/batch, batch_idx=54, gpu=0, loss=0.417, v_num=3drc8ka5]
# Epoch 5:  79%|███████▊  | 84/107 [01:35<00:24,  1.07s/batch, batch_idx=54, gpu=0, loss=0.417, v_num=3drc8ka5]
# Epoch 5:  79%|███████▉  | 85/107 [01:36<00:22,  1.01s/batch, batch_idx=54, gpu=0, loss=0.417, v_num=3drc8ka5]
# Epoch 5:  80%|████████  | 86/107 [01:37<00:21,  1.03s/batch, batch_idx=54, gpu=0, loss=0.417, v_num=3drc8ka5]
# Epoch 5:  81%|████████▏ | 87/107 [01:38<00:19,  1.01batch/s, batch_idx=54, gpu=0, loss=0.417, v_num=3drc8ka5]
# Epoch 5:  82%|████████▏ | 88/107 [01:39<00:17,  1.07batch/s, batch_idx=54, gpu=0, loss=0.417, v_num=3drc8ka5]
# Epoch 5:  83%|████████▎ | 89/107 [01:40<00:18,  1.01s/batch, batch_idx=54, gpu=0, loss=0.417, v_num=3drc8ka5]
# Epoch 5:  84%|████████▍ | 90/107 [01:42<00:20,  1.23s/batch, batch_idx=54, gpu=0, loss=0.417, v_num=3drc8ka5]
# Epoch 5:  85%|████████▌ | 91/107 [01:43<00:18,  1.14s/batch, batch_idx=54, gpu=0, loss=0.417, v_num=3drc8ka5]
# Epoch 5:  86%|████████▌ | 92/107 [01:46<00:24,  1.65s/batch, batch_idx=54, gpu=0, loss=0.417, v_num=3drc8ka5]
# Epoch 5:  87%|████████▋ | 93/107 [01:46<00:20,  1.43s/batch, batch_idx=54, gpu=0, loss=0.417, v_num=3drc8ka5]
# Epoch 5:  88%|████████▊ | 94/107 [01:49<00:21,  1.67s/batch, batch_idx=54, gpu=0, loss=0.417, v_num=3drc8ka5]
# Epoch 5:  89%|████████▉ | 95/107 [01:56<00:40,  3.35s/batch, batch_idx=54, gpu=0, loss=0.417, v_num=3drc8ka5]
# Epoch 5:  90%|████████▉ | 96/107 [01:57<00:30,  2.76s/batch, batch_idx=54, gpu=0, loss=0.417, v_num=3drc8ka5]
# Epoch 5:  91%|█████████ | 97/107 [02:04<00:39,  3.94s/batch, batch_idx=54, gpu=0, loss=0.417, v_num=3drc8ka5]
# Epoch 5:  92%|█████████▏| 98/107 [02:05<00:27,  3.05s/batch, batch_idx=54, gpu=0, loss=0.417, v_num=3drc8ka5]
# Epoch 5:  93%|█████████▎| 99/107 [02:06<00:19,  2.46s/batch, batch_idx=54, gpu=0, loss=0.417, v_num=3drc8ka5]
# Epoch 5:  93%|█████████▎| 100/107 [02:07<00:13,  1.97s/batch, batch_idx=54, gpu=0, loss=0.417, v_num=3drc8ka5]
# Epoch 5:  94%|█████████▍| 101/107 [02:08<00:09,  1.61s/batch, batch_idx=54, gpu=0, loss=0.417, v_num=3drc8ka5]
# Epoch 5:  95%|█████████▌| 102/107 [02:10<00:08,  1.69s/batch, batch_idx=54, gpu=0, loss=0.417, v_num=3drc8ka5]
# Epoch 5:  96%|█████████▋| 103/107 [02:10<00:05,  1.44s/batch, batch_idx=54, gpu=0, loss=0.417, v_num=3drc8ka5]
# Epoch 5:  97%|█████████▋| 104/107 [02:11<00:03,  1.27s/batch, batch_idx=54, gpu=0, loss=0.417, v_num=3drc8ka5]
# Epoch 5:  98%|█████████▊| 105/107 [02:12<00:02,  1.21s/batch, batch_idx=54, gpu=0, loss=0.417, v_num=3drc8ka5]
# Epoch 5:  99%|█████████▉| 106/107 [02:14<00:01,  1.30s/batch, batch_idx=54, gpu=0, loss=0.417, v_num=3drc8ka5]
# Epoch 5: 100%|██████████| 107/107 [02:18<00:00,  1.13s/batch, batch_idx=54, gpu=0, loss=0.417, v_num=3drc8ka5]
# Epoch 6:  51%|█████▏    | 55/107 [00:41<00:31,  1.67batch/s, batch_idx=54, gpu=0, loss=0.355, v_num=3drc8ka5]
# Validating:   0%|          | 0/52 [00:00<?, ?batch/s]
# Epoch 6:  52%|█████▏    | 56/107 [00:46<01:42,  2.01s/batch, batch_idx=54, gpu=0, loss=0.355, v_num=3drc8ka5]
# Epoch 6:  53%|█████▎    | 57/107 [00:50<02:11,  2.62s/batch, batch_idx=54, gpu=0, loss=0.355, v_num=3drc8ka5]
# Epoch 6:  54%|█████▍    | 58/107 [00:52<01:57,  2.40s/batch, batch_idx=54, gpu=0, loss=0.355, v_num=3drc8ka5]
# Epoch 6:  55%|█████▌    | 59/107 [00:54<01:54,  2.39s/batch, batch_idx=54, gpu=0, loss=0.355, v_num=3drc8ka5]
# Epoch 6:  56%|█████▌    | 60/107 [00:56<01:44,  2.22s/batch, batch_idx=54, gpu=0, loss=0.355, v_num=3drc8ka5]
# Epoch 6:  57%|█████▋    | 61/107 [00:58<01:29,  1.94s/batch, batch_idx=54, gpu=0, loss=0.355, v_num=3drc8ka5]
# Epoch 6:  58%|█████▊    | 62/107 [01:00<01:40,  2.23s/batch, batch_idx=54, gpu=0, loss=0.355, v_num=3drc8ka5]
# Epoch 6:  59%|█████▉    | 63/107 [01:02<01:24,  1.91s/batch, batch_idx=54, gpu=0, loss=0.355, v_num=3drc8ka5]
# Epoch 6:  60%|█████▉    | 64/107 [01:03<01:20,  1.87s/batch, batch_idx=54, gpu=0, loss=0.355, v_num=3drc8ka5]
# Epoch 6:  61%|██████    | 65/107 [01:04<01:08,  1.62s/batch, batch_idx=54, gpu=0, loss=0.355, v_num=3drc8ka5]
# Epoch 6:  62%|██████▏   | 66/107 [01:06<01:08,  1.68s/batch, batch_idx=54, gpu=0, loss=0.355, v_num=3drc8ka5]
# Epoch 6:  63%|██████▎   | 67/107 [01:08<01:04,  1.61s/batch, batch_idx=54, gpu=0, loss=0.355, v_num=3drc8ka5]
# Epoch 6:  64%|██████▎   | 68/107 [01:09<00:58,  1.50s/batch, batch_idx=54, gpu=0, loss=0.355, v_num=3drc8ka5]
# Epoch 6:  64%|██████▍   | 69/107 [01:11<00:58,  1.54s/batch, batch_idx=54, gpu=0, loss=0.355, v_num=3drc8ka5]
# Epoch 6:  65%|██████▌   | 70/107 [01:12<00:56,  1.52s/batch, batch_idx=54, gpu=0, loss=0.355, v_num=3drc8ka5]
# Epoch 6:  66%|██████▋   | 71/107 [01:15<01:07,  1.88s/batch, batch_idx=54, gpu=0, loss=0.355, v_num=3drc8ka5]
# Epoch 6:  67%|██████▋   | 72/107 [01:17<01:04,  1.84s/batch, batch_idx=54, gpu=0, loss=0.355, v_num=3drc8ka5]
# Epoch 6:  68%|██████▊   | 73/107 [01:17<00:50,  1.49s/batch, batch_idx=54, gpu=0, loss=0.355, v_num=3drc8ka5]
# Epoch 6:  69%|██████▉   | 74/107 [01:19<00:50,  1.52s/batch, batch_idx=54, gpu=0, loss=0.355, v_num=3drc8ka5]
# Epoch 6:  70%|███████   | 75/107 [01:20<00:42,  1.33s/batch, batch_idx=54, gpu=0, loss=0.355, v_num=3drc8ka5]
# Epoch 6:  71%|███████   | 76/107 [01:21<00:37,  1.22s/batch, batch_idx=54, gpu=0, loss=0.355, v_num=3drc8ka5]
# Epoch 6:  72%|███████▏  | 77/107 [01:22<00:36,  1.23s/batch, batch_idx=54, gpu=0, loss=0.355, v_num=3drc8ka5]
# Epoch 6:  73%|███████▎  | 78/107 [01:25<00:48,  1.67s/batch, batch_idx=54, gpu=0, loss=0.355, v_num=3drc8ka5]
# Epoch 6:  74%|███████▍  | 79/107 [01:25<00:39,  1.43s/batch, batch_idx=54, gpu=0, loss=0.355, v_num=3drc8ka5]
# Epoch 6:  75%|███████▍  | 80/107 [01:27<00:38,  1.42s/batch, batch_idx=54, gpu=0, loss=0.355, v_num=3drc8ka5]
# Epoch 6:  76%|███████▌  | 81/107 [01:27<00:30,  1.18s/batch, batch_idx=54, gpu=0, loss=0.355, v_num=3drc8ka5]
# Epoch 6:  77%|███████▋  | 82/107 [01:28<00:27,  1.09s/batch, batch_idx=54, gpu=0, loss=0.355, v_num=3drc8ka5]
# Epoch 6:  78%|███████▊  | 83/107 [01:30<00:28,  1.17s/batch, batch_idx=54, gpu=0, loss=0.355, v_num=3drc8ka5]
# Epoch 6:  79%|███████▊  | 84/107 [01:30<00:24,  1.05s/batch, batch_idx=54, gpu=0, loss=0.355, v_num=3drc8ka5]
# Epoch 6:  79%|███████▉  | 85/107 [01:31<00:21,  1.01batch/s, batch_idx=54, gpu=0, loss=0.355, v_num=3drc8ka5]
# Epoch 6:  80%|████████  | 86/107 [01:32<00:21,  1.02s/batch, batch_idx=54, gpu=0, loss=0.355, v_num=3drc8ka5]
# Epoch 6:  81%|████████▏ | 87/107 [01:33<00:19,  1.00batch/s, batch_idx=54, gpu=0, loss=0.355, v_num=3drc8ka5]
# Epoch 6:  82%|████████▏ | 88/107 [01:34<00:17,  1.07batch/s, batch_idx=54, gpu=0, loss=0.355, v_num=3drc8ka5]
# Epoch 6:  83%|████████▎ | 89/107 [01:35<00:18,  1.01s/batch, batch_idx=54, gpu=0, loss=0.355, v_num=3drc8ka5]
# Epoch 6:  84%|████████▍ | 90/107 [01:37<00:20,  1.23s/batch, batch_idx=54, gpu=0, loss=0.355, v_num=3drc8ka5]
# Epoch 6:  85%|████████▌ | 91/107 [01:38<00:17,  1.11s/batch, batch_idx=54, gpu=0, loss=0.355, v_num=3drc8ka5]
# Epoch 6:  86%|████████▌ | 92/107 [01:41<00:24,  1.62s/batch, batch_idx=54, gpu=0, loss=0.355, v_num=3drc8ka5]
# Epoch 6:  87%|████████▋ | 93/107 [01:42<00:19,  1.41s/batch, batch_idx=54, gpu=0, loss=0.355, v_num=3drc8ka5]
# Epoch 6:  88%|████████▊ | 94/107 [01:44<00:21,  1.65s/batch, batch_idx=54, gpu=0, loss=0.355, v_num=3drc8ka5]
# Epoch 6:  89%|████████▉ | 95/107 [01:51<00:39,  3.31s/batch, batch_idx=54, gpu=0, loss=0.355, v_num=3drc8ka5]
# Epoch 6:  90%|████████▉ | 96/107 [01:52<00:30,  2.74s/batch, batch_idx=54, gpu=0, loss=0.355, v_num=3drc8ka5]
# Epoch 6:  91%|█████████ | 97/107 [02:00<00:40,  4.06s/batch, batch_idx=54, gpu=0, loss=0.355, v_num=3drc8ka5]
# Epoch 6:  92%|█████████▏| 98/107 [02:01<00:28,  3.14s/batch, batch_idx=54, gpu=0, loss=0.355, v_num=3drc8ka5]
# Epoch 6:  93%|█████████▎| 99/107 [02:02<00:20,  2.51s/batch, batch_idx=54, gpu=0, loss=0.355, v_num=3drc8ka5]
# Epoch 6:  93%|█████████▎| 100/107 [02:02<00:13,  2.00s/batch, batch_idx=54, gpu=0, loss=0.355, v_num=3drc8ka5]
# Epoch 6:  94%|█████████▍| 101/107 [02:03<00:09,  1.63s/batch, batch_idx=54, gpu=0, loss=0.355, v_num=3drc8ka5]
# Epoch 6:  95%|█████████▌| 102/107 [02:05<00:08,  1.70s/batch, batch_idx=54, gpu=0, loss=0.355, v_num=3drc8ka5]
# Epoch 6:  96%|█████████▋| 103/107 [02:06<00:05,  1.45s/batch, batch_idx=54, gpu=0, loss=0.355, v_num=3drc8ka5]
# Epoch 6:  97%|█████████▋| 104/107 [02:07<00:03,  1.27s/batch, batch_idx=54, gpu=0, loss=0.355, v_num=3drc8ka5]
# Epoch 6:  98%|█████████▊| 105/107 [02:08<00:02,  1.20s/batch, batch_idx=54, gpu=0, loss=0.355, v_num=3drc8ka5]
# Epoch 6:  99%|█████████▉| 106/107 [02:09<00:01,  1.29s/batch, batch_idx=54, gpu=0, loss=0.355, v_num=3drc8ka5]
# Epoch 6: 100%|██████████| 107/107 [02:13<00:00,  1.12s/batch, batch_idx=54, gpu=0, loss=0.355, v_num=3drc8ka5]
# Epoch 7:  51%|█████▏    | 55/107 [00:42<00:37,  1.40batch/s, batch_idx=54, gpu=0, loss=0.309, v_num=3drc8ka5]
# Validating:   0%|          | 0/52 [00:00<?, ?batch/s]
# Epoch 7:  52%|█████▏    | 56/107 [00:47<01:53,  2.23s/batch, batch_idx=54, gpu=0, loss=0.309, v_num=3drc8ka5]
# Epoch 7:  53%|█████▎    | 57/107 [00:51<02:09,  2.59s/batch, batch_idx=54, gpu=0, loss=0.309, v_num=3drc8ka5]
# Epoch 7:  54%|█████▍    | 58/107 [00:52<01:52,  2.29s/batch, batch_idx=54, gpu=0, loss=0.309, v_num=3drc8ka5]
# Epoch 7:  55%|█████▌    | 59/107 [00:57<02:17,  2.87s/batch, batch_idx=54, gpu=0, loss=0.309, v_num=3drc8ka5]
# Epoch 7:  56%|█████▌    | 60/107 [00:58<01:57,  2.50s/batch, batch_idx=54, gpu=0, loss=0.309, v_num=3drc8ka5]
# Epoch 7:  57%|█████▋    | 61/107 [00:59<01:33,  2.04s/batch, batch_idx=54, gpu=0, loss=0.309, v_num=3drc8ka5]
# Epoch 7:  58%|█████▊    | 62/107 [01:03<01:56,  2.60s/batch, batch_idx=54, gpu=0, loss=0.309, v_num=3drc8ka5]
# Epoch 7:  59%|█████▉    | 63/107 [01:04<01:37,  2.20s/batch, batch_idx=54, gpu=0, loss=0.309, v_num=3drc8ka5]
# Epoch 7:  60%|█████▉    | 64/107 [01:06<01:30,  2.11s/batch, batch_idx=54, gpu=0, loss=0.309, v_num=3drc8ka5]
# Epoch 7:  61%|██████    | 65/107 [01:07<01:17,  1.84s/batch, batch_idx=54, gpu=0, loss=0.309, v_num=3drc8ka5]
# Epoch 7:  62%|██████▏   | 66/107 [01:09<01:15,  1.84s/batch, batch_idx=54, gpu=0, loss=0.309, v_num=3drc8ka5]
# Epoch 7:  63%|██████▎   | 67/107 [01:11<01:08,  1.71s/batch, batch_idx=54, gpu=0, loss=0.309, v_num=3drc8ka5]
# Epoch 7:  64%|██████▎   | 68/107 [01:13<01:09,  1.77s/batch, batch_idx=54, gpu=0, loss=0.309, v_num=3drc8ka5]
# Epoch 7:  64%|██████▍   | 69/107 [01:14<01:04,  1.69s/batch, batch_idx=54, gpu=0, loss=0.309, v_num=3drc8ka5]
# Epoch 7:  65%|██████▌   | 70/107 [01:16<00:59,  1.60s/batch, batch_idx=54, gpu=0, loss=0.309, v_num=3drc8ka5]
# Epoch 7:  66%|██████▋   | 71/107 [01:18<01:07,  1.88s/batch, batch_idx=54, gpu=0, loss=0.309, v_num=3drc8ka5]
# Epoch 7:  67%|██████▋   | 72/107 [01:20<01:04,  1.84s/batch, batch_idx=54, gpu=0, loss=0.309, v_num=3drc8ka5]
# Epoch 7:  68%|██████▊   | 73/107 [01:20<00:50,  1.49s/batch, batch_idx=54, gpu=0, loss=0.309, v_num=3drc8ka5]
# Epoch 7:  69%|██████▉   | 74/107 [01:22<00:50,  1.52s/batch, batch_idx=54, gpu=0, loss=0.309, v_num=3drc8ka5]
# Epoch 7:  70%|███████   | 75/107 [01:23<00:42,  1.33s/batch, batch_idx=54, gpu=0, loss=0.309, v_num=3drc8ka5]
# Epoch 7:  71%|███████   | 76/107 [01:24<00:37,  1.21s/batch, batch_idx=54, gpu=0, loss=0.309, v_num=3drc8ka5]
# Epoch 7:  72%|███████▏  | 77/107 [01:25<00:36,  1.21s/batch, batch_idx=54, gpu=0, loss=0.309, v_num=3drc8ka5]
# Epoch 7:  73%|███████▎  | 78/107 [01:28<00:48,  1.67s/batch, batch_idx=54, gpu=0, loss=0.309, v_num=3drc8ka5]
# Epoch 7:  74%|███████▍  | 79/107 [01:29<00:40,  1.43s/batch, batch_idx=54, gpu=0, loss=0.309, v_num=3drc8ka5]
# Epoch 7:  75%|███████▍  | 80/107 [01:30<00:38,  1.42s/batch, batch_idx=54, gpu=0, loss=0.309, v_num=3drc8ka5]
# Epoch 7:  76%|███████▌  | 81/107 [01:31<00:30,  1.18s/batch, batch_idx=54, gpu=0, loss=0.309, v_num=3drc8ka5]
# Epoch 7:  77%|███████▋  | 82/107 [01:32<00:27,  1.10s/batch, batch_idx=54, gpu=0, loss=0.309, v_num=3drc8ka5]
# Epoch 7:  78%|███████▊  | 83/107 [01:33<00:28,  1.19s/batch, batch_idx=54, gpu=0, loss=0.309, v_num=3drc8ka5]
# Epoch 7:  79%|███████▊  | 84/107 [01:34<00:24,  1.08s/batch, batch_idx=54, gpu=0, loss=0.309, v_num=3drc8ka5]
# Epoch 7:  79%|███████▉  | 85/107 [01:35<00:22,  1.02s/batch, batch_idx=54, gpu=0, loss=0.309, v_num=3drc8ka5]
# Epoch 7:  80%|████████  | 86/107 [01:36<00:22,  1.06s/batch, batch_idx=54, gpu=0, loss=0.309, v_num=3drc8ka5]
# Epoch 7:  81%|████████▏ | 87/107 [01:37<00:20,  1.02s/batch, batch_idx=54, gpu=0, loss=0.309, v_num=3drc8ka5]
# Epoch 7:  82%|████████▏ | 88/107 [01:38<00:18,  1.05batch/s, batch_idx=54, gpu=0, loss=0.309, v_num=3drc8ka5]
# Epoch 7:  83%|████████▎ | 89/107 [01:39<00:18,  1.03s/batch, batch_idx=54, gpu=0, loss=0.309, v_num=3drc8ka5]
# Epoch 7:  84%|████████▍ | 90/107 [01:41<00:21,  1.26s/batch, batch_idx=54, gpu=0, loss=0.309, v_num=3drc8ka5]
# Epoch 7:  85%|████████▌ | 91/107 [01:41<00:18,  1.14s/batch, batch_idx=54, gpu=0, loss=0.309, v_num=3drc8ka5]
# Epoch 7:  86%|████████▌ | 92/107 [01:44<00:24,  1.64s/batch, batch_idx=54, gpu=0, loss=0.309, v_num=3drc8ka5]
# Epoch 7:  87%|████████▋ | 93/107 [01:45<00:19,  1.41s/batch, batch_idx=54, gpu=0, loss=0.309, v_num=3drc8ka5]
# Epoch 7:  88%|████████▊ | 94/107 [01:47<00:21,  1.66s/batch, batch_idx=54, gpu=0, loss=0.309, v_num=3drc8ka5]
# Epoch 7:  89%|████████▉ | 95/107 [01:55<00:39,  3.33s/batch, batch_idx=54, gpu=0, loss=0.309, v_num=3drc8ka5]
# Epoch 7:  90%|████████▉ | 96/107 [01:56<00:30,  2.76s/batch, batch_idx=54, gpu=0, loss=0.309, v_num=3drc8ka5]
# Epoch 7:  91%|█████████ | 97/107 [02:00<00:30,  3.02s/batch, batch_idx=54, gpu=0, loss=0.309, v_num=3drc8ka5]
# Epoch 7:  92%|█████████▏| 98/107 [02:01<00:21,  2.41s/batch, batch_idx=54, gpu=0, loss=0.309, v_num=3drc8ka5]
# Epoch 7:  93%|█████████▎| 99/107 [02:02<00:16,  2.01s/batch, batch_idx=54, gpu=0, loss=0.309, v_num=3drc8ka5]
# Epoch 7:  93%|█████████▎| 100/107 [02:03<00:11,  1.64s/batch, batch_idx=54, gpu=0, loss=0.309, v_num=3drc8ka5]
# Epoch 7:  94%|█████████▍| 101/107 [02:03<00:08,  1.39s/batch, batch_idx=54, gpu=0, loss=0.309, v_num=3drc8ka5]
# Epoch 7:  95%|█████████▌| 102/107 [02:05<00:07,  1.55s/batch, batch_idx=54, gpu=0, loss=0.309, v_num=3drc8ka5]
# Epoch 7:  96%|█████████▋| 103/107 [02:06<00:05,  1.35s/batch, batch_idx=54, gpu=0, loss=0.309, v_num=3drc8ka5]
# Epoch 7:  97%|█████████▋| 104/107 [02:07<00:03,  1.22s/batch, batch_idx=54, gpu=0, loss=0.309, v_num=3drc8ka5]
# Epoch 7:  98%|█████████▊| 105/107 [02:08<00:02,  1.17s/batch, batch_idx=54, gpu=0, loss=0.309, v_num=3drc8ka5]
# Epoch 7:  99%|█████████▉| 106/107 [02:10<00:01,  1.30s/batch, batch_idx=54, gpu=0, loss=0.309, v_num=3drc8ka5]
# Epoch 7: 100%|██████████| 107/107 [02:13<00:00,  1.14s/batch, batch_idx=54, gpu=0, loss=0.309, v_num=3drc8ka5]
# Epoch 8:  51%|█████▏    | 55/107 [00:43<00:34,  1.49batch/s, batch_idx=54, gpu=0, loss=0.276, v_num=3drc8ka5]
# Validating:   0%|          | 0/52 [00:00<?, ?batch/s]
# Epoch 8:  52%|█████▏    | 56/107 [00:49<01:54,  2.24s/batch, batch_idx=54, gpu=0, loss=0.276, v_num=3drc8ka5]
# Epoch 8:  53%|█████▎    | 57/107 [01:05<05:21,  6.42s/batch, batch_idx=54, gpu=0, loss=0.276, v_num=3drc8ka5]
# Epoch 8:  54%|█████▍    | 58/107 [01:07<04:03,  4.98s/batch, batch_idx=54, gpu=0, loss=0.276, v_num=3drc8ka5]
# Epoch 8:  55%|█████▌    | 59/107 [01:09<03:21,  4.20s/batch, batch_idx=54, gpu=0, loss=0.276, v_num=3drc8ka5]
# Epoch 8:  56%|█████▌    | 60/107 [01:10<02:39,  3.39s/batch, batch_idx=54, gpu=0, loss=0.276, v_num=3drc8ka5]
# Epoch 8:  57%|█████▋    | 61/107 [01:11<02:02,  2.66s/batch, batch_idx=54, gpu=0, loss=0.276, v_num=3drc8ka5]
# Epoch 8:  58%|█████▊    | 62/107 [01:14<02:04,  2.77s/batch, batch_idx=54, gpu=0, loss=0.276, v_num=3drc8ka5]
# Epoch 8:  59%|█████▉    | 63/107 [01:16<01:40,  2.27s/batch, batch_idx=54, gpu=0, loss=0.276, v_num=3drc8ka5]
# Epoch 8:  60%|█████▉    | 64/107 [01:18<01:35,  2.22s/batch, batch_idx=54, gpu=0, loss=0.276, v_num=3drc8ka5]
# Epoch 8:  61%|██████    | 65/107 [01:19<01:20,  1.91s/batch, batch_idx=54, gpu=0, loss=0.276, v_num=3drc8ka5]
# Epoch 8:  62%|██████▏   | 66/107 [01:21<01:19,  1.93s/batch, batch_idx=54, gpu=0, loss=0.276, v_num=3drc8ka5]
# Epoch 8:  63%|██████▎   | 67/107 [01:22<01:10,  1.77s/batch, batch_idx=54, gpu=0, loss=0.276, v_num=3drc8ka5]
# Epoch 8:  64%|██████▎   | 68/107 [01:23<01:02,  1.60s/batch, batch_idx=54, gpu=0, loss=0.276, v_num=3drc8ka5]
# Epoch 8:  64%|██████▍   | 69/107 [01:25<01:00,  1.61s/batch, batch_idx=54, gpu=0, loss=0.276, v_num=3drc8ka5]
# Epoch 8:  65%|██████▌   | 70/107 [01:26<00:57,  1.55s/batch, batch_idx=54, gpu=0, loss=0.276, v_num=3drc8ka5]
# Epoch 8:  66%|██████▋   | 71/107 [01:29<01:06,  1.84s/batch, batch_idx=54, gpu=0, loss=0.276, v_num=3drc8ka5]
# Epoch 8:  67%|██████▋   | 72/107 [01:31<01:04,  1.83s/batch, batch_idx=54, gpu=0, loss=0.276, v_num=3drc8ka5]
# Epoch 8:  68%|██████▊   | 73/107 [01:31<00:50,  1.48s/batch, batch_idx=54, gpu=0, loss=0.276, v_num=3drc8ka5]
# Epoch 8:  69%|██████▉   | 74/107 [01:33<00:50,  1.53s/batch, batch_idx=54, gpu=0, loss=0.276, v_num=3drc8ka5]
# Epoch 8:  70%|███████   | 75/107 [01:34<00:43,  1.34s/batch, batch_idx=54, gpu=0, loss=0.276, v_num=3drc8ka5]
# Epoch 8:  71%|███████   | 76/107 [01:35<00:38,  1.23s/batch, batch_idx=54, gpu=0, loss=0.276, v_num=3drc8ka5]
# Epoch 8:  72%|███████▏  | 77/107 [01:36<00:37,  1.24s/batch, batch_idx=54, gpu=0, loss=0.276, v_num=3drc8ka5]
# Epoch 8:  73%|███████▎  | 78/107 [01:39<00:49,  1.71s/batch, batch_idx=54, gpu=0, loss=0.276, v_num=3drc8ka5]
# Epoch 8:  74%|███████▍  | 79/107 [01:40<00:41,  1.47s/batch, batch_idx=54, gpu=0, loss=0.276, v_num=3drc8ka5]
# Epoch 8:  75%|███████▍  | 80/107 [01:41<00:39,  1.48s/batch, batch_idx=54, gpu=0, loss=0.276, v_num=3drc8ka5]
# Epoch 8:  76%|███████▌  | 81/107 [01:42<00:32,  1.23s/batch, batch_idx=54, gpu=0, loss=0.276, v_num=3drc8ka5]
# Epoch 8:  77%|███████▋  | 82/107 [01:43<00:28,  1.13s/batch, batch_idx=54, gpu=0, loss=0.276, v_num=3drc8ka5]
# Epoch 8:  78%|███████▊  | 83/107 [01:44<00:29,  1.23s/batch, batch_idx=54, gpu=0, loss=0.276, v_num=3drc8ka5]
# Epoch 8:  79%|███████▊  | 84/107 [01:45<00:25,  1.10s/batch, batch_idx=54, gpu=0, loss=0.276, v_num=3drc8ka5]
# Epoch 8:  79%|███████▉  | 85/107 [01:46<00:22,  1.03s/batch, batch_idx=54, gpu=0, loss=0.276, v_num=3drc8ka5]
# Epoch 8:  80%|████████  | 86/107 [01:47<00:22,  1.06s/batch, batch_idx=54, gpu=0, loss=0.276, v_num=3drc8ka5]
# Epoch 8:  81%|████████▏ | 87/107 [01:48<00:20,  1.01s/batch, batch_idx=54, gpu=0, loss=0.276, v_num=3drc8ka5]
# Epoch 8:  82%|████████▏ | 88/107 [01:49<00:18,  1.05batch/s, batch_idx=54, gpu=0, loss=0.276, v_num=3drc8ka5]
# Epoch 8:  83%|████████▎ | 89/107 [01:50<00:18,  1.02s/batch, batch_idx=54, gpu=0, loss=0.276, v_num=3drc8ka5]
# Epoch 8:  84%|████████▍ | 90/107 [01:52<00:21,  1.25s/batch, batch_idx=54, gpu=0, loss=0.276, v_num=3drc8ka5]
# Epoch 8:  85%|████████▌ | 91/107 [01:53<00:18,  1.13s/batch, batch_idx=54, gpu=0, loss=0.276, v_num=3drc8ka5]
# Epoch 8:  86%|████████▌ | 92/107 [01:56<00:24,  1.66s/batch, batch_idx=54, gpu=0, loss=0.276, v_num=3drc8ka5]
# Epoch 8:  87%|████████▋ | 93/107 [01:57<00:20,  1.43s/batch, batch_idx=54, gpu=0, loss=0.276, v_num=3drc8ka5]
# Epoch 8:  88%|████████▊ | 94/107 [01:59<00:22,  1.69s/batch, batch_idx=54, gpu=0, loss=0.276, v_num=3drc8ka5]
# Epoch 8:  89%|████████▉ | 95/107 [02:06<00:41,  3.46s/batch, batch_idx=54, gpu=0, loss=0.276, v_num=3drc8ka5]
# Epoch 8:  90%|████████▉ | 96/107 [02:08<00:31,  2.84s/batch, batch_idx=54, gpu=0, loss=0.276, v_num=3drc8ka5]
# Epoch 8:  91%|█████████ | 97/107 [02:11<00:30,  3.03s/batch, batch_idx=54, gpu=0, loss=0.276, v_num=3drc8ka5]
# Epoch 8:  92%|█████████▏| 98/107 [02:12<00:21,  2.42s/batch, batch_idx=54, gpu=0, loss=0.276, v_num=3drc8ka5]
# Epoch 8:  93%|█████████▎| 99/107 [02:13<00:16,  2.02s/batch, batch_idx=54, gpu=0, loss=0.276, v_num=3drc8ka5]
# Epoch 8:  93%|█████████▎| 100/107 [02:14<00:11,  1.65s/batch, batch_idx=54, gpu=0, loss=0.276, v_num=3drc8ka5]
# Epoch 8:  94%|█████████▍| 101/107 [02:15<00:08,  1.39s/batch, batch_idx=54, gpu=0, loss=0.276, v_num=3drc8ka5]
# Epoch 8:  95%|█████████▌| 102/107 [02:17<00:07,  1.55s/batch, batch_idx=54, gpu=0, loss=0.276, v_num=3drc8ka5]
# Epoch 8:  96%|█████████▋| 103/107 [02:18<00:05,  1.35s/batch, batch_idx=54, gpu=0, loss=0.276, v_num=3drc8ka5]
# Epoch 8:  97%|█████████▋| 104/107 [02:19<00:03,  1.21s/batch, batch_idx=54, gpu=0, loss=0.276, v_num=3drc8ka5]
# Epoch 8:  98%|█████████▊| 105/107 [02:20<00:02,  1.17s/batch, batch_idx=54, gpu=0, loss=0.276, v_num=3drc8ka5]
# Epoch 8:  99%|█████████▉| 106/107 [02:21<00:01,  1.29s/batch, batch_idx=54, gpu=0, loss=0.276, v_num=3drc8ka5]
# Epoch 8: 100%|██████████| 107/107 [02:25<00:00,  1.12s/batch, batch_idx=54, gpu=0, loss=0.276, v_num=3drc8ka5]
# Epoch 9:  51%|█████▏    | 55/107 [00:45<00:46,  1.12batch/s, batch_idx=54, gpu=0, loss=0.250, v_num=3drc8ka5]
# Validating:   0%|          | 0/52 [00:00<?, ?batch/s]
# Epoch 9:  52%|█████▏    | 56/107 [00:51<02:17,  2.70s/batch, batch_idx=54, gpu=0, loss=0.250, v_num=3drc8ka5]
# Epoch 9:  53%|█████▎    | 57/107 [00:55<02:25,  2.90s/batch, batch_idx=54, gpu=0, loss=0.250, v_num=3drc8ka5]
# Epoch 9:  54%|█████▍    | 58/107 [00:57<02:10,  2.66s/batch, batch_idx=54, gpu=0, loss=0.250, v_num=3drc8ka5]
# Epoch 9:  55%|█████▌    | 59/107 [01:00<02:08,  2.67s/batch, batch_idx=54, gpu=0, loss=0.250, v_num=3drc8ka5]
# Epoch 9:  56%|█████▌    | 60/107 [01:02<01:54,  2.44s/batch, batch_idx=54, gpu=0, loss=0.250, v_num=3drc8ka5]
# Epoch 9:  57%|█████▋    | 61/107 [01:03<01:36,  2.09s/batch, batch_idx=54, gpu=0, loss=0.250, v_num=3drc8ka5]
# ...
# Epoch 17:  84%|████████▍ | 90/107 [01:50<00:22,  1.31s/batch, batch_idx=54, gpu=0, loss=0.140, v_num=3drc8ka5]
# Epoch 17:  85%|████████▌ | 91/107 [01:51<00:18,  1.18s/batch, batch_idx=54, gpu=0, loss=0.140, v_num=3drc8ka5]
# Epoch 17:  86%|████████▌ | 92/107 [01:54<00:25,  1.71s/batch, batch_idx=54, gpu=0, loss=0.140, v_num=3drc8ka5]
# Epoch 17:  87%|████████▋ | 93/107 [01:55<00:20,  1.48s/batch, batch_idx=54, gpu=0, loss=0.140, v_num=3drc8ka5]
# Epoch 17:  88%|████████▊ | 94/107 [01:58<00:22,  1.73s/batch, batch_idx=54, gpu=0, loss=0.140, v_num=3drc8ka5]
# Epoch 17:  89%|████████▉ | 95/107 [02:05<00:41,  3.49s/batch, batch_idx=54, gpu=0, loss=0.140, v_num=3drc8ka5]
# Epoch 17:  90%|████████▉ | 96/107 [02:07<00:31,  2.87s/batch, batch_idx=54, gpu=0, loss=0.140, v_num=3drc8ka5]
# Epoch 17:  91%|█████████ | 97/107 [02:10<00:30,  3.09s/batch, batch_idx=54, gpu=0, loss=0.140, v_num=3drc8ka5]
# Epoch 17:  92%|█████████▏| 98/107 [02:11<00:22,  2.46s/batch, batch_idx=54, gpu=0, loss=0.140, v_num=3drc8ka5]
# Epoch 17:  93%|█████████▎| 99/107 [02:12<00:16,  2.05s/batch, batch_idx=54, gpu=0, loss=0.140, v_num=3drc8ka5]
# Epoch 17:  93%|█████████▎| 100/107 [02:13<00:11,  1.68s/batch, batch_idx=54, gpu=0, loss=0.140, v_num=3drc8ka5]
# Epoch 17:  94%|█████████▍| 101/107 [02:14<00:08,  1.42s/batch, batch_idx=54, gpu=0, loss=0.140, v_num=3drc8ka5]
# Epoch 17:  95%|█████████▌| 102/107 [02:16<00:07,  1.58s/batch, batch_idx=54, gpu=0, loss=0.140, v_num=3drc8ka5]
# Epoch 17:  96%|█████████▋| 103/107 [02:17<00:05,  1.37s/batch, batch_idx=54, gpu=0, loss=0.140, v_num=3drc8ka5]
# Epoch 17:  97%|█████████▋| 104/107 [02:18<00:03,  1.22s/batch, batch_idx=54, gpu=0, loss=0.140, v_num=3drc8ka5]
# Epoch 17:  98%|█████████▊| 105/107 [02:19<00:02,  1.18s/batch, batch_idx=54, gpu=0, loss=0.140, v_num=3drc8ka5]
# Epoch 17:  99%|█████████▉| 106/107 [02:20<00:01,  1.31s/batch, batch_idx=54, gpu=0, loss=0.140, v_num=3drc8ka5]
# Epoch 17: 100%|██████████| 107/107 [02:24<00:00,  1.14s/batch, batch_idx=54, gpu=0, loss=0.140, v_num=3drc8ka5]
# Epoch 18:  51%|█████▏    | 55/107 [00:49<00:28,  1.83batch/s, batch_idx=54, gpu=0, loss=0.106, v_num=3drc8ka5]
# Validating:   0%|          | 0/52 [00:00<?, ?batch/s]
# Epoch 18:  52%|█████▏    | 56/107 [00:58<02:35,  3.05s/batch, batch_idx=54, gpu=0, loss=0.106, v_num=3drc8ka5]
# Epoch 18:  53%|█████▎    | 57/107 [01:02<02:39,  3.19s/batch, batch_idx=54, gpu=0, loss=0.106, v_num=3drc8ka5]
# Epoch 18:  54%|█████▍    | 58/107 [01:03<02:14,  2.74s/batch, batch_idx=54, gpu=0, loss=0.106, v_num=3drc8ka5]
# Epoch 18:  55%|█████▌    | 59/107 [01:07<02:25,  3.03s/batch, batch_idx=54, gpu=0, loss=0.106, v_num=3drc8ka5]
# Epoch 18:  56%|█████▌    | 60/107 [01:09<02:01,  2.58s/batch, batch_idx=54, gpu=0, loss=0.106, v_num=3drc8ka5]
# Epoch 18:  57%|█████▋    | 61/107 [01:10<01:37,  2.12s/batch, batch_idx=54, gpu=0, loss=0.106, v_num=3drc8ka5]
# Epoch 18:  58%|█████▊    | 62/107 [01:14<02:08,  2.85s/batch, batch_idx=54, gpu=0, loss=0.106, v_num=3drc8ka5]
# Epoch 18:  59%|█████▉    | 63/107 [01:15<01:41,  2.32s/batch, batch_idx=54, gpu=0, loss=0.106, v_num=3drc8ka5]
# Epoch 18:  60%|█████▉    | 64/107 [01:17<01:32,  2.15s/batch, batch_idx=54, gpu=0, loss=0.106, v_num=3drc8ka5]
# Epoch 18:  61%|██████    | 65/107 [01:18<01:19,  1.90s/batch, batch_idx=54, gpu=0, loss=0.106, v_num=3drc8ka5]
# Epoch 18:  62%|██████▏   | 66/107 [01:20<01:19,  1.93s/batch, batch_idx=54, gpu=0, loss=0.106, v_num=3drc8ka5]
# Epoch 18:  63%|██████▎   | 67/107 [01:22<01:11,  1.79s/batch, batch_idx=54, gpu=0, loss=0.106, v_num=3drc8ka5]
# Epoch 18:  64%|██████▎   | 68/107 [01:23<01:03,  1.63s/batch, batch_idx=54, gpu=0, loss=0.106, v_num=3drc8ka5]
# Epoch 18:  64%|██████▍   | 69/107 [01:25<01:08,  1.79s/batch, batch_idx=54, gpu=0, loss=0.106, v_num=3drc8ka5]
# Epoch 18:  65%|██████▌   | 70/107 [01:27<01:01,  1.67s/batch, batch_idx=54, gpu=0, loss=0.106, v_num=3drc8ka5]
# Epoch 18:  66%|██████▋   | 71/107 [01:29<01:10,  1.95s/batch, batch_idx=54, gpu=0, loss=0.106, v_num=3drc8ka5]
# Epoch 18:  67%|██████▋   | 72/107 [01:31<01:07,  1.92s/batch, batch_idx=54, gpu=0, loss=0.106, v_num=3drc8ka5]
# Epoch 18:  68%|██████▊   | 73/107 [01:32<00:52,  1.56s/batch, batch_idx=54, gpu=0, loss=0.106, v_num=3drc8ka5]
# Epoch 18:  69%|██████▉   | 74/107 [01:34<00:52,  1.60s/batch, batch_idx=54, gpu=0, loss=0.106, v_num=3drc8ka5]
# Epoch 18:  70%|███████   | 75/107 [01:35<00:45,  1.42s/batch, batch_idx=54, gpu=0, loss=0.106, v_num=3drc8ka5]
# Epoch 18:  71%|███████   | 76/107 [01:48<02:33,  4.96s/batch, batch_idx=54, gpu=0, loss=0.106, v_num=3drc8ka5]
# Epoch 18:  72%|███████▏  | 77/107 [01:49<01:55,  3.85s/batch, batch_idx=54, gpu=0, loss=0.106, v_num=3drc8ka5]
# Epoch 18:  73%|███████▎  | 78/107 [01:52<01:42,  3.53s/batch, batch_idx=54, gpu=0, loss=0.106, v_num=3drc8ka5]
# Epoch 18:  74%|███████▍  | 79/107 [01:53<01:16,  2.75s/batch, batch_idx=54, gpu=0, loss=0.106, v_num=3drc8ka5]
# Epoch 18:  75%|███████▍  | 80/107 [01:54<01:03,  2.36s/batch, batch_idx=54, gpu=0, loss=0.106, v_num=3drc8ka5]
# Epoch 18:  76%|███████▌  | 81/107 [01:55<00:47,  1.84s/batch, batch_idx=54, gpu=0, loss=0.106, v_num=3drc8ka5]
# Epoch 18:  77%|███████▋  | 82/107 [01:56<00:38,  1.56s/batch, batch_idx=54, gpu=0, loss=0.106, v_num=3drc8ka5]
# Epoch 18:  78%|███████▊  | 83/107 [01:57<00:36,  1.51s/batch, batch_idx=54, gpu=0, loss=0.106, v_num=3drc8ka5]
# Epoch 18:  79%|███████▊  | 84/107 [01:58<00:29,  1.30s/batch, batch_idx=54, gpu=0, loss=0.106, v_num=3drc8ka5]
# Epoch 18:  79%|███████▉  | 85/107 [01:59<00:26,  1.19s/batch, batch_idx=54, gpu=0, loss=0.106, v_num=3drc8ka5]
# Epoch 18:  80%|████████  | 86/107 [02:00<00:24,  1.17s/batch, batch_idx=54, gpu=0, loss=0.106, v_num=3drc8ka5]
# Epoch 18:  81%|████████▏ | 87/107 [02:01<00:21,  1.10s/batch, batch_idx=54, gpu=0, loss=0.106, v_num=3drc8ka5]
# Epoch 18:  82%|████████▏ | 88/107 [02:02<00:19,  1.02s/batch, batch_idx=54, gpu=0, loss=0.106, v_num=3drc8ka5]
# Epoch 18:  83%|████████▎ | 89/107 [02:03<00:19,  1.08s/batch, batch_idx=54, gpu=0, loss=0.106, v_num=3drc8ka5]
# Epoch 18:  84%|████████▍ | 90/107 [02:05<00:22,  1.30s/batch, batch_idx=54, gpu=0, loss=0.106, v_num=3drc8ka5]
# Epoch 18:  85%|████████▌ | 91/107 [02:06<00:18,  1.17s/batch, batch_idx=54, gpu=0, loss=0.106, v_num=3drc8ka5]
# Epoch 18:  86%|████████▌ | 92/107 [02:09<00:25,  1.67s/batch, batch_idx=54, gpu=0, loss=0.106, v_num=3drc8ka5]
# Epoch 18:  87%|████████▋ | 93/107 [02:09<00:20,  1.44s/batch, batch_idx=54, gpu=0, loss=0.106, v_num=3drc8ka5]
# Epoch 18:  88%|████████▊ | 94/107 [02:12<00:21,  1.69s/batch, batch_idx=54, gpu=0, loss=0.106, v_num=3drc8ka5]
# Epoch 18:  89%|████████▉ | 95/107 [02:19<00:40,  3.41s/batch, batch_idx=54, gpu=0, loss=0.106, v_num=3drc8ka5]
# Epoch 18:  90%|████████▉ | 96/107 [02:21<00:30,  2.81s/batch, batch_idx=54, gpu=0, loss=0.106, v_num=3drc8ka5]
# Epoch 18:  91%|█████████ | 97/107 [02:24<00:30,  3.01s/batch, batch_idx=54, gpu=0, loss=0.106, v_num=3drc8ka5]
# Epoch 18:  92%|█████████▏| 98/107 [02:25<00:21,  2.40s/batch, batch_idx=54, gpu=0, loss=0.106, v_num=3drc8ka5]
# Epoch 18:  93%|█████████▎| 99/107 [02:26<00:16,  2.00s/batch, batch_idx=54, gpu=0, loss=0.106, v_num=3drc8ka5]
# Epoch 18:  93%|█████████▎| 100/107 [02:27<00:11,  1.64s/batch, batch_idx=54, gpu=0, loss=0.106, v_num=3drc8ka5]
# Epoch 18:  94%|█████████▍| 101/107 [02:28<00:08,  1.38s/batch, batch_idx=54, gpu=0, loss=0.106, v_num=3drc8ka5]Traceback (most recent call last):
#   File "/home/tshimko/.virtualenvs/tesselate/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-7-3fb5b484c4ec>", line 18, in <module>
#     trainer.fit(model)
#   File "/home/tshimko/.virtualenvs/tesselate/lib/python3.6/site-packages/pytorch_lightning/trainer/trainer.py", line 695, in fit
#     self.single_gpu_train(model)
#   File "/home/tshimko/.virtualenvs/tesselate/lib/python3.6/site-packages/pytorch_lightning/trainer/distrib_parts.py", line 441, in single_gpu_train
#     self.run_pretrain_routine(model)
#   File "/home/tshimko/.virtualenvs/tesselate/lib/python3.6/site-packages/pytorch_lightning/trainer/trainer.py", line 829, in run_pretrain_routine
#     self.train()
#   File "/home/tshimko/.virtualenvs/tesselate/lib/python3.6/site-packages/pytorch_lightning/trainer/training_loop.py", line 332, in train
#     self.run_training_epoch()
#   File "/home/tshimko/.virtualenvs/tesselate/lib/python3.6/site-packages/pytorch_lightning/trainer/training_loop.py", line 402, in run_training_epoch
#     self.run_evaluation(test=self.testing)
#   File "/home/tshimko/.virtualenvs/tesselate/lib/python3.6/site-packages/pytorch_lightning/trainer/evaluation_loop.py", line 305, in run_evaluation
#     test)
#   File "/home/tshimko/.virtualenvs/tesselate/lib/python3.6/site-packages/pytorch_lightning/trainer/evaluation_loop.py", line 234, in evaluate
#     test)
#   File "/home/tshimko/.virtualenvs/tesselate/lib/python3.6/site-packages/pytorch_lightning/trainer/evaluation_loop.py", line 365, in evaluation_forward
#     output = model.validation_step(*args)
#   File "<ipython-input-4-8c0709a507f1>", line 149, in validation_step
#     y_hat = self.forward(batch).squeeze()
#   File "<ipython-input-4-8c0709a507f1>", line 103, in forward
#     pairwise = pairwise_mat(x_position, method='sum').matmul(x_position)
#   File "<ipython-input-3-1238227ed3eb>", line 30, in pairwise_mat
#     combos = torch.zeros([idxs.shape[0], nodes.shape[0]]).scatter(1, idxs, 1)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/tshimko/.virtualenvs/tesselate/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/tshimko/.virtualenvs/tesselate/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1151, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/tshimko/.virtualenvs/tesselate/lib/python3.6/site-packages/IPython/core/ultratb.py", line 319, in wrapped
#     return f(*args, **kwargs)
#   File "/home/tshimko/.virtualenvs/tesselate/lib/python3.6/site-packages/IPython/core/ultratb.py", line 353, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.6/inspect.py", line 1490, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.6/inspect.py", line 1448, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/usr/lib/python3.6/inspect.py", line 742, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "/home/tshimko/.virtualenvs/tesselate/lib/python3.6/posixpath.py", line 395, in realpath
#     path, ok = _joinrealpath(filename[:0], filename, {})
#   File "/home/tshimko/.virtualenvs/tesselate/lib/python3.6/posixpath.py", line 429, in _joinrealpath
#     if not islink(newpath):
#   File "/home/tshimko/.virtualenvs/tesselate/lib/python3.6/posixpath.py", line 171, in islink
#     st = os.lstat(path)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# Error in callback <function _init_jupyter.<locals>.cleanup at 0x7f36d0216048> (for post_run_cell):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/.virtualenvs/tesselate/lib/python3.6/site-packages/backcall/backcall.py in adapted(*args, **kwargs)
#     102                 kwargs.pop(name)
#     103 #            print(args, kwargs, unmatched_pos, cut_positional, unmatched_kw)
# --> 104             return callback(*args, **kwargs)
#     105
#     106         return adapted
#
# ~/.virtualenvs/tesselate/lib/python3.6/site-packages/wandb/__init__.py in cleanup()
#     480         # shutdown async logger because _user_process_finished isn't called in jupyter
#     481         shutdown_async_log_thread()
# --> 482         run._stop_jupyter_agent()
#     483     ipython.events.register('post_run_cell', cleanup)
#     484
#
# ~/.virtualenvs/tesselate/lib/python3.6/site-packages/wandb/wandb_run.py in _stop_jupyter_agent(self)
#     180
#     181     def _stop_jupyter_agent(self):
# --> 182         self._jupyter_agent.stop()
#     183
#     184     def send_message(self, options):
#
# ~/.virtualenvs/tesselate/lib/python3.6/site-packages/wandb/jupyter.py in stop(self)
#     134         if not self.paused:
#     135             self.rm.unmirror_stdout_stderr()
# --> 136             self.rm.shutdown()
#     137             wandb.run.close_files()
#     138             self.paused = True
#
# ~/.virtualenvs/tesselate/lib/python3.6/site-packages/wandb/run_manager.py in shutdown(self, exitcode)
#    1058         logger.info("shutting down system stats and metadata service")
#    1059         self._system_stats.shutdown()
# -> 1060         self._meta.shutdown()
#    1061         for watcher in self._tensorboard_watchers:
#    1062             watcher.shutdown()
#
# ~/.virtualenvs/tesselate/lib/python3.6/site-packages/wandb/meta.py in shutdown(self)
#     170         self._shutdown = True
#     171         try:
# --> 172             self._thread.join()
#     173         # Incase we never start it
#     174         except RuntimeError:
#
# /usr/lib/python3.6/threading.py in join(self, timeout)
#    1054
#    1055         if timeout is None:
# -> 1056             self._wait_for_tstate_lock()
#    1057         else:
#    1058             # the behavior of a negative timeout isn't documented, but
#
# /usr/lib/python3.6/threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1070         if lock is None:  # already determined that the C code is done
#    1071             assert self._is_stopped
# -> 1072         elif lock.acquire(block, timeout):
#    1073             lock.release()
#    1074             self._stop()
#
# KeyboardInterrupt:
# Error in callback <function _init_jupyter.<locals>.cleanup at 0x7f36d0216048> (for post_run_cell):
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/.virtualenvs/tesselate/lib/python3.6/site-packages/backcall/backcall.py in adapted(*args, **kwargs)
#     102                 kwargs.pop(name)
#     103 #            print(args, kwargs, unmatched_pos, cut_positional, unmatched_kw)
# --> 104             return callback(*args, **kwargs)
#     105
#     106         return adapted
#
# ~/.virtualenvs/tesselate/lib/python3.6/site-packages/wandb/__init__.py in cleanup()
#     480         # shutdown async logger because _user_process_finished isn't called in jupyter
#     481         shutdown_async_log_thread()
# --> 482         run._stop_jupyter_agent()
#     483     ipython.events.register('post_run_cell', cleanup)
#     484
#
# ~/.virtualenvs/tesselate/lib/python3.6/site-packages/wandb/wandb_run.py in _stop_jupyter_agent(self)
#     180
#     181     def _stop_jupyter_agent(self):
# --> 182         self._jupyter_agent.stop()
#     183
#     184     def send_message(self, options):
#
# ~/.virtualenvs/tesselate/lib/python3.6/site-packages/wandb/jupyter.py in stop(self)
#     133     def stop(self):
#     134         if not self.paused:
# --> 135             self.rm.unmirror_stdout_stderr()
#     136             self.rm.shutdown()
#     137             wandb.run.close_files()
#
# ~/.virtualenvs/tesselate/lib/python3.6/site-packages/wandb/run_manager.py in unmirror_stdout_stderr(self)
#     784         if hasattr(sys.stdout, "orig_write"):
#     785             sys.stdout.write = sys.stdout.orig_write
# --> 786             sys.stderr.write = sys.stderr.orig_write
#     787
#     788     def _get_stdout_stderr_streams(self):
#
# AttributeError: 'OutStream' object has no attribute 'orig_write'

# %% [markdown]
# # Analysis

# %%
from torch.utils.data import DataLoader

data_base = '/home/tshimko/tesselate/'

data_load = [
                'pdb_id',
#                 'model',
                'atom_nodes',
                'atom_adj',
#                 'atom_contact',
#                 'atom_mask',
                'res_adj',
                'res_dist',
                'chain_mem',
                'res_contact',
                'conn_adj',
                'res_mask',
                'mem_mat',
#                 'idx2atom_dict',
#                 'idx2res_dict'
            ]

train_data = TesselateDataset(data_base + 'test4.txt',
                              graph_dir=data_base + 'data/graphs',
                              contacts_dir=data_base + 'data/contacts',
                              return_data=data_load, in_memory=True)


for idx, i in enumerate(DataLoader(train_data, shuffle=False, num_workers=30, pin_memory=True)):
    print(idx, i['pdb_id'])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-3377bef9d3dd> in <module>
#      27
#      28
# ---> 29 for idx, i in enumerate(DataLoader(train_data, shuffle=False, num_workers=30, pin_memory=True)):
#      30     print(idx, i['pdb_id'])
#
# ~/.virtualenvs/tesselate/lib/python3.6/site-packages/torch/utils/data/dataloader.py in __iter__(self)
#     277             return _SingleProcessDataLoaderIter(self)
#     278         else:
# --> 279             return _MultiProcessingDataLoaderIter(self)
#     280
#     281     @property
#
# ~/.virtualenvs/tesselate/lib/python3.6/site-packages/torch/utils/data/dataloader.py in __init__(self, loader)
#     717             #     before it starts, and __del__ tries to join but will get:
#     718             #     AssertionError: can only join a started process.
# --> 719             w.start()
#     720             self._index_queues.append(index_queue)
#     721             self._workers.append(w)
#
# /usr/lib/python3.6/multiprocessing/process.py in start(self)
#     103                'daemonic processes are not allowed to have children'
#     104         _cleanup()
# --> 105         self._popen = self._Popen(self)
#     106         self._sentinel = self._popen.sentinel
#     107         # Avoid a refcycle if the target function holds an indirect
#
# /usr/lib/python3.6/multiprocessing/context.py in _Popen(process_obj)
#     221     @staticmethod
#     222     def _Popen(process_obj):
# --> 223         return _default_context.get_context().Process._Popen(process_obj)
#     224
#     225 class DefaultContext(BaseContext):
#
# /usr/lib/python3.6/multiprocessing/context.py in _Popen(process_obj)
#     275         def _Popen(process_obj):
#     276             from .popen_fork import Popen
# --> 277             return Popen(process_obj)
#     278
#     279     class SpawnProcess(process.BaseProcess):
#
# /usr/lib/python3.6/multiprocessing/popen_fork.py in __init__(self, process_obj)
#      17         util._flush_std_streams()
#      18         self.returncode = None
# ---> 19         self._launch(process_obj)
#      20
#      21     def duplicate_for_child(self, fd):
#
# /usr/lib/python3.6/multiprocessing/popen_fork.py in _launch(self, process_obj)
#      64         code = 1
#      65         parent_r, child_w = os.pipe()
# ---> 66         self.pid = os.fork()
#      67         if self.pid == 0:
#      68             try:
#
# KeyboardInterrupt:
# Error in callback <function _init_jupyter.<locals>.cleanup at 0x7f36d0216048> (for post_run_cell):
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/.virtualenvs/tesselate/lib/python3.6/site-packages/backcall/backcall.py in adapted(*args, **kwargs)
#     102                 kwargs.pop(name)
#     103 #            print(args, kwargs, unmatched_pos, cut_positional, unmatched_kw)
# --> 104             return callback(*args, **kwargs)
#     105
#     106         return adapted
#
# ~/.virtualenvs/tesselate/lib/python3.6/site-packages/wandb/__init__.py in cleanup()
#     480         # shutdown async logger because _user_process_finished isn't called in jupyter
#     481         shutdown_async_log_thread()
# --> 482         run._stop_jupyter_agent()
#     483     ipython.events.register('post_run_cell', cleanup)
#     484
#
# ~/.virtualenvs/tesselate/lib/python3.6/site-packages/wandb/wandb_run.py in _stop_jupyter_agent(self)
#     180
#     181     def _stop_jupyter_agent(self):
# --> 182         self._jupyter_agent.stop()
#     183
#     184     def send_message(self, options):
#
# ~/.virtualenvs/tesselate/lib/python3.6/site-packages/wandb/jupyter.py in stop(self)
#     133     def stop(self):
#     134         if not self.paused:
# --> 135             self.rm.unmirror_stdout_stderr()
#     136             self.rm.shutdown()
#     137             wandb.run.close_files()
#
# ~/.virtualenvs/tesselate/lib/python3.6/site-packages/wandb/run_manager.py in unmirror_stdout_stderr(self)
#     784         if hasattr(sys.stdout, "orig_write"):
#     785             sys.stdout.write = sys.stdout.orig_write
# --> 786             sys.stderr.write = sys.stderr.orig_write
#     787
#     788     def _get_stdout_stderr_streams(self):
#
# AttributeError: 'OutStream' object has no attribute 'orig_write'

# %%
train_data.accessions
