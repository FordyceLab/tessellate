# %% [markdown]
# # Benchmark position-aware graph neural network/2D CNN architecture
#
# This notebook contains all of the code to overfit a GAT to four contact channels of a single structure (6E6O).
#
# ## Setup

# %% [markdown]
# ### Dataloader code

# %%
import torch
from torch.utils.data import Dataset
import numpy as np
import periodictable as pt
import pandas as pd
import os
import matplotlib.pyplot as plt
import networkx as nx
import itertools as it


def read_files(acc, model, graph_dir, contacts_dir):
    """
    Read graph and contacts files.

    Args:
    - acc (str) - String of the PDB ID (lowercese).
    - model (int) - Model number of the desired bioassembly.
    - graph_dir (str) - Directory containing the nodes, edges,
        and mask files.
    - contacts_dir (str) - Directory containing the .contacts
        files from get_contacts.py.

    Returns:
    - Dictionary of DataFrames and lists corresponding to
        graph nodes, edges, mask, and contacts.
    """

    # Get the file names for the graph files
    node_file = os.path.join(graph_dir, '{}-{}_nodes.csv'.format(acc, model))
    edge_file = os.path.join(graph_dir, '{}-{}_edges.csv'.format(acc, model))
    mask_file = os.path.join(graph_dir, '{}-{}_mask.csv'.format(acc, model))

    # Get the contacts file
    contacts_file = os.path.join(contacts_dir, '{}-{}.contacts'.format(acc, model))

    # Read the nodes and edges
    nodes = pd.read_csv(node_file)
    edges = pd.read_csv(edge_file)

    # Check if the mask is empty
    if os.path.getsize(mask_file) > 0:
        with open(mask_file) as f:
            mask = f.read().split('\n')
    else:
        mask = []

    # Read the contacts
    contacts = pd.read_table(contacts_file, sep='\t',
                             header=None, names=['type', 'start', 'end'])

    # Return the data
    data = {
        'nodes': nodes,
        'edges': edges,
        'mask': mask,
        'contacts': contacts
    }

    return data


def process_res_data(data):
    """
    Process residue-level data from atom-level data.

    Args:
    - data (dict) - Dictionary of graph data output from `read_files`.

    Returns:
    - Dictionary of atom and residue graph and contact data.
    """

    # Extract data form dict
    nodes = data['nodes']
    edges = data['edges']
    mask = data['mask']
    contacts = data['contacts']

    # Get residue nodes
    res_nodes = pd.DataFrame()
    res_nodes['res'] = [':'.join(atom.split(':')[:3]) for atom in nodes['atom']]
    res_nodes = res_nodes.drop_duplicates().reset_index(drop=True)

    # Get residue edges
    res_edges = edges.copy()
    res_edges['start'] = [':'.join(atom.split(':')[:3]) for atom in res_edges['start']]
    res_edges['end'] = [':'.join(atom.split(':')[:3]) for atom in res_edges['end']]
    res_edges = res_edges[res_edges['start'] != res_edges['end']].drop_duplicates().reset_index(drop=True)

    # Get residue contacts
    res_contacts = contacts.copy()
    res_contacts['start'] = [':'.join(atom.split(':')[:3]) for atom in res_contacts['start']]
    res_contacts['end'] = [':'.join(atom.split(':')[:3]) for atom in res_contacts['end']]
    res_contacts = res_contacts[res_contacts['start'] != res_contacts['end']].drop_duplicates().reset_index(drop=True)

    # Get residue mask
    res_mask = list(set([':'.join(atom.split(':')[:3]) for atom in mask]))

    # Return data dict
    data = {
        'atom_nodes': nodes,
        'atom_edges': edges,
        'atom_contact': contacts,
        'atom_mask': mask,
        'res_nodes': res_nodes,
        'res_edges': res_edges,
        'res_contact': res_contacts,
        'res_mask': res_mask
    }

    return data


def get_map_dicts(entity_list):
    """
    Map identifiers to indices and vice versa.

    Args:
    - entity_list (list) - List of entities (atoms, residues, etc.)
        to index.

    Returns:
    - Tuple of the entity to index and index to entity dicts, respectively.
    """

    # Create the entity:index dictionary
    ent2idx_dict = {entity: idx for idx, entity in enumerate(entity_list)}

    # Create the index:entity dictionary
    idx2ent_dict = {idx: entity for entity, idx in ent2idx_dict.items()}

    return (ent2idx_dict, idx2ent_dict)


def create_adj_mat(data, dict_map, mat_type):
    """
    Creates an adjacency matrix.

    Args:
    - data (DataFrame) - Dataframe with 'start' and 'end' column
        for each interaction. For atom-level adjacency, 'order'
        column is also required. For atom or residue conatcts,
        'type' column is also required.

    Returns:
    - Coordinate format matrix (numpy). For atom adjacency, third column
        corresponds to bond order. For contacts, third column
        corresponds to channel.

    Channel mappings (shorthand from get_contacts.py source):

        0:
            hp             hydrophobic interactions
        1:
            hb             hydrogen bonds
            lhb            ligand hydrogen bonds
            hbbb           backbone-backbone hydrogen bonds
            hbsb           backbone-sidechain hydrogen bonds
            hbss           sidechain-sidechain hydrogen bonds
            hbls           ligand-sidechain residue hydrogen bonds
            hblb           ligand-backbone residue hydrogen bonds
        2:
            vdw            van der Waals
        3:
            wb             water bridges
            wb2            extended water bridges
            lwb            ligand water bridges
            lwb2           extended ligand water bridges
        4:
            sb             salt bridges
        5:
            ps             pi-stacking
        6:
            pc             pi-cation
        7:
            ts             t-stacking
    """

    # Initialize the coordinate list
    coord_mat = []

    # Map channel names to numeric channels
    channel = {
        # Hydrophobic interactions in first channel
        'hp': 0,
        'hplp': 0,
        'hpll': 0,

        # Hydrogen bonds in second channel
        'hb': 1,
        'lhb': 1,
        'hbbb': 1,
        'hbsb': 1,
        'hbss': 1,
        'hbls': 1,
        'hblb': 1,

        # VdW in third channel
        'vdw': 2,

        # Water bridges
        'wb': 3,
        'wb2': 3,
        'lwb': 3,
        'lwb2': 3,

        # Salt bridges
        'sb': 4,
        'sbpl': 4,
        'sbll': 4,

        # Other interactions
        'ps': 5,
        'pc': 6,
        'ts': 7,
    }

    # Assemble the contacts
    for idx, row in data.iterrows():

        if row['start'] in dict_map and row['end'] in dict_map:

            entry = [dict_map[row['start']], dict_map[row['end']]]

            # Add order or type if necessary
            if mat_type == 'atom_graph':
                entry.append(row['order'])
            elif mat_type == 'atom_contact':
                entry.append(channel[row['type']])
            elif mat_type == 'res_contact':
                entry.append(channel[row['type']])

            coord_mat.append(entry)

    return np.array(coord_mat)


def create_conn_adj_mat(adj):
    """
    Create connection adjacency matrix
    """

    conn_map = {(a, b): idx for idx, (a, b) in enumerate(zip(*np.triu_indices_from(adj)))}

    one_hop_neighbors = {idx: np.argwhere(row > 0).squeeze().tolist() for idx, row in enumerate(adj)}

    conns = []

    for i, j in it.combinations_with_replacement(one_hop_neighbors, 2):
        row = conn_map[(i, j)]
        adj_conn_coords = set([(m, n) if m <= n else (n, m)
                               for m, n in it.product(one_hop_neighbors[i],
                                                      one_hop_neighbors[j])])
        adj_conns = [conn_map[x] for x in adj_conn_coords]

        conns.append(np.array(list(it.product([row], adj_conns))))

    conn_adj = np.concatenate(conns, axis=0).T

    return conn_adj


def create_mem_mat(atom_dict, res_dict):
    """
    Create a membership matrix mapping atoms to residues.

    Args:
    - atom_dict (dict) - Dictionary mapping atoms to indices.
    - res_dict (dict) - Dictionary mapping residues to indices.

    Returns:
    - Coordinate format membership matrix (numpy) with first
        row being residue number and the second column being
        atom number.
    """

    # Initialize the coordinate list
    mem_coord = []

    # Map atoms to residues
    for atom, atom_idx in atom_dict.items():
        res_idx = res_dict[':'.join(atom.split(':')[:3])]

        mem_coord.append([res_idx, atom_idx])

    mem_coord = np.array(mem_coord)

    return mem_coord


def create_idx_list(id_list, dict_map):
    """
    Create list of indices.

    Args:
    - id_list (list) - List of masked atom or residue identifiers.
    - dict_map (dict) - Dictionary mapping entities to indices.

    Returns:
    - A numpy array of the masked indices.
    """

    # Generate the numpy index array
    idx_array = np.array([dict_map[iden] for iden in id_list])

    return idx_array


class TesselateDataset(Dataset):
    """
    Dataset class for structural data.

    Args:
    - accession_list (str) - File path from which to read PDB IDs for dataset.
    - graph_dir (str) - Directory containing the nodes, edges, and mask files.
    - contacts_dir (str) - Directory containing the .contacts files from
        get_contacts.py.
    - return_data (list) - List of datasets to return. Value must be 'all' or
        a subset of the following list:
            - pdb_id
            - model
            - atom_nodes
            - atom_adj
            - atom_contact
            - atom_mask
            - res_adj
            - res_dist
            - res_contact
            - res_mask
            - mem_mat
            - idx2atom_dict
            - idx2res_dict
    """

    def __init__(self, accession_list, graph_dir, contacts_dir, add_covalent=False, return_data='all', in_memory=False):

        if return_data == 'all':
            self.return_data = [
                'pdb_id',
                'model',
                'atom_nodes',
                'atom_adj',
                'atom_contact',
                'atom_mask',
                'res_adj',
                'res_dist',
                'conn_adj',
                'res_contact',
                'res_mask',
                'mem_mat',
                'idx2atom_dict',
                'idx2res_dict'
            ]

        else:
            self.return_data = return_data

        # Store reference to accession list file
        self.accession_list = accession_list

        # Store references to the necessary directories
        self.graph_dir = graph_dir
        self.contacts_dir = contacts_dir

        # Whether to add covalent bonds to prediction task and
        # remove sequence non-deterministic covalent bonds from the adjacency matrix
        self.add_covalent=add_covalent

        # Read in and store a list of accession IDs
        with open(accession_list, 'r') as handle:
            self.accessions = np.array([acc.strip().lower().split() for acc in handle.readlines()])

        self.data = {}


    def __len__(self):
        """
        Return the length of the dataset.

        Returns:
        - Integer count of number of examples.
        """
        return len(self.accessions)


    def __getitem__(self, idx):
        """
        Get an item with a particular index value.

        Args:
        - idx (int) - Index of desired sample.

        Returns:
        - Dictionary of dataset example. All tensors are sparse when possible.
        """

        try:
            if idx in self.data:
                return self.data[idx]

            # initialize the return dictionary
            return_dict = {}

            acc_entry = self.accessions[idx]

            # Get the PDB ID
            acc = acc_entry[0]

            # Get the model number if one exists
            if len(acc_entry) == 1:
                model = 1
            else:
                model = acc_entry[1]

            # Read and process the files
            data = read_files(acc, model, self.graph_dir, self.contacts_dir)
            data = process_res_data(data)

            # Generate the mapping dictionaries
            atom2idx_dict, idx2atom_dict = get_map_dicts(data['atom_nodes']['atom'].unique())
            res2idx_dict, idx2res_dict = get_map_dicts(data['res_nodes']['res'].unique())

            # Get numbers of atoms and residues per sample
            n_atoms = len(atom2idx_dict)
            n_res = len(res2idx_dict)

            # Handle all of the possible returned datasets
            if 'pdb_id' in self.return_data:
                return_dict['pdb_id'] = acc

            if 'model' in self.return_data:
                return_dict['model'] = model

            if 'atom_nodes' in self.return_data:
                ele_nums = [pt.elements.symbol(element).number for element in data['atom_nodes']['element']]
                return_dict['atom_nodes'] = torch.LongTensor(ele_nums)
                assert not torch.isnan(return_dict['atom_nodes']).any()

            if 'atom_adj' in self.return_data:

                adj = create_adj_mat(data['atom_edges'], atom2idx_dict, mat_type='atom_graph').T

                x = torch.LongTensor(adj[0, :]).squeeze()
                y = torch.LongTensor(adj[1, :]).squeeze()
                val = torch.FloatTensor(adj[2, :]).squeeze()

                atom_adj = torch.zeros([n_atoms, n_atoms]).index_put_((x, y), val, accumulate=False)

                atom_adj = atom_adj.index_put_((y, x), val, accumulate=False)

                atom_adj[range(n_atoms), range(n_atoms)] = 1

                atom_adj = (atom_adj > 0).float()

                return_dict['atom_adj'] = atom_adj

                assert not torch.isnan(return_dict['atom_adj']).any()

            if 'atom_contact' in self.return_data:
                atom_contact = create_adj_mat(data['atom_contact'], atom2idx_dict, mat_type='atom_contact').T

                x = torch.LongTensor(atom_contact[0, :]).squeeze()
                y = torch.LongTensor(atom_contact[1, :]).squeeze()
                z = torch.LongTensor(atom_contact[2, :]).squeeze()

                atom_contact = torch.zeros([n_atoms, n_atoms, 8]).index_put_((x, y, z),
                                                                        torch.ones(len(x)))
                atom_contact = atom_contact.index_put_((y, x, z),
                                                       torch.ones(len(x)))

                return_dict['atom_contact'] = atom_contact

                assert not torch.isnan(return_dict['atom_contact']).any()

            if 'atom_mask' in self.return_data:
                atom_mask = create_idx_list(data['atom_mask'], atom2idx_dict)

                masked_pos = torch.from_numpy(atom_mask)

                if self.add_covalent:
                    channels = 9
                else:
                    channels = 8

                mask = torch.ones([n_atoms, n_atoms, channels])

                if len(masked_pos) > 0:
                    mask[masked_pos, :, :] = 0
                    mask[:, masked_pos, :] = 0

                return_dict['atom_mask'] = mask

                assert not torch.isnan(return_dict['atom_mask']).any()

            if 'res_adj' in self.return_data:
                adj = create_adj_mat(data['res_edges'], res2idx_dict, mat_type='res_graph').T

                x = torch.LongTensor(adj[0, :]).squeeze()
                y = torch.LongTensor(adj[1, :]).squeeze()

                res_adj = torch.zeros([n_res, n_res]).index_put_((x, y), torch.ones(len(x)))

                res_adj = res_adj.index_put_((y, x), torch.ones(len(x)))

                res_adj[range(n_res), range(n_res)] = 1

                return_dict['res_adj'] = res_adj

                assert not torch.isnan(return_dict['res_adj']).any()

                if 'res_dist' in self.return_data:
                    G = nx.from_numpy_matrix(return_dict['res_adj'].numpy())
                    res_dist = torch.from_numpy(nx.floyd_warshall_numpy(G)).float()

                    res_dist[torch.isinf(res_dist)] = -1

                    return_dict['res_dist'] = res_dist

                    chain_mem = torch.zeros(res_dist.shape)
                    chain_mem[~torch.isinf(return_dict['res_dist'])] = 1

                    return_dict['chain_mem'] = chain_mem

                    assert not torch.isnan(return_dict['res_dist']).any()
                    assert not torch.isinf(return_dict['res_dist']).any()
                    assert not torch.isnan(return_dict['chain_mem']).any()
                    assert not torch.isinf(return_dict['chain_mem']).any()

                if 'conn_adj' in self.return_data:

                    conn_adj = create_conn_adj_mat(return_dict['res_adj'].numpy())

                    return_dict['conn_adj'] = torch.from_numpy(conn_adj)

            if 'res_contact' in self.return_data:
                res_contact = create_adj_mat(data['res_contact'], res2idx_dict, mat_type='res_contact').T

                x = torch.LongTensor(res_contact[0, :]).squeeze()
                y = torch.LongTensor(res_contact[1, :]).squeeze()
                z = torch.LongTensor(res_contact[2, :]).squeeze()

                res_contact = torch.zeros([n_res, n_res, 8]).index_put_((x, y, z),
                                                                        torch.ones(len(x)))

                res_contact = res_contact.index_put_((y, x, z),
                                                     torch.ones(len(x)))

                return_dict['res_contact'] = res_contact

                assert not torch.isnan(return_dict['res_contact']).any()

            if 'res_mask' in self.return_data:
                res_mask = create_idx_list(data['res_mask'], res2idx_dict)

                masked_pos = torch.from_numpy(res_mask)

                if self.add_covalent:
                    channels = 9
                else:
                    channels = 8

                mask = torch.ones([n_res, n_res, channels])

                if len(masked_pos) > 0:
                    mask[masked_pos, :, :] = 0
                    mask[:, masked_pos, :] = 0

                return_dict['res_mask'] = mask

                assert not torch.isnan(return_dict['res_mask']).any()

            if 'mem_mat' in self.return_data:
                mem_mat = create_mem_mat(atom2idx_dict, res2idx_dict).T

                x = torch.LongTensor(mem_mat[0, :]).squeeze()
                y = torch.LongTensor(mem_mat[1, :]).squeeze()

                mem_mat = torch.zeros([n_res, n_atoms]).index_put_((x, y),
                                                                   torch.ones(len(x)))

                return_dict['mem_mat'] = mem_mat

                assert not torch.isnan(return_dict['mem_mat']).any()

            if 'idx2atom_dict' in self.return_data:
                return_dict['idx2atom_dict'] = idx2atom_dict

            if 'idx2res_dict' in self.return_data:
                return_dict['idx2res_dict'] = idx2res_dict

            self.data[idx] = return_dict

            # Return the processed data
            return return_dict

        except Exception as e:
            print("Error:", acc, str(e))
            raise e
            return np.array([0])

# %% [markdown]
# ### Modules

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import itertools as it
from torch_scatter import scatter_softmax


####################
# Embedding layers #
####################

class AtomEmbed(nn.Module):
    """
    Embed the atoms to fixed-length input vectors.

    Args:
    - num_features (int) - Size of the returned embedding vectors.
    - scale_grad_by_freq (bool) - Scale gradients by the inverse of
        frequency (default=True).
    """

    def __init__(self, n_features, scale_grad_by_freq=True):
        super(AtomEmbed, self).__init__()
        self.embedding = nn.Embedding(118,
                                      n_features,
                                      scale_grad_by_freq=scale_grad_by_freq)

    def forward(self, atomic_numbers):
        """
        Return the embeddings for each atom in the graph.

        Args:
        - atoms (torch.LongTensor) - Tensor (n_atoms) containing atomic numbers.

        Returns:
        - torch.FloatTensor of dimension (n_atoms, n_features) containing
            the embedding vectors.
        """

        # Get and return the embeddings for each atom
        embedded_atoms = self.embedding(atomic_numbers)
        return embedded_atoms


####################
# Attention layers #
####################

class SpecialSpmmFunction(torch.autograd.Function):
    """Special function for only sparse region backpropataion layer."""
    @staticmethod
    def forward(ctx, indices, values, shape, b):
        assert indices.requires_grad == False
        a = torch.sparse_coo_tensor(indices, values, shape)
        ctx.save_for_backward(a, b)
        ctx.N = shape[0]
        return torch.matmul(a, b)

    @staticmethod
    def backward(ctx, grad_output):
        a, b = ctx.saved_tensors
        grad_values = grad_b = None
        if ctx.needs_input_grad[1]:
            grad_a_dense = grad_output.matmul(b.t())
            edge_idx = a._indices()[0, :] * ctx.N + a._indices()[1, :]
            grad_values = grad_a_dense.view(-1)[edge_idx]
        if ctx.needs_input_grad[3]:
            grad_b = a.t().matmul(grad_output)
        return None, grad_values, None, grad_b


class SpecialSpmm(nn.Module):
    def forward(self, indices, values, shape, b):
        return SpecialSpmmFunction.apply(indices, values, shape, b)


class GraphAttnLayer(nn.Module):
    """
    Sparse version GAT layer, similar to https://arxiv.org/abs/1710.10903
    """

    def __init__(self, in_features, out_features, dropout, alpha, concat=True):
        super(GraphAttnLayer, self).__init__()
        self.in_features = in_features
        self.out_features = out_features
        self.alpha = alpha
        self.concat = concat

        self.W = nn.Parameter(torch.zeros(size=(in_features, out_features)))
        nn.init.xavier_normal_(self.W.data, gain=1.414)

        self.a = nn.Parameter(torch.zeros(size=(1, 2*out_features)))
        nn.init.xavier_normal_(self.a.data, gain=1.414)

        self.dropout = nn.Dropout(dropout)
        self.leakyrelu = nn.LeakyReLU(self.alpha)
        self.special_spmm = SpecialSpmm()

    def forward(self, input, adj):
        dv = 'cuda' if input.is_cuda else 'cpu'

        N = input.size()[0]

        if adj.shape[0] == adj.shape[1]:
            edge = adj.nonzero().t()
        else:
            edge = adj

#         mask = adj.byte()

        h = torch.mm(input, self.W)
        # h: N x out
        assert not torch.isnan(h).any()

        # Self-attention on the nodes - Shared attention mechanism
        edge_h = torch.cat((h[edge[0, :], :], h[edge[1, :], :]), dim=1).t()
        # edge: 2*D x E

        values = self.leakyrelu(self.a.mm(edge_h).squeeze())

        edge_e = scatter_softmax(values, edge[0])
        assert not torch.isnan(edge_e).any()
        # edge_e: E

        edge_e = self.dropout(edge_e)
        # edge_e: E

        h_prime = self.special_spmm(edge, edge_e, torch.Size([N, N]), h)
        assert not torch.isnan(h_prime).any()
        # h_prime: N x out

        if self.concat:
            # if this layer is not last layer,
            return F.elu(h_prime)
        else:
            # if this layer is last layer,
            return h_prime

    def __repr__(self):
        return self.__class__.__name__ + ' (' + str(self.in_features) + ' -> ' + str(self.out_features) + ')'


class GraphAttn(nn.Module):

    def __init__(self, in_features, out_features, dropout, alpha, concat=True):
        super(GraphAttn, self).__init__()
        self.attn = GraphAttnLayer(in_features, out_features, dropout, alpha, concat)
        self.batch_norm = nn.BatchNorm1d(out_features)

    def forward(self, input, adj):

        out = self.attn(input, adj)
        out_norm = self.batch_norm(out)

        return out


class MultiHeadGraphAttn(nn.Module):
    """
    Multi-head graph attention layer.

    Args:
    - n_head (int) - Number of heads for the attention layer.
    - in_features (int) - Number of total input features.
    - out_features (int) - Number of output features per head.
    - dropout (bool) - P(keep) for dropout.
    - alpha (float) - Alpha value for leaky ReLU.
    """

    def __init__(self, n_heads, in_features, out_features, dropout, alpha):
        super(MultiHeadGraphAttn, self).__init__()

        # Parameters
        self.in_features = in_features
        self.out_features = out_features
        self.dropout = dropout
        self.alpha = alpha

        # Operations
        heads = [GraphAttn(in_features, out_features, dropout, alpha)
                 for i in range(n_heads)]
        self.attn_heads = nn.ModuleList(heads)

    def forward(self, nodes, adj, cat_dim=1):
        """
        Perform forward pass through multi-head graph attention layer.

        Args:
        - nodes (torch.FloatTensor) - Node feature matrix
            (n_nodes, in_features).
        - adj (torch.FloatTensor) - Adjacency matrix (n_nodes, n_nodes).

        Returns:
        - torch.FloatTensor of dimension (n_nodes, n_nodes) of attentional
            coefficients where a_ij is the attention value of for node j with
            respect to node i.
        """

        if cat_dim == 1:
            vals = torch.cat([head(nodes, adj) for head in self.attn_heads],
                         dim = 1)

        elif cat_dim == -1:
            vals = torch.stack([head(nodes, adj) for head in self.attn_heads])

        return vals


class FCContactPred(nn.Module):
    """
    Fully connected layer to perform contact prediction.

    Args:
    - node_features (int) - Number of input features.
    - out_features (int) - Number of output prediction values.
    """

    def __init__(self, node_features, out_preds, layers=3):
        super(FCContactPred, self).__init__()

        self.linear_first = nn.Linear(node_features, 25, bias=True)

        self.int_layers = nn.ModuleList([nn.Linear(25, 25, bias=True)
                                         for i in range(layers - 2)])

        self.linear_final = nn.Linear(25, out_preds, bias=True)

    def forward(self, combined_nodes):
        """
        Predict pointwise multichannel contacts from summarized pairwise
        residue features.

        Args:
        - nodes (torch.FloatTensor) - Tensor of (convolved) node features
            (n_pairwise, n_features).

        Returns:
        - torch.FloatTensor (n_contacts, n_channels) containing the prediction
            for every potential contact point and every contact channel.
        """
        # Get the logits from the linear layer
        prelogits = self.linear_first(combined_nodes)
        prelogits = F.relu(prelogits)

        for layer in self.int_layers:
            prelogits = layer(prelogits)
            prelogits = F.relu(prelogits)

        logits = self.linear_final(prelogits)

        return logits


class AttnLinkPredict(nn.Module):
    """
    Multi-head graph attention for link prediction.

    Args:
    - n_layers (int) - Number of layers.
    - n_head (int) - Number of heads for the attention layer.
    - in_features (int) - Number of total input features.
    - out_features (int) - Number of output features per head.
    - dropout (bool) - P(keep) for dropout.
    - alpha (float) - Alpha value for leaky ReLU.
    """

    def __init__(self, n_layers, n_heads, in_features, out_features, dropout, alpha):
        super(AttnLinkPredict, self).__init__()

        # Parameters
        self.in_features = in_features
        self.out_features = out_features
        self.dropout = dropout
        self.alpha = alpha

        layers = [MultiHeadGraphAttn(n_heads, in_features,
                                     out_features, dropout,
                                     alpha)]

        layers.extend([MultiHeadGraphAttn(n_heads, n_heads * out_features,
                                     out_features, dropout,
                                     alpha)
                      for i in range(n_layers - 1)])

        self.attn_layers = nn.ModuleList(layers)

        self.attn_batch_norm = nn.BatchNorm1d(n_heads * out_features)

        self.output_linear = nn.Linear(n_heads * out_features, 8)

    def forward(self, nodes, adjacency):

        outputs = []

        for target1, target2 in it.combinations_with_replacement(range(len(nodes)), 2):
            targets = adjacency[[target1, target2], :]

            where = [target1, target2]
            where.extend([ind for ind in np.where(targets.cpu() > 0)[1] if ind not in where])

            out_adj_size = len(where) + 1
            adj = torch.zeros(out_adj_size, out_adj_size)
            adj[[0, 0, 1, 2], [1, 2, 0, 0]] = 1

            neighbors = adjacency[where][:, where]
            adj[1:, 1:] = neighbors

            node_feats = nodes[where]

            node_feats = torch.cat((torch.sum(node_feats[:2], dim=0, keepdim=True), node_feats), dim=0)

            for layer in self.attn_layers:
                node_feats = layer(node_feats, adj)

            outputs.append(node_feats[0, :].unsqueeze(0))

        linear_in = self.attn_batch_norm(torch.cat(outputs, dim=0))

        return self.output_linear(linear_in)


class LinkPredict(nn.Module):
    """
    Multi-head graph attention for link prediction.

    Args:
    - n_layers (int) - Number of layers.
    - n_head (int) - Number of heads for the attention layer.
    - in_features (int) - Number of total input features.
    - out_features (int) - Number of output features per head.
    - dropout (bool) - P(keep) for dropout.
    - alpha (float) - Alpha value for leaky ReLU.
    """

    def __init__(self, n_layers, n_heads, in_features, out_features, dropout, alpha):
        super(AttnLinkPredict, self).__init__()

        # Parameters
        self.in_features = in_features
        self.out_features = out_features
        self.dropout = dropout
        self.alpha = alpha

        layers = [MultiHeadGraphAttn(n_heads, in_features,
                                     out_features, dropout,
                                     alpha)]

        layers.extend([MultiHeadGraphAttn(n_heads, n_heads * out_features,
                                     out_features, dropout,
                                     alpha)
                      for i in range(n_layers - 1)])

        self.attn_layers = nn.ModuleList(layers)

        self.attn_batch_norm = nn.BatchNorm1d(n_heads * out_features)

        self.output_linear = nn.Linear(n_heads * out_features, 8)

    def forward(self, nodes, adjacency):

        outputs = []

        for target1, target2 in it.combinations_with_replacement(range(len(nodes)), 2):
            targets = adjacency[[target1, target2], :]

            where = [target1, target2]
            where.extend([ind for ind in np.where(targets.cpu() > 0)[1] if ind not in where])

            out_adj_size = len(where) + 1
            adj = torch.zeros(out_adj_size, out_adj_size)
            adj[[0, 0, 1, 2], [1, 2, 0, 0]] = 1

            neighbors = adjacency[where][:, where]
            adj[1:, 1:] = neighbors

            node_feats = nodes[where]

            node_feats = torch.cat((torch.sum(node_feats[:2], dim=0, keepdim=True), node_feats), dim=0)

            for layer in self.attn_layers:
                node_feats = layer(node_feats, adj)

            outputs.append(node_feats[0, :].unsqueeze(0))

        linear_in = self.attn_batch_norm(torch.cat(outputs, dim=0))

        return self.output_linear(linear_in)

# %% [markdown]
# # Functions

# %%
import numpy as np
import torch

########################################
# Pairwise matrix generation functions #
########################################

def pairwise_mat(nodes, method='mean'):
    """
    Generate matrix for pairwise determination of interactions.

    Args:
    - nodes (torch.FloatTensor) - Tensor of node (n_nodes, n_features) features.
    - method (str) - One of 'sum' or 'mean' for combination startegy for
        pairwise combination matrix (default = 'mean').

    Returns:
    - torch.FloatTensor of shape (n_pairwise, n_nodes) than can be used used to
        combine feature vectors. Values are 1 if method == "sum" and 0.5 if
        method == "mean".
    """

    # Get the upper triangle indices
    triu = np.vstack(np.triu_indices(nodes.shape[0]))

    # Loop through all indices and add to list with
    idxs = torch.from_numpy(triu).T

    # Convert to tensor
    combos = torch.zeros([idxs.shape[0], nodes.shape[0]]).scatter(1, idxs, 1)

    # Set to 0.5 if method is 'mean'
    if method == 'mean':
        combos *= 0.5

    return combos


####################################
# Pairwise concatenation functions #
####################################

def cat_pairwise(embeddings):

    triu = np.vstack(np.triu_indices(embeddings.shape[0])).T

    node1 = []
    node2 = []

    for i, j in triu:
        node1.append(embeddings[i])
        node2.append(embeddings[j])

    node1 = torch.stack(node1, dim=0)
    node2 = torch.flip(torch.stack(node2, dim=0), dims=(1,))

    return torch.cat((node1, node2), dim=1)


############################
# Upper triangle functions #
############################

def triu_condense(input_tensor):
    """
    Condense the upper triangle of a tensor into a 2d dense representation.

    Args:
    - input_tensor (torch.Tensor) - Tensor of shape (n, n, m).

    Returns:
    - Tensor of shape (n(n+1)/2, m) where elements along the third dimension in
        the original tensor are packed row-wise according to the upper
        triangular indices.
    """

    # Get upper triangle index info
    row_idx, col_idx = np.triu_indices(input_tensor.shape[0])
    row_idx = torch.LongTensor(row_idx)
    col_idx = torch.LongTensor(col_idx)

    # Return the packed matrix
    output = input_tensor[row_idx, col_idx, :]

    return output


def triu_expand(input_matrix):
    """
    Expand a dense representation of the upper triangle of a tensor into
    a 3D squareform representation.

    Args:
    - input_matrix (torch.Tensor) - Tensor of shape (n(n+1)/2, m).

    Returns:
    - Tensor of shape (n, n, m) where elements along the third dimension in the
        original tensor are packed row-wise according to the upper triangular
        indices.
    """
    # Get the edge size n of the tensor
    n_elements = input_matrix.shape[0]
    n_chan = input_matrix.shape[1]
    n_res = int((-1 + np.sqrt(1 + 4 * 2 * (n_elements))) / 2)

    # Get upper triangle index info
    row_idx, col_idx = np.triu_indices(n_res)
    row_idx = torch.LongTensor(row_idx)
    col_idx = torch.LongTensor(col_idx)

    # Generate the output tensor
    output = torch.zeros((n_res, n_res, n_chan))

    # Input the triu values
    for i in range(n_chan):
        i_tens = torch.full((len(row_idx),), i, dtype=torch.long)
        output.index_put_((row_idx, col_idx, i_tens), input_matrix[:, i])

    # Input the tril values
    for i in range(n_chan):
        i_tens = torch.full((len(row_idx),), i, dtype=torch.long)
        output.index_put_((col_idx, row_idx, i_tens), input_matrix[:, i])

    return output


#############
# Kronecker #
#############

def kronecker_product(t1, t2, size_t1, size_t2):
    fusion_tensor = torch.bmm(t1.unsqueeze(2), t2.unsqueeze(1))
    fusion_tensor = fusion_tensor.view(-1, size_t1 * size_t2)
    return fusion_tensor

# %% [markdown]
# ### Model

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F
from torch import autograd
import pytorch_lightning as pl
from torch.utils.data import DataLoader
from torch.utils.checkpoint import checkpoint
from tqdm import *
import wandb

import gc


def track_mem():
    for obj in gc.get_objects():
        try:
            if (torch.is_tensor(obj) or (hasattr(obj, 'data') and torch.is_tensor(obj.data))) and hasattr(obj, '__name__'):
                print(obj.__name__, obj.size())
        except:
            pass


class GAT(pl.LightningModule):

    def __init__(self, embed_features, atom_out_features, res_out_features,
                 n_contact_channels, dropout, alpha, train_data, val_data,
                 test_data):
        super(GAT, self).__init__()

        # Properties
        self.embed_features = embed_features
        self.atom_out_features = atom_out_features
        self.res_out_features = res_out_features
        self.n_contact_channels = n_contact_channels
        self.dropout = dropout
        self.alpha = alpha

        # Datasets
        self.train_data = train_data
        self.val_data = val_data
        self.test_data = test_data

        # Model components
        self.embed = AtomEmbed(embed_features, scale_grad_by_freq=True)

        self.embed_batch_norm = nn.BatchNorm1d(embed_features)

        # Define number of graph conv layers and heads
        n_atom_layers = 8
        n_atom_heads = 3

        n_res_layers = 0
        n_res_heads = 3

        # Set up atom attention
        self.atom_attns = nn.ModuleList([])
        for i in range(n_atom_layers):
            if i == 0:
                attn_layer = MultiHeadGraphAttn(n_atom_heads, embed_features,
                                                atom_out_features,
                                                dropout, alpha)
            else:
                attn_layer = MultiHeadGraphAttn(n_atom_heads,
                                                n_atom_heads * atom_out_features,
                                                atom_out_features,
                                                dropout, alpha)

            self.atom_attns.append(attn_layer)


        # Set up condensation
        self.condense_batch_norm = nn.BatchNorm1d(n_atom_heads * atom_out_features)

        # Set up res attention
        self.res_attns = nn.ModuleList([])
        for i in range(n_res_layers):
            if i == 0:
                attn_layer = MultiHeadGraphAttn(n_res_heads,
                                                n_atom_heads * atom_out_features,
                                                res_out_features, dropout,
                                                alpha)
            else:
                attn_layer = MultiHeadGraphAttn(n_res_heads,
                                                n_res_heads * res_out_features,
                                                res_out_features, dropout,
                                                alpha)

            self.res_attns.append(attn_layer)

        self.final_attn = MultiHeadGraphAttn(n_res_heads,
                                             n_res_heads * res_out_features,
                                             res_out_features, dropout,
                                             alpha)
        
        self.conv = nn.Conv2d(30, 10, 3, stride=1, padding=1)
        self.conv_batch_norm = nn.BatchNorm2d(10)
        
        self.conv2 = nn.Conv2d(10, 10, 3, stride=1, padding=1)
        self.conv_batch_norm2 = nn.BatchNorm2d(10)
        
        self.conv3 = nn.Conv2d(10, 8, 3, stride=1, padding=1)

        self.activation = nn.LeakyReLU(self.alpha)

        self.pred_contact_batch_norm = nn.BatchNorm1d(n_contact_channels)

        self.activations = {}


        # Validation information
        self.reset_epoch_metrics()


    def forward(self, x):
#         # Put on gpus
#         self.embed.cuda(0)
#         self.embed_batch_norm.cuda(0)
#         [layer.cuda(0) for layer in self.atom_attns]
# #         self.condense.cuda(0)
#         self.condense_batch_norm.cuda(0)
#         [layer.cuda(0) for layer in self.res_attns]
#         self.final_attn.cuda(0)
#         self.linear1.cuda(1)
#         self.linear2.cuda(1)
#         self.linear_predict.cuda(1)
# #         self.conn_attn.cuda(1)
#         self.pred_contact_batch_norm.cuda(1)

        # Regular forward pass
        atom_embed = self.embed(x['atom_nodes'].squeeze())

        atom_embed_update = self.embed_batch_norm(atom_embed)

        atom_adj = x['atom_adj'].squeeze()

        for layer in self.atom_attns:
                atom_embed_update = checkpoint(layer, atom_embed_update, atom_adj)

        res_embed = torch.matmul(x['mem_mat'].squeeze(), atom_embed_update)

        res_embed_update = self.condense_batch_norm(res_embed)

        adj = x['res_adj'].squeeze()

        for layer in self.res_attns:
            res_embed_update = checkpoint(layer, res_embed_update, adj)

        res_embed_update = self.final_attn(res_embed_update, adj)

#         preds = torch.matmul(res_embed_update, res_embed_update.T).view(1, 1, res_embed_update.shape[0], -1)
        
        
#         preds = kronecker_product(res_embed_update, res_embed_update.T, res_embed_update.shape, res_embed_update.T.shape)
#         preds = res_embed_update.repeat(30, 1, 1).matmul(res_embed_update.T).unsqueeze(0)
        res_embed_update = res_embed_update.unsqueeze(1).repeat(1, res_embed_update.shape[0], 1)
        preds = (res_embed_update + res_embed_update.permute(1, 0, 2)).permute(2, 0, 1).unsqueeze(0)
        
        preds = torch.relu(self.conv(preds))
        preds = self.conv_batch_norm(preds)
        preds = torch.relu(self.conv2(preds))
        preds = self.conv_batch_norm2(preds)
        preds = self.conv3(preds).squeeze(0).permute(1, 2, 0)
        preds = preds + preds.permute(1, 0, 2)

        preds = triu_condense(preds)

        preds = self.pred_contact_batch_norm(preds)

        return preds

    def training_step(self, batch, batch_nb):
        # REQUIRED
        y_hat = self.forward(batch).squeeze()
        y = triu_condense(batch['res_contact'].squeeze())
        weights = triu_condense(batch['res_mask'].squeeze())

        loss = F.binary_cross_entropy_with_logits(y_hat, y, weight=weights)

        self.train_losses.append(loss.item())

        return {'loss': loss}

    def validation_step(self, batch, batch_nb):
        # OPTIONAL
        y_hat = self.forward(batch).squeeze()
        y = triu_condense(batch['res_contact'].squeeze())
        weights = triu_condense(batch['res_mask'].squeeze())

        loss = F.binary_cross_entropy_with_logits(y_hat, y, weight=weights)

        self.val_losses.append(loss.item())

        _, _, auroc = calc_metric_curve(y_hat.sigmoid().cpu(), y.cpu(), 'ROC', squareform=False)
        _, _, auprc = calc_metric_curve(y_hat.sigmoid().cpu(), y.cpu(), 'PRC', squareform=False)

        self.auroc['Hydrophobic'].append(auroc[0])
        self.auroc['Hydrogen bond'].append(auroc[1])
        self.auroc['Van der Waals'].append(auroc[2])
        self.auroc['Water bridges'].append(auroc[3])
        self.auroc['Salt bridges'].append(auroc[4])
        self.auroc['Pi-stacking'].append(auroc[5])
        self.auroc['Pi-cation'].append(auroc[6])
        self.auroc['T-stacking'].append(auroc[7])

        self.auprc['Hydrophobic'].append(auprc[0])
        self.auprc['Hydrogen bond'].append(auprc[1])
        self.auprc['Van der Waals'].append(auprc[2])
        self.auprc['Water bridges'].append(auprc[3])
        self.auprc['Salt bridges'].append(auprc[4])
        self.auprc['Pi-stacking'].append(auprc[5])
        self.auprc['Pi-cation'].append(auprc[6])
        self.auprc['T-stacking'].append(auprc[7])

        self.pred_example.append(wandb.Image(plot_channels(triu_expand(y_hat.detach().cpu()))))

    def on_post_performance_check(self):

        epoch_metrics = {}
        all_metrics = {}

        for key in self.auroc:
            values = np.asarray(self.auroc[key])
            all_metrics[f'AUROC - {key}'] = values

            values = values[~np.isnan(values)]
            epoch_metrics[f'AUROC - {key}'] = wandb.Histogram(values)


        for key in self.auprc:
            values = np.asarray(self.auprc[key])
            all_metrics[f'AUPRC - {key}'] = values

            values = values[~np.isnan(values)]
            epoch_metrics[f'AUPRC - {key}'] = wandb.Histogram(values)

        epoch_metrics['Train Losses'] = wandb.Histogram(self.train_losses)

        epoch_metrics['Val Losses'] = wandb.Histogram(self.val_losses)
        all_metrics['Val Losses'] = np.asarray(self.val_losses)

        all_metrics = pd.DataFrame(all_metrics)
        cor_mat = all_metrics.corr()

        corr_plot = metric_corr_plot(cor_mat)
        epoch_metrics['Metric Corr Plot'] = wandb.Image(corr_plot)

        epoch_metrics['train_loss'] = np.asarray(self.train_losses).mean()
        epoch_metrics['val_loss'] = np.asarray(self.val_losses).mean()

        epoch_metrics['Example Prediction'] = self.pred_example
        epoch_metrics['Epoch'] = self.current_epoch

        self.logger.experiment.log(epoch_metrics)

        self.reset_epoch_metrics()

    def reset_epoch_metrics(self):

        # Validation information
        self.auroc = {
            'Hydrophobic': [],
            'Hydrogen bond': [],
            'Van der Waals': [],
            'Water bridges': [],
            'Salt bridges': [],
            'Pi-stacking': [],
            'Pi-cation': [],
            'T-stacking': []
        }

        self.auprc = {
            'Hydrophobic': [],
            'Hydrogen bond': [],
            'Van der Waals': [],
            'Water bridges': [],
            'Salt bridges': [],
            'Pi-stacking': [],
            'Pi-cation': [],
            'T-stacking': []
        }

        self.val_losses = []
        self.train_losses = []
        self.pred_example = []


#     def validation_end(self, outputs):
#         # OPTIONAL
# #         avg_loss = torch.stack([x['val_loss'] for x in outputs]).mean()
# #         return {'avg_val_loss': avg_loss}
#         pass

    def configure_optimizers(self):
        # REQUIRED
        # can return multiple optimizers and learning_rate schedulers

        parameters = filter(lambda p: p.requires_grad, self.parameters())

        return torch.optim.SGD(parameters, lr=0.1, momentum=0.9, weight_decay=1e-6)

    @pl.data_loader
    def train_dataloader(self):
        # REQUIRED
        return DataLoader(self.train_data, shuffle=True, num_workers=30, pin_memory=True)

    @pl.data_loader
    def val_dataloader(self):
        # OPTIONAL
        return DataLoader(self.val_data, shuffle=False, num_workers=20, pin_memory=True)

#     def on_batch_end(self):
#         wandb.log({key: plt.imshow(self.activations[key][:20]) for key in self.activations})

# %% [markdown]
# ### Analysis functions

# %%
import seaborn as sns

def plot_channels(values):
    fig, ax = plt.subplots(nrows=2, ncols=4, figsize=(20, 10))

    ax = ax.flatten()

    channel_names = [
        'Hydrophobic',
        'Hydrogen bond',
        'Van der Waals',
        'Water bridges',
        'Salt bridges',
        'Pi-stacking',
        'Pi-cation',
        'T-stacking'
    ]

    for channel in range(values.shape[-1]):
        ax[channel].imshow(values[:, :, channel].squeeze(), vmin=0, vmax=1)
        ax[channel].set(title=channel_names[channel], xlabel='Residue #', ylabel='Residue #')

    plt.close()
    return fig


######################
# ROC and PRC curves #
######################
from sklearn.metrics import precision_recall_curve, roc_curve, auc

def calc_metric_curve(preds, target, curve_type, squareform=False):
    """
    Calculate ROC or PRC curves and area for the predicted contact channels.

    Args:
    - preds (np.ndarray) - Numpy array of model predictions either of form
        (n_res, n_res, n_chan) or (n_res * [n_res - 1] / 2, n_chan).
    - target (np.ndarray) - Numpy array of target values either of form
        (n_res, n_res, n_chan) or (n_res * [n_res - 1] / 2, n_chan),
        must match form of preds.
    - curve_type (str) - One of 'ROC' or 'PRC' to denote type of curve.
    - squareform (bool) - True if tensors are of shape (n_res, n_res, n_chan),
        False if they are of shape (n_res * [n_res - 1] / 2, n_chan)
        (default = True).

    Returns:
    - Tuple of x, y, and AUC values to be used for plotting the curves
        using plot_curve metric.
    """

    # Get correct curve function
    if curve_type.upper() == 'ROC':
        curve_func = roc_curve
    elif curve_type.upper() == 'PRC':
        curve_func = precision_recall_curve

    # Generate dicts to hold outputs from curve generation functions
    x = dict()
    y = dict()
    auc_ = dict()

    # Handle case of squareform matrix (only get non-redundant triu indices)
    if squareform:
        indices = np.triu_indices(target.shape[0])

    # For each channel
    for i in range(target.shape[-1]):

        # Handle case of squareform
        if squareform:
            var1, var2, _ = curve_func(target[:, :, i][indices],
                                       preds[:, :, i][indices])

        # Handle case of pairwise
        else:
            var1, var2, _ = curve_func(target[:, i], preds[:, i])

        # Assign outputs to correct dict for plotting
        if curve_type.upper() == 'ROC':
            x[i] = var1
            y[i] = var2
        elif curve_type.upper() == 'PRC':
            x[i] = var2
            y[i] = var1

        # Calc AUC
        auc_[i] = auc(x[i], y[i])

    return (x, y, auc_)


def plot_curve_metric(x, y, auc, curve_type, title=None, labels=None):
    """
    Plot ROC or PRC curves per output channel.

    Args:
    - x (dict) - Dict of numpy arrays for values to plot on x axis.
    - y (dict) - Dict of numpy arrays for values to plot on x axis.
    - auc (dict) - Dict of numpy arrays for areas under each curve.
    - curve_type (str) - One of 'ROC' or 'PRC' to denote type of curve.
    - title
    - labels

    Returns:
    - pyplot object of curves.
    """

    # Generate figure
    plt.figure()

    # Linetype spec
    lw = 2
    curve_type = curve_type.upper()

    # Get the number of channels being plotted
    n_chan = len(x)

    # Make labels numeric if not provided
    if labels is None:
        labels = list(range(n_chan))

    # Check to make sure the labels are the right length
    if len(labels) != n_chan:
        raise ValueError('Number of labels ({}) does not match number of prediction channels ({}).'.format(len(labels), n_chan))

    # Get a lit of colors for all the channels
    color_list = plt.cm.Set1(np.linspace(0, 1, n_chan))

    # Plot each line
    for i, color in enumerate(color_list):
        plt.plot(x[i], y[i], color=color,
                 lw=lw, label='{} (area = {:0.2f})'.format(labels[i], auc[i]))

    # Add labels and diagonal line for ROC
    if curve_type == 'ROC':
        xlab = 'FPR'
        ylab = 'TPR'
        plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
        plt.legend(loc="lower right")

    # Add labels for PRC
    elif curve_type == 'PRC':
        xlab = 'Recall'
        ylab = 'Precision'
        plt.legend(loc="lower left")

    # Extend limits, add labels and title
    plt.xlim([-0.05, 1.05])
    plt.ylim([-0.05, 1.05])
    plt.xlabel(xlab)
    plt.ylabel(ylab)

    if title is not None:
        plt.title('{} for {}'.format(curve_type, title))
    else:
        plt.title('{}'.format(curve_type))

    return plt.axes()

def plot_curve(preds, target, curve_type, title=None, labels=None,
               squareform=False):
    """
    Wrapper to directly plot curves from model output and target.

    Args:
    - preds (np array-like) - Array or tensor of predicted values output by
        model.
    - target (np array-like) - Array or tensor of target values.
    - curve_type (str) - One of 'ROC' or 'PRC'.
    - title (str) - Title of plot (default = None).
    - labels (list) - List of labels for each channel on the plot
        (default = None).
    - squareform (bool) - Whether the predictions and targets are in square form
        (default = False).
    """
    x, y, auc_ = calc_metric_curve(preds, target, curve_type, squareform)
    return plot_curve_metric(x, y, auc_, curve_type, title, labels)


################################
# Correlations between metrics #
################################

def metric_corr_plot(corr):
    mask = np.triu(np.ones_like(corr, dtype=np.bool))

    fig, ax = plt.subplots(figsize=(11, 9))
    cmap = sns.diverging_palette(220, 10, as_cmap=True)

    sns.heatmap(corr, mask=mask, cmap=cmap, vmax=1.0, vmin = -1.0, center=0,
                square=True, linewidths=.5, cbar_kws={"shrink": .5}, ax=ax)

    plt.tight_layout()
    plt.close()
    return fig

# %% [markdown]
# ## Training
#
# ### Instantiate dataloader and model

# %%
from pytorch_lightning.callbacks import ModelCheckpoint
torch.autograd.set_detect_anomaly(True)

data_base = '/home/tshimko/tesselate/'

torch.manual_seed(10)

data_load = [
                'pdb_id',
#                 'model',
                'atom_nodes',
                'atom_adj',
#                 'atom_contact',
#                 'atom_mask',
                'res_adj',
                'res_dist',
                'chain_mem',
                'res_contact',
                'conn_adj',
                'res_mask',
                'mem_mat',
#                 'idx2atom_dict',
#                 'idx2res_dict'
            ]

# train_data = TesselateDataset(data_base + 'id_lists/ligand_free_monomers/small_train.txt',
#                               graph_dir=data_base + 'data/graphs',
#                               contacts_dir=data_base + 'data/contacts',
#                               return_data=data_load, in_memory=False)

train_data = TesselateDataset(data_base + 'test4.txt',
                              graph_dir=data_base + 'data/graphs',
                              contacts_dir=data_base + 'data/contacts',
                              return_data=data_load, in_memory=True)

# train_data = TesselateDataset(data_base + 'test3.txt',
#                               graph_dir=data_base + 'data/graphs',
#                               contacts_dir=data_base + 'data/contacts',
#                               return_data=data_load, in_memory=True)

# val_data = TesselateDataset(data_base + 'test3.txt',
#                               graph_dir=data_base + 'data/graphs',
#                               contacts_dir=data_base + 'data/contacts',
#                               return_data=data_load, in_memory=True)

val_data = TesselateDataset(data_base + 'id_lists/ligand_free_monomers/small_val.txt',
                            graph_dir=data_base + 'data/graphs',
                            contacts_dir=data_base + 'data/contacts',
                            return_data=data_load, in_memory=True)


checkpoint_callback = ModelCheckpoint(
    filepath=os.getcwd() + '/checkpoints',
    save_top_k=0,
    verbose=False,
    monitor='val_loss',
    mode='min',
    prefix=''
)

model = GAT(embed_features=10, atom_out_features=10, res_out_features=10,
             n_contact_channels=8, dropout=0, alpha=0.2, train_data=train_data, val_data=val_data,
             test_data=None)

# %%
# %%capture --no-stdout
import logging
logging.getLogger().setLevel(logging.CRITICAL)

from pytorch_lightning import Trainer
from pytorch_lightning.logging import WandbLogger

logger = WandbLogger(project='tesselate')

trainer = Trainer(max_nb_epochs=10000, checkpoint_callback=checkpoint_callback,
                  early_stop_callback=False, accumulate_grad_batches=8,
                  logger=logger, gpus=[1]) #, gradient_clip_val=0.5) # amp_level='O2', use_amp=True) <-- for half precision
trainer.fit(model)
# Out:
# Epoch 1:  51%|█████▏    | 55/107 [00:26<00:18,  2.79batch/s, batch_idx=54, gpu=1, loss=0.564, v_num=g0ku9slz]
# Validating:   0%|          | 0/52 [00:00<?, ?batch/s]
# Epoch 1:  52%|█████▏    | 56/107 [00:29<01:06,  1.31s/batch, batch_idx=54, gpu=1, loss=0.564, v_num=g0ku9slz]
# Epoch 1:  53%|█████▎    | 57/107 [00:32<01:23,  1.68s/batch, batch_idx=54, gpu=1, loss=0.564, v_num=g0ku9slz]
# Epoch 1:  54%|█████▍    | 58/107 [00:33<01:20,  1.65s/batch, batch_idx=54, gpu=1, loss=0.564, v_num=g0ku9slz]
# Epoch 1:  55%|█████▌    | 59/107 [00:35<01:14,  1.55s/batch, batch_idx=54, gpu=1, loss=0.564, v_num=g0ku9slz]
# Epoch 1:  56%|█████▌    | 60/107 [00:36<01:07,  1.45s/batch, batch_idx=54, gpu=1, loss=0.564, v_num=g0ku9slz]
# Epoch 1:  57%|█████▋    | 61/107 [00:37<01:01,  1.34s/batch, batch_idx=54, gpu=1, loss=0.564, v_num=g0ku9slz]
# Epoch 1:  58%|█████▊    | 62/107 [00:38<01:01,  1.37s/batch, batch_idx=54, gpu=1, loss=0.564, v_num=g0ku9slz]
# Epoch 1:  59%|█████▉    | 63/107 [00:40<00:57,  1.30s/batch, batch_idx=54, gpu=1, loss=0.564, v_num=g0ku9slz]
# Epoch 1:  60%|█████▉    | 64/107 [00:41<00:53,  1.24s/batch, batch_idx=54, gpu=1, loss=0.564, v_num=g0ku9slz]
# Epoch 1:  61%|██████    | 65/107 [00:42<00:48,  1.15s/batch, batch_idx=54, gpu=1, loss=0.564, v_num=g0ku9slz]
# Epoch 1:  62%|██████▏   | 66/107 [00:43<00:49,  1.22s/batch, batch_idx=54, gpu=1, loss=0.564, v_num=g0ku9slz]
# Epoch 1:  63%|██████▎   | 67/107 [00:44<00:46,  1.16s/batch, batch_idx=54, gpu=1, loss=0.564, v_num=g0ku9slz]
# Epoch 1:  64%|██████▎   | 68/107 [00:45<00:42,  1.09s/batch, batch_idx=54, gpu=1, loss=0.564, v_num=g0ku9slz]
# Epoch 1:  64%|██████▍   | 69/107 [00:46<00:44,  1.17s/batch, batch_idx=54, gpu=1, loss=0.564, v_num=g0ku9slz]
# Epoch 1:  65%|██████▌   | 70/107 [00:47<00:42,  1.14s/batch, batch_idx=54, gpu=1, loss=0.564, v_num=g0ku9slz]
# Epoch 1:  66%|██████▋   | 71/107 [00:49<00:43,  1.21s/batch, batch_idx=54, gpu=1, loss=0.564, v_num=g0ku9slz]
# Epoch 1:  67%|██████▋   | 72/107 [00:50<00:41,  1.19s/batch, batch_idx=54, gpu=1, loss=0.564, v_num=g0ku9slz]
# Epoch 1:  68%|██████▊   | 73/107 [00:51<00:35,  1.04s/batch, batch_idx=54, gpu=1, loss=0.564, v_num=g0ku9slz]
# Epoch 1:  69%|██████▉   | 74/107 [00:52<00:35,  1.06s/batch, batch_idx=54, gpu=1, loss=0.564, v_num=g0ku9slz]
# Epoch 1:  70%|███████   | 75/107 [00:53<00:32,  1.00s/batch, batch_idx=54, gpu=1, loss=0.564, v_num=g0ku9slz]
# Epoch 1:  71%|███████   | 76/107 [00:53<00:30,  1.03batch/s, batch_idx=54, gpu=1, loss=0.564, v_num=g0ku9slz]
# Epoch 1:  72%|███████▏  | 77/107 [00:55<00:32,  1.09s/batch, batch_idx=54, gpu=1, loss=0.564, v_num=g0ku9slz]
# Epoch 1:  73%|███████▎  | 78/107 [00:56<00:34,  1.19s/batch, batch_idx=54, gpu=1, loss=0.564, v_num=g0ku9slz]
# Epoch 1:  74%|███████▍  | 79/107 [00:57<00:30,  1.10s/batch, batch_idx=54, gpu=1, loss=0.564, v_num=g0ku9slz]
# Epoch 1:  75%|███████▍  | 80/107 [00:58<00:29,  1.10s/batch, batch_idx=54, gpu=1, loss=0.564, v_num=g0ku9slz]
# Epoch 1:  76%|███████▌  | 81/107 [00:59<00:25,  1.04batch/s, batch_idx=54, gpu=1, loss=0.564, v_num=g0ku9slz]
# Epoch 1:  77%|███████▋  | 82/107 [01:00<00:23,  1.08batch/s, batch_idx=54, gpu=1, loss=0.564, v_num=g0ku9slz]
# Epoch 1:  78%|███████▊  | 83/107 [01:01<00:22,  1.05batch/s, batch_idx=54, gpu=1, loss=0.564, v_num=g0ku9slz]
# Epoch 1:  79%|███████▊  | 84/107 [01:01<00:20,  1.10batch/s, batch_idx=54, gpu=1, loss=0.564, v_num=g0ku9slz]
# Epoch 1:  79%|███████▉  | 85/107 [01:02<00:19,  1.10batch/s, batch_idx=54, gpu=1, loss=0.564, v_num=g0ku9slz]
# Epoch 1:  80%|████████  | 86/107 [01:04<00:22,  1.07s/batch, batch_idx=54, gpu=1, loss=0.564, v_num=g0ku9slz]
# Epoch 1:  81%|████████▏ | 87/107 [01:05<00:20,  1.02s/batch, batch_idx=54, gpu=1, loss=0.564, v_num=g0ku9slz]
# Epoch 1:  82%|████████▏ | 88/107 [01:06<00:18,  1.04batch/s, batch_idx=54, gpu=1, loss=0.564, v_num=g0ku9slz]
# Epoch 1:  83%|████████▎ | 89/107 [01:07<00:17,  1.04batch/s, batch_idx=54, gpu=1, loss=0.564, v_num=g0ku9slz]
# Epoch 1:  84%|████████▍ | 90/107 [01:08<00:17,  1.02s/batch, batch_idx=54, gpu=1, loss=0.564, v_num=g0ku9slz]
# Epoch 1:  85%|████████▌ | 91/107 [01:09<00:15,  1.03batch/s, batch_idx=54, gpu=1, loss=0.564, v_num=g0ku9slz]
# Epoch 1:  86%|████████▌ | 92/107 [01:10<00:16,  1.11s/batch, batch_idx=54, gpu=1, loss=0.564, v_num=g0ku9slz]
# Epoch 1:  87%|████████▋ | 93/107 [01:11<00:14,  1.04s/batch, batch_idx=54, gpu=1, loss=0.564, v_num=g0ku9slz]
# Epoch 1:  88%|████████▊ | 94/107 [01:12<00:14,  1.11s/batch, batch_idx=54, gpu=1, loss=0.564, v_num=g0ku9slz]
# Epoch 1:  89%|████████▉ | 95/107 [01:15<00:18,  1.58s/batch, batch_idx=54, gpu=1, loss=0.564, v_num=g0ku9slz]
# Epoch 1:  90%|████████▉ | 96/107 [01:16<00:15,  1.42s/batch, batch_idx=54, gpu=1, loss=0.564, v_num=g0ku9slz]
# Epoch 1:  91%|█████████ | 97/107 [01:17<00:14,  1.47s/batch, batch_idx=54, gpu=1, loss=0.564, v_num=g0ku9slz]
# Epoch 1:  92%|█████████▏| 98/107 [01:19<00:13,  1.45s/batch, batch_idx=54, gpu=1, loss=0.564, v_num=g0ku9slz]
# Epoch 1:  93%|█████████▎| 99/107 [01:20<00:10,  1.30s/batch, batch_idx=54, gpu=1, loss=0.564, v_num=g0ku9slz]
# Epoch 1:  93%|█████████▎| 100/107 [01:21<00:08,  1.16s/batch, batch_idx=54, gpu=1, loss=0.564, v_num=g0ku9slz]
# Epoch 1:  94%|█████████▍| 101/107 [01:21<00:06,  1.06s/batch, batch_idx=54, gpu=1, loss=0.564, v_num=g0ku9slz]
# Epoch 1:  95%|█████████▌| 102/107 [01:23<00:05,  1.08s/batch, batch_idx=54, gpu=1, loss=0.564, v_num=g0ku9slz]
# Epoch 1:  96%|█████████▋| 103/107 [01:23<00:04,  1.02s/batch, batch_idx=54, gpu=1, loss=0.564, v_num=g0ku9slz]
# Epoch 1:  97%|█████████▋| 104/107 [01:24<00:02,  1.03batch/s, batch_idx=54, gpu=1, loss=0.564, v_num=g0ku9slz]
# Epoch 1:  98%|█████████▊| 105/107 [01:25<00:01,  1.04batch/s, batch_idx=54, gpu=1, loss=0.564, v_num=g0ku9slz]
# Epoch 1:  99%|█████████▉| 106/107 [01:26<00:01,  1.02s/batch, batch_idx=54, gpu=1, loss=0.564, v_num=g0ku9slz]
# Epoch 1: 100%|██████████| 107/107 [01:33<00:00,  1.06batch/s, batch_idx=54, gpu=1, loss=0.564, v_num=g0ku9slz]
# Epoch 2:  51%|█████▏    | 55/107 [00:24<00:17,  3.00batch/s, batch_idx=54, gpu=1, loss=0.520, v_num=g0ku9slz]
# Validating:   0%|          | 0/52 [00:00<?, ?batch/s]
# Epoch 2:  52%|█████▏    | 56/107 [00:28<01:08,  1.34s/batch, batch_idx=54, gpu=1, loss=0.520, v_num=g0ku9slz]
# Epoch 2:  53%|█████▎    | 57/107 [00:30<01:22,  1.66s/batch, batch_idx=54, gpu=1, loss=0.520, v_num=g0ku9slz]
# Epoch 2:  54%|█████▍    | 58/107 [00:32<01:27,  1.78s/batch, batch_idx=54, gpu=1, loss=0.520, v_num=g0ku9slz]
# Epoch 2:  55%|█████▌    | 59/107 [00:34<01:18,  1.63s/batch, batch_idx=54, gpu=1, loss=0.520, v_num=g0ku9slz]
# Epoch 2:  56%|█████▌    | 60/107 [00:35<01:07,  1.44s/batch, batch_idx=54, gpu=1, loss=0.520, v_num=g0ku9slz]
# Epoch 2:  57%|█████▋    | 61/107 [00:36<01:10,  1.53s/batch, batch_idx=54, gpu=1, loss=0.520, v_num=g0ku9slz]
# Epoch 2:  58%|█████▊    | 62/107 [00:38<01:07,  1.51s/batch, batch_idx=54, gpu=1, loss=0.520, v_num=g0ku9slz]
# Epoch 2:  59%|█████▉    | 63/107 [00:39<00:56,  1.28s/batch, batch_idx=54, gpu=1, loss=0.520, v_num=g0ku9slz]
# Epoch 2:  60%|█████▉    | 64/107 [00:40<00:51,  1.19s/batch, batch_idx=54, gpu=1, loss=0.520, v_num=g0ku9slz]
# Epoch 2:  61%|██████    | 65/107 [00:40<00:45,  1.08s/batch, batch_idx=54, gpu=1, loss=0.520, v_num=g0ku9slz]
# Epoch 2:  62%|██████▏   | 66/107 [00:42<00:45,  1.11s/batch, batch_idx=54, gpu=1, loss=0.520, v_num=g0ku9slz]
# Epoch 2:  63%|██████▎   | 67/107 [00:43<00:42,  1.05s/batch, batch_idx=54, gpu=1, loss=0.520, v_num=g0ku9slz]
# Epoch 2:  64%|██████▎   | 68/107 [00:43<00:39,  1.02s/batch, batch_idx=54, gpu=1, loss=0.520, v_num=g0ku9slz]
# Epoch 2:  64%|██████▍   | 69/107 [00:45<00:39,  1.03s/batch, batch_idx=54, gpu=1, loss=0.520, v_num=g0ku9slz]
# Epoch 2:  65%|██████▌   | 70/107 [00:46<00:37,  1.01s/batch, batch_idx=54, gpu=1, loss=0.520, v_num=g0ku9slz]
# Epoch 2:  66%|██████▋   | 71/107 [00:47<00:38,  1.08s/batch, batch_idx=54, gpu=1, loss=0.520, v_num=g0ku9slz]
# Epoch 2:  67%|██████▋   | 72/107 [00:48<00:37,  1.06s/batch, batch_idx=54, gpu=1, loss=0.520, v_num=g0ku9slz]
# Epoch 2:  68%|██████▊   | 73/107 [00:48<00:32,  1.05batch/s, batch_idx=54, gpu=1, loss=0.520, v_num=g0ku9slz]
# Epoch 2:  69%|██████▉   | 74/107 [00:49<00:32,  1.03batch/s, batch_idx=54, gpu=1, loss=0.520, v_num=g0ku9slz]
# Epoch 2:  70%|███████   | 75/107 [00:50<00:29,  1.08batch/s, batch_idx=54, gpu=1, loss=0.520, v_num=g0ku9slz]
# Epoch 2:  71%|███████   | 76/107 [00:51<00:27,  1.12batch/s, batch_idx=54, gpu=1, loss=0.520, v_num=g0ku9slz]
# Epoch 2:  72%|███████▏  | 77/107 [00:52<00:27,  1.11batch/s, batch_idx=54, gpu=1, loss=0.520, v_num=g0ku9slz]
# Epoch 2:  73%|███████▎  | 78/107 [00:53<00:29,  1.02s/batch, batch_idx=54, gpu=1, loss=0.520, v_num=g0ku9slz]
# Epoch 2:  74%|███████▍  | 79/107 [00:55<00:34,  1.22s/batch, batch_idx=54, gpu=1, loss=0.520, v_num=g0ku9slz]
# Epoch 2:  75%|███████▍  | 80/107 [00:56<00:31,  1.15s/batch, batch_idx=54, gpu=1, loss=0.520, v_num=g0ku9slz]
# Epoch 2:  76%|███████▌  | 81/107 [00:57<00:26,  1.00s/batch, batch_idx=54, gpu=1, loss=0.520, v_num=g0ku9slz]
# Epoch 2:  77%|███████▋  | 82/107 [00:57<00:23,  1.08batch/s, batch_idx=54, gpu=1, loss=0.520, v_num=g0ku9slz]
# Epoch 2:  78%|███████▊  | 83/107 [00:58<00:22,  1.07batch/s, batch_idx=54, gpu=1, loss=0.520, v_num=g0ku9slz]
# Epoch 2:  79%|███████▊  | 84/107 [00:59<00:20,  1.14batch/s, batch_idx=54, gpu=1, loss=0.520, v_num=g0ku9slz]
# Epoch 2:  79%|███████▉  | 85/107 [01:00<00:18,  1.18batch/s, batch_idx=54, gpu=1, loss=0.520, v_num=g0ku9slz]
# Epoch 2:  80%|████████  | 86/107 [01:01<00:17,  1.18batch/s, batch_idx=54, gpu=1, loss=0.520, v_num=g0ku9slz]
# Epoch 2:  81%|████████▏ | 87/107 [01:02<00:16,  1.19batch/s, batch_idx=54, gpu=1, loss=0.520, v_num=g0ku9slz]
# Epoch 2:  82%|████████▏ | 88/107 [01:02<00:15,  1.23batch/s, batch_idx=54, gpu=1, loss=0.520, v_num=g0ku9slz]
# Epoch 2:  83%|████████▎ | 89/107 [01:03<00:14,  1.20batch/s, batch_idx=54, gpu=1, loss=0.520, v_num=g0ku9slz]
# Epoch 2:  84%|████████▍ | 90/107 [01:04<00:15,  1.12batch/s, batch_idx=54, gpu=1, loss=0.520, v_num=g0ku9slz]
# Epoch 2:  85%|████████▌ | 91/107 [01:05<00:13,  1.15batch/s, batch_idx=54, gpu=1, loss=0.520, v_num=g0ku9slz]
# Epoch 2:  86%|████████▌ | 92/107 [01:06<00:15,  1.00s/batch, batch_idx=54, gpu=1, loss=0.520, v_num=g0ku9slz]
# Epoch 2:  87%|████████▋ | 93/107 [01:07<00:13,  1.06batch/s, batch_idx=54, gpu=1, loss=0.520, v_num=g0ku9slz]
# Epoch 2:  88%|████████▊ | 94/107 [01:08<00:12,  1.01batch/s, batch_idx=54, gpu=1, loss=0.520, v_num=g0ku9slz]
# Epoch 2:  89%|████████▉ | 95/107 [01:11<00:17,  1.46s/batch, batch_idx=54, gpu=1, loss=0.520, v_num=g0ku9slz]
# Epoch 2:  90%|████████▉ | 96/107 [01:12<00:14,  1.30s/batch, batch_idx=54, gpu=1, loss=0.520, v_num=g0ku9slz]
# Epoch 2:  91%|█████████ | 97/107 [01:13<00:13,  1.36s/batch, batch_idx=54, gpu=1, loss=0.520, v_num=g0ku9slz]
# Epoch 2:  92%|█████████▏| 98/107 [01:14<00:10,  1.19s/batch, batch_idx=54, gpu=1, loss=0.520, v_num=g0ku9slz]
# Epoch 2:  93%|█████████▎| 99/107 [01:15<00:08,  1.08s/batch, batch_idx=54, gpu=1, loss=0.520, v_num=g0ku9slz]
# Epoch 2:  93%|█████████▎| 100/107 [01:16<00:06,  1.03batch/s, batch_idx=54, gpu=1, loss=0.520, v_num=g0ku9slz]
# Epoch 2:  94%|█████████▍| 101/107 [01:16<00:05,  1.11batch/s, batch_idx=54, gpu=1, loss=0.520, v_num=g0ku9slz]
# Epoch 2:  95%|█████████▌| 102/107 [01:18<00:06,  1.26s/batch, batch_idx=54, gpu=1, loss=0.520, v_num=g0ku9slz]
# Epoch 2:  96%|█████████▋| 103/107 [01:19<00:04,  1.12s/batch, batch_idx=54, gpu=1, loss=0.520, v_num=g0ku9slz]
# Epoch 2:  97%|█████████▋| 104/107 [01:20<00:03,  1.02s/batch, batch_idx=54, gpu=1, loss=0.520, v_num=g0ku9slz]
# Epoch 2:  98%|█████████▊| 105/107 [01:21<00:01,  1.04batch/s, batch_idx=54, gpu=1, loss=0.520, v_num=g0ku9slz]
# Epoch 2:  99%|█████████▉| 106/107 [01:22<00:00,  1.03batch/s, batch_idx=54, gpu=1, loss=0.520, v_num=g0ku9slz]
# Epoch 2: 100%|██████████| 107/107 [01:26<00:00,  1.12batch/s, batch_idx=54, gpu=1, loss=0.520, v_num=g0ku9slz]
# Epoch 3:  51%|█████▏    | 55/107 [00:24<00:17,  2.98batch/s, batch_idx=54, gpu=1, loss=0.478, v_num=g0ku9slz]
# Validating:   0%|          | 0/52 [00:00<?, ?batch/s]
# Epoch 3:  52%|█████▏    | 56/107 [00:29<01:15,  1.47s/batch, batch_idx=54, gpu=1, loss=0.478, v_num=g0ku9slz]
# Epoch 3:  53%|█████▎    | 57/107 [00:31<01:23,  1.67s/batch, batch_idx=54, gpu=1, loss=0.478, v_num=g0ku9slz]
# Epoch 3:  54%|█████▍    | 58/107 [00:32<01:11,  1.47s/batch, batch_idx=54, gpu=1, loss=0.478, v_num=g0ku9slz]
# Epoch 3:  55%|█████▌    | 59/107 [00:33<01:05,  1.37s/batch, batch_idx=54, gpu=1, loss=0.478, v_num=g0ku9slz]
# Epoch 3:  56%|█████▌    | 60/107 [00:34<00:59,  1.27s/batch, batch_idx=54, gpu=1, loss=0.478, v_num=g0ku9slz]
# Epoch 3:  57%|█████▋    | 61/107 [00:35<00:53,  1.17s/batch, batch_idx=54, gpu=1, loss=0.478, v_num=g0ku9slz]
# Epoch 3:  58%|█████▊    | 62/107 [00:36<00:53,  1.19s/batch, batch_idx=54, gpu=1, loss=0.478, v_num=g0ku9slz]
# Epoch 3:  59%|█████▉    | 63/107 [00:37<00:47,  1.08s/batch, batch_idx=54, gpu=1, loss=0.478, v_num=g0ku9slz]
# Epoch 3:  60%|█████▉    | 64/107 [00:38<00:45,  1.05s/batch, batch_idx=54, gpu=1, loss=0.478, v_num=g0ku9slz]
# Epoch 3:  61%|██████    | 65/107 [00:39<00:41,  1.00batch/s, batch_idx=54, gpu=1, loss=0.478, v_num=g0ku9slz]
# Epoch 3:  62%|██████▏   | 66/107 [00:40<00:41,  1.01s/batch, batch_idx=54, gpu=1, loss=0.478, v_num=g0ku9slz]
# Epoch 3:  63%|██████▎   | 67/107 [00:41<00:40,  1.00s/batch, batch_idx=54, gpu=1, loss=0.478, v_num=g0ku9slz]
# Epoch 3:  64%|██████▎   | 68/107 [00:42<00:37,  1.04batch/s, batch_idx=54, gpu=1, loss=0.478, v_num=g0ku9slz]
# Epoch 3:  64%|██████▍   | 69/107 [00:43<00:36,  1.03batch/s, batch_idx=54, gpu=1, loss=0.478, v_num=g0ku9slz]
# Epoch 3:  65%|██████▌   | 70/107 [00:44<00:35,  1.04batch/s, batch_idx=54, gpu=1, loss=0.478, v_num=g0ku9slz]
# Epoch 3:  66%|██████▋   | 71/107 [00:45<00:37,  1.04s/batch, batch_idx=54, gpu=1, loss=0.478, v_num=g0ku9slz]
# Epoch 3:  67%|██████▋   | 72/107 [00:46<00:36,  1.04s/batch, batch_idx=54, gpu=1, loss=0.478, v_num=g0ku9slz]
# Epoch 3:  68%|██████▊   | 73/107 [00:46<00:31,  1.07batch/s, batch_idx=54, gpu=1, loss=0.478, v_num=g0ku9slz]
# Epoch 3:  69%|██████▉   | 74/107 [00:48<00:31,  1.05batch/s, batch_idx=54, gpu=1, loss=0.478, v_num=g0ku9slz]
# Epoch 3:  70%|███████   | 75/107 [00:48<00:28,  1.11batch/s, batch_idx=54, gpu=1, loss=0.478, v_num=g0ku9slz]
# Epoch 3:  71%|███████   | 76/107 [00:49<00:26,  1.16batch/s, batch_idx=54, gpu=1, loss=0.478, v_num=g0ku9slz]
# Epoch 3:  72%|███████▏  | 77/107 [00:51<00:39,  1.31s/batch, batch_idx=54, gpu=1, loss=0.478, v_num=g0ku9slz]
# Epoch 3:  73%|███████▎  | 78/107 [00:53<00:37,  1.30s/batch, batch_idx=54, gpu=1, loss=0.478, v_num=g0ku9slz]
# Epoch 3:  74%|███████▍  | 79/107 [00:53<00:32,  1.15s/batch, batch_idx=54, gpu=1, loss=0.478, v_num=g0ku9slz]
# Epoch 3:  75%|███████▍  | 80/107 [00:54<00:29,  1.10s/batch, batch_idx=54, gpu=1, loss=0.478, v_num=g0ku9slz]
# Epoch 3:  76%|███████▌  | 81/107 [00:55<00:25,  1.03batch/s, batch_idx=54, gpu=1, loss=0.478, v_num=g0ku9slz]
# Epoch 3:  77%|███████▋  | 82/107 [00:56<00:22,  1.10batch/s, batch_idx=54, gpu=1, loss=0.478, v_num=g0ku9slz]
# Epoch 3:  78%|███████▊  | 83/107 [00:57<00:21,  1.10batch/s, batch_idx=54, gpu=1, loss=0.478, v_num=g0ku9slz]
# Epoch 3:  79%|███████▊  | 84/107 [00:58<00:19,  1.16batch/s, batch_idx=54, gpu=1, loss=0.478, v_num=g0ku9slz]
# Epoch 3:  79%|███████▉  | 85/107 [00:58<00:18,  1.19batch/s, batch_idx=54, gpu=1, loss=0.478, v_num=g0ku9slz]
# Epoch 3:  80%|████████  | 86/107 [00:59<00:17,  1.20batch/s, batch_idx=54, gpu=1, loss=0.478, v_num=g0ku9slz]
# Epoch 3:  81%|████████▏ | 87/107 [01:00<00:16,  1.21batch/s, batch_idx=54, gpu=1, loss=0.478, v_num=g0ku9slz]
# Epoch 3:  82%|████████▏ | 88/107 [01:01<00:15,  1.23batch/s, batch_idx=54, gpu=1, loss=0.478, v_num=g0ku9slz]
# Epoch 3:  83%|████████▎ | 89/107 [01:02<00:14,  1.21batch/s, batch_idx=54, gpu=1, loss=0.478, v_num=g0ku9slz]
# Epoch 3:  84%|████████▍ | 90/107 [01:03<00:15,  1.12batch/s, batch_idx=54, gpu=1, loss=0.478, v_num=g0ku9slz]
# Epoch 3:  85%|████████▌ | 91/107 [01:03<00:13,  1.17batch/s, batch_idx=54, gpu=1, loss=0.478, v_num=g0ku9slz]
# Epoch 3:  86%|████████▌ | 92/107 [01:05<00:14,  1.01batch/s, batch_idx=54, gpu=1, loss=0.478, v_num=g0ku9slz]
# Epoch 3:  87%|████████▋ | 93/107 [01:06<00:12,  1.08batch/s, batch_idx=54, gpu=1, loss=0.478, v_num=g0ku9slz]
# Epoch 3:  88%|████████▊ | 94/107 [01:07<00:12,  1.02batch/s, batch_idx=54, gpu=1, loss=0.478, v_num=g0ku9slz]
# Epoch 3:  89%|████████▉ | 95/107 [01:09<00:17,  1.44s/batch, batch_idx=54, gpu=1, loss=0.478, v_num=g0ku9slz]
# Epoch 3:  90%|████████▉ | 96/107 [01:10<00:14,  1.28s/batch, batch_idx=54, gpu=1, loss=0.478, v_num=g0ku9slz]
# Epoch 3:  91%|█████████ | 97/107 [01:12<00:13,  1.35s/batch, batch_idx=54, gpu=1, loss=0.478, v_num=g0ku9slz]
# Epoch 3:  92%|█████████▏| 98/107 [01:12<00:10,  1.18s/batch, batch_idx=54, gpu=1, loss=0.478, v_num=g0ku9slz]
# Epoch 3:  93%|█████████▎| 99/107 [01:13<00:08,  1.06s/batch, batch_idx=54, gpu=1, loss=0.478, v_num=g0ku9slz]
# Epoch 3:  93%|█████████▎| 100/107 [01:14<00:06,  1.03batch/s, batch_idx=54, gpu=1, loss=0.478, v_num=g0ku9slz]
# Epoch 3:  94%|█████████▍| 101/107 [01:15<00:05,  1.13batch/s, batch_idx=54, gpu=1, loss=0.478, v_num=g0ku9slz]
# Epoch 3:  95%|█████████▌| 102/107 [01:16<00:04,  1.09batch/s, batch_idx=54, gpu=1, loss=0.478, v_num=g0ku9slz]
# Epoch 3:  96%|█████████▋| 103/107 [01:16<00:03,  1.15batch/s, batch_idx=54, gpu=1, loss=0.478, v_num=g0ku9slz]
# Epoch 3:  97%|█████████▋| 104/107 [01:17<00:02,  1.20batch/s, batch_idx=54, gpu=1, loss=0.478, v_num=g0ku9slz]
# Epoch 3:  98%|█████████▊| 105/107 [01:18<00:01,  1.21batch/s, batch_idx=54, gpu=1, loss=0.478, v_num=g0ku9slz]
# Epoch 3:  99%|█████████▉| 106/107 [01:19<00:00,  1.16batch/s, batch_idx=54, gpu=1, loss=0.478, v_num=g0ku9slz]
# Epoch 3: 100%|██████████| 107/107 [01:23<00:00,  1.23batch/s, batch_idx=54, gpu=1, loss=0.478, v_num=g0ku9slz]
# Epoch 4:  51%|█████▏    | 55/107 [00:24<00:16,  3.09batch/s, batch_idx=54, gpu=1, loss=0.441, v_num=g0ku9slz]
# Validating:   0%|          | 0/52 [00:00<?, ?batch/s]
# Epoch 4:  52%|█████▏    | 56/107 [00:28<01:15,  1.47s/batch, batch_idx=54, gpu=1, loss=0.441, v_num=g0ku9slz]
# Epoch 4:  53%|█████▎    | 57/107 [00:31<01:30,  1.81s/batch, batch_idx=54, gpu=1, loss=0.441, v_num=g0ku9slz]
# Epoch 4:  54%|█████▍    | 58/107 [00:32<01:17,  1.58s/batch, batch_idx=54, gpu=1, loss=0.441, v_num=g0ku9slz]
# Epoch 4:  55%|█████▌    | 59/107 [00:33<01:13,  1.53s/batch, batch_idx=54, gpu=1, loss=0.441, v_num=g0ku9slz]
# Epoch 4:  56%|█████▌    | 60/107 [00:36<01:32,  1.96s/batch, batch_idx=54, gpu=1, loss=0.441, v_num=g0ku9slz]
# Epoch 4:  57%|█████▋    | 61/107 [00:37<01:15,  1.65s/batch, batch_idx=54, gpu=1, loss=0.441, v_num=g0ku9slz]
# Epoch 4:  58%|█████▊    | 62/107 [00:39<01:07,  1.51s/batch, batch_idx=54, gpu=1, loss=0.441, v_num=g0ku9slz]
# Epoch 4:  59%|█████▉    | 63/107 [00:39<00:56,  1.29s/batch, batch_idx=54, gpu=1, loss=0.441, v_num=g0ku9slz]
# Epoch 4:  60%|█████▉    | 64/107 [00:40<00:51,  1.19s/batch, batch_idx=54, gpu=1, loss=0.441, v_num=g0ku9slz]
# Epoch 4:  61%|██████    | 65/107 [00:41<00:46,  1.12s/batch, batch_idx=54, gpu=1, loss=0.441, v_num=g0ku9slz]
# Epoch 4:  62%|██████▏   | 66/107 [00:42<00:45,  1.12s/batch, batch_idx=54, gpu=1, loss=0.441, v_num=g0ku9slz]
# Epoch 4:  63%|██████▎   | 67/107 [00:43<00:43,  1.09s/batch, batch_idx=54, gpu=1, loss=0.441, v_num=g0ku9slz]
# Epoch 4:  64%|██████▎   | 68/107 [00:44<00:40,  1.05s/batch, batch_idx=54, gpu=1, loss=0.441, v_num=g0ku9slz]
# Epoch 4:  64%|██████▍   | 69/107 [00:45<00:39,  1.05s/batch, batch_idx=54, gpu=1, loss=0.441, v_num=g0ku9slz]
# Epoch 4:  65%|██████▌   | 70/107 [00:46<00:38,  1.03s/batch, batch_idx=54, gpu=1, loss=0.441, v_num=g0ku9slz]
# Epoch 4:  66%|██████▋   | 71/107 [00:48<00:39,  1.10s/batch, batch_idx=54, gpu=1, loss=0.441, v_num=g0ku9slz]
# Epoch 4:  67%|██████▋   | 72/107 [00:49<00:37,  1.08s/batch, batch_idx=54, gpu=1, loss=0.441, v_num=g0ku9slz]
# Epoch 4:  68%|██████▊   | 73/107 [00:49<00:33,  1.03batch/s, batch_idx=54, gpu=1, loss=0.441, v_num=g0ku9slz]
# Epoch 4:  69%|██████▉   | 74/107 [00:50<00:33,  1.00s/batch, batch_idx=54, gpu=1, loss=0.441, v_num=g0ku9slz]
# Epoch 4:  70%|███████   | 75/107 [00:51<00:29,  1.07batch/s, batch_idx=54, gpu=1, loss=0.441, v_num=g0ku9slz]
# Epoch 4:  71%|███████   | 76/107 [00:52<00:27,  1.13batch/s, batch_idx=54, gpu=1, loss=0.441, v_num=g0ku9slz]
# Epoch 4:  72%|███████▏  | 77/107 [00:53<00:26,  1.12batch/s, batch_idx=54, gpu=1, loss=0.441, v_num=g0ku9slz]
# Epoch 4:  73%|███████▎  | 78/107 [00:54<00:29,  1.01s/batch, batch_idx=54, gpu=1, loss=0.441, v_num=g0ku9slz]
# Epoch 4:  74%|███████▍  | 79/107 [00:55<00:26,  1.07batch/s, batch_idx=54, gpu=1, loss=0.441, v_num=g0ku9slz]
# Epoch 4:  75%|███████▍  | 80/107 [00:56<00:25,  1.05batch/s, batch_idx=54, gpu=1, loss=0.441, v_num=g0ku9slz]
# Epoch 4:  76%|███████▌  | 81/107 [00:57<00:22,  1.16batch/s, batch_idx=54, gpu=1, loss=0.441, v_num=g0ku9slz]
# Epoch 4:  77%|███████▋  | 82/107 [00:57<00:20,  1.20batch/s, batch_idx=54, gpu=1, loss=0.441, v_num=g0ku9slz]
# Epoch 4:  78%|███████▊  | 83/107 [00:58<00:20,  1.18batch/s, batch_idx=54, gpu=1, loss=0.441, v_num=g0ku9slz]
# Epoch 4:  79%|███████▊  | 84/107 [00:59<00:18,  1.23batch/s, batch_idx=54, gpu=1, loss=0.441, v_num=g0ku9slz]
# Epoch 4:  79%|███████▉  | 85/107 [01:00<00:17,  1.25batch/s, batch_idx=54, gpu=1, loss=0.441, v_num=g0ku9slz]
# Epoch 4:  80%|████████  | 86/107 [01:01<00:17,  1.23batch/s, batch_idx=54, gpu=1, loss=0.441, v_num=g0ku9slz]
# Epoch 4:  81%|████████▏ | 87/107 [01:01<00:16,  1.23batch/s, batch_idx=54, gpu=1, loss=0.441, v_num=g0ku9slz]
# Epoch 4:  82%|████████▏ | 88/107 [01:02<00:15,  1.24batch/s, batch_idx=54, gpu=1, loss=0.441, v_num=g0ku9slz]
# Epoch 4:  83%|████████▎ | 89/107 [01:03<00:14,  1.22batch/s, batch_idx=54, gpu=1, loss=0.441, v_num=g0ku9slz]
# Epoch 4:  84%|████████▍ | 90/107 [01:04<00:15,  1.13batch/s, batch_idx=54, gpu=1, loss=0.441, v_num=g0ku9slz]
# Epoch 4:  85%|████████▌ | 91/107 [01:05<00:13,  1.17batch/s, batch_idx=54, gpu=1, loss=0.441, v_num=g0ku9slz]
# Epoch 4:  86%|████████▌ | 92/107 [01:06<00:14,  1.01batch/s, batch_idx=54, gpu=1, loss=0.441, v_num=g0ku9slz]
# Epoch 4:  87%|████████▋ | 93/107 [01:07<00:12,  1.08batch/s, batch_idx=54, gpu=1, loss=0.441, v_num=g0ku9slz]
# Epoch 4:  88%|████████▊ | 94/107 [01:08<00:12,  1.03batch/s, batch_idx=54, gpu=1, loss=0.441, v_num=g0ku9slz]
# Epoch 4:  89%|████████▉ | 95/107 [01:11<00:17,  1.43s/batch, batch_idx=54, gpu=1, loss=0.441, v_num=g0ku9slz]
# Epoch 4:  90%|████████▉ | 96/107 [01:11<00:14,  1.27s/batch, batch_idx=54, gpu=1, loss=0.441, v_num=g0ku9slz]
# Epoch 4:  91%|█████████ | 97/107 [01:13<00:13,  1.35s/batch, batch_idx=54, gpu=1, loss=0.441, v_num=g0ku9slz]
# Epoch 4:  92%|█████████▏| 98/107 [01:14<00:10,  1.19s/batch, batch_idx=54, gpu=1, loss=0.441, v_num=g0ku9slz]
# Epoch 4:  93%|█████████▎| 99/107 [01:15<00:08,  1.09s/batch, batch_idx=54, gpu=1, loss=0.441, v_num=g0ku9slz]
# Epoch 4:  93%|█████████▎| 100/107 [01:15<00:06,  1.01batch/s, batch_idx=54, gpu=1, loss=0.441, v_num=g0ku9slz]
# Epoch 4:  94%|█████████▍| 101/107 [01:16<00:05,  1.11batch/s, batch_idx=54, gpu=1, loss=0.441, v_num=g0ku9slz]
# Epoch 4:  95%|█████████▌| 102/107 [01:17<00:04,  1.06batch/s, batch_idx=54, gpu=1, loss=0.441, v_num=g0ku9slz]
# Epoch 4:  96%|█████████▋| 103/107 [01:18<00:03,  1.10batch/s, batch_idx=54, gpu=1, loss=0.441, v_num=g0ku9slz]
# Epoch 4:  97%|█████████▋| 104/107 [01:21<00:04,  1.51s/batch, batch_idx=54, gpu=1, loss=0.441, v_num=g0ku9slz]
# Epoch 4:  98%|█████████▊| 105/107 [01:22<00:02,  1.32s/batch, batch_idx=54, gpu=1, loss=0.441, v_num=g0ku9slz]
# Epoch 4:  99%|█████████▉| 106/107 [01:23<00:01,  1.24s/batch, batch_idx=54, gpu=1, loss=0.441, v_num=g0ku9slz]
# Epoch 4: 100%|██████████| 107/107 [01:28<00:00,  1.09s/batch, batch_idx=54, gpu=1, loss=0.441, v_num=g0ku9slz]
# Epoch 5:  51%|█████▏    | 55/107 [00:25<00:17,  2.97batch/s, batch_idx=54, gpu=1, loss=0.410, v_num=g0ku9slz]
# Validating:   0%|          | 0/52 [00:00<?, ?batch/s]
# Epoch 5:  52%|█████▏    | 56/107 [00:29<01:16,  1.49s/batch, batch_idx=54, gpu=1, loss=0.410, v_num=g0ku9slz]
# Epoch 5:  53%|█████▎    | 57/107 [00:31<01:26,  1.74s/batch, batch_idx=54, gpu=1, loss=0.410, v_num=g0ku9slz]
# Epoch 5:  54%|█████▍    | 58/107 [00:32<01:15,  1.55s/batch, batch_idx=54, gpu=1, loss=0.410, v_num=g0ku9slz]
# Epoch 5:  55%|█████▌    | 59/107 [00:34<01:14,  1.54s/batch, batch_idx=54, gpu=1, loss=0.410, v_num=g0ku9slz]
# Epoch 5:  56%|█████▌    | 60/107 [00:35<01:04,  1.37s/batch, batch_idx=54, gpu=1, loss=0.410, v_num=g0ku9slz]
# Epoch 5:  57%|█████▋    | 61/107 [00:36<00:58,  1.26s/batch, batch_idx=54, gpu=1, loss=0.410, v_num=g0ku9slz]
# Epoch 5:  58%|█████▊    | 62/107 [00:37<00:58,  1.30s/batch, batch_idx=54, gpu=1, loss=0.410, v_num=g0ku9slz]
# Epoch 5:  59%|█████▉    | 63/107 [00:38<00:50,  1.14s/batch, batch_idx=54, gpu=1, loss=0.410, v_num=g0ku9slz]
# Epoch 5:  60%|█████▉    | 64/107 [00:39<00:46,  1.09s/batch, batch_idx=54, gpu=1, loss=0.410, v_num=g0ku9slz]
# Epoch 5:  61%|██████    | 65/107 [00:40<00:41,  1.00batch/s, batch_idx=54, gpu=1, loss=0.410, v_num=g0ku9slz]
# Epoch 5:  62%|██████▏   | 66/107 [00:41<00:41,  1.01s/batch, batch_idx=54, gpu=1, loss=0.410, v_num=g0ku9slz]
# Epoch 5:  63%|██████▎   | 67/107 [00:42<00:39,  1.02batch/s, batch_idx=54, gpu=1, loss=0.410, v_num=g0ku9slz]
# Epoch 5:  64%|██████▎   | 68/107 [00:43<00:37,  1.05batch/s, batch_idx=54, gpu=1, loss=0.410, v_num=g0ku9slz]
# Epoch 5:  64%|██████▍   | 69/107 [00:44<00:36,  1.05batch/s, batch_idx=54, gpu=1, loss=0.410, v_num=g0ku9slz]
# Epoch 5:  65%|██████▌   | 70/107 [00:44<00:34,  1.07batch/s, batch_idx=54, gpu=1, loss=0.410, v_num=g0ku9slz]
# Epoch 5:  66%|██████▋   | 71/107 [00:46<00:36,  1.01s/batch, batch_idx=54, gpu=1, loss=0.410, v_num=g0ku9slz]
# Epoch 5:  67%|██████▋   | 72/107 [00:47<00:35,  1.01s/batch, batch_idx=54, gpu=1, loss=0.410, v_num=g0ku9slz]
# Epoch 5:  68%|██████▊   | 73/107 [00:47<00:30,  1.11batch/s, batch_idx=54, gpu=1, loss=0.410, v_num=g0ku9slz]
# Epoch 5:  69%|██████▉   | 74/107 [00:48<00:30,  1.08batch/s, batch_idx=54, gpu=1, loss=0.410, v_num=g0ku9slz]
# Epoch 5:  70%|███████   | 75/107 [00:49<00:27,  1.15batch/s, batch_idx=54, gpu=1, loss=0.410, v_num=g0ku9slz]
# Epoch 5:  71%|███████   | 76/107 [00:50<00:25,  1.21batch/s, batch_idx=54, gpu=1, loss=0.410, v_num=g0ku9slz]
# Epoch 5:  72%|███████▏  | 77/107 [00:51<00:25,  1.19batch/s, batch_idx=54, gpu=1, loss=0.410, v_num=g0ku9slz]
# Epoch 5:  73%|███████▎  | 78/107 [00:52<00:27,  1.04batch/s, batch_idx=54, gpu=1, loss=0.410, v_num=g0ku9slz]
# Epoch 5:  74%|███████▍  | 79/107 [00:53<00:24,  1.12batch/s, batch_idx=54, gpu=1, loss=0.410, v_num=g0ku9slz]
# Epoch 5:  75%|███████▍  | 80/107 [00:53<00:24,  1.10batch/s, batch_idx=54, gpu=1, loss=0.410, v_num=g0ku9slz]
# Epoch 5:  76%|███████▌  | 81/107 [00:54<00:21,  1.21batch/s, batch_idx=54, gpu=1, loss=0.410, v_num=g0ku9slz]
# Epoch 5:  77%|███████▋  | 82/107 [00:55<00:19,  1.25batch/s, batch_idx=54, gpu=1, loss=0.410, v_num=g0ku9slz]
# Epoch 5:  78%|███████▊  | 83/107 [00:56<00:19,  1.22batch/s, batch_idx=54, gpu=1, loss=0.410, v_num=g0ku9slz]
# Epoch 5:  79%|███████▊  | 84/107 [00:56<00:18,  1.27batch/s, batch_idx=54, gpu=1, loss=0.410, v_num=g0ku9slz]
# Epoch 5:  79%|███████▉  | 85/107 [00:57<00:16,  1.30batch/s, batch_idx=54, gpu=1, loss=0.410, v_num=g0ku9slz]
# Epoch 5:  80%|████████  | 86/107 [00:58<00:16,  1.29batch/s, batch_idx=54, gpu=1, loss=0.410, v_num=g0ku9slz]
# Epoch 5:  81%|████████▏ | 87/107 [00:59<00:15,  1.28batch/s, batch_idx=54, gpu=1, loss=0.410, v_num=g0ku9slz]
# Epoch 5:  82%|████████▏ | 88/107 [01:00<00:14,  1.29batch/s, batch_idx=54, gpu=1, loss=0.410, v_num=g0ku9slz]
# Epoch 5:  83%|████████▎ | 89/107 [01:00<00:14,  1.25batch/s, batch_idx=54, gpu=1, loss=0.410, v_num=g0ku9slz]
# Epoch 5:  84%|████████▍ | 90/107 [01:01<00:14,  1.16batch/s, batch_idx=54, gpu=1, loss=0.410, v_num=g0ku9slz]
# Epoch 5:  85%|████████▌ | 91/107 [01:02<00:13,  1.20batch/s, batch_idx=54, gpu=1, loss=0.410, v_num=g0ku9slz]
# Epoch 5:  86%|████████▌ | 92/107 [01:03<00:14,  1.04batch/s, batch_idx=54, gpu=1, loss=0.410, v_num=g0ku9slz]
# Epoch 5:  87%|████████▋ | 93/107 [01:04<00:12,  1.11batch/s, batch_idx=54, gpu=1, loss=0.410, v_num=g0ku9slz]
# Epoch 5:  88%|████████▊ | 94/107 [01:05<00:12,  1.03batch/s, batch_idx=54, gpu=1, loss=0.410, v_num=g0ku9slz]
# Epoch 5:  89%|████████▉ | 95/107 [01:08<00:17,  1.43s/batch, batch_idx=54, gpu=1, loss=0.410, v_num=g0ku9slz]
# Epoch 5:  90%|████████▉ | 96/107 [01:09<00:13,  1.27s/batch, batch_idx=54, gpu=1, loss=0.410, v_num=g0ku9slz]
# Epoch 5:  91%|█████████ | 97/107 [01:10<00:13,  1.32s/batch, batch_idx=54, gpu=1, loss=0.410, v_num=g0ku9slz]
# Epoch 5:  92%|█████████▏| 98/107 [01:11<00:10,  1.15s/batch, batch_idx=54, gpu=1, loss=0.410, v_num=g0ku9slz]
# Epoch 5:  93%|█████████▎| 99/107 [01:12<00:08,  1.04s/batch, batch_idx=54, gpu=1, loss=0.410, v_num=g0ku9slz]
# Epoch 5:  93%|█████████▎| 100/107 [01:12<00:06,  1.05batch/s, batch_idx=54, gpu=1, loss=0.410, v_num=g0ku9slz]
# Epoch 5:  94%|█████████▍| 101/107 [01:13<00:05,  1.13batch/s, batch_idx=54, gpu=1, loss=0.410, v_num=g0ku9slz]
# Epoch 5:  95%|█████████▌| 102/107 [01:14<00:04,  1.09batch/s, batch_idx=54, gpu=1, loss=0.410, v_num=g0ku9slz]
# Epoch 5:  96%|█████████▋| 103/107 [01:15<00:03,  1.15batch/s, batch_idx=54, gpu=1, loss=0.410, v_num=g0ku9slz]
# Epoch 5:  97%|█████████▋| 104/107 [01:16<00:02,  1.22batch/s, batch_idx=54, gpu=1, loss=0.410, v_num=g0ku9slz]
# Epoch 5:  98%|█████████▊| 105/107 [01:19<00:03,  1.70s/batch, batch_idx=54, gpu=1, loss=0.410, v_num=g0ku9slz]
# Epoch 5:  99%|█████████▉| 106/107 [01:20<00:01,  1.47s/batch, batch_idx=54, gpu=1, loss=0.410, v_num=g0ku9slz]
# Epoch 5: 100%|██████████| 107/107 [01:24<00:00,  1.24s/batch, batch_idx=54, gpu=1, loss=0.410, v_num=g0ku9slz]
# Epoch 6:  51%|█████▏    | 55/107 [00:25<00:17,  2.96batch/s, batch_idx=54, gpu=1, loss=0.381, v_num=g0ku9slz]
# Validating:   0%|          | 0/52 [00:00<?, ?batch/s]
# Epoch 6:  52%|█████▏    | 56/107 [00:30<01:28,  1.74s/batch, batch_idx=54, gpu=1, loss=0.381, v_num=g0ku9slz]
# Epoch 6:  53%|█████▎    | 57/107 [00:32<01:33,  1.88s/batch, batch_idx=54, gpu=1, loss=0.381, v_num=g0ku9slz]
# Epoch 6:  54%|█████▍    | 58/107 [00:33<01:19,  1.62s/batch, batch_idx=54, gpu=1, loss=0.381, v_num=g0ku9slz]
# Epoch 6:  55%|█████▌    | 59/107 [00:34<01:10,  1.47s/batch, batch_idx=54, gpu=1, loss=0.381, v_num=g0ku9slz]
# Epoch 6:  56%|█████▌    | 60/107 [00:36<01:02,  1.34s/batch, batch_idx=54, gpu=1, loss=0.381, v_num=g0ku9slz]
# Epoch 6:  57%|█████▋    | 61/107 [00:36<00:54,  1.18s/batch, batch_idx=54, gpu=1, loss=0.381, v_num=g0ku9slz]
# Epoch 6:  58%|█████▊    | 62/107 [00:38<00:55,  1.23s/batch, batch_idx=54, gpu=1, loss=0.381, v_num=g0ku9slz]
# Epoch 6:  59%|█████▉    | 63/107 [00:39<00:49,  1.12s/batch, batch_idx=54, gpu=1, loss=0.381, v_num=g0ku9slz]
# Epoch 6:  60%|█████▉    | 64/107 [00:39<00:45,  1.07s/batch, batch_idx=54, gpu=1, loss=0.381, v_num=g0ku9slz]
# Epoch 6:  61%|██████    | 65/107 [00:40<00:41,  1.01batch/s, batch_idx=54, gpu=1, loss=0.381, v_num=g0ku9slz]
# Epoch 6:  62%|██████▏   | 66/107 [00:41<00:42,  1.04s/batch, batch_idx=54, gpu=1, loss=0.381, v_num=g0ku9slz]
# Epoch 6:  63%|██████▎   | 67/107 [00:42<00:41,  1.03s/batch, batch_idx=54, gpu=1, loss=0.381, v_num=g0ku9slz]
# Epoch 6:  64%|██████▎   | 68/107 [00:43<00:37,  1.03batch/s, batch_idx=54, gpu=1, loss=0.381, v_num=g0ku9slz]
# Epoch 6:  64%|██████▍   | 69/107 [00:44<00:37,  1.02batch/s, batch_idx=54, gpu=1, loss=0.381, v_num=g0ku9slz]
# Epoch 6:  65%|██████▌   | 70/107 [00:45<00:35,  1.04batch/s, batch_idx=54, gpu=1, loss=0.381, v_num=g0ku9slz]
# Epoch 6:  66%|██████▋   | 71/107 [00:46<00:37,  1.03s/batch, batch_idx=54, gpu=1, loss=0.381, v_num=g0ku9slz]
# Epoch 6:  67%|██████▋   | 72/107 [00:47<00:35,  1.02s/batch, batch_idx=54, gpu=1, loss=0.381, v_num=g0ku9slz]
# Epoch 6:  68%|██████▊   | 73/107 [00:48<00:31,  1.07batch/s, batch_idx=54, gpu=1, loss=0.381, v_num=g0ku9slz]
# Epoch 6:  69%|██████▉   | 74/107 [00:49<00:31,  1.04batch/s, batch_idx=54, gpu=1, loss=0.381, v_num=g0ku9slz]
# Epoch 6:  70%|███████   | 75/107 [00:50<00:28,  1.11batch/s, batch_idx=54, gpu=1, loss=0.381, v_num=g0ku9slz]
# Epoch 6:  71%|███████   | 76/107 [00:51<00:26,  1.16batch/s, batch_idx=54, gpu=1, loss=0.381, v_num=g0ku9slz]
# Epoch 6:  72%|███████▏  | 77/107 [00:52<00:25,  1.15batch/s, batch_idx=54, gpu=1, loss=0.381, v_num=g0ku9slz]
# Epoch 6:  73%|███████▎  | 78/107 [00:53<00:28,  1.01batch/s, batch_idx=54, gpu=1, loss=0.381, v_num=g0ku9slz]
# Epoch 6:  74%|███████▍  | 79/107 [00:54<00:25,  1.09batch/s, batch_idx=54, gpu=1, loss=0.381, v_num=g0ku9slz]
# Epoch 6:  75%|███████▍  | 80/107 [00:55<00:25,  1.07batch/s, batch_idx=54, gpu=1, loss=0.381, v_num=g0ku9slz]
# Epoch 6:  76%|███████▌  | 81/107 [00:55<00:21,  1.18batch/s, batch_idx=54, gpu=1, loss=0.381, v_num=g0ku9slz]
# Epoch 6:  77%|███████▋  | 82/107 [00:56<00:20,  1.22batch/s, batch_idx=54, gpu=1, loss=0.381, v_num=g0ku9slz]
# Epoch 6:  78%|███████▊  | 83/107 [00:57<00:20,  1.18batch/s, batch_idx=54, gpu=1, loss=0.381, v_num=g0ku9slz]
# Epoch 6:  79%|███████▊  | 84/107 [00:58<00:18,  1.24batch/s, batch_idx=54, gpu=1, loss=0.381, v_num=g0ku9slz]
# Epoch 6:  79%|███████▉  | 85/107 [00:58<00:17,  1.26batch/s, batch_idx=54, gpu=1, loss=0.381, v_num=g0ku9slz]
# Epoch 6:  80%|████████  | 86/107 [00:59<00:16,  1.24batch/s, batch_idx=54, gpu=1, loss=0.381, v_num=g0ku9slz]
# Epoch 6:  81%|████████▏ | 87/107 [01:00<00:16,  1.25batch/s, batch_idx=54, gpu=1, loss=0.381, v_num=g0ku9slz]
# Epoch 6:  82%|████████▏ | 88/107 [01:01<00:15,  1.24batch/s, batch_idx=54, gpu=1, loss=0.381, v_num=g0ku9slz]
# Epoch 6:  83%|████████▎ | 89/107 [01:02<00:14,  1.22batch/s, batch_idx=54, gpu=1, loss=0.381, v_num=g0ku9slz]
# Epoch 6:  84%|████████▍ | 90/107 [01:03<00:14,  1.15batch/s, batch_idx=54, gpu=1, loss=0.381, v_num=g0ku9slz]
# Epoch 6:  85%|████████▌ | 91/107 [01:03<00:13,  1.18batch/s, batch_idx=54, gpu=1, loss=0.381, v_num=g0ku9slz]
# Epoch 6:  86%|████████▌ | 92/107 [01:05<00:14,  1.03batch/s, batch_idx=54, gpu=1, loss=0.381, v_num=g0ku9slz]
# Epoch 6:  87%|████████▋ | 93/107 [01:05<00:12,  1.09batch/s, batch_idx=54, gpu=1, loss=0.381, v_num=g0ku9slz]
# Epoch 6:  88%|████████▊ | 94/107 [01:07<00:12,  1.03batch/s, batch_idx=54, gpu=1, loss=0.381, v_num=g0ku9slz]
# Epoch 6:  89%|████████▉ | 95/107 [01:09<00:17,  1.43s/batch, batch_idx=54, gpu=1, loss=0.381, v_num=g0ku9slz]
# Epoch 6:  90%|████████▉ | 96/107 [01:10<00:14,  1.27s/batch, batch_idx=54, gpu=1, loss=0.381, v_num=g0ku9slz]
# Epoch 6:  91%|█████████ | 97/107 [01:11<00:13,  1.34s/batch, batch_idx=54, gpu=1, loss=0.381, v_num=g0ku9slz]
# Epoch 6:  92%|█████████▏| 98/107 [01:12<00:10,  1.18s/batch, batch_idx=54, gpu=1, loss=0.381, v_num=g0ku9slz]
# Epoch 6:  93%|█████████▎| 99/107 [01:13<00:08,  1.07s/batch, batch_idx=54, gpu=1, loss=0.381, v_num=g0ku9slz]
# Epoch 6:  93%|█████████▎| 100/107 [01:14<00:06,  1.03batch/s, batch_idx=54, gpu=1, loss=0.381, v_num=g0ku9slz]
# Epoch 6:  94%|█████████▍| 101/107 [01:15<00:05,  1.11batch/s, batch_idx=54, gpu=1, loss=0.381, v_num=g0ku9slz]
# Epoch 6:  95%|█████████▌| 102/107 [01:16<00:04,  1.06batch/s, batch_idx=54, gpu=1, loss=0.381, v_num=g0ku9slz]
# Epoch 6:  96%|█████████▋| 103/107 [01:16<00:03,  1.10batch/s, batch_idx=54, gpu=1, loss=0.381, v_num=g0ku9slz]
# Epoch 6:  97%|█████████▋| 104/107 [01:17<00:02,  1.15batch/s, batch_idx=54, gpu=1, loss=0.381, v_num=g0ku9slz]
# Epoch 6:  98%|█████████▊| 105/107 [01:18<00:01,  1.17batch/s, batch_idx=54, gpu=1, loss=0.381, v_num=g0ku9slz]
# Epoch 6:  99%|█████████▉| 106/107 [01:19<00:00,  1.13batch/s, batch_idx=54, gpu=1, loss=0.381, v_num=g0ku9slz]
# Epoch 6: 100%|██████████| 107/107 [01:23<00:00,  1.17batch/s, batch_idx=54, gpu=1, loss=0.381, v_num=g0ku9slz]
# Epoch 7:  51%|█████▏    | 55/107 [00:24<00:17,  2.90batch/s, batch_idx=54, gpu=1, loss=0.355, v_num=g0ku9slz]
# Validating:   0%|          | 0/52 [00:00<?, ?batch/s]
# Epoch 7:  52%|█████▏    | 56/107 [00:29<01:22,  1.63s/batch, batch_idx=54, gpu=1, loss=0.355, v_num=g0ku9slz]
# Epoch 7:  53%|█████▎    | 57/107 [00:31<01:28,  1.77s/batch, batch_idx=54, gpu=1, loss=0.355, v_num=g0ku9slz]
# Epoch 7:  54%|█████▍    | 58/107 [00:32<01:14,  1.52s/batch, batch_idx=54, gpu=1, loss=0.355, v_num=g0ku9slz]
# Epoch 7:  55%|█████▌    | 59/107 [00:33<01:06,  1.39s/batch, batch_idx=54, gpu=1, loss=0.355, v_num=g0ku9slz]
# Epoch 7:  56%|█████▌    | 60/107 [00:34<00:59,  1.27s/batch, batch_idx=54, gpu=1, loss=0.355, v_num=g0ku9slz]
# Epoch 7:  57%|█████▋    | 61/107 [00:35<00:52,  1.15s/batch, batch_idx=54, gpu=1, loss=0.355, v_num=g0ku9slz]
# Epoch 7:  58%|█████▊    | 62/107 [00:37<00:59,  1.32s/batch, batch_idx=54, gpu=1, loss=0.355, v_num=g0ku9slz]
# Epoch 7:  59%|█████▉    | 63/107 [00:38<00:52,  1.20s/batch, batch_idx=54, gpu=1, loss=0.355, v_num=g0ku9slz]
# Epoch 7:  60%|█████▉    | 64/107 [00:38<00:47,  1.11s/batch, batch_idx=54, gpu=1, loss=0.355, v_num=g0ku9slz]
# Epoch 7:  61%|██████    | 65/107 [00:39<00:42,  1.02s/batch, batch_idx=54, gpu=1, loss=0.355, v_num=g0ku9slz]
# Epoch 7:  62%|██████▏   | 66/107 [00:40<00:41,  1.01s/batch, batch_idx=54, gpu=1, loss=0.355, v_num=g0ku9slz]
# Epoch 7:  63%|██████▎   | 67/107 [00:45<01:25,  2.13s/batch, batch_idx=54, gpu=1, loss=0.355, v_num=g0ku9slz]
# Epoch 7:  64%|██████▎   | 68/107 [00:46<01:07,  1.73s/batch, batch_idx=54, gpu=1, loss=0.355, v_num=g0ku9slz]
# Epoch 7:  64%|██████▍   | 69/107 [00:47<00:57,  1.51s/batch, batch_idx=54, gpu=1, loss=0.355, v_num=g0ku9slz]
# Epoch 7:  65%|██████▌   | 70/107 [00:48<00:48,  1.32s/batch, batch_idx=54, gpu=1, loss=0.355, v_num=g0ku9slz]
# Epoch 7:  66%|██████▋   | 71/107 [00:49<00:45,  1.28s/batch, batch_idx=54, gpu=1, loss=0.355, v_num=g0ku9slz]
# Epoch 7:  67%|██████▋   | 72/107 [00:50<00:41,  1.19s/batch, batch_idx=54, gpu=1, loss=0.355, v_num=g0ku9slz]
# Epoch 7:  68%|██████▊   | 73/107 [00:50<00:34,  1.03s/batch, batch_idx=54, gpu=1, loss=0.355, v_num=g0ku9slz]
# Epoch 7:  69%|██████▉   | 74/107 [00:51<00:33,  1.01s/batch, batch_idx=54, gpu=1, loss=0.355, v_num=g0ku9slz]
# Epoch 7:  70%|███████   | 75/107 [00:52<00:29,  1.08batch/s, batch_idx=54, gpu=1, loss=0.355, v_num=g0ku9slz]
# Epoch 7:  71%|███████   | 76/107 [00:53<00:27,  1.14batch/s, batch_idx=54, gpu=1, loss=0.355, v_num=g0ku9slz]
# Epoch 7:  72%|███████▏  | 77/107 [00:54<00:26,  1.15batch/s, batch_idx=54, gpu=1, loss=0.355, v_num=g0ku9slz]
# Epoch 7:  73%|███████▎  | 78/107 [00:55<00:28,  1.02batch/s, batch_idx=54, gpu=1, loss=0.355, v_num=g0ku9slz]
# Epoch 7:  74%|███████▍  | 79/107 [00:56<00:25,  1.11batch/s, batch_idx=54, gpu=1, loss=0.355, v_num=g0ku9slz]
# Epoch 7:  75%|███████▍  | 80/107 [00:57<00:24,  1.10batch/s, batch_idx=54, gpu=1, loss=0.355, v_num=g0ku9slz]
# Epoch 7:  76%|███████▌  | 81/107 [00:57<00:21,  1.21batch/s, batch_idx=54, gpu=1, loss=0.355, v_num=g0ku9slz]
# Epoch 7:  77%|███████▋  | 82/107 [00:58<00:20,  1.23batch/s, batch_idx=54, gpu=1, loss=0.355, v_num=g0ku9slz]
# Epoch 7:  78%|███████▊  | 83/107 [00:59<00:19,  1.20batch/s, batch_idx=54, gpu=1, loss=0.355, v_num=g0ku9slz]
# Epoch 7:  79%|███████▊  | 84/107 [01:00<00:18,  1.26batch/s, batch_idx=54, gpu=1, loss=0.355, v_num=g0ku9slz]
# Epoch 7:  79%|███████▉  | 85/107 [01:00<00:17,  1.28batch/s, batch_idx=54, gpu=1, loss=0.355, v_num=g0ku9slz]
# Epoch 7:  80%|████████  | 86/107 [01:01<00:16,  1.28batch/s, batch_idx=54, gpu=1, loss=0.355, v_num=g0ku9slz]
# Epoch 7:  81%|████████▏ | 87/107 [01:02<00:15,  1.29batch/s, batch_idx=54, gpu=1, loss=0.355, v_num=g0ku9slz]
# Epoch 7:  82%|████████▏ | 88/107 [01:03<00:14,  1.29batch/s, batch_idx=54, gpu=1, loss=0.355, v_num=g0ku9slz]
# Epoch 7:  83%|████████▎ | 89/107 [01:04<00:14,  1.25batch/s, batch_idx=54, gpu=1, loss=0.355, v_num=g0ku9slz]
# Epoch 7:  84%|████████▍ | 90/107 [01:05<00:14,  1.15batch/s, batch_idx=54, gpu=1, loss=0.355, v_num=g0ku9slz]
# Epoch 7:  85%|████████▌ | 91/107 [01:05<00:13,  1.19batch/s, batch_idx=54, gpu=1, loss=0.355, v_num=g0ku9slz]
# Epoch 7:  86%|████████▌ | 92/107 [01:07<00:14,  1.04batch/s, batch_idx=54, gpu=1, loss=0.355, v_num=g0ku9slz]
# Epoch 7:  87%|████████▋ | 93/107 [01:07<00:12,  1.12batch/s, batch_idx=54, gpu=1, loss=0.355, v_num=g0ku9slz]
# Epoch 7:  88%|████████▊ | 94/107 [01:08<00:12,  1.05batch/s, batch_idx=54, gpu=1, loss=0.355, v_num=g0ku9slz]
# Epoch 7:  89%|████████▉ | 95/107 [01:11<00:16,  1.41s/batch, batch_idx=54, gpu=1, loss=0.355, v_num=g0ku9slz]
# Epoch 7:  90%|████████▉ | 96/107 [01:12<00:13,  1.26s/batch, batch_idx=54, gpu=1, loss=0.355, v_num=g0ku9slz]
# Epoch 7:  91%|█████████ | 97/107 [01:13<00:13,  1.31s/batch, batch_idx=54, gpu=1, loss=0.355, v_num=g0ku9slz]
# Epoch 7:  92%|█████████▏| 98/107 [01:14<00:10,  1.15s/batch, batch_idx=54, gpu=1, loss=0.355, v_num=g0ku9slz]
# Epoch 7:  93%|█████████▎| 99/107 [01:15<00:08,  1.04s/batch, batch_idx=54, gpu=1, loss=0.355, v_num=g0ku9slz]
# Epoch 7:  93%|█████████▎| 100/107 [01:16<00:06,  1.05batch/s, batch_idx=54, gpu=1, loss=0.355, v_num=g0ku9slz]
# Epoch 7:  94%|█████████▍| 101/107 [01:16<00:05,  1.14batch/s, batch_idx=54, gpu=1, loss=0.355, v_num=g0ku9slz]
# Epoch 7:  95%|█████████▌| 102/107 [01:17<00:04,  1.09batch/s, batch_idx=54, gpu=1, loss=0.355, v_num=g0ku9slz]
# Epoch 7:  96%|█████████▋| 103/107 [01:18<00:03,  1.15batch/s, batch_idx=54, gpu=1, loss=0.355, v_num=g0ku9slz]
# Epoch 7:  97%|█████████▋| 104/107 [01:19<00:02,  1.22batch/s, batch_idx=54, gpu=1, loss=0.355, v_num=g0ku9slz]
# Epoch 7:  98%|█████████▊| 105/107 [01:20<00:01,  1.23batch/s, batch_idx=54, gpu=1, loss=0.355, v_num=g0ku9slz]
# Epoch 7:  99%|█████████▉| 106/107 [01:20<00:00,  1.18batch/s, batch_idx=54, gpu=1, loss=0.355, v_num=g0ku9slz]
# Epoch 7: 100%|██████████| 107/107 [01:24<00:00,  1.24batch/s, batch_idx=54, gpu=1, loss=0.355, v_num=g0ku9slz]
# Epoch 8:  51%|█████▏    | 55/107 [00:26<00:17,  2.90batch/s, batch_idx=54, gpu=1, loss=0.332, v_num=g0ku9slz]
# Validating:   0%|          | 0/52 [00:00<?, ?batch/s]
# Epoch 8:  52%|█████▏    | 56/107 [00:32<01:35,  1.88s/batch, batch_idx=54, gpu=1, loss=0.332, v_num=g0ku9slz]
# Epoch 8:  53%|█████▎    | 57/107 [00:33<01:27,  1.75s/batch, batch_idx=54, gpu=1, loss=0.332, v_num=g0ku9slz]
# Epoch 8:  54%|█████▍    | 58/107 [00:34<01:14,  1.52s/batch, batch_idx=54, gpu=1, loss=0.332, v_num=g0ku9slz]
# Epoch 8:  55%|█████▌    | 59/107 [00:35<01:07,  1.42s/batch, batch_idx=54, gpu=1, loss=0.332, v_num=g0ku9slz]
# Epoch 8:  56%|█████▌    | 60/107 [00:36<00:59,  1.28s/batch, batch_idx=54, gpu=1, loss=0.332, v_num=g0ku9slz]
# Epoch 8:  57%|█████▋    | 61/107 [00:37<00:51,  1.13s/batch, batch_idx=54, gpu=1, loss=0.332, v_num=g0ku9slz]
# Epoch 8:  58%|█████▊    | 62/107 [00:39<00:58,  1.29s/batch, batch_idx=54, gpu=1, loss=0.332, v_num=g0ku9slz]
# Epoch 8:  59%|█████▉    | 63/107 [00:40<00:51,  1.18s/batch, batch_idx=54, gpu=1, loss=0.332, v_num=g0ku9slz]
# Epoch 8:  60%|█████▉    | 64/107 [00:41<00:48,  1.12s/batch, batch_idx=54, gpu=1, loss=0.332, v_num=g0ku9slz]
# Epoch 8:  61%|██████    | 65/107 [00:41<00:43,  1.04s/batch, batch_idx=54, gpu=1, loss=0.332, v_num=g0ku9slz]
# Epoch 8:  62%|██████▏   | 66/107 [00:42<00:42,  1.04s/batch, batch_idx=54, gpu=1, loss=0.332, v_num=g0ku9slz]
# Epoch 8:  63%|██████▎   | 67/107 [00:43<00:39,  1.01batch/s, batch_idx=54, gpu=1, loss=0.332, v_num=g0ku9slz]
# Epoch 8:  64%|██████▎   | 68/107 [00:44<00:37,  1.03batch/s, batch_idx=54, gpu=1, loss=0.332, v_num=g0ku9slz]
# Epoch 8:  64%|██████▍   | 69/107 [00:45<00:37,  1.03batch/s, batch_idx=54, gpu=1, loss=0.332, v_num=g0ku9slz]
# Epoch 8:  65%|██████▌   | 70/107 [00:46<00:35,  1.05batch/s, batch_idx=54, gpu=1, loss=0.332, v_num=g0ku9slz]
# Epoch 8:  66%|██████▋   | 71/107 [00:47<00:36,  1.02s/batch, batch_idx=54, gpu=1, loss=0.332, v_num=g0ku9slz]
# Epoch 8:  67%|██████▋   | 72/107 [00:48<00:35,  1.01s/batch, batch_idx=54, gpu=1, loss=0.332, v_num=g0ku9slz]
# Epoch 8:  68%|██████▊   | 73/107 [00:49<00:30,  1.11batch/s, batch_idx=54, gpu=1, loss=0.332, v_num=g0ku9slz]
# Epoch 8:  69%|██████▉   | 74/107 [00:50<00:30,  1.08batch/s, batch_idx=54, gpu=1, loss=0.332, v_num=g0ku9slz]
# Epoch 8:  70%|███████   | 75/107 [00:51<00:27,  1.15batch/s, batch_idx=54, gpu=1, loss=0.332, v_num=g0ku9slz]
# Epoch 8:  71%|███████   | 76/107 [00:51<00:25,  1.20batch/s, batch_idx=54, gpu=1, loss=0.332, v_num=g0ku9slz]
# Epoch 8:  72%|███████▏  | 77/107 [00:52<00:25,  1.20batch/s, batch_idx=54, gpu=1, loss=0.332, v_num=g0ku9slz]
# Epoch 8:  73%|███████▎  | 78/107 [00:53<00:27,  1.05batch/s, batch_idx=54, gpu=1, loss=0.332, v_num=g0ku9slz]
# Epoch 8:  74%|███████▍  | 79/107 [00:54<00:24,  1.13batch/s, batch_idx=54, gpu=1, loss=0.332, v_num=g0ku9slz]
# Epoch 8:  75%|███████▍  | 80/107 [00:55<00:24,  1.11batch/s, batch_idx=54, gpu=1, loss=0.332, v_num=g0ku9slz]
# Epoch 8:  76%|███████▌  | 81/107 [00:56<00:21,  1.22batch/s, batch_idx=54, gpu=1, loss=0.332, v_num=g0ku9slz]
# Epoch 8:  77%|███████▋  | 82/107 [00:57<00:19,  1.25batch/s, batch_idx=54, gpu=1, loss=0.332, v_num=g0ku9slz]
# Epoch 8:  78%|███████▊  | 83/107 [00:57<00:19,  1.22batch/s, batch_idx=54, gpu=1, loss=0.332, v_num=g0ku9slz]
# Epoch 8:  79%|███████▊  | 84/107 [00:58<00:18,  1.27batch/s, batch_idx=54, gpu=1, loss=0.332, v_num=g0ku9slz]
# Epoch 8:  79%|███████▉  | 85/107 [00:59<00:16,  1.30batch/s, batch_idx=54, gpu=1, loss=0.332, v_num=g0ku9slz]
# Epoch 8:  80%|████████  | 86/107 [01:00<00:16,  1.29batch/s, batch_idx=54, gpu=1, loss=0.332, v_num=g0ku9slz]
# Epoch 8:  81%|████████▏ | 87/107 [01:00<00:15,  1.30batch/s, batch_idx=54, gpu=1, loss=0.332, v_num=g0ku9slz]
# Epoch 8:  82%|████████▏ | 88/107 [01:01<00:14,  1.30batch/s, batch_idx=54, gpu=1, loss=0.332, v_num=g0ku9slz]
# Epoch 8:  83%|████████▎ | 89/107 [01:02<00:14,  1.26batch/s, batch_idx=54, gpu=1, loss=0.332, v_num=g0ku9slz]
# Epoch 8:  84%|████████▍ | 90/107 [01:03<00:14,  1.15batch/s, batch_idx=54, gpu=1, loss=0.332, v_num=g0ku9slz]
# Epoch 8:  85%|████████▌ | 91/107 [01:04<00:13,  1.17batch/s, batch_idx=54, gpu=1, loss=0.332, v_num=g0ku9slz]
# Epoch 8:  86%|████████▌ | 92/107 [01:05<00:14,  1.02batch/s, batch_idx=54, gpu=1, loss=0.332, v_num=g0ku9slz]
# Epoch 8:  87%|████████▋ | 93/107 [01:06<00:12,  1.10batch/s, batch_idx=54, gpu=1, loss=0.332, v_num=g0ku9slz]
# Epoch 8:  88%|████████▊ | 94/107 [01:07<00:12,  1.03batch/s, batch_idx=54, gpu=1, loss=0.332, v_num=g0ku9slz]
# Epoch 8:  89%|████████▉ | 95/107 [01:10<00:17,  1.43s/batch, batch_idx=54, gpu=1, loss=0.332, v_num=g0ku9slz]
# Epoch 8:  90%|████████▉ | 96/107 [01:10<00:13,  1.27s/batch, batch_idx=54, gpu=1, loss=0.332, v_num=g0ku9slz]
# Epoch 8:  91%|█████████ | 97/107 [01:12<00:13,  1.33s/batch, batch_idx=54, gpu=1, loss=0.332, v_num=g0ku9slz]
# Epoch 8:  92%|█████████▏| 98/107 [01:18<00:23,  2.63s/batch, batch_idx=54, gpu=1, loss=0.332, v_num=g0ku9slz]
# Epoch 8:  93%|█████████▎| 99/107 [01:18<00:16,  2.08s/batch, batch_idx=54, gpu=1, loss=0.332, v_num=g0ku9slz]
# Epoch 8:  93%|█████████▎| 100/107 [01:19<00:11,  1.67s/batch, batch_idx=54, gpu=1, loss=0.332, v_num=g0ku9slz]
# Epoch 8:  94%|█████████▍| 101/107 [01:20<00:08,  1.38s/batch, batch_idx=54, gpu=1, loss=0.332, v_num=g0ku9slz]
# Epoch 8:  95%|█████████▌| 102/107 [01:21<00:06,  1.26s/batch, batch_idx=54, gpu=1, loss=0.332, v_num=g0ku9slz]
# Epoch 8:  96%|█████████▋| 103/107 [01:21<00:04,  1.10s/batch, batch_idx=54, gpu=1, loss=0.332, v_num=g0ku9slz]
# Epoch 8:  97%|█████████▋| 104/107 [01:22<00:02,  1.02batch/s, batch_idx=54, gpu=1, loss=0.332, v_num=g0ku9slz]
# Epoch 8:  98%|█████████▊| 105/107 [01:23<00:01,  1.08batch/s, batch_idx=54, gpu=1, loss=0.332, v_num=g0ku9slz]
# Epoch 8:  99%|█████████▉| 106/107 [01:24<00:00,  1.08batch/s, batch_idx=54, gpu=1, loss=0.332, v_num=g0ku9slz]
# Epoch 8: 100%|██████████| 107/107 [01:28<00:00,  1.16batch/s, batch_idx=54, gpu=1, loss=0.332, v_num=g0ku9slz]
# Epoch 9:  51%|█████▏    | 55/107 [00:25<00:17,  2.95batch/s, batch_idx=54, gpu=1, loss=0.313, v_num=g0ku9slz]
# Validating:   0%|          | 0/52 [00:00<?, ?batch/s]
# Epoch 9:  52%|█████▏    | 56/107 [00:30<01:27,  1.71s/batch, batch_idx=54, gpu=1, loss=0.313, v_num=g0ku9slz]
# Epoch 9:  53%|█████▎    | 57/107 [00:33<01:36,  1.93s/batch, batch_idx=54, gpu=1, loss=0.313, v_num=g0ku9slz]
# Epoch 9:  54%|█████▍    | 58/107 [00:34<01:21,  1.67s/batch, batch_idx=54, gpu=1, loss=0.313, v_num=g0ku9slz]
# Epoch 9:  55%|█████▌    | 59/107 [00:35<01:14,  1.56s/batch, batch_idx=54, gpu=1, loss=0.313, v_num=g0ku9slz]
# Epoch 9:  56%|█████▌    | 60/107 [00:36<01:06,  1.40s/batch, batch_idx=54, gpu=1, loss=0.313, v_num=g0ku9slz]
# Epoch 9:  57%|█████▋    | 61/107 [00:37<00:57,  1.25s/batch, batch_idx=54, gpu=1, loss=0.313, v_num=g0ku9slz]
# ...
# Epoch 12:  51%|█████▏    | 55/107 [00:26<00:17,  2.90batch/s, batch_idx=54, gpu=1, loss=0.268, v_num=g0ku9slz]
# Validating:   0%|          | 0/52 [00:00<?, ?batch/s]
# Epoch 12:  52%|█████▏    | 56/107 [00:31<01:34,  1.84s/batch, batch_idx=54, gpu=1, loss=0.268, v_num=g0ku9slz]
# Epoch 12:  53%|█████▎    | 57/107 [00:33<01:39,  2.00s/batch, batch_idx=54, gpu=1, loss=0.268, v_num=g0ku9slz]
# Epoch 12:  54%|█████▍    | 58/107 [00:34<01:22,  1.69s/batch, batch_idx=54, gpu=1, loss=0.268, v_num=g0ku9slz]
# Epoch 12:  55%|█████▌    | 59/107 [00:36<01:14,  1.56s/batch, batch_idx=54, gpu=1, loss=0.268, v_num=g0ku9slz]
# Epoch 12:  56%|█████▌    | 60/107 [00:37<01:05,  1.39s/batch, batch_idx=54, gpu=1, loss=0.268, v_num=g0ku9slz]
# Epoch 12:  57%|█████▋    | 61/107 [00:38<00:56,  1.22s/batch, batch_idx=54, gpu=1, loss=0.268, v_num=g0ku9slz]
# Epoch 12:  58%|█████▊    | 62/107 [00:39<00:57,  1.29s/batch, batch_idx=54, gpu=1, loss=0.268, v_num=g0ku9slz]
# Epoch 12:  59%|█████▉    | 63/107 [00:40<00:50,  1.15s/batch, batch_idx=54, gpu=1, loss=0.268, v_num=g0ku9slz]
# Epoch 12:  60%|█████▉    | 64/107 [00:41<00:46,  1.07s/batch, batch_idx=54, gpu=1, loss=0.268, v_num=g0ku9slz]
# Epoch 12:  61%|██████    | 65/107 [00:42<00:42,  1.01s/batch, batch_idx=54, gpu=1, loss=0.268, v_num=g0ku9slz]
# Epoch 12:  62%|██████▏   | 66/107 [00:43<00:42,  1.04s/batch, batch_idx=54, gpu=1, loss=0.268, v_num=g0ku9slz]
# Epoch 12:  63%|██████▎   | 67/107 [00:44<00:42,  1.06s/batch, batch_idx=54, gpu=1, loss=0.268, v_num=g0ku9slz]
# Epoch 12:  64%|██████▎   | 68/107 [00:45<00:38,  1.00batch/s, batch_idx=54, gpu=1, loss=0.268, v_num=g0ku9slz]
# Epoch 12:  64%|██████▍   | 69/107 [00:46<00:37,  1.01batch/s, batch_idx=54, gpu=1, loss=0.268, v_num=g0ku9slz]
# Epoch 12:  65%|██████▌   | 70/107 [00:47<00:35,  1.03batch/s, batch_idx=54, gpu=1, loss=0.268, v_num=g0ku9slz]
# Epoch 12:  66%|██████▋   | 71/107 [00:48<00:37,  1.04s/batch, batch_idx=54, gpu=1, loss=0.268, v_num=g0ku9slz]
# Epoch 12:  67%|██████▋   | 72/107 [00:49<00:36,  1.03s/batch, batch_idx=54, gpu=1, loss=0.268, v_num=g0ku9slz]
# Epoch 12:  68%|██████▊   | 73/107 [00:49<00:31,  1.08batch/s, batch_idx=54, gpu=1, loss=0.268, v_num=g0ku9slz]
# Epoch 12:  69%|██████▉   | 74/107 [00:50<00:31,  1.06batch/s, batch_idx=54, gpu=1, loss=0.268, v_num=g0ku9slz]
# Epoch 12:  70%|███████   | 75/107 [00:51<00:28,  1.13batch/s, batch_idx=54, gpu=1, loss=0.268, v_num=g0ku9slz]
# Epoch 12:  71%|███████   | 76/107 [00:52<00:26,  1.18batch/s, batch_idx=54, gpu=1, loss=0.268, v_num=g0ku9slz]
# Epoch 12:  72%|███████▏  | 77/107 [00:53<00:25,  1.17batch/s, batch_idx=54, gpu=1, loss=0.268, v_num=g0ku9slz]
# Epoch 12:  73%|███████▎  | 78/107 [00:54<00:28,  1.03batch/s, batch_idx=54, gpu=1, loss=0.268, v_num=g0ku9slz]
# Epoch 12:  74%|███████▍  | 79/107 [00:55<00:25,  1.10batch/s, batch_idx=54, gpu=1, loss=0.268, v_num=g0ku9slz]
# Epoch 12:  75%|███████▍  | 80/107 [00:56<00:25,  1.06batch/s, batch_idx=54, gpu=1, loss=0.268, v_num=g0ku9slz]
# Epoch 12:  76%|███████▌  | 81/107 [00:56<00:22,  1.15batch/s, batch_idx=54, gpu=1, loss=0.268, v_num=g0ku9slz]
# Epoch 12:  77%|███████▋  | 82/107 [00:57<00:20,  1.20batch/s, batch_idx=54, gpu=1, loss=0.268, v_num=g0ku9slz]
# Epoch 12:  78%|███████▊  | 83/107 [00:58<00:20,  1.17batch/s, batch_idx=54, gpu=1, loss=0.268, v_num=g0ku9slz]
# Epoch 12:  79%|███████▊  | 84/107 [00:59<00:18,  1.22batch/s, batch_idx=54, gpu=1, loss=0.268, v_num=g0ku9slz]
# Epoch 12:  79%|███████▉  | 85/107 [01:00<00:17,  1.24batch/s, batch_idx=54, gpu=1, loss=0.268, v_num=g0ku9slz]
# Epoch 12:  80%|████████  | 86/107 [01:00<00:16,  1.24batch/s, batch_idx=54, gpu=1, loss=0.268, v_num=g0ku9slz]
# Epoch 12:  81%|████████▏ | 87/107 [01:01<00:15,  1.25batch/s, batch_idx=54, gpu=1, loss=0.268, v_num=g0ku9slz]
# Epoch 12:  82%|████████▏ | 88/107 [01:02<00:14,  1.27batch/s, batch_idx=54, gpu=1, loss=0.268, v_num=g0ku9slz]
# Epoch 12:  83%|████████▎ | 89/107 [01:03<00:14,  1.23batch/s, batch_idx=54, gpu=1, loss=0.268, v_num=g0ku9slz]
# Epoch 12:  84%|████████▍ | 90/107 [01:04<00:14,  1.14batch/s, batch_idx=54, gpu=1, loss=0.268, v_num=g0ku9slz]
# Epoch 12:  85%|████████▌ | 91/107 [01:05<00:13,  1.18batch/s, batch_idx=54, gpu=1, loss=0.268, v_num=g0ku9slz]
# Epoch 12:  86%|████████▌ | 92/107 [01:06<00:14,  1.03batch/s, batch_idx=54, gpu=1, loss=0.268, v_num=g0ku9slz]
# Epoch 12:  87%|████████▋ | 93/107 [01:07<00:12,  1.08batch/s, batch_idx=54, gpu=1, loss=0.268, v_num=g0ku9slz]
# Epoch 12:  88%|████████▊ | 94/107 [01:08<00:12,  1.02batch/s, batch_idx=54, gpu=1, loss=0.268, v_num=g0ku9slz]
# Epoch 12:  89%|████████▉ | 95/107 [01:10<00:17,  1.43s/batch, batch_idx=54, gpu=1, loss=0.268, v_num=g0ku9slz]
# Epoch 12:  90%|████████▉ | 96/107 [01:11<00:14,  1.29s/batch, batch_idx=54, gpu=1, loss=0.268, v_num=g0ku9slz]
# Epoch 12:  91%|█████████ | 97/107 [01:13<00:13,  1.34s/batch, batch_idx=54, gpu=1, loss=0.268, v_num=g0ku9slz]
# Epoch 12:  92%|█████████▏| 98/107 [01:14<00:10,  1.17s/batch, batch_idx=54, gpu=1, loss=0.268, v_num=g0ku9slz]
# Epoch 12:  93%|█████████▎| 99/107 [01:14<00:08,  1.05s/batch, batch_idx=54, gpu=1, loss=0.268, v_num=g0ku9slz]
# Epoch 12:  93%|█████████▎| 100/107 [01:15<00:06,  1.06batch/s, batch_idx=54, gpu=1, loss=0.268, v_num=g0ku9slz]
# Epoch 12:  94%|█████████▍| 101/107 [01:16<00:05,  1.15batch/s, batch_idx=54, gpu=1, loss=0.268, v_num=g0ku9slz]
# Epoch 12:  95%|█████████▌| 102/107 [01:17<00:04,  1.11batch/s, batch_idx=54, gpu=1, loss=0.268, v_num=g0ku9slz]
# Epoch 12:  96%|█████████▋| 103/107 [01:17<00:03,  1.17batch/s, batch_idx=54, gpu=1, loss=0.268, v_num=g0ku9slz]
# Epoch 12:  97%|█████████▋| 104/107 [01:18<00:02,  1.23batch/s, batch_idx=54, gpu=1, loss=0.268, v_num=g0ku9slz]
# Epoch 12:  98%|█████████▊| 105/107 [01:19<00:01,  1.25batch/s, batch_idx=54, gpu=1, loss=0.268, v_num=g0ku9slz]
# Epoch 12:  99%|█████████▉| 106/107 [01:20<00:00,  1.19batch/s, batch_idx=54, gpu=1, loss=0.268, v_num=g0ku9slz]
# Epoch 12: 100%|██████████| 107/107 [01:24<00:00,  1.25batch/s, batch_idx=54, gpu=1, loss=0.268, v_num=g0ku9slz]
# Epoch 13:  41%|████      | 44/107 [00:22<00:20,  3.01batch/s, batch_idx=43, gpu=1, loss=0.258, v_num=g0ku9slz] Traceback (most recent call last):
#   File "/home/tshimko/.virtualenvs/tesselate/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-7-ab66e5fc0ee8>", line 12, in <module>
#     trainer.fit(model)
#   File "/home/tshimko/.virtualenvs/tesselate/lib/python3.6/site-packages/pytorch_lightning/trainer/trainer.py", line 695, in fit
#     self.single_gpu_train(model)
#   File "/home/tshimko/.virtualenvs/tesselate/lib/python3.6/site-packages/pytorch_lightning/trainer/distrib_parts.py", line 441, in single_gpu_train
#     self.run_pretrain_routine(model)
#   File "/home/tshimko/.virtualenvs/tesselate/lib/python3.6/site-packages/pytorch_lightning/trainer/trainer.py", line 829, in run_pretrain_routine
#     self.train()
#   File "/home/tshimko/.virtualenvs/tesselate/lib/python3.6/site-packages/pytorch_lightning/trainer/training_loop.py", line 332, in train
#     self.run_training_epoch()
#   File "/home/tshimko/.virtualenvs/tesselate/lib/python3.6/site-packages/pytorch_lightning/trainer/training_loop.py", line 386, in run_training_epoch
#     output = self.run_training_batch(batch, batch_idx)
#   File "/home/tshimko/.virtualenvs/tesselate/lib/python3.6/site-packages/pytorch_lightning/trainer/training_loop.py", line 506, in run_training_batch
#     loss = optimizer_closure()
#   File "/home/tshimko/.virtualenvs/tesselate/lib/python3.6/site-packages/pytorch_lightning/trainer/training_loop.py", line 475, in optimizer_closure
#     split_batch, batch_idx, opt_idx, self.hiddens)
#   File "/home/tshimko/.virtualenvs/tesselate/lib/python3.6/site-packages/pytorch_lightning/trainer/training_loop.py", line 593, in training_forward
#     output = self.model.training_step(*args)
#   File "<ipython-input-4-3c7ce4c0af25>", line 173, in training_step
#     y_hat = self.forward(batch).squeeze()
#   File "<ipython-input-4-3c7ce4c0af25>", line 148, in forward
#     res_embed_update = self.final_attn(res_embed_update, adj)
#   File "/home/tshimko/.virtualenvs/tesselate/lib/python3.6/site-packages/torch/nn/modules/module.py", line 532, in __call__
#     result = self.forward(*input, **kwargs)
#   File "<ipython-input-2-84e353115928>", line 202, in forward
#     vals = torch.cat([head(nodes, adj) for head in self.attn_heads],
#   File "<ipython-input-2-84e353115928>", line 202, in <listcomp>
#     vals = torch.cat([head(nodes, adj) for head in self.attn_heads],
#   File "/home/tshimko/.virtualenvs/tesselate/lib/python3.6/site-packages/torch/nn/modules/module.py", line 532, in __call__
#     result = self.forward(*input, **kwargs)
#   File "<ipython-input-2-84e353115928>", line 154, in forward
#     out = self.attn(input, adj)
#   File "/home/tshimko/.virtualenvs/tesselate/lib/python3.6/site-packages/torch/nn/modules/module.py", line 532, in __call__
#     result = self.forward(*input, **kwargs)
#   File "<ipython-input-2-84e353115928>", line 118, in forward
#     edge_h = torch.cat((h[edge[0, :], :], h[edge[1, :], :]), dim=1).t()
#   File "/usr/lib/python3.6/traceback.py", line 197, in format_stack
#     return format_list(extract_stack(f, limit=limit))
#   File "/usr/lib/python3.6/traceback.py", line 39, in format_list
#     return StackSummary.from_list(extracted_list).format()
#   File "/usr/lib/python3.6/traceback.py", line 428, in format
#     result.append(''.join(row))
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/tshimko/.virtualenvs/tesselate/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/tshimko/.virtualenvs/tesselate/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1151, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/tshimko/.virtualenvs/tesselate/lib/python3.6/site-packages/IPython/core/ultratb.py", line 319, in wrapped
#     return f(*args, **kwargs)
#   File "/home/tshimko/.virtualenvs/tesselate/lib/python3.6/site-packages/IPython/core/ultratb.py", line 353, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.6/inspect.py", line 1490, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.6/inspect.py", line 1448, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/usr/lib/python3.6/inspect.py", line 742, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "/home/tshimko/.virtualenvs/tesselate/lib/python3.6/posixpath.py", line 396, in realpath
#     return abspath(path)
#   File "/home/tshimko/.virtualenvs/tesselate/lib/python3.6/posixpath.py", line 385, in abspath
#     return normpath(path)
#   File "/home/tshimko/.virtualenvs/tesselate/lib/python3.6/posixpath.py", line 370, in normpath
#     path = sep.join(comps)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# Error in callback <function _init_jupyter.<locals>.cleanup at 0x7f12fcfe6950> (for post_run_cell):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/.virtualenvs/tesselate/lib/python3.6/site-packages/backcall/backcall.py in adapted(*args, **kwargs)
#     102                 kwargs.pop(name)
#     103 #            print(args, kwargs, unmatched_pos, cut_positional, unmatched_kw)
# --> 104             return callback(*args, **kwargs)
#     105
#     106         return adapted
#
# ~/.virtualenvs/tesselate/lib/python3.6/site-packages/wandb/__init__.py in cleanup()
#     480         # shutdown async logger because _user_process_finished isn't called in jupyter
#     481         shutdown_async_log_thread()
# --> 482         run._stop_jupyter_agent()
#     483     ipython.events.register('post_run_cell', cleanup)
#     484
#
# ~/.virtualenvs/tesselate/lib/python3.6/site-packages/wandb/wandb_run.py in _stop_jupyter_agent(self)
#     180
#     181     def _stop_jupyter_agent(self):
# --> 182         self._jupyter_agent.stop()
#     183
#     184     def send_message(self, options):
#
# ~/.virtualenvs/tesselate/lib/python3.6/site-packages/wandb/jupyter.py in stop(self)
#     134         if not self.paused:
#     135             self.rm.unmirror_stdout_stderr()
# --> 136             self.rm.shutdown()
#     137             wandb.run.close_files()
#     138             self.paused = True
#
# ~/.virtualenvs/tesselate/lib/python3.6/site-packages/wandb/run_manager.py in shutdown(self, exitcode)
#    1058         logger.info("shutting down system stats and metadata service")
#    1059         self._system_stats.shutdown()
# -> 1060         self._meta.shutdown()
#    1061         for watcher in self._tensorboard_watchers:
#    1062             watcher.shutdown()
#
# ~/.virtualenvs/tesselate/lib/python3.6/site-packages/wandb/meta.py in shutdown(self)
#     170         self._shutdown = True
#     171         try:
# --> 172             self._thread.join()
#     173         # Incase we never start it
#     174         except RuntimeError:
#
# /usr/lib/python3.6/threading.py in join(self, timeout)
#    1054
#    1055         if timeout is None:
# -> 1056             self._wait_for_tstate_lock()
#    1057         else:
#    1058             # the behavior of a negative timeout isn't documented, but
#
# /usr/lib/python3.6/threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1070         if lock is None:  # already determined that the C code is done
#    1071             assert self._is_stopped
# -> 1072         elif lock.acquire(block, timeout):
#    1073             lock.release()
#    1074             self._stop()
#
# KeyboardInterrupt:
# Error in callback <function _init_jupyter.<locals>.cleanup at 0x7f12fcfe6950> (for post_run_cell):
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/.virtualenvs/tesselate/lib/python3.6/site-packages/backcall/backcall.py in adapted(*args, **kwargs)
#     102                 kwargs.pop(name)
#     103 #            print(args, kwargs, unmatched_pos, cut_positional, unmatched_kw)
# --> 104             return callback(*args, **kwargs)
#     105
#     106         return adapted
#
# ~/.virtualenvs/tesselate/lib/python3.6/site-packages/wandb/__init__.py in cleanup()
#     480         # shutdown async logger because _user_process_finished isn't called in jupyter
#     481         shutdown_async_log_thread()
# --> 482         run._stop_jupyter_agent()
#     483     ipython.events.register('post_run_cell', cleanup)
#     484
#
# ~/.virtualenvs/tesselate/lib/python3.6/site-packages/wandb/wandb_run.py in _stop_jupyter_agent(self)
#     180
#     181     def _stop_jupyter_agent(self):
# --> 182         self._jupyter_agent.stop()
#     183
#     184     def send_message(self, options):
#
# ~/.virtualenvs/tesselate/lib/python3.6/site-packages/wandb/jupyter.py in stop(self)
#     133     def stop(self):
#     134         if not self.paused:
# --> 135             self.rm.unmirror_stdout_stderr()
#     136             self.rm.shutdown()
#     137             wandb.run.close_files()
#
# ~/.virtualenvs/tesselate/lib/python3.6/site-packages/wandb/run_manager.py in unmirror_stdout_stderr(self)
#     784         if hasattr(sys.stdout, "orig_write"):
#     785             sys.stdout.write = sys.stdout.orig_write
# --> 786             sys.stderr.write = sys.stderr.orig_write
#     787
#     788     def _get_stdout_stderr_streams(self):
#
# AttributeError: 'OutStream' object has no attribute 'orig_write'

# %% [markdown]
# # Analysis

# %%
from torch.utils.data import DataLoader

data_base = '/home/tshimko/tesselate/'

data_load = [
                'pdb_id',
#                 'model',
                'atom_nodes',
                'atom_adj',
#                 'atom_contact',
#                 'atom_mask',
                'res_adj',
                'res_dist',
                'chain_mem',
                'res_contact',
                'conn_adj',
                'res_mask',
                'mem_mat',
#                 'idx2atom_dict',
#                 'idx2res_dict'
            ]

train_data = TesselateDataset(data_base + 'test4.txt',
                              graph_dir=data_base + 'data/graphs',
                              contacts_dir=data_base + 'data/contacts',
                              return_data=data_load, in_memory=True)


for idx, i in enumerate(DataLoader(train_data, shuffle=False, num_workers=30, pin_memory=True)):
    print(idx, i['pdb_id'])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-3377bef9d3dd> in <module>
#      27
#      28
# ---> 29 for idx, i in enumerate(DataLoader(train_data, shuffle=False, num_workers=30, pin_memory=True)):
#      30     print(idx, i['pdb_id'])
#
# ~/.virtualenvs/tesselate/lib/python3.6/site-packages/torch/utils/data/dataloader.py in __iter__(self)
#     277             return _SingleProcessDataLoaderIter(self)
#     278         else:
# --> 279             return _MultiProcessingDataLoaderIter(self)
#     280
#     281     @property
#
# ~/.virtualenvs/tesselate/lib/python3.6/site-packages/torch/utils/data/dataloader.py in __init__(self, loader)
#     717             #     before it starts, and __del__ tries to join but will get:
#     718             #     AssertionError: can only join a started process.
# --> 719             w.start()
#     720             self._index_queues.append(index_queue)
#     721             self._workers.append(w)
#
# /usr/lib/python3.6/multiprocessing/process.py in start(self)
#     103                'daemonic processes are not allowed to have children'
#     104         _cleanup()
# --> 105         self._popen = self._Popen(self)
#     106         self._sentinel = self._popen.sentinel
#     107         # Avoid a refcycle if the target function holds an indirect
#
# /usr/lib/python3.6/multiprocessing/context.py in _Popen(process_obj)
#     221     @staticmethod
#     222     def _Popen(process_obj):
# --> 223         return _default_context.get_context().Process._Popen(process_obj)
#     224
#     225 class DefaultContext(BaseContext):
#
# /usr/lib/python3.6/multiprocessing/context.py in _Popen(process_obj)
#     275         def _Popen(process_obj):
#     276             from .popen_fork import Popen
# --> 277             return Popen(process_obj)
#     278
#     279     class SpawnProcess(process.BaseProcess):
#
# /usr/lib/python3.6/multiprocessing/popen_fork.py in __init__(self, process_obj)
#      17         util._flush_std_streams()
#      18         self.returncode = None
# ---> 19         self._launch(process_obj)
#      20
#      21     def duplicate_for_child(self, fd):
#
# /usr/lib/python3.6/multiprocessing/popen_fork.py in _launch(self, process_obj)
#      64         code = 1
#      65         parent_r, child_w = os.pipe()
# ---> 66         self.pid = os.fork()
#      67         if self.pid == 0:
#      68             try:
#
# KeyboardInterrupt:
# Error in callback <function _init_jupyter.<locals>.cleanup at 0x7f12fcfe6950> (for post_run_cell):
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/.virtualenvs/tesselate/lib/python3.6/site-packages/backcall/backcall.py in adapted(*args, **kwargs)
#     102                 kwargs.pop(name)
#     103 #            print(args, kwargs, unmatched_pos, cut_positional, unmatched_kw)
# --> 104             return callback(*args, **kwargs)
#     105
#     106         return adapted
#
# ~/.virtualenvs/tesselate/lib/python3.6/site-packages/wandb/__init__.py in cleanup()
#     480         # shutdown async logger because _user_process_finished isn't called in jupyter
#     481         shutdown_async_log_thread()
# --> 482         run._stop_jupyter_agent()
#     483     ipython.events.register('post_run_cell', cleanup)
#     484
#
# ~/.virtualenvs/tesselate/lib/python3.6/site-packages/wandb/wandb_run.py in _stop_jupyter_agent(self)
#     180
#     181     def _stop_jupyter_agent(self):
# --> 182         self._jupyter_agent.stop()
#     183
#     184     def send_message(self, options):
#
# ~/.virtualenvs/tesselate/lib/python3.6/site-packages/wandb/jupyter.py in stop(self)
#     133     def stop(self):
#     134         if not self.paused:
# --> 135             self.rm.unmirror_stdout_stderr()
#     136             self.rm.shutdown()
#     137             wandb.run.close_files()
#
# ~/.virtualenvs/tesselate/lib/python3.6/site-packages/wandb/run_manager.py in unmirror_stdout_stderr(self)
#     784         if hasattr(sys.stdout, "orig_write"):
#     785             sys.stdout.write = sys.stdout.orig_write
# --> 786             sys.stderr.write = sys.stderr.orig_write
#     787
#     788     def _get_stdout_stderr_streams(self):
#
# AttributeError: 'OutStream' object has no attribute 'orig_write'

# %%
preds = triu_expand(out).sigmoid()

# %%
f = plot_channels(preds.detach())

# %%
plot_channels(triu_expand(i['res_contact'].squeeze()))

# %%
f

# %%
# Plot the predictions
preds = triu_expand(torch.from_numpy(acts['preds'])).sigmoid()
plot_channels(preds)

# %%
# Plot the true values
plot_channels(x['res_contact'])

# %%
plot_channels(x['res_mask'])

# %% [markdown]
# ## ROC

# %%
plot_curve(torch.from_numpy(acts['preds']).sigmoid(), triu_condense(x['res_contact'].squeeze()), 'ROC')

# %% [markdown]
# ## PRC

# %%
plot_curve(torch.from_numpy(acts['preds']).sigmoid(), triu_condense(x['res_contact'].squeeze()), 'PRC')

# %%
a = 5

# %%
x = train_data[0]

# %%
y = model(x)

# %%
x

# %%
import torch
x = torch.tensor([1., 2., 3.])

# %%
torch.pow(torch.div(x, 2), 5)

# %%
torch.relu(x - 2)

# %%
torch.randn((5, 5, 3)).sum(dim=-1).sum(dim=-1)

# %%
train_data.accessions
