# %% [markdown]
# # Benchmark position-aware graph neural network/2D CNN architecture
#
# This notebook contains all of the code to overfit a GAT to four contact channels of a single structure (6E6O).
#
# ## Setup

# %% [markdown]
# ### Dataloader code

# %%
import torch
from torch.utils.data import Dataset
import numpy as np
import periodictable as pt
import pandas as pd
import os
import matplotlib.pyplot as plt
import networkx as nx


def read_files(acc, model, graph_dir, contacts_dir):
    """
    Read graph and contacts files.

    Args:
    - acc (str) - String of the PDB ID (lowercese).
    - model (int) - Model number of the desired bioassembly.
    - graph_dir (str) - Directory containing the nodes, edges,
        and mask files.
    - contacts_dir (str) - Directory containing the .contacts
        files from get_contacts.py.

    Returns:
    - Dictionary of DataFrames and lists corresponding to
        graph nodes, edges, mask, and contacts.
    """

    # Get the file names for the graph files
    node_file = os.path.join(graph_dir, '{}-{}_nodes.csv'.format(acc, model))
    edge_file = os.path.join(graph_dir, '{}-{}_edges.csv'.format(acc, model))
    mask_file = os.path.join(graph_dir, '{}-{}_mask.csv'.format(acc, model))

    # Get the contacts file
    contacts_file = os.path.join(contacts_dir, '{}-{}.contacts'.format(acc, model))

    # Read the nodes and edges
    nodes = pd.read_csv(node_file)
    edges = pd.read_csv(edge_file)

    # Check if the mask is empty
    if os.path.getsize(mask_file) > 0:
        with open(mask_file) as f:
            mask = f.read().split('\n')
    else:
        mask = []

    # Read the contacts
    contacts = pd.read_table(contacts_file, sep='\t',
                             header=None, names=['type', 'start', 'end'])

    # Return the data
    data = {
        'nodes': nodes,
        'edges': edges,
        'mask': mask,
        'contacts': contacts
    }

    return data


def process_res_data(data):
    """
    Process residue-level data from atom-level data.

    Args:
    - data (dict) - Dictionary of graph data output from `read_files`.

    Returns:
    - Dictionary of atom and residue graph and contact data.
    """

    # Extract data form dict
    nodes = data['nodes']
    edges = data['edges']
    mask = data['mask']
    contacts = data['contacts']

    # Get residue nodes
    res_nodes = pd.DataFrame()
    res_nodes['res'] = [':'.join(atom.split(':')[:3]) for atom in nodes['atom']]
    res_nodes = res_nodes.drop_duplicates().reset_index(drop=True)

    # Get residue edges
    res_edges = edges.copy()
    res_edges['start'] = [':'.join(atom.split(':')[:3]) for atom in res_edges['start']]
    res_edges['end'] = [':'.join(atom.split(':')[:3]) for atom in res_edges['end']]
    res_edges = res_edges[res_edges['start'] != res_edges['end']].drop_duplicates().reset_index(drop=True)

    # Get residue contacts
    res_contacts = contacts.copy()
    res_contacts['start'] = [':'.join(atom.split(':')[:3]) for atom in res_contacts['start']]
    res_contacts['end'] = [':'.join(atom.split(':')[:3]) for atom in res_contacts['end']]
    res_contacts = res_contacts[res_contacts['start'] != res_contacts['end']].drop_duplicates().reset_index(drop=True)

    # Get residue mask
    res_mask = list(set([':'.join(atom.split(':')[:3]) for atom in mask]))

    # Return data dict
    data = {
        'atom_nodes': nodes,
        'atom_edges': edges,
        'atom_contact': contacts,
        'atom_mask': mask,
        'res_nodes': res_nodes,
        'res_edges': res_edges,
        'res_contact': res_contacts,
        'res_mask': res_mask
    }

    return data


def get_map_dicts(entity_list):
    """
    Map identifiers to indices and vice versa.

    Args:
    - entity_list (list) - List of entities (atoms, residues, etc.)
        to index.

    Returns:
    - Tuple of the entity to index and index to entity dicts, respectively.
    """

    # Create the entity:index dictionary
    ent2idx_dict = {entity: idx for idx, entity in enumerate(entity_list)}

    # Create the index:entity dictionary
    idx2ent_dict = {idx: entity for entity, idx in ent2idx_dict.items()}

    return (ent2idx_dict, idx2ent_dict)


def create_adj_mat(data, dict_map, mat_type):
    """
    Creates an adjacency matrix.

    Args:
    - data (DataFrame) - Dataframe with 'start' and 'end' column
        for each interaction. For atom-level adjacency, 'order'
        column is also required. For atom or residue conatcts,
        'type' column is also required.

    Returns:
    - Coordinate format matrix (numpy). For atom adjacency, third column
        corresponds to bond order. For contacts, third column
        corresponds to channel.

    Channel mappings (shorthand from get_contacts.py source):

        0:
            hp             hydrophobic interactions
        1:
            hb             hydrogen bonds
            lhb            ligand hydrogen bonds
            hbbb           backbone-backbone hydrogen bonds
            hbsb           backbone-sidechain hydrogen bonds
            hbss           sidechain-sidechain hydrogen bonds
            hbls           ligand-sidechain residue hydrogen bonds
            hblb           ligand-backbone residue hydrogen bonds
        2:
            vdw            van der Waals
        3:
            wb             water bridges
            wb2            extended water bridges
            lwb            ligand water bridges
            lwb2           extended ligand water bridges
        4:
            sb             salt bridges
        5:
            ps             pi-stacking
        6:
            pc             pi-cation
        7:
            ts             t-stacking
    """

    # Initialize the coordinate list
    coord_mat = []

    # Map channel names to numeric channels
    channel = {
        # Hydrophobic interactions in first channel
        'hp': 0,
        'hplp': 0,
        'hpll': 0,

        # Hydrogen bonds in second channel
        'hb': 1,
        'lhb': 1,
        'hbbb': 1,
        'hbsb': 1,
        'hbss': 1,
        'hbls': 1,
        'hblb': 1,

        # VdW in third channel
        'vdw': 2,

        # Water bridges
        'wb': 3,
        'wb2': 3,
        'lwb': 3,
        'lwb2': 3,

        # Salt bridges
        'sb': 4,
        'sbpl': 4,

        # Other interactions
        'ps': 5,
        'pc': 6,
        'ts': 7,
    }

    # Assemble the contacts
    for idx, row in data.iterrows():

        if row['start'] in dict_map and row['end'] in dict_map:

            entry = [dict_map[row['start']], dict_map[row['end']]]

            # Add order or type if necessary
            if mat_type == 'atom_graph':
                entry.append(row['order'])
            elif mat_type == 'atom_contact':
                entry.append(channel[row['type']])
            elif mat_type == 'res_contact':
                entry.append(channel[row['type']])

            coord_mat.append(entry)

    return np.array(coord_mat)


def create_conn_adj_mat(adj):
    """
    Create connection adjacency matrix
    """

    conn_map = {(a, b): idx for idx, (a, b) in enumerate(zip(*np.triu_indices_from(adj)))}

    one_hop_neighbors = {idx: np.argwhere(row > 0).squeeze().tolist() for idx, row in enumerate(adj)}

    conns = []

    for i, j in it.combinations_with_replacement(one_hop_neighbors, 2):
        row = conn_map[(i, j)]
        adj_conn_coords = set([(m, n) if m <= n else (n, m)
                               for m, n in it.product(one_hop_neighbors[i],
                                                      one_hop_neighbors[j])])
        adj_conns = [conn_map[x] for x in adj_conn_coords]

        conns.append(np.array(list(it.product([row], adj_conns))))

    conn_adj = np.concatenate(conns, axis=0).T

    return conn_adj


def create_mem_mat(atom_dict, res_dict):
    """
    Create a membership matrix mapping atoms to residues.

    Args:
    - atom_dict (dict) - Dictionary mapping atoms to indices.
    - res_dict (dict) - Dictionary mapping residues to indices.

    Returns:
    - Coordinate format membership matrix (numpy) with first
        row being residue number and the second column being
        atom number.
    """

    # Initialize the coordinate list
    mem_coord = []

    # Map atoms to residues
    for atom, atom_idx in atom_dict.items():
        res_idx = res_dict[':'.join(atom.split(':')[:3])]

        mem_coord.append([res_idx, atom_idx])

    mem_coord = np.array(mem_coord)

    return mem_coord


def create_idx_list(id_list, dict_map):
    """
    Create list of indices.

    Args:
    - id_list (list) - List of masked atom or residue identifiers.
    - dict_map (dict) - Dictionary mapping entities to indices.

    Returns:
    - A numpy array of the masked indices.
    """

    # Generate the numpy index array
    idx_array = np.array([dict_map[iden] for iden in id_list])

    return idx_array


class TesselateDataset(Dataset):
    """
    Dataset class for structural data.

    Args:
    - accession_list (str) - File path from which to read PDB IDs for dataset.
    - graph_dir (str) - Directory containing the nodes, edges, and mask files.
    - contacts_dir (str) - Directory containing the .contacts files from
        get_contacts.py.
    - return_data (list) - List of datasets to return. Value must be 'all' or
        a subset of the following list:
            - pdb_id
            - model
            - atom_nodes
            - atom_adj
            - atom_contact
            - atom_mask
            - res_adj
            - res_dist
            - res_contact
            - res_mask
            - mem_mat
            - idx2atom_dict
            - idx2res_dict
    """

    def __init__(self, accession_list, graph_dir, contacts_dir, add_covalent=False, return_data='all', in_memory=False):

        if return_data == 'all':
            self.return_data = [
                'pdb_id',
                'model',
                'atom_nodes',
                'atom_adj',
                'atom_contact',
                'atom_mask',
                'res_adj',
                'res_dist',
                'conn_adj',
                'res_contact',
                'res_mask',
                'mem_mat',
                'idx2atom_dict',
                'idx2res_dict'
            ]

        else:
            self.return_data = return_data

        # Store reference to accession list file
        self.accession_list = accession_list

        # Store references to the necessary directories
        self.graph_dir = graph_dir
        self.contacts_dir = contacts_dir

        # Whether to add covalent bonds to prediction task and
        # remove sequence non-deterministic covalent bonds from the adjacency matrix
        self.add_covalent=add_covalent

        # Read in and store a list of accession IDs
        with open(accession_list, 'r') as handle:
            self.accessions = np.array([acc.strip().lower().split() for acc in handle.readlines()])

        self.data = {}


    def __len__(self):
        """
        Return the length of the dataset.

        Returns:
        - Integer count of number of examples.
        """
        return len(self.accessions)


    def __getitem__(self, idx):
        """
        Get an item with a particular index value.

        Args:
        - idx (int) - Index of desired sample.

        Returns:
        - Dictionary of dataset example. All tensors are sparse when possible.
        """

        try:
            if idx in self.data:
                return self.data[idx]

            # initialize the return dictionary
            return_dict = {}

            acc_entry = self.accessions[idx]

            # Get the PDB ID
            acc = acc_entry[0]

            # Get the model number if one exists
            if len(acc_entry) == 1:
                model = 1
            else:
                model = acc_entry[1]

            # Read and process the files
            data = read_files(acc, model, self.graph_dir, self.contacts_dir)
            data = process_res_data(data)

            # Generate the mapping dictionaries
            atom2idx_dict, idx2atom_dict = get_map_dicts(data['atom_nodes']['atom'].unique())
            res2idx_dict, idx2res_dict = get_map_dicts(data['res_nodes']['res'].unique())

            # Get numbers of atoms and residues per sample
            n_atoms = len(atom2idx_dict)
            n_res = len(res2idx_dict)

            # Handle all of the possible returned datasets
            if 'pdb_id' in self.return_data:
                return_dict['pdb_id'] = acc

            if 'model' in self.return_data:
                return_dict['model'] = model

            if 'atom_nodes' in self.return_data:
                ele_nums = [pt.elements.symbol(element).number for element in data['atom_nodes']['element']]
                return_dict['atom_nodes'] = torch.LongTensor(ele_nums)
                assert not torch.isnan(return_dict['atom_nodes']).any()

            if 'atom_adj' in self.return_data:

                adj = create_adj_mat(data['atom_edges'], atom2idx_dict, mat_type='atom_graph').T

                x = torch.LongTensor(adj[0, :]).squeeze()
                y = torch.LongTensor(adj[1, :]).squeeze()
                val = torch.FloatTensor(adj[2, :]).squeeze()

                atom_adj = torch.zeros([n_atoms, n_atoms]).index_put_((x, y), val, accumulate=False)

                atom_adj = atom_adj.index_put_((y, x), val, accumulate=False)

                atom_adj[range(n_atoms), range(n_atoms)] = 1

                atom_adj = (atom_adj > 0).float()

                return_dict['atom_adj'] = atom_adj

                assert not torch.isnan(return_dict['atom_adj']).any()

            if 'atom_contact' in self.return_data:
                atom_contact = create_adj_mat(data['atom_contact'], atom2idx_dict, mat_type='atom_contact').T

                x = torch.LongTensor(atom_contact[0, :]).squeeze()
                y = torch.LongTensor(atom_contact[1, :]).squeeze()
                z = torch.LongTensor(atom_contact[2, :]).squeeze()

                atom_contact = torch.zeros([n_atoms, n_atoms, 8]).index_put_((x, y, z),
                                                                        torch.ones(len(x)))
                atom_contact = atom_contact.index_put_((y, x, z),
                                                       torch.ones(len(x)))

                return_dict['atom_contact'] = atom_contact

                assert not torch.isnan(return_dict['atom_contact']).any()

            if 'atom_mask' in self.return_data:
                atom_mask = create_idx_list(data['atom_mask'], atom2idx_dict)

                masked_pos = torch.from_numpy(atom_mask)

                if self.add_covalent:
                    channels = 9
                else:
                    channels = 8

                mask = torch.ones([n_atoms, n_atoms, channels])

                if len(masked_pos) > 0:
                    mask[masked_pos, :, :] = 0
                    mask[:, masked_pos, :] = 0

                return_dict['atom_mask'] = mask

                assert not torch.isnan(return_dict['atom_mask']).any()

            if 'res_adj' in self.return_data:
                adj = create_adj_mat(data['res_edges'], res2idx_dict, mat_type='res_graph').T

                x = torch.LongTensor(adj[0, :]).squeeze()
                y = torch.LongTensor(adj[1, :]).squeeze()

                res_adj = torch.zeros([n_res, n_res]).index_put_((x, y), torch.ones(len(x)))

                res_adj = res_adj.index_put_((y, x), torch.ones(len(x)))

                res_adj[range(n_res), range(n_res)] = 1

                return_dict['res_adj'] = res_adj

                assert not torch.isnan(return_dict['res_adj']).any()

                if 'res_dist' in self.return_data:
                    G = nx.from_numpy_matrix(return_dict['res_adj'].numpy())
                    res_dist = torch.from_numpy(nx.floyd_warshall_numpy(G)).float()

                    res_dist[torch.isinf(res_dist)] = -1

                    return_dict['res_dist'] = res_dist

                    chain_mem = torch.zeros(res_dist.shape)
                    chain_mem[~torch.isinf(return_dict['res_dist'])] = 1

                    return_dict['chain_mem'] = chain_mem

                    assert not torch.isnan(return_dict['res_dist']).any()
                    assert not torch.isinf(return_dict['res_dist']).any()
                    assert not torch.isnan(return_dict['chain_mem']).any()
                    assert not torch.isinf(return_dict['chain_mem']).any()

                if 'conn_adj' in self.return_data:

                    conn_adj = create_conn_adj_mat(return_dict['res_adj'].numpy())

                    return_dict['conn_adj'] = torch.from_numpy(conn_adj)

            if 'res_contact' in self.return_data:
                res_contact = create_adj_mat(data['res_contact'], res2idx_dict, mat_type='res_contact').T

                x = torch.LongTensor(res_contact[0, :]).squeeze()
                y = torch.LongTensor(res_contact[1, :]).squeeze()
                z = torch.LongTensor(res_contact[2, :]).squeeze()

                res_contact = torch.zeros([n_res, n_res, 8]).index_put_((x, y, z),
                                                                        torch.ones(len(x)))

                res_contact = res_contact.index_put_((y, x, z),
                                                     torch.ones(len(x)))

                return_dict['res_contact'] = res_contact

                assert not torch.isnan(return_dict['res_contact']).any()

            if 'res_mask' in self.return_data:
                res_mask = create_idx_list(data['res_mask'], res2idx_dict)

                masked_pos = torch.from_numpy(res_mask)

                if self.add_covalent:
                    channels = 9
                else:
                    channels = 8

                mask = torch.ones([n_res, n_res, channels])

                if len(masked_pos) > 0:
                    mask[masked_pos, :, :] = 0
                    mask[:, masked_pos, :] = 0

                return_dict['res_mask'] = mask

                assert not torch.isnan(return_dict['res_mask']).any()

            if 'mem_mat' in self.return_data:
                mem_mat = create_mem_mat(atom2idx_dict, res2idx_dict).T

                x = torch.LongTensor(mem_mat[0, :]).squeeze()
                y = torch.LongTensor(mem_mat[1, :]).squeeze()

                mem_mat = torch.zeros([n_res, n_atoms]).index_put_((x, y),
                                                                   torch.ones(len(x)))

                return_dict['mem_mat'] = mem_mat

                assert not torch.isnan(return_dict['mem_mat']).any()

            if 'idx2atom_dict' in self.return_data:
                return_dict['idx2atom_dict'] = idx2atom_dict

            if 'idx2res_dict' in self.return_data:
                return_dict['idx2res_dict'] = idx2res_dict

            self.data[idx] = return_dict

            # Return the processed data
            return return_dict

        except Exception as e:
            print("Error:", acc, str(e))
            return np.array([0])

# %% [markdown]
# ### Modules

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import itertools as it
from torch_scatter import scatter_softmax


####################
# Embedding layers #
####################

class AtomEmbed(nn.Module):
    """
    Embed the atoms to fixed-length input vectors.

    Args:
    - num_features (int) - Size of the returned embedding vectors.
    - scale_grad_by_freq (bool) - Scale gradients by the inverse of
        frequency (default=True).
    """

    def __init__(self, n_features, scale_grad_by_freq=True):
        super(AtomEmbed, self).__init__()
        self.embedding = nn.Embedding(118,
                                      n_features,
                                      scale_grad_by_freq=scale_grad_by_freq)

    def forward(self, atomic_numbers):
        """
        Return the embeddings for each atom in the graph.

        Args:
        - atoms (torch.LongTensor) - Tensor (n_atoms) containing atomic numbers.

        Returns:
        - torch.FloatTensor of dimension (n_atoms, n_features) containing
            the embedding vectors.
        """

        # Get and return the embeddings for each atom
        embedded_atoms = self.embedding(atomic_numbers)
        return embedded_atoms


####################
# Attention layers #
####################

class SpecialSpmmFunction(torch.autograd.Function):
    """Special function for only sparse region backpropataion layer."""
    @staticmethod
    def forward(ctx, indices, values, shape, b):
        assert indices.requires_grad == False
        a = torch.sparse_coo_tensor(indices, values, shape)
        ctx.save_for_backward(a, b)
        ctx.N = shape[0]
        return torch.matmul(a, b)

    @staticmethod
    def backward(ctx, grad_output):
        a, b = ctx.saved_tensors
        grad_values = grad_b = None
        if ctx.needs_input_grad[1]:
            grad_a_dense = grad_output.matmul(b.t())
            edge_idx = a._indices()[0, :] * ctx.N + a._indices()[1, :]
            grad_values = grad_a_dense.view(-1)[edge_idx]
        if ctx.needs_input_grad[3]:
            grad_b = a.t().matmul(grad_output)
        return None, grad_values, None, grad_b


class SpecialSpmm(nn.Module):
    def forward(self, indices, values, shape, b):
        return SpecialSpmmFunction.apply(indices, values, shape, b)


class GraphAttnLayer(nn.Module):
    """
    Sparse version GAT layer, similar to https://arxiv.org/abs/1710.10903
    """

    def __init__(self, in_features, out_features, dropout, alpha, concat=True):
        super(GraphAttnLayer, self).__init__()
        self.in_features = in_features
        self.out_features = out_features
        self.alpha = alpha
        self.concat = concat

        self.W = nn.Parameter(torch.zeros(size=(in_features, out_features)))
        nn.init.xavier_normal_(self.W.data, gain=1.414)

        self.a = nn.Parameter(torch.zeros(size=(1, 2*out_features)))
        nn.init.xavier_normal_(self.a.data, gain=1.414)

        self.dropout = nn.Dropout(dropout)
        self.leakyrelu = nn.LeakyReLU(self.alpha)
        self.special_spmm = SpecialSpmm()

    def forward(self, input, adj):
        dv = 'cuda' if input.is_cuda else 'cpu'

        N = input.size()[0]

        if adj.shape[0] == adj.shape[1]:
            edge = adj.nonzero().t()
        else:
            edge = adj

#         mask = adj.byte()

        h = torch.mm(input, self.W)
        # h: N x out
        assert not torch.isnan(h).any()

        # Self-attention on the nodes - Shared attention mechanism
        edge_h = torch.cat((h[edge[0, :], :], h[edge[1, :], :]), dim=1).t()
        # edge: 2*D x E

        values = self.leakyrelu(self.a.mm(edge_h).squeeze())

        edge_e = scatter_softmax(values, edge[0])
        assert not torch.isnan(edge_e).any()
        # edge_e: E

        edge_e = self.dropout(edge_e)
        # edge_e: E

        h_prime = self.special_spmm(edge, edge_e, torch.Size([N, N]), h)
        assert not torch.isnan(h_prime).any()
        # h_prime: N x out

        if self.concat:
            # if this layer is not last layer,
            return F.elu(h_prime)
        else:
            # if this layer is last layer,
            return h_prime

    def __repr__(self):
        return self.__class__.__name__ + ' (' + str(self.in_features) + ' -> ' + str(self.out_features) + ')'


class GraphAttn(nn.Module):

    def __init__(self, in_features, out_features, dropout, alpha, concat=True):
        super(GraphAttn, self).__init__()
        self.attn = GraphAttnLayer(in_features, out_features, dropout, alpha, concat)
        self.batch_norm = nn.BatchNorm1d(out_features)

    def forward(self, input, adj):

        out = self.attn(input, adj)
        out_norm = self.batch_norm(out)

        return out


class MultiHeadGraphAttn(nn.Module):
    """
    Multi-head graph attention layer.

    Args:
    - n_head (int) - Number of heads for the attention layer.
    - in_features (int) - Number of total input features.
    - out_features (int) - Number of output features per head.
    - dropout (bool) - P(keep) for dropout.
    - alpha (float) - Alpha value for leaky ReLU.
    """

    def __init__(self, n_heads, in_features, out_features, dropout, alpha):
        super(MultiHeadGraphAttn, self).__init__()

        # Parameters
        self.in_features = in_features
        self.out_features = out_features
        self.dropout = dropout
        self.alpha = alpha

        # Operations
        heads = [GraphAttn(in_features, out_features, dropout, alpha)
                 for i in range(n_heads)]
        self.attn_heads = nn.ModuleList(heads)

    def forward(self, nodes, adj, cat_dim=1):
        """
        Perform forward pass through multi-head graph attention layer.

        Args:
        - nodes (torch.FloatTensor) - Node feature matrix
            (n_nodes, in_features).
        - adj (torch.FloatTensor) - Adjacency matrix (n_nodes, n_nodes).

        Returns:
        - torch.FloatTensor of dimension (n_nodes, n_nodes) of attentional
            coefficients where a_ij is the attention value of for node j with
            respect to node i.
        """

        if cat_dim == 1:
            vals = torch.cat([head(nodes, adj) for head in self.attn_heads],
                         dim = 1)

        elif cat_dim == -1:
            vals = torch.stack([head(nodes, adj) for head in self.attn_heads])

        return vals


class FCContactPred(nn.Module):
    """
    Fully connected layer to perform contact prediction.

    Args:
    - node_features (int) - Number of input features.
    - out_features (int) - Number of output prediction values.
    """

    def __init__(self, node_features, out_preds, layers=3):
        super(FCContactPred, self).__init__()

        self.linear_first = nn.Linear(node_features, 25, bias=True)

        self.int_layers = nn.ModuleList([nn.Linear(25, 25, bias=True)
                                         for i in range(layers - 2)])

        self.linear_final = nn.Linear(25, out_preds, bias=True)

    def forward(self, combined_nodes):
        """
        Predict pointwise multichannel contacts from summarized pairwise
        residue features.

        Args:
        - nodes (torch.FloatTensor) - Tensor of (convolved) node features
            (n_pairwise, n_features).

        Returns:
        - torch.FloatTensor (n_contacts, n_channels) containing the prediction
            for every potential contact point and every contact channel.
        """
        # Get the logits from the linear layer
        prelogits = self.linear_first(combined_nodes)
        prelogits = F.relu(prelogits)

        for layer in self.int_layers:
            prelogits = layer(prelogits)
            prelogits = F.relu(prelogits)

        logits = self.linear_final(prelogits)

        return logits


class AttnLinkPredict(nn.Module):
    """
    Multi-head graph attention for link prediction.

    Args:
    - n_layers (int) - Number of layers.
    - n_head (int) - Number of heads for the attention layer.
    - in_features (int) - Number of total input features.
    - out_features (int) - Number of output features per head.
    - dropout (bool) - P(keep) for dropout.
    - alpha (float) - Alpha value for leaky ReLU.
    """

    def __init__(self, n_layers, n_heads, in_features, out_features, dropout, alpha):
        super(AttnLinkPredict, self).__init__()

        # Parameters
        self.in_features = in_features
        self.out_features = out_features
        self.dropout = dropout
        self.alpha = alpha

        layers = [MultiHeadGraphAttn(n_heads, in_features,
                                     out_features, dropout,
                                     alpha)]

        layers.extend([MultiHeadGraphAttn(n_heads, n_heads * out_features,
                                     out_features, dropout,
                                     alpha)
                      for i in range(n_layers - 1)])

        self.attn_layers = nn.ModuleList(layers)

        self.attn_batch_norm = nn.BatchNorm1d(n_heads * out_features)

        self.output_linear = nn.Linear(n_heads * out_features, 8)

    def forward(self, nodes, adjacency):

        outputs = []

        for target1, target2 in it.combinations_with_replacement(range(len(nodes)), 2):
            targets = adjacency[[target1, target2], :]

            where = [target1, target2]
            where.extend([ind for ind in np.where(targets.cpu() > 0)[1] if ind not in where])

            out_adj_size = len(where) + 1
            adj = torch.zeros(out_adj_size, out_adj_size)
            adj[[0, 0, 1, 2], [1, 2, 0, 0]] = 1

            neighbors = adjacency[where][:, where]
            adj[1:, 1:] = neighbors

            node_feats = nodes[where]

            node_feats = torch.cat((torch.sum(node_feats[:2], dim=0, keepdim=True), node_feats), dim=0)

            for layer in self.attn_layers:
                node_feats = layer(node_feats, adj)

            outputs.append(node_feats[0, :].unsqueeze(0))

        linear_in = self.attn_batch_norm(torch.cat(outputs, dim=0))

        return self.output_linear(linear_in)


class LinkPredict(nn.Module):
    """
    Multi-head graph attention for link prediction.

    Args:
    - n_layers (int) - Number of layers.
    - n_head (int) - Number of heads for the attention layer.
    - in_features (int) - Number of total input features.
    - out_features (int) - Number of output features per head.
    - dropout (bool) - P(keep) for dropout.
    - alpha (float) - Alpha value for leaky ReLU.
    """

    def __init__(self, n_layers, n_heads, in_features, out_features, dropout, alpha):
        super(AttnLinkPredict, self).__init__()

        # Parameters
        self.in_features = in_features
        self.out_features = out_features
        self.dropout = dropout
        self.alpha = alpha

        layers = [MultiHeadGraphAttn(n_heads, in_features,
                                     out_features, dropout,
                                     alpha)]

        layers.extend([MultiHeadGraphAttn(n_heads, n_heads * out_features,
                                     out_features, dropout,
                                     alpha)
                      for i in range(n_layers - 1)])

        self.attn_layers = nn.ModuleList(layers)

        self.attn_batch_norm = nn.BatchNorm1d(n_heads * out_features)

        self.output_linear = nn.Linear(n_heads * out_features, 8)

    def forward(self, nodes, adjacency):

        outputs = []

        for target1, target2 in it.combinations_with_replacement(range(len(nodes)), 2):
            targets = adjacency[[target1, target2], :]

            where = [target1, target2]
            where.extend([ind for ind in np.where(targets.cpu() > 0)[1] if ind not in where])

            out_adj_size = len(where) + 1
            adj = torch.zeros(out_adj_size, out_adj_size)
            adj[[0, 0, 1, 2], [1, 2, 0, 0]] = 1

            neighbors = adjacency[where][:, where]
            adj[1:, 1:] = neighbors

            node_feats = nodes[where]

            node_feats = torch.cat((torch.sum(node_feats[:2], dim=0, keepdim=True), node_feats), dim=0)

            for layer in self.attn_layers:
                node_feats = layer(node_feats, adj)

            outputs.append(node_feats[0, :].unsqueeze(0))

        linear_in = self.attn_batch_norm(torch.cat(outputs, dim=0))

        return self.output_linear(linear_in)

# %% [markdown]
# # Functions

# %%
import numpy as np
import torch

########################################
# Pairwise matrix generation functions #
########################################

def pairwise_mat(nodes, method='mean'):
    """
    Generate matrix for pairwise determination of interactions.

    Args:
    - nodes (torch.FloatTensor) - Tensor of node (n_nodes, n_features) features.
    - method (str) - One of 'sum' or 'mean' for combination startegy for
        pairwise combination matrix (default = 'mean').

    Returns:
    - torch.FloatTensor of shape (n_pairwise, n_nodes) than can be used used to
        combine feature vectors. Values are 1 if method == "sum" and 0.5 if
        method == "mean".
    """

    # Get the upper triangle indices
    triu = np.vstack(np.triu_indices(nodes.shape[0]))

    # Loop through all indices and add to list with
    idxs = torch.from_numpy(triu).T

    # Convert to tensor
    combos = torch.zeros([idxs.shape[0], nodes.shape[0]]).scatter(1, idxs, 1)

    # Set to 0.5 if method is 'mean'
    if method == 'mean':
        combos *= 0.5

    return combos


####################################
# Pairwise concatenation functions #
####################################

def cat_pairwise(embeddings):

    triu = np.vstack(np.triu_indices(embeddings.shape[0])).T

    node1 = []
    node2 = []

    for i, j in triu:
        node1.append(embeddings[i])
        node2.append(embeddings[j])

    node1 = torch.stack(node1, dim=0)
    node2 = torch.flip(torch.stack(node2, dim=0), dims=(1,))

    return torch.cat((node1, node2), dim=1)


############################
# Upper triangle functions #
############################

def triu_condense(input_tensor):
    """
    Condense the upper triangle of a tensor into a 2d dense representation.

    Args:
    - input_tensor (torch.Tensor) - Tensor of shape (n, n, m).

    Returns:
    - Tensor of shape (n(n+1)/2, m) where elements along the third dimension in
        the original tensor are packed row-wise according to the upper
        triangular indices.
    """

    # Get upper triangle index info
    row_idx, col_idx = np.triu_indices(input_tensor.shape[0])
    row_idx = torch.LongTensor(row_idx)
    col_idx = torch.LongTensor(col_idx)

    # Return the packed matrix
    output = input_tensor[row_idx, col_idx, :]

    return output


def triu_expand(input_matrix):
    """
    Expand a dense representation of the upper triangle of a tensor into
    a 3D squareform representation.

    Args:
    - input_matrix (torch.Tensor) - Tensor of shape (n(n+1)/2, m).

    Returns:
    - Tensor of shape (n, n, m) where elements along the third dimension in the
        original tensor are packed row-wise according to the upper triangular
        indices.
    """
    # Get the edge size n of the tensor
    n_elements = input_matrix.shape[0]
    n_chan = input_matrix.shape[1]
    n_res = int((-1 + np.sqrt(1 + 4 * 2 * (n_elements))) / 2)

    # Get upper triangle index info
    row_idx, col_idx = np.triu_indices(n_res)
    row_idx = torch.LongTensor(row_idx)
    col_idx = torch.LongTensor(col_idx)

    # Generate the output tensor
    output = torch.zeros((n_res, n_res, n_chan))

    # Input the triu values
    for i in range(n_chan):
        i_tens = torch.full((len(row_idx),), i, dtype=torch.long)
        output.index_put_((row_idx, col_idx, i_tens), input_matrix[:, i])

    # Input the tril values
    for i in range(n_chan):
        i_tens = torch.full((len(row_idx),), i, dtype=torch.long)
        output.index_put_((col_idx, row_idx, i_tens), input_matrix[:, i])

    return output

# %% [markdown]
# ### Model

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F
from torch import autograd
import pytorch_lightning as pl
from torch.utils.data import DataLoader
from torch.utils.checkpoint import checkpoint
from tqdm import *
import wandb

import gc


def track_mem():
    for obj in gc.get_objects():
        try:
            if (torch.is_tensor(obj) or (hasattr(obj, 'data') and torch.is_tensor(obj.data))) and hasattr(obj, '__name__'):
                print(obj.__name__, obj.size())
        except:
            pass


class GAT(pl.LightningModule):

    def __init__(self, embed_features, atom_out_features, res_out_features,
                 n_contact_channels, dropout, alpha, train_data, val_data,
                 test_data):
        super(GAT, self).__init__()

        # Properties
        self.embed_features = embed_features
        self.atom_out_features = atom_out_features
        self.res_out_features = res_out_features
        self.n_contact_channels = n_contact_channels
        self.dropout = dropout
        self.alpha = alpha

        # Datasets
        self.train_data = train_data
        self.val_data = val_data
        self.test_data = test_data

        # Model components
        self.embed = AtomEmbed(embed_features, scale_grad_by_freq=True)

        self.embed_batch_norm = nn.BatchNorm1d(embed_features)

        # Define number of graph conv layers and heads
        n_atom_layers = 5
        n_atom_heads = 3

        n_res_layers = 2
        n_res_heads = 3

        # Set up atom attention
        self.atom_attns = nn.ModuleList([])
        for i in range(n_atom_layers):
            if i == 0:
                attn_layer = MultiHeadGraphAttn(n_atom_heads, embed_features,
                                                atom_out_features,
                                                dropout, alpha)
            else:
                attn_layer = MultiHeadGraphAttn(n_atom_heads,
                                                n_atom_heads * atom_out_features,
                                                atom_out_features,
                                                dropout, alpha)

            self.atom_attns.append(attn_layer)


        # Set up condensation
        self.condense_batch_norm = nn.BatchNorm1d(n_atom_heads * atom_out_features)

        # Set up res attention
        self.res_attns = nn.ModuleList([])
        for i in range(n_res_layers):
            if i == 0:
                attn_layer = MultiHeadGraphAttn(n_res_heads,
                                                n_atom_heads * atom_out_features,
                                                res_out_features, dropout,
                                                alpha)
            else:
                attn_layer = MultiHeadGraphAttn(n_res_heads,
                                                n_res_heads * res_out_features,
                                                res_out_features, dropout,
                                                alpha)

            self.res_attns.append(attn_layer)

        self.final_attn = MultiHeadGraphAttn(n_res_heads,
                                             n_res_heads * res_out_features,
                                             res_out_features, dropout,
                                             alpha)

        self.expansion = nn.Linear(1, 8)

        self.activation = nn.LeakyReLU(self.alpha)

        self.linear1 = nn.Linear(1 * res_out_features + 2, 10)
        self.linear2 = nn.Linear(10, 10)
        self.linear_predict = nn.Linear(10, 8)

        self.pred_contact_batch_norm = nn.BatchNorm1d(n_contact_channels)

        self.activations = {}


        # Validation information
        self.reset_epoch_metrics()


    def forward(self, x):
#         # Put on gpus
#         self.embed.cuda(0)
#         self.embed_batch_norm.cuda(0)
#         [layer.cuda(0) for layer in self.atom_attns]
# #         self.condense.cuda(0)
#         self.condense_batch_norm.cuda(0)
#         [layer.cuda(0) for layer in self.res_attns]
#         self.final_attn.cuda(0)
#         self.linear1.cuda(1)
#         self.linear2.cuda(1)
#         self.linear_predict.cuda(1)
# #         self.conn_attn.cuda(1)
#         self.pred_contact_batch_norm.cuda(1)

        # Regular forward pass
        atom_embed = self.embed(x['atom_nodes'].squeeze())

        atom_embed_update = self.embed_batch_norm(atom_embed)

        atom_adj = x['atom_adj'].squeeze()

        for layer in self.atom_attns:
                atom_embed_update = checkpoint(layer, atom_embed_update, atom_adj)

        res_embed = torch.matmul( x['mem_mat'].squeeze(), atom_embed_update)

        res_embed_update = self.condense_batch_norm(res_embed)

        adj = x['res_adj'].squeeze()

        for layer in self.res_attns:
            res_embed_update = checkpoint(layer, res_embed_update, adj)

        res_embed_update = self.final_attn(res_embed_update, adj).unsqueeze(-1)

#         preds = torch.matmul(res_embed_update, res_embed_update.T)

        expanded = torch.relu(self.expansion(res_embed_update).permute(2, 0, 1))

        preds = torch.matmul(expanded, res_embed_update.permute(2, 1, 0)).permute(1, 2, 0)

#         preds = torch.matmul(res_embed_update, res_embed_update.T).unsqueeze(-1)


#         preds = preds.repeat(1, 1, 8)

        preds = triu_condense(preds)


#         atom_attns = [[head.f_attn for head in layer.attn_heads]
#                       for layer in self.atom_attns]
#         res_attns = [[head.f_attn for head in layer.attn_heads]
#                       for layer in self.res_attns]

        preds = self.pred_contact_batch_norm(preds)

#         self.activations = {
#             'atom_embed': atom_embed.detach().cpu().numpy(),
#             'atom_embed_update': atom_embed_update.detach().cpu().numpy(),
# #             'atom_attn': atom_attns,
#             'res_embed': res_embed.detach().cpu().numpy(),
#             'res_embed_update': res_embed_update.detach().cpu().numpy(),
# #             'res_attn': res_attns,
# #             'pairwise': pairwise.detach().cpu().numpy(),
# #             'combined': combined.detach().cpu().numpy(),
#             'preds': preds.detach().cpu().numpy()
#         }

        return preds

    def training_step(self, batch, batch_nb):
        # REQUIRED
        y_hat = self.forward(batch).squeeze()
        y = triu_condense(batch['res_contact'].squeeze())
        weights = triu_condense(batch['res_mask'].squeeze())

        loss = F.binary_cross_entropy_with_logits(y_hat, y, weight=weights)

        self.train_losses.append(loss.item())

        return {'loss': loss}

    def validation_step(self, batch, batch_nb):
        # OPTIONAL
        y_hat = self.forward(batch).squeeze()
        y = triu_condense(batch['res_contact'].squeeze())
        weights = triu_condense(batch['res_mask'].squeeze())

        loss = F.binary_cross_entropy_with_logits(y_hat, y, weight=weights)

        self.val_losses.append(loss.item())

        _, _, auroc = calc_metric_curve(y_hat.sigmoid().cpu(), y.cpu(), 'ROC', squareform=False)
        _, _, auprc = calc_metric_curve(y_hat.sigmoid().cpu(), y.cpu(), 'PRC', squareform=False)

        self.auroc['Hydrophobic'].append(auroc[0])
        self.auroc['Hydrogen bond'].append(auroc[1])
        self.auroc['Van der Waals'].append(auroc[2])
        self.auroc['Water bridges'].append(auroc[3])
        self.auroc['Salt bridges'].append(auroc[4])
        self.auroc['Pi-stacking'].append(auroc[5])
        self.auroc['Pi-cation'].append(auroc[6])
        self.auroc['T-stacking'].append(auroc[7])

        self.auprc['Hydrophobic'].append(auprc[0])
        self.auprc['Hydrogen bond'].append(auprc[1])
        self.auprc['Van der Waals'].append(auprc[2])
        self.auprc['Water bridges'].append(auprc[3])
        self.auprc['Salt bridges'].append(auprc[4])
        self.auprc['Pi-stacking'].append(auprc[5])
        self.auprc['Pi-cation'].append(auprc[6])
        self.auprc['T-stacking'].append(auprc[7])

        if batch_nb == 0:
            self.pred_example = plot_channels(triu_expand(y_hat.detach().cpu()))

    def on_post_performance_check(self):

        epoch_metrics = {}
        all_metrics = {}

        for key in self.auroc:
            values = np.asarray(self.auroc[key])
            all_metrics[f'AUROC - {key}'] = values

            values = values[~np.isnan(values)]
            epoch_metrics[f'AUROC - {key}'] = wandb.Histogram(values)


        for key in self.auprc:
            values = np.asarray(self.auprc[key])
            all_metrics[f'AUPRC - {key}'] = values

            values = values[~np.isnan(values)]
            epoch_metrics[f'AUPRC - {key}'] = wandb.Histogram(values)

        epoch_metrics['Train Losses'] = wandb.Histogram(self.train_losses)

        epoch_metrics['Val Losses'] = wandb.Histogram(self.val_losses)
        all_metrics['Val Losses'] = np.asarray(self.val_losses)

        all_metrics = pd.DataFrame(all_metrics)
        cor_mat = all_metrics.corr()

        corr_plot = metric_corr_plot(cor_mat)
        epoch_metrics['Metric Corr Plot'] = wandb.Image(corr_plot)

        epoch_metrics['train_loss'] = np.asarray(self.train_losses).mean()
        epoch_metrics['val_loss'] = np.asarray(self.val_losses).mean()

        epoch_metrics['Example Prediction'] = wandb.Image(self.pred_example)

        self.logger.experiment.log(epoch_metrics)

        self.reset_epoch_metrics()

    def reset_epoch_metrics(self):

        # Validation information
        self.auroc = {
            'Hydrophobic': [],
            'Hydrogen bond': [],
            'Van der Waals': [],
            'Water bridges': [],
            'Salt bridges': [],
            'Pi-stacking': [],
            'Pi-cation': [],
            'T-stacking': []
        }

        self.auprc = {
            'Hydrophobic': [],
            'Hydrogen bond': [],
            'Van der Waals': [],
            'Water bridges': [],
            'Salt bridges': [],
            'Pi-stacking': [],
            'Pi-cation': [],
            'T-stacking': []
        }

        self.val_losses = []
        self.train_losses = []


#     def validation_end(self, outputs):
#         # OPTIONAL
# #         avg_loss = torch.stack([x['val_loss'] for x in outputs]).mean()
# #         return {'avg_val_loss': avg_loss}
#         pass

    def configure_optimizers(self):
        # REQUIRED
        # can return multiple optimizers and learning_rate schedulers

        parameters = filter(lambda p: p.requires_grad, self.parameters())

        return torch.optim.SGD(parameters, lr=0.1, momentum=0.9, weight_decay=1e-6)

    @pl.data_loader
    def train_dataloader(self):
        # REQUIRED
        return DataLoader(self.train_data, shuffle=True, num_workers=30, pin_memory=True)

    @pl.data_loader
    def val_dataloader(self):
        # OPTIONAL
        return DataLoader(self.val_data, shuffle=False, num_workers=20, pin_memory=True)

#     def on_batch_end(self):
#         wandb.log({key: plt.imshow(self.activations[key][:20]) for key in self.activations})

# %% [markdown]
# ### Analysis functions

# %%
import seaborn as sns

def plot_channels(values):
    fig, ax = plt.subplots(nrows=2, ncols=4, figsize=(20, 10))

    ax = ax.flatten()

    channel_names = [
        'Hydrophobic',
        'Hydrogen bond',
        'Van der Waals',
        'Water bridges',
        'Salt bridges',
        'Pi-stacking',
        'Pi-cation',
        'T-stacking'
    ]

    for channel in range(values.shape[-1]):
        ax[channel].imshow(values[:, :, channel].squeeze(), vmin=0, vmax=1)
        ax[channel].set(title=channel_names[channel], xlabel='Residue #', ylabel='Residue #')

    plt.close()
    return fig


######################
# ROC and PRC curves #
######################
from sklearn.metrics import precision_recall_curve, roc_curve, auc

def calc_metric_curve(preds, target, curve_type, squareform=False):
    """
    Calculate ROC or PRC curves and area for the predicted contact channels.

    Args:
    - preds (np.ndarray) - Numpy array of model predictions either of form
        (n_res, n_res, n_chan) or (n_res * [n_res - 1] / 2, n_chan).
    - target (np.ndarray) - Numpy array of target values either of form
        (n_res, n_res, n_chan) or (n_res * [n_res - 1] / 2, n_chan),
        must match form of preds.
    - curve_type (str) - One of 'ROC' or 'PRC' to denote type of curve.
    - squareform (bool) - True if tensors are of shape (n_res, n_res, n_chan),
        False if they are of shape (n_res * [n_res - 1] / 2, n_chan)
        (default = True).

    Returns:
    - Tuple of x, y, and AUC values to be used for plotting the curves
        using plot_curve metric.
    """

    # Get correct curve function
    if curve_type.upper() == 'ROC':
        curve_func = roc_curve
    elif curve_type.upper() == 'PRC':
        curve_func = precision_recall_curve

    # Generate dicts to hold outputs from curve generation functions
    x = dict()
    y = dict()
    auc_ = dict()

    # Handle case of squareform matrix (only get non-redundant triu indices)
    if squareform:
        indices = np.triu_indices(target.shape[0])

    # For each channel
    for i in range(target.shape[-1]):

        # Handle case of squareform
        if squareform:
            var1, var2, _ = curve_func(target[:, :, i][indices],
                                       preds[:, :, i][indices])

        # Handle case of pairwise
        else:
            var1, var2, _ = curve_func(target[:, i], preds[:, i])

        # Assign outputs to correct dict for plotting
        if curve_type.upper() == 'ROC':
            x[i] = var1
            y[i] = var2
        elif curve_type.upper() == 'PRC':
            x[i] = var2
            y[i] = var1

        # Calc AUC
        auc_[i] = auc(x[i], y[i])

    return (x, y, auc_)


def plot_curve_metric(x, y, auc, curve_type, title=None, labels=None):
    """
    Plot ROC or PRC curves per output channel.

    Args:
    - x (dict) - Dict of numpy arrays for values to plot on x axis.
    - y (dict) - Dict of numpy arrays for values to plot on x axis.
    - auc (dict) - Dict of numpy arrays for areas under each curve.
    - curve_type (str) - One of 'ROC' or 'PRC' to denote type of curve.
    - title
    - labels

    Returns:
    - pyplot object of curves.
    """

    # Generate figure
    plt.figure()

    # Linetype spec
    lw = 2
    curve_type = curve_type.upper()

    # Get the number of channels being plotted
    n_chan = len(x)

    # Make labels numeric if not provided
    if labels is None:
        labels = list(range(n_chan))

    # Check to make sure the labels are the right length
    if len(labels) != n_chan:
        raise ValueError('Number of labels ({}) does not match number of prediction channels ({}).'.format(len(labels), n_chan))

    # Get a lit of colors for all the channels
    color_list = plt.cm.Set1(np.linspace(0, 1, n_chan))

    # Plot each line
    for i, color in enumerate(color_list):
        plt.plot(x[i], y[i], color=color,
                 lw=lw, label='{} (area = {:0.2f})'.format(labels[i], auc[i]))

    # Add labels and diagonal line for ROC
    if curve_type == 'ROC':
        xlab = 'FPR'
        ylab = 'TPR'
        plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
        plt.legend(loc="lower right")

    # Add labels for PRC
    elif curve_type == 'PRC':
        xlab = 'Recall'
        ylab = 'Precision'
        plt.legend(loc="lower left")

    # Extend limits, add labels and title
    plt.xlim([-0.05, 1.05])
    plt.ylim([-0.05, 1.05])
    plt.xlabel(xlab)
    plt.ylabel(ylab)

    if title is not None:
        plt.title('{} for {}'.format(curve_type, title))
    else:
        plt.title('{}'.format(curve_type))

    return plt.axes()

def plot_curve(preds, target, curve_type, title=None, labels=None,
               squareform=False):
    """
    Wrapper to directly plot curves from model output and target.

    Args:
    - preds (np array-like) - Array or tensor of predicted values output by
        model.
    - target (np array-like) - Array or tensor of target values.
    - curve_type (str) - One of 'ROC' or 'PRC'.
    - title (str) - Title of plot (default = None).
    - labels (list) - List of labels for each channel on the plot
        (default = None).
    - squareform (bool) - Whether the predictions and targets are in square form
        (default = False).
    """
    x, y, auc_ = calc_metric_curve(preds, target, curve_type, squareform)
    return plot_curve_metric(x, y, auc_, curve_type, title, labels)


################################
# Correlations between metrics #
################################

def metric_corr_plot(corr):
    mask = np.triu(np.ones_like(corr, dtype=np.bool))

    fig, ax = plt.subplots(figsize=(11, 9))
    cmap = sns.diverging_palette(220, 10, as_cmap=True)

    sns.heatmap(corr, mask=mask, cmap=cmap, vmax=1.0, vmin = -1.0, center=0,
                square=True, linewidths=.5, cbar_kws={"shrink": .5}, ax=ax)

    plt.tight_layout()
    plt.close()
    return fig

# %% [markdown]
# ## Training
#
# ### Instantiate dataloader and model

# %%
from pytorch_lightning.callbacks import ModelCheckpoint
torch.autograd.set_detect_anomaly(True)

data_base = '/home/tshimko/tesselate/'

torch.manual_seed(0)

data_load = [
                'pdb_id',
#                 'model',
                'atom_nodes',
                'atom_adj',
#                 'atom_contact',
#                 'atom_mask',
                'res_adj',
                'res_dist',
                'chain_mem',
                'res_contact',
                'conn_adj',
                'res_mask',
                'mem_mat',
#                 'idx2atom_dict',
#                 'idx2res_dict'
            ]

# train_data = TesselateDataset(data_base + 'id_lists/ligand_free_monomers/small_train.txt',
#                               graph_dir=data_base + 'data/graphs',
#                               contacts_dir=data_base + 'data/contacts',
#                               return_data=data_load, in_memory=False)

train_data = TesselateDataset(data_base + 'test4.txt',
                              graph_dir=data_base + 'data/graphs',
                              contacts_dir=data_base + 'data/contacts',
                              return_data=data_load, in_memory=True)

# train_data = TesselateDataset(data_base + 'test3.txt',
#                               graph_dir=data_base + 'data/graphs',
#                               contacts_dir=data_base + 'data/contacts',
#                               return_data=data_load, in_memory=True)

# val_data = TesselateDataset(data_base + 'test3.txt',
#                               graph_dir=data_base + 'data/graphs',
#                               contacts_dir=data_base + 'data/contacts',
#                               return_data=data_load, in_memory=True)

val_data = TesselateDataset(data_base + 'id_lists/ligand_free_monomers/small_val.txt',
                            graph_dir=data_base + 'data/graphs',
                            contacts_dir=data_base + 'data/contacts',
                            return_data=data_load, in_memory=True)


checkpoint_callback = ModelCheckpoint(
    filepath=os.getcwd() + '/checkpoints',
    save_top_k=0,
    verbose=False,
    monitor='val_loss',
    mode='min',
    prefix=''
)

model = GAT(embed_features=10, atom_out_features=10, res_out_features=10,
             n_contact_channels=8, dropout=0, alpha=0.2, train_data=train_data, val_data=val_data,
             test_data=None)

# %%
# %%capture --no-stdout
import logging
logging.getLogger().setLevel(logging.CRITICAL)

from pytorch_lightning import Trainer
from pytorch_lightning.logging import WandbLogger

logger = WandbLogger(project='tesselate')

trainer = Trainer(max_nb_epochs=2000, checkpoint_callback=checkpoint_callback,
                  early_stop_callback=False, accumulate_grad_batches=8,
                  logger=logger, gpus=1) #, gradient_clip_val=0.5) # amp_level='O2', use_amp=True) <-- for half precision
trainer.fit(model)
# Out:
# Epoch 1:  51%|█████▏    | 55/107 [00:21<00:16,  3.18batch/s, batch_idx=54, gpu=0, loss=0.560, v_num=9sg5v24z]
# Validating:   0%|          | 0/52 [00:00<?, ?batch/s]
# Epoch 1:  52%|█████▏    | 56/107 [00:24<00:57,  1.12s/batch, batch_idx=54, gpu=0, loss=0.560, v_num=9sg5v24z]
# Epoch 1:  53%|█████▎    | 57/107 [00:26<01:04,  1.29s/batch, batch_idx=54, gpu=0, loss=0.560, v_num=9sg5v24z]
# Epoch 1:  54%|█████▍    | 58/107 [00:26<00:48,  1.01batch/s, batch_idx=54, gpu=0, loss=0.560, v_num=9sg5v24z]
# Epoch 1:  55%|█████▌    | 59/107 [00:26<00:39,  1.23batch/s, batch_idx=54, gpu=0, loss=0.560, v_num=9sg5v24z]
# Epoch 1:  56%|█████▌    | 60/107 [00:27<00:30,  1.53batch/s, batch_idx=54, gpu=0, loss=0.560, v_num=9sg5v24z]
# Epoch 1:  57%|█████▋    | 61/107 [00:27<00:22,  2.02batch/s, batch_idx=54, gpu=0, loss=0.560, v_num=9sg5v24z]
# Epoch 1:  58%|█████▊    | 62/107 [00:28<00:37,  1.19batch/s, batch_idx=54, gpu=0, loss=0.560, v_num=9sg5v24z]
# Epoch 1:  59%|█████▉    | 63/107 [00:29<00:28,  1.55batch/s, batch_idx=54, gpu=0, loss=0.560, v_num=9sg5v24z]
# Epoch 1:  60%|█████▉    | 64/107 [00:29<00:23,  1.82batch/s, batch_idx=54, gpu=0, loss=0.560, v_num=9sg5v24z]
# Epoch 1:  61%|██████    | 65/107 [00:29<00:17,  2.38batch/s, batch_idx=54, gpu=0, loss=0.560, v_num=9sg5v24z]
# Epoch 1:  62%|██████▏   | 66/107 [00:29<00:17,  2.41batch/s, batch_idx=54, gpu=0, loss=0.560, v_num=9sg5v24z]
# Epoch 1:  63%|██████▎   | 67/107 [00:30<00:16,  2.49batch/s, batch_idx=54, gpu=0, loss=0.560, v_num=9sg5v24z]
# Epoch 1:  64%|██████▎   | 68/107 [00:30<00:13,  2.88batch/s, batch_idx=54, gpu=0, loss=0.560, v_num=9sg5v24z]
# Epoch 1:  64%|██████▍   | 69/107 [00:30<00:13,  2.89batch/s, batch_idx=54, gpu=0, loss=0.560, v_num=9sg5v24z]
# Epoch 1:  65%|██████▌   | 70/107 [00:31<00:12,  2.97batch/s, batch_idx=54, gpu=0, loss=0.560, v_num=9sg5v24z]
# Epoch 1:  66%|██████▋   | 71/107 [00:31<00:15,  2.30batch/s, batch_idx=54, gpu=0, loss=0.560, v_num=9sg5v24z]
# Epoch 1:  67%|██████▋   | 72/107 [00:32<00:14,  2.45batch/s, batch_idx=54, gpu=0, loss=0.560, v_num=9sg5v24z]
# Epoch 1:  69%|██████▉   | 74/107 [00:32<00:11,  2.85batch/s, batch_idx=54, gpu=0, loss=0.560, v_num=9sg5v24z]
# Epoch 1:  70%|███████   | 75/107 [00:32<00:09,  3.45batch/s, batch_idx=54, gpu=0, loss=0.560, v_num=9sg5v24z]
# Epoch 1:  71%|███████   | 76/107 [00:32<00:07,  3.88batch/s, batch_idx=54, gpu=0, loss=0.560, v_num=9sg5v24z]
# Epoch 1:  72%|███████▏  | 77/107 [00:33<00:07,  3.88batch/s, batch_idx=54, gpu=0, loss=0.560, v_num=9sg5v24z]
# Epoch 1:  73%|███████▎  | 78/107 [00:33<00:11,  2.47batch/s, batch_idx=54, gpu=0, loss=0.560, v_num=9sg5v24z]
# Epoch 1:  74%|███████▍  | 79/107 [00:34<00:09,  3.08batch/s, batch_idx=54, gpu=0, loss=0.560, v_num=9sg5v24z]
# Epoch 1:  75%|███████▍  | 80/107 [00:34<00:08,  3.23batch/s, batch_idx=54, gpu=0, loss=0.560, v_num=9sg5v24z]
# Epoch 1:  76%|███████▌  | 81/107 [00:34<00:06,  3.99batch/s, batch_idx=54, gpu=0, loss=0.560, v_num=9sg5v24z]
# Epoch 1:  77%|███████▋  | 82/107 [00:34<00:05,  4.58batch/s, batch_idx=54, gpu=0, loss=0.560, v_num=9sg5v24z]
# Epoch 1:  78%|███████▊  | 83/107 [00:34<00:05,  4.31batch/s, batch_idx=54, gpu=0, loss=0.560, v_num=9sg5v24z]
# Epoch 1:  79%|███████▊  | 84/107 [00:34<00:04,  5.14batch/s, batch_idx=54, gpu=0, loss=0.560, v_num=9sg5v24z]
# Epoch 1:  79%|███████▉  | 85/107 [00:35<00:03,  5.68batch/s, batch_idx=54, gpu=0, loss=0.560, v_num=9sg5v24z]
# Epoch 1:  80%|████████  | 86/107 [00:35<00:03,  5.51batch/s, batch_idx=54, gpu=0, loss=0.560, v_num=9sg5v24z]
# Epoch 1:  81%|████████▏ | 87/107 [00:35<00:03,  5.92batch/s, batch_idx=54, gpu=0, loss=0.560, v_num=9sg5v24z]
# Epoch 1:  82%|████████▏ | 88/107 [00:35<00:02,  6.65batch/s, batch_idx=54, gpu=0, loss=0.560, v_num=9sg5v24z]
# Epoch 1:  83%|████████▎ | 89/107 [00:35<00:03,  5.98batch/s, batch_idx=54, gpu=0, loss=0.560, v_num=9sg5v24z]
# Epoch 1:  84%|████████▍ | 90/107 [00:36<00:03,  4.41batch/s, batch_idx=54, gpu=0, loss=0.560, v_num=9sg5v24z]
# Epoch 1:  85%|████████▌ | 91/107 [00:36<00:03,  5.01batch/s, batch_idx=54, gpu=0, loss=0.560, v_num=9sg5v24z]
# Epoch 1:  86%|████████▌ | 92/107 [00:37<00:05,  2.78batch/s, batch_idx=54, gpu=0, loss=0.560, v_num=9sg5v24z]
# Epoch 1:  87%|████████▋ | 93/107 [00:37<00:04,  3.34batch/s, batch_idx=54, gpu=0, loss=0.560, v_num=9sg5v24z]
# Epoch 1:  88%|████████▊ | 94/107 [00:37<00:04,  2.73batch/s, batch_idx=54, gpu=0, loss=0.560, v_num=9sg5v24z]
# Epoch 1:  89%|████████▉ | 95/107 [00:39<00:09,  1.28batch/s, batch_idx=54, gpu=0, loss=0.560, v_num=9sg5v24z]
# Epoch 1:  90%|████████▉ | 96/107 [00:39<00:06,  1.59batch/s, batch_idx=54, gpu=0, loss=0.560, v_num=9sg5v24z]
# Epoch 1:  91%|█████████ | 97/107 [00:40<00:06,  1.49batch/s, batch_idx=54, gpu=0, loss=0.560, v_num=9sg5v24z]
# Epoch 1:  92%|█████████▏| 98/107 [00:40<00:04,  1.91batch/s, batch_idx=54, gpu=0, loss=0.560, v_num=9sg5v24z]
# Epoch 1:  93%|█████████▎| 99/107 [00:40<00:03,  2.35batch/s, batch_idx=54, gpu=0, loss=0.560, v_num=9sg5v24z]
# Epoch 1:  93%|█████████▎| 100/107 [00:40<00:02,  2.96batch/s, batch_idx=54, gpu=0, loss=0.560, v_num=9sg5v24z]
# Epoch 1:  94%|█████████▍| 101/107 [00:41<00:01,  3.74batch/s, batch_idx=54, gpu=0, loss=0.560, v_num=9sg5v24z]
# Epoch 1:  95%|█████████▌| 102/107 [00:41<00:01,  3.31batch/s, batch_idx=54, gpu=0, loss=0.560, v_num=9sg5v24z]
# Epoch 1:  96%|█████████▋| 103/107 [00:41<00:01,  3.99batch/s, batch_idx=54, gpu=0, loss=0.560, v_num=9sg5v24z]
# Epoch 1:  97%|█████████▋| 104/107 [00:41<00:00,  4.58batch/s, batch_idx=54, gpu=0, loss=0.560, v_num=9sg5v24z]
# Epoch 1:  98%|█████████▊| 105/107 [00:41<00:00,  4.83batch/s, batch_idx=54, gpu=0, loss=0.560, v_num=9sg5v24z]
# Epoch 1:  99%|█████████▉| 106/107 [00:42<00:00,  4.26batch/s, batch_idx=54, gpu=0, loss=0.560, v_num=9sg5v24z]
# Epoch 1: 100%|██████████| 107/107 [00:43<00:00,  5.14batch/s, batch_idx=54, gpu=0, loss=0.560, v_num=9sg5v24z]
# Epoch 2:  51%|█████▏    | 55/107 [00:19<00:14,  3.59batch/s, batch_idx=54, gpu=0, loss=0.532, v_num=9sg5v24z]
# Validating:   0%|          | 0/52 [00:00<?, ?batch/s]
# Epoch 2:  52%|█████▏    | 56/107 [00:21<00:43,  1.18batch/s, batch_idx=54, gpu=0, loss=0.532, v_num=9sg5v24z]
# Epoch 2:  53%|█████▎    | 57/107 [00:23<00:50,  1.00s/batch, batch_idx=54, gpu=0, loss=0.532, v_num=9sg5v24z]
# Epoch 2:  54%|█████▍    | 58/107 [00:23<00:42,  1.16batch/s, batch_idx=54, gpu=0, loss=0.532, v_num=9sg5v24z]
# Epoch 2:  55%|█████▌    | 59/107 [00:26<01:12,  1.50s/batch, batch_idx=54, gpu=0, loss=0.532, v_num=9sg5v24z]
# Epoch 2:  56%|█████▌    | 60/107 [00:27<00:53,  1.13s/batch, batch_idx=54, gpu=0, loss=0.532, v_num=9sg5v24z]
# Epoch 2:  57%|█████▋    | 61/107 [00:27<00:38,  1.21batch/s, batch_idx=54, gpu=0, loss=0.532, v_num=9sg5v24z]
# Epoch 2:  58%|█████▊    | 62/107 [00:28<00:37,  1.21batch/s, batch_idx=54, gpu=0, loss=0.532, v_num=9sg5v24z]
# Epoch 2:  59%|█████▉    | 63/107 [00:28<00:26,  1.63batch/s, batch_idx=54, gpu=0, loss=0.532, v_num=9sg5v24z]
# Epoch 2:  60%|█████▉    | 64/107 [00:28<00:22,  1.92batch/s, batch_idx=54, gpu=0, loss=0.532, v_num=9sg5v24z]
# Epoch 2:  61%|██████    | 65/107 [00:28<00:17,  2.38batch/s, batch_idx=54, gpu=0, loss=0.532, v_num=9sg5v24z]
# Epoch 2:  62%|██████▏   | 66/107 [00:29<00:16,  2.46batch/s, batch_idx=54, gpu=0, loss=0.532, v_num=9sg5v24z]
# Epoch 2:  63%|██████▎   | 67/107 [00:29<00:14,  2.73batch/s, batch_idx=54, gpu=0, loss=0.532, v_num=9sg5v24z]
# Epoch 2:  64%|██████▎   | 68/107 [00:29<00:12,  3.06batch/s, batch_idx=54, gpu=0, loss=0.532, v_num=9sg5v24z]
# Epoch 2:  64%|██████▍   | 69/107 [00:29<00:12,  3.02batch/s, batch_idx=54, gpu=0, loss=0.532, v_num=9sg5v24z]
# Epoch 2:  65%|██████▌   | 70/107 [00:30<00:12,  2.99batch/s, batch_idx=54, gpu=0, loss=0.532, v_num=9sg5v24z]
# Epoch 2:  66%|██████▋   | 71/107 [00:30<00:15,  2.34batch/s, batch_idx=54, gpu=0, loss=0.532, v_num=9sg5v24z]
# Epoch 2:  67%|██████▋   | 72/107 [00:31<00:14,  2.43batch/s, batch_idx=54, gpu=0, loss=0.532, v_num=9sg5v24z]
# Epoch 2:  69%|██████▉   | 74/107 [00:31<00:11,  2.85batch/s, batch_idx=54, gpu=0, loss=0.532, v_num=9sg5v24z]
# Epoch 2:  70%|███████   | 75/107 [00:31<00:09,  3.47batch/s, batch_idx=54, gpu=0, loss=0.532, v_num=9sg5v24z]
# Epoch 2:  71%|███████   | 76/107 [00:31<00:07,  3.94batch/s, batch_idx=54, gpu=0, loss=0.532, v_num=9sg5v24z]
# Epoch 2:  72%|███████▏  | 77/107 [00:32<00:07,  4.04batch/s, batch_idx=54, gpu=0, loss=0.532, v_num=9sg5v24z]
# Epoch 2:  73%|███████▎  | 78/107 [00:32<00:10,  2.77batch/s, batch_idx=54, gpu=0, loss=0.532, v_num=9sg5v24z]
# Epoch 2:  74%|███████▍  | 79/107 [00:33<00:08,  3.31batch/s, batch_idx=54, gpu=0, loss=0.532, v_num=9sg5v24z]
# Epoch 2:  75%|███████▍  | 80/107 [00:33<00:07,  3.43batch/s, batch_idx=54, gpu=0, loss=0.532, v_num=9sg5v24z]
# Epoch 2:  76%|███████▌  | 81/107 [00:33<00:06,  4.21batch/s, batch_idx=54, gpu=0, loss=0.532, v_num=9sg5v24z]
# Epoch 2:  77%|███████▋  | 82/107 [00:33<00:05,  4.85batch/s, batch_idx=54, gpu=0, loss=0.532, v_num=9sg5v24z]
# Epoch 2:  78%|███████▊  | 83/107 [00:33<00:05,  4.52batch/s, batch_idx=54, gpu=0, loss=0.532, v_num=9sg5v24z]
# Epoch 2:  79%|███████▊  | 84/107 [00:33<00:04,  5.35batch/s, batch_idx=54, gpu=0, loss=0.532, v_num=9sg5v24z]
# Epoch 2:  79%|███████▉  | 85/107 [00:34<00:03,  5.85batch/s, batch_idx=54, gpu=0, loss=0.532, v_num=9sg5v24z]
# Epoch 2:  80%|████████  | 86/107 [00:34<00:03,  5.34batch/s, batch_idx=54, gpu=0, loss=0.532, v_num=9sg5v24z]
# Epoch 2:  81%|████████▏ | 87/107 [00:34<00:03,  5.75batch/s, batch_idx=54, gpu=0, loss=0.532, v_num=9sg5v24z]
# Epoch 2:  82%|████████▏ | 88/107 [00:34<00:02,  6.47batch/s, batch_idx=54, gpu=0, loss=0.532, v_num=9sg5v24z]
# Epoch 2:  83%|████████▎ | 89/107 [00:34<00:03,  5.71batch/s, batch_idx=54, gpu=0, loss=0.532, v_num=9sg5v24z]
# Epoch 2:  84%|████████▍ | 90/107 [00:35<00:04,  3.93batch/s, batch_idx=54, gpu=0, loss=0.532, v_num=9sg5v24z]
# Epoch 2:  85%|████████▌ | 91/107 [00:35<00:03,  4.59batch/s, batch_idx=54, gpu=0, loss=0.532, v_num=9sg5v24z]
# Epoch 2:  86%|████████▌ | 92/107 [00:35<00:05,  2.93batch/s, batch_idx=54, gpu=0, loss=0.532, v_num=9sg5v24z]
# Epoch 2:  87%|████████▋ | 93/107 [00:36<00:03,  3.58batch/s, batch_idx=54, gpu=0, loss=0.532, v_num=9sg5v24z]
# Epoch 2:  88%|████████▊ | 94/107 [00:36<00:04,  2.99batch/s, batch_idx=54, gpu=0, loss=0.532, v_num=9sg5v24z]
# Epoch 2:  89%|████████▉ | 95/107 [00:38<00:09,  1.32batch/s, batch_idx=54, gpu=0, loss=0.532, v_num=9sg5v24z]
# Epoch 2:  90%|████████▉ | 96/107 [00:38<00:06,  1.65batch/s, batch_idx=54, gpu=0, loss=0.532, v_num=9sg5v24z]
# Epoch 2:  91%|█████████ | 97/107 [00:39<00:06,  1.53batch/s, batch_idx=54, gpu=0, loss=0.532, v_num=9sg5v24z]
# Epoch 2:  92%|█████████▏| 98/107 [00:39<00:04,  1.97batch/s, batch_idx=54, gpu=0, loss=0.532, v_num=9sg5v24z]
# Epoch 2:  93%|█████████▎| 99/107 [00:39<00:03,  2.42batch/s, batch_idx=54, gpu=0, loss=0.532, v_num=9sg5v24z]
# Epoch 2:  93%|█████████▎| 100/107 [00:39<00:02,  3.13batch/s, batch_idx=54, gpu=0, loss=0.532, v_num=9sg5v24z]
# Epoch 2:  95%|█████████▌| 102/107 [00:40<00:01,  3.38batch/s, batch_idx=54, gpu=0, loss=0.532, v_num=9sg5v24z]
# Epoch 2:  96%|█████████▋| 103/107 [00:40<00:00,  4.04batch/s, batch_idx=54, gpu=0, loss=0.532, v_num=9sg5v24z]
# Epoch 2:  97%|█████████▋| 104/107 [00:40<00:00,  4.62batch/s, batch_idx=54, gpu=0, loss=0.532, v_num=9sg5v24z]
# Epoch 2:  98%|█████████▊| 105/107 [00:40<00:00,  4.83batch/s, batch_idx=54, gpu=0, loss=0.532, v_num=9sg5v24z]
# Epoch 2:  99%|█████████▉| 106/107 [00:40<00:00,  4.23batch/s, batch_idx=54, gpu=0, loss=0.532, v_num=9sg5v24z]
# Epoch 2: 100%|██████████| 107/107 [00:42<00:00,  4.82batch/s, batch_idx=54, gpu=0, loss=0.532, v_num=9sg5v24z]
# Epoch 3:  51%|█████▏    | 55/107 [00:20<00:14,  3.50batch/s, batch_idx=54, gpu=0, loss=0.498, v_num=9sg5v24z]
# Validating:   0%|          | 0/52 [00:00<?, ?batch/s]
# Epoch 3:  52%|█████▏    | 56/107 [00:22<00:48,  1.04batch/s, batch_idx=54, gpu=0, loss=0.498, v_num=9sg5v24z]
# Epoch 3:  53%|█████▎    | 57/107 [00:25<01:11,  1.43s/batch, batch_idx=54, gpu=0, loss=0.498, v_num=9sg5v24z]
# Epoch 3:  54%|█████▍    | 58/107 [00:25<00:52,  1.08s/batch, batch_idx=54, gpu=0, loss=0.498, v_num=9sg5v24z]
# Epoch 3:  55%|█████▌    | 59/107 [00:27<01:00,  1.27s/batch, batch_idx=54, gpu=0, loss=0.498, v_num=9sg5v24z]
# Epoch 3:  56%|█████▌    | 60/107 [00:27<00:46,  1.01batch/s, batch_idx=54, gpu=0, loss=0.498, v_num=9sg5v24z]
# Epoch 3:  57%|█████▋    | 61/107 [00:27<00:33,  1.35batch/s, batch_idx=54, gpu=0, loss=0.498, v_num=9sg5v24z]
# Epoch 3:  58%|█████▊    | 62/107 [00:28<00:39,  1.15batch/s, batch_idx=54, gpu=0, loss=0.498, v_num=9sg5v24z]
# Epoch 3:  59%|█████▉    | 63/107 [00:28<00:29,  1.52batch/s, batch_idx=54, gpu=0, loss=0.498, v_num=9sg5v24z]
# Epoch 3:  60%|█████▉    | 64/107 [00:29<00:23,  1.80batch/s, batch_idx=54, gpu=0, loss=0.498, v_num=9sg5v24z]
# Epoch 3:  61%|██████    | 65/107 [00:29<00:18,  2.29batch/s, batch_idx=54, gpu=0, loss=0.498, v_num=9sg5v24z]
# Epoch 3:  62%|██████▏   | 66/107 [00:29<00:17,  2.35batch/s, batch_idx=54, gpu=0, loss=0.498, v_num=9sg5v24z]
# Epoch 3:  63%|██████▎   | 67/107 [00:30<00:15,  2.61batch/s, batch_idx=54, gpu=0, loss=0.498, v_num=9sg5v24z]
# Epoch 3:  64%|██████▎   | 68/107 [00:30<00:13,  2.97batch/s, batch_idx=54, gpu=0, loss=0.498, v_num=9sg5v24z]
# Epoch 3:  64%|██████▍   | 69/107 [00:30<00:12,  2.98batch/s, batch_idx=54, gpu=0, loss=0.498, v_num=9sg5v24z]
# Epoch 3:  65%|██████▌   | 70/107 [00:30<00:11,  3.10batch/s, batch_idx=54, gpu=0, loss=0.498, v_num=9sg5v24z]
# Epoch 3:  66%|██████▋   | 71/107 [00:31<00:14,  2.40batch/s, batch_idx=54, gpu=0, loss=0.498, v_num=9sg5v24z]
# Epoch 3:  67%|██████▋   | 72/107 [00:31<00:14,  2.41batch/s, batch_idx=54, gpu=0, loss=0.498, v_num=9sg5v24z]
# Epoch 3:  68%|██████▊   | 73/107 [00:32<00:10,  3.12batch/s, batch_idx=54, gpu=0, loss=0.498, v_num=9sg5v24z]
# Epoch 3:  69%|██████▉   | 74/107 [00:32<00:10,  3.04batch/s, batch_idx=54, gpu=0, loss=0.498, v_num=9sg5v24z]
# Epoch 3:  70%|███████   | 75/107 [00:32<00:08,  3.63batch/s, batch_idx=54, gpu=0, loss=0.498, v_num=9sg5v24z]
# Epoch 3:  71%|███████   | 76/107 [00:32<00:07,  4.08batch/s, batch_idx=54, gpu=0, loss=0.498, v_num=9sg5v24z]
# Epoch 3:  72%|███████▏  | 77/107 [00:32<00:07,  4.21batch/s, batch_idx=54, gpu=0, loss=0.498, v_num=9sg5v24z]
# Epoch 3:  73%|███████▎  | 78/107 [00:33<00:10,  2.89batch/s, batch_idx=54, gpu=0, loss=0.498, v_num=9sg5v24z]
# Epoch 3:  74%|███████▍  | 79/107 [00:33<00:08,  3.48batch/s, batch_idx=54, gpu=0, loss=0.498, v_num=9sg5v24z]
# Epoch 3:  75%|███████▍  | 80/107 [00:33<00:07,  3.50batch/s, batch_idx=54, gpu=0, loss=0.498, v_num=9sg5v24z]
# Epoch 3:  77%|███████▋  | 82/107 [00:34<00:05,  4.28batch/s, batch_idx=54, gpu=0, loss=0.498, v_num=9sg5v24z]
# Epoch 3:  78%|███████▊  | 83/107 [00:34<00:05,  4.05batch/s, batch_idx=54, gpu=0, loss=0.498, v_num=9sg5v24z]
# Epoch 3:  79%|███████▊  | 84/107 [00:34<00:04,  4.85batch/s, batch_idx=54, gpu=0, loss=0.498, v_num=9sg5v24z]
# Epoch 3:  79%|███████▉  | 85/107 [00:34<00:04,  5.33batch/s, batch_idx=54, gpu=0, loss=0.498, v_num=9sg5v24z]
# Epoch 3:  80%|████████  | 86/107 [00:34<00:04,  5.09batch/s, batch_idx=54, gpu=0, loss=0.498, v_num=9sg5v24z]
# Epoch 3:  81%|████████▏ | 87/107 [00:35<00:03,  5.38batch/s, batch_idx=54, gpu=0, loss=0.498, v_num=9sg5v24z]
# Epoch 3:  82%|████████▏ | 88/107 [00:35<00:03,  5.78batch/s, batch_idx=54, gpu=0, loss=0.498, v_num=9sg5v24z]
# Epoch 3:  83%|████████▎ | 89/107 [00:35<00:03,  5.41batch/s, batch_idx=54, gpu=0, loss=0.498, v_num=9sg5v24z]
# Epoch 3:  84%|████████▍ | 90/107 [00:35<00:04,  3.93batch/s, batch_idx=54, gpu=0, loss=0.498, v_num=9sg5v24z]
# Epoch 3:  85%|████████▌ | 91/107 [00:36<00:03,  4.47batch/s, batch_idx=54, gpu=0, loss=0.498, v_num=9sg5v24z]
# Epoch 3:  86%|████████▌ | 92/107 [00:36<00:05,  2.80batch/s, batch_idx=54, gpu=0, loss=0.498, v_num=9sg5v24z]
# Epoch 3:  87%|████████▋ | 93/107 [00:36<00:04,  3.46batch/s, batch_idx=54, gpu=0, loss=0.498, v_num=9sg5v24z]
# Epoch 3:  88%|████████▊ | 94/107 [00:37<00:04,  2.95batch/s, batch_idx=54, gpu=0, loss=0.498, v_num=9sg5v24z]
# Epoch 3:  89%|████████▉ | 95/107 [00:39<00:09,  1.33batch/s, batch_idx=54, gpu=0, loss=0.498, v_num=9sg5v24z]
# Epoch 3:  90%|████████▉ | 96/107 [00:39<00:06,  1.65batch/s, batch_idx=54, gpu=0, loss=0.498, v_num=9sg5v24z]
# Epoch 3:  91%|█████████ | 97/107 [00:40<00:06,  1.55batch/s, batch_idx=54, gpu=0, loss=0.498, v_num=9sg5v24z]
# Epoch 3:  92%|█████████▏| 98/107 [00:40<00:04,  2.00batch/s, batch_idx=54, gpu=0, loss=0.498, v_num=9sg5v24z]
# Epoch 3:  93%|█████████▎| 99/107 [00:40<00:03,  2.45batch/s, batch_idx=54, gpu=0, loss=0.498, v_num=9sg5v24z]
# Epoch 3:  93%|█████████▎| 100/107 [00:40<00:02,  3.17batch/s, batch_idx=54, gpu=0, loss=0.498, v_num=9sg5v24z]
# Epoch 3:  94%|█████████▍| 101/107 [00:40<00:01,  3.97batch/s, batch_idx=54, gpu=0, loss=0.498, v_num=9sg5v24z]
# Epoch 3:  95%|█████████▌| 102/107 [00:40<00:01,  3.44batch/s, batch_idx=54, gpu=0, loss=0.498, v_num=9sg5v24z]
# Epoch 3:  96%|█████████▋| 103/107 [00:41<00:00,  4.12batch/s, batch_idx=54, gpu=0, loss=0.498, v_num=9sg5v24z]
# Epoch 3:  97%|█████████▋| 104/107 [00:41<00:00,  4.70batch/s, batch_idx=54, gpu=0, loss=0.498, v_num=9sg5v24z]
# Epoch 3:  98%|█████████▊| 105/107 [00:41<00:00,  4.94batch/s, batch_idx=54, gpu=0, loss=0.498, v_num=9sg5v24z]
# Epoch 3: 100%|██████████| 107/107 [00:43<00:00,  4.32batch/s, batch_idx=54, gpu=0, loss=0.498, v_num=9sg5v24z]
# Epoch 4:  51%|█████▏    | 55/107 [00:21<00:15,  3.37batch/s, batch_idx=54, gpu=0, loss=0.465, v_num=9sg5v24z]
# Validating:   0%|          | 0/52 [00:00<?, ?batch/s]
# Epoch 4:  52%|█████▏    | 56/107 [00:23<00:45,  1.11batch/s, batch_idx=54, gpu=0, loss=0.465, v_num=9sg5v24z]
# Epoch 4:  53%|█████▎    | 57/107 [00:26<01:10,  1.41s/batch, batch_idx=54, gpu=0, loss=0.465, v_num=9sg5v24z]
# Epoch 4:  54%|█████▍    | 58/107 [00:26<00:52,  1.07s/batch, batch_idx=54, gpu=0, loss=0.465, v_num=9sg5v24z]
# Epoch 4:  55%|█████▌    | 59/107 [00:27<00:47,  1.01batch/s, batch_idx=54, gpu=0, loss=0.465, v_num=9sg5v24z]
# Epoch 4:  56%|█████▌    | 60/107 [00:27<00:36,  1.30batch/s, batch_idx=54, gpu=0, loss=0.465, v_num=9sg5v24z]
# Epoch 4:  57%|█████▋    | 61/107 [00:27<00:26,  1.73batch/s, batch_idx=54, gpu=0, loss=0.465, v_num=9sg5v24z]
# Epoch 4:  58%|█████▊    | 62/107 [00:29<00:40,  1.12batch/s, batch_idx=54, gpu=0, loss=0.465, v_num=9sg5v24z]
# Epoch 4:  59%|█████▉    | 63/107 [00:29<00:29,  1.50batch/s, batch_idx=54, gpu=0, loss=0.465, v_num=9sg5v24z]
# Epoch 4:  60%|█████▉    | 64/107 [00:30<00:25,  1.72batch/s, batch_idx=54, gpu=0, loss=0.465, v_num=9sg5v24z]
# Epoch 4:  61%|██████    | 65/107 [00:30<00:20,  2.07batch/s, batch_idx=54, gpu=0, loss=0.465, v_num=9sg5v24z]
# Epoch 4:  62%|██████▏   | 66/107 [00:30<00:18,  2.19batch/s, batch_idx=54, gpu=0, loss=0.465, v_num=9sg5v24z]
# Epoch 4:  63%|██████▎   | 67/107 [00:30<00:16,  2.48batch/s, batch_idx=54, gpu=0, loss=0.465, v_num=9sg5v24z]
# Epoch 4:  64%|██████▎   | 68/107 [00:31<00:14,  2.68batch/s, batch_idx=54, gpu=0, loss=0.465, v_num=9sg5v24z]
# Epoch 4:  64%|██████▍   | 69/107 [00:31<00:13,  2.78batch/s, batch_idx=54, gpu=0, loss=0.465, v_num=9sg5v24z]
# Epoch 4:  65%|██████▌   | 70/107 [00:31<00:12,  2.95batch/s, batch_idx=54, gpu=0, loss=0.465, v_num=9sg5v24z]
# Epoch 4:  66%|██████▋   | 71/107 [00:32<00:14,  2.41batch/s, batch_idx=54, gpu=0, loss=0.465, v_num=9sg5v24z]
# Epoch 4:  67%|██████▋   | 72/107 [00:32<00:13,  2.51batch/s, batch_idx=54, gpu=0, loss=0.465, v_num=9sg5v24z]
# Epoch 4:  68%|██████▊   | 73/107 [00:33<00:11,  3.01batch/s, batch_idx=54, gpu=0, loss=0.465, v_num=9sg5v24z]
# Epoch 4:  69%|██████▉   | 74/107 [00:33<00:10,  3.00batch/s, batch_idx=54, gpu=0, loss=0.465, v_num=9sg5v24z]
# Epoch 4:  70%|███████   | 75/107 [00:33<00:08,  3.58batch/s, batch_idx=54, gpu=0, loss=0.465, v_num=9sg5v24z]
# Epoch 4:  71%|███████   | 76/107 [00:33<00:07,  4.03batch/s, batch_idx=54, gpu=0, loss=0.465, v_num=9sg5v24z]
# Epoch 4:  72%|███████▏  | 77/107 [00:33<00:07,  4.14batch/s, batch_idx=54, gpu=0, loss=0.465, v_num=9sg5v24z]
# Epoch 4:  73%|███████▎  | 78/107 [00:34<00:10,  2.90batch/s, batch_idx=54, gpu=0, loss=0.465, v_num=9sg5v24z]
# Epoch 4:  74%|███████▍  | 79/107 [00:34<00:07,  3.53batch/s, batch_idx=54, gpu=0, loss=0.465, v_num=9sg5v24z]
# Epoch 4:  75%|███████▍  | 80/107 [00:34<00:07,  3.54batch/s, batch_idx=54, gpu=0, loss=0.465, v_num=9sg5v24z]
# Epoch 4:  77%|███████▋  | 82/107 [00:35<00:05,  4.37batch/s, batch_idx=54, gpu=0, loss=0.465, v_num=9sg5v24z]
# Epoch 4:  78%|███████▊  | 83/107 [00:35<00:05,  4.26batch/s, batch_idx=54, gpu=0, loss=0.465, v_num=9sg5v24z]
# Epoch 4:  79%|███████▊  | 84/107 [00:35<00:04,  5.04batch/s, batch_idx=54, gpu=0, loss=0.465, v_num=9sg5v24z]
# Epoch 4:  79%|███████▉  | 85/107 [00:35<00:04,  5.31batch/s, batch_idx=54, gpu=0, loss=0.465, v_num=9sg5v24z]
# Epoch 4:  80%|████████  | 86/107 [00:35<00:04,  4.96batch/s, batch_idx=54, gpu=0, loss=0.465, v_num=9sg5v24z]
# Epoch 4:  81%|████████▏ | 87/107 [00:36<00:03,  5.38batch/s, batch_idx=54, gpu=0, loss=0.465, v_num=9sg5v24z]
# Epoch 4:  82%|████████▏ | 88/107 [00:36<00:03,  6.05batch/s, batch_idx=54, gpu=0, loss=0.465, v_num=9sg5v24z]
# Epoch 4:  83%|████████▎ | 89/107 [00:36<00:03,  5.53batch/s, batch_idx=54, gpu=0, loss=0.465, v_num=9sg5v24z]
# Epoch 4:  84%|████████▍ | 90/107 [00:36<00:04,  4.23batch/s, batch_idx=54, gpu=0, loss=0.465, v_num=9sg5v24z]
# Epoch 4:  85%|████████▌ | 91/107 [00:36<00:03,  4.84batch/s, batch_idx=54, gpu=0, loss=0.465, v_num=9sg5v24z]
# Epoch 4:  86%|████████▌ | 92/107 [00:37<00:05,  2.83batch/s, batch_idx=54, gpu=0, loss=0.465, v_num=9sg5v24z]
# Epoch 4:  87%|████████▋ | 93/107 [00:37<00:04,  3.49batch/s, batch_idx=54, gpu=0, loss=0.465, v_num=9sg5v24z]
# Epoch 4:  88%|████████▊ | 94/107 [00:38<00:04,  2.93batch/s, batch_idx=54, gpu=0, loss=0.465, v_num=9sg5v24z]
# Epoch 4:  89%|████████▉ | 95/107 [00:39<00:08,  1.34batch/s, batch_idx=54, gpu=0, loss=0.465, v_num=9sg5v24z]
# Epoch 4:  90%|████████▉ | 96/107 [00:40<00:06,  1.67batch/s, batch_idx=54, gpu=0, loss=0.465, v_num=9sg5v24z]
# Epoch 4:  91%|█████████ | 97/107 [00:40<00:06,  1.55batch/s, batch_idx=54, gpu=0, loss=0.465, v_num=9sg5v24z]
# Epoch 4:  92%|█████████▏| 98/107 [00:41<00:04,  2.01batch/s, batch_idx=54, gpu=0, loss=0.465, v_num=9sg5v24z]
# Epoch 4:  93%|█████████▎| 99/107 [00:41<00:03,  2.47batch/s, batch_idx=54, gpu=0, loss=0.465, v_num=9sg5v24z]
# Epoch 4:  93%|█████████▎| 100/107 [00:41<00:02,  3.18batch/s, batch_idx=54, gpu=0, loss=0.465, v_num=9sg5v24z]
# Epoch 4:  94%|█████████▍| 101/107 [00:41<00:01,  4.00batch/s, batch_idx=54, gpu=0, loss=0.465, v_num=9sg5v24z]
# Epoch 4:  95%|█████████▌| 102/107 [00:41<00:01,  3.47batch/s, batch_idx=54, gpu=0, loss=0.465, v_num=9sg5v24z]
# Epoch 4:  96%|█████████▋| 103/107 [00:41<00:00,  4.15batch/s, batch_idx=54, gpu=0, loss=0.465, v_num=9sg5v24z]
# Epoch 4:  97%|█████████▋| 104/107 [00:42<00:00,  4.73batch/s, batch_idx=54, gpu=0, loss=0.465, v_num=9sg5v24z]
# Epoch 4:  98%|█████████▊| 105/107 [00:42<00:00,  4.96batch/s, batch_idx=54, gpu=0, loss=0.465, v_num=9sg5v24z]
# Epoch 4: 100%|██████████| 107/107 [00:43<00:00,  4.35batch/s, batch_idx=54, gpu=0, loss=0.465, v_num=9sg5v24z]
# Epoch 5:  51%|█████▏    | 55/107 [00:20<00:14,  3.59batch/s, batch_idx=54, gpu=0, loss=0.434, v_num=9sg5v24z]
# Validating:   0%|          | 0/52 [00:00<?, ?batch/s]
# Epoch 5:  52%|█████▏    | 56/107 [00:22<00:48,  1.05batch/s, batch_idx=54, gpu=0, loss=0.434, v_num=9sg5v24z]
# Epoch 5:  53%|█████▎    | 57/107 [00:25<01:12,  1.44s/batch, batch_idx=54, gpu=0, loss=0.434, v_num=9sg5v24z]
# Epoch 5:  54%|█████▍    | 58/107 [00:25<00:52,  1.08s/batch, batch_idx=54, gpu=0, loss=0.434, v_num=9sg5v24z]
# Epoch 5:  55%|█████▌    | 59/107 [00:26<00:46,  1.03batch/s, batch_idx=54, gpu=0, loss=0.434, v_num=9sg5v24z]
# Epoch 5:  56%|█████▌    | 60/107 [00:26<00:35,  1.31batch/s, batch_idx=54, gpu=0, loss=0.434, v_num=9sg5v24z]
# Epoch 5:  57%|█████▋    | 61/107 [00:26<00:26,  1.75batch/s, batch_idx=54, gpu=0, loss=0.434, v_num=9sg5v24z]
# Epoch 5:  58%|█████▊    | 62/107 [00:28<00:41,  1.10batch/s, batch_idx=54, gpu=0, loss=0.434, v_num=9sg5v24z]
# Epoch 5:  59%|█████▉    | 63/107 [00:28<00:29,  1.48batch/s, batch_idx=54, gpu=0, loss=0.434, v_num=9sg5v24z]
# Epoch 5:  60%|█████▉    | 64/107 [00:28<00:23,  1.81batch/s, batch_idx=54, gpu=0, loss=0.434, v_num=9sg5v24z]
# Epoch 5:  61%|██████    | 65/107 [00:29<00:18,  2.24batch/s, batch_idx=54, gpu=0, loss=0.434, v_num=9sg5v24z]
# Epoch 5:  62%|██████▏   | 66/107 [00:29<00:18,  2.23batch/s, batch_idx=54, gpu=0, loss=0.434, v_num=9sg5v24z]
# Epoch 5:  63%|██████▎   | 67/107 [00:29<00:15,  2.54batch/s, batch_idx=54, gpu=0, loss=0.434, v_num=9sg5v24z]
# Epoch 5:  64%|██████▎   | 68/107 [00:29<00:13,  2.96batch/s, batch_idx=54, gpu=0, loss=0.434, v_num=9sg5v24z]
# Epoch 5:  64%|██████▍   | 69/107 [00:30<00:12,  2.98batch/s, batch_idx=54, gpu=0, loss=0.434, v_num=9sg5v24z]
# Epoch 5:  65%|██████▌   | 70/107 [00:30<00:12,  3.08batch/s, batch_idx=54, gpu=0, loss=0.434, v_num=9sg5v24z]
# Epoch 5:  66%|██████▋   | 71/107 [00:31<00:14,  2.47batch/s, batch_idx=54, gpu=0, loss=0.434, v_num=9sg5v24z]
# Epoch 5:  67%|██████▋   | 72/107 [00:31<00:14,  2.43batch/s, batch_idx=54, gpu=0, loss=0.434, v_num=9sg5v24z]
# Epoch 5:  69%|██████▉   | 74/107 [00:32<00:11,  2.85batch/s, batch_idx=54, gpu=0, loss=0.434, v_num=9sg5v24z]
# Epoch 5:  70%|███████   | 75/107 [00:32<00:09,  3.47batch/s, batch_idx=54, gpu=0, loss=0.434, v_num=9sg5v24z]
# Epoch 5:  71%|███████   | 76/107 [00:32<00:07,  3.94batch/s, batch_idx=54, gpu=0, loss=0.434, v_num=9sg5v24z]
# Epoch 5:  72%|███████▏  | 77/107 [00:32<00:07,  4.05batch/s, batch_idx=54, gpu=0, loss=0.434, v_num=9sg5v24z]
# Epoch 5:  73%|███████▎  | 78/107 [00:33<00:10,  2.78batch/s, batch_idx=54, gpu=0, loss=0.434, v_num=9sg5v24z]
# Epoch 5:  74%|███████▍  | 79/107 [00:33<00:08,  3.41batch/s, batch_idx=54, gpu=0, loss=0.434, v_num=9sg5v24z]
# Epoch 5:  75%|███████▍  | 80/107 [00:33<00:07,  3.50batch/s, batch_idx=54, gpu=0, loss=0.434, v_num=9sg5v24z]
# Epoch 5:  77%|███████▋  | 82/107 [00:33<00:05,  4.33batch/s, batch_idx=54, gpu=0, loss=0.434, v_num=9sg5v24z]
# Epoch 5:  78%|███████▊  | 83/107 [00:34<00:05,  4.24batch/s, batch_idx=54, gpu=0, loss=0.434, v_num=9sg5v24z]
# Epoch 5:  79%|███████▊  | 84/107 [00:34<00:04,  5.09batch/s, batch_idx=54, gpu=0, loss=0.434, v_num=9sg5v24z]
# Epoch 5:  79%|███████▉  | 85/107 [00:34<00:03,  5.61batch/s, batch_idx=54, gpu=0, loss=0.434, v_num=9sg5v24z]
# Epoch 5:  80%|████████  | 86/107 [00:34<00:03,  5.49batch/s, batch_idx=54, gpu=0, loss=0.434, v_num=9sg5v24z]
# Epoch 5:  81%|████████▏ | 87/107 [00:34<00:03,  5.92batch/s, batch_idx=54, gpu=0, loss=0.434, v_num=9sg5v24z]
# Epoch 5:  82%|████████▏ | 88/107 [00:34<00:02,  6.68batch/s, batch_idx=54, gpu=0, loss=0.434, v_num=9sg5v24z]
# Epoch 5:  83%|████████▎ | 89/107 [00:34<00:02,  6.07batch/s, batch_idx=54, gpu=0, loss=0.434, v_num=9sg5v24z]
# Epoch 5:  84%|████████▍ | 90/107 [00:35<00:04,  4.20batch/s, batch_idx=54, gpu=0, loss=0.434, v_num=9sg5v24z]
# Epoch 5:  85%|████████▌ | 91/107 [00:35<00:03,  4.92batch/s, batch_idx=54, gpu=0, loss=0.434, v_num=9sg5v24z]
# Epoch 5:  86%|████████▌ | 92/107 [00:36<00:04,  3.12batch/s, batch_idx=54, gpu=0, loss=0.434, v_num=9sg5v24z]
# Epoch 5:  87%|████████▋ | 93/107 [00:36<00:03,  3.76batch/s, batch_idx=54, gpu=0, loss=0.434, v_num=9sg5v24z]
# Epoch 5:  88%|████████▊ | 94/107 [00:36<00:04,  3.10batch/s, batch_idx=54, gpu=0, loss=0.434, v_num=9sg5v24z]
# Epoch 5:  89%|████████▉ | 95/107 [00:38<00:08,  1.36batch/s, batch_idx=54, gpu=0, loss=0.434, v_num=9sg5v24z]
# Epoch 5:  90%|████████▉ | 96/107 [00:38<00:06,  1.69batch/s, batch_idx=54, gpu=0, loss=0.434, v_num=9sg5v24z]
# Epoch 5:  91%|█████████ | 97/107 [00:39<00:06,  1.58batch/s, batch_idx=54, gpu=0, loss=0.434, v_num=9sg5v24z]
# Epoch 5:  92%|█████████▏| 98/107 [00:39<00:04,  2.02batch/s, batch_idx=54, gpu=0, loss=0.434, v_num=9sg5v24z]
# Epoch 5:  93%|█████████▎| 99/107 [00:39<00:03,  2.49batch/s, batch_idx=54, gpu=0, loss=0.434, v_num=9sg5v24z]
# Epoch 5:  94%|█████████▍| 101/107 [00:39<00:01,  3.22batch/s, batch_idx=54, gpu=0, loss=0.434, v_num=9sg5v24z]
# Epoch 5:  95%|█████████▌| 102/107 [00:40<00:01,  3.02batch/s, batch_idx=54, gpu=0, loss=0.434, v_num=9sg5v24z]
# Epoch 5:  96%|█████████▋| 103/107 [00:40<00:01,  3.69batch/s, batch_idx=54, gpu=0, loss=0.434, v_num=9sg5v24z]
# Epoch 5:  97%|█████████▋| 104/107 [00:40<00:00,  4.31batch/s, batch_idx=54, gpu=0, loss=0.434, v_num=9sg5v24z]
# Epoch 5:  98%|█████████▊| 105/107 [00:40<00:00,  4.64batch/s, batch_idx=54, gpu=0, loss=0.434, v_num=9sg5v24z]
# Epoch 5: 100%|██████████| 107/107 [00:42<00:00,  4.17batch/s, batch_idx=54, gpu=0, loss=0.434, v_num=9sg5v24z]
# Epoch 6:  51%|█████▏    | 55/107 [00:21<00:15,  3.37batch/s, batch_idx=54, gpu=0, loss=0.408, v_num=9sg5v24z]
# Validating:   0%|          | 0/52 [00:00<?, ?batch/s]
# Epoch 6:  52%|█████▏    | 56/107 [00:24<01:01,  1.21s/batch, batch_idx=54, gpu=0, loss=0.408, v_num=9sg5v24z]
# Epoch 6:  53%|█████▎    | 57/107 [00:26<01:07,  1.34s/batch, batch_idx=54, gpu=0, loss=0.408, v_num=9sg5v24z]
# Epoch 6:  54%|█████▍    | 58/107 [00:26<00:53,  1.10s/batch, batch_idx=54, gpu=0, loss=0.408, v_num=9sg5v24z]
# Epoch 6:  55%|█████▌    | 59/107 [00:27<00:42,  1.13batch/s, batch_idx=54, gpu=0, loss=0.408, v_num=9sg5v24z]
# Epoch 6:  56%|█████▌    | 60/107 [00:27<00:32,  1.43batch/s, batch_idx=54, gpu=0, loss=0.408, v_num=9sg5v24z]
# Epoch 6:  57%|█████▋    | 61/107 [00:27<00:24,  1.90batch/s, batch_idx=54, gpu=0, loss=0.408, v_num=9sg5v24z]
# Epoch 6:  58%|█████▊    | 62/107 [00:28<00:32,  1.39batch/s, batch_idx=54, gpu=0, loss=0.408, v_num=9sg5v24z]
# Epoch 6:  59%|█████▉    | 63/107 [00:28<00:24,  1.83batch/s, batch_idx=54, gpu=0, loss=0.408, v_num=9sg5v24z]
# Epoch 6:  60%|█████▉    | 64/107 [00:29<00:20,  2.09batch/s, batch_idx=54, gpu=0, loss=0.408, v_num=9sg5v24z]
# Epoch 6:  61%|██████    | 65/107 [00:29<00:15,  2.69batch/s, batch_idx=54, gpu=0, loss=0.408, v_num=9sg5v24z]
# Epoch 6:  62%|██████▏   | 66/107 [00:29<00:15,  2.71batch/s, batch_idx=54, gpu=0, loss=0.408, v_num=9sg5v24z]
# Epoch 6:  63%|██████▎   | 67/107 [00:30<00:13,  2.94batch/s, batch_idx=54, gpu=0, loss=0.408, v_num=9sg5v24z]
# Epoch 6:  64%|██████▎   | 68/107 [00:30<00:11,  3.25batch/s, batch_idx=54, gpu=0, loss=0.408, v_num=9sg5v24z]
# Epoch 6:  64%|██████▍   | 69/107 [00:30<00:11,  3.20batch/s, batch_idx=54, gpu=0, loss=0.408, v_num=9sg5v24z]
# Epoch 6:  65%|██████▌   | 70/107 [00:30<00:11,  3.22batch/s, batch_idx=54, gpu=0, loss=0.408, v_num=9sg5v24z]
# Epoch 6:  66%|██████▋   | 71/107 [00:31<00:14,  2.54batch/s, batch_idx=54, gpu=0, loss=0.408, v_num=9sg5v24z]
# Epoch 6:  67%|██████▋   | 72/107 [00:31<00:13,  2.59batch/s, batch_idx=54, gpu=0, loss=0.408, v_num=9sg5v24z]
# Epoch 6:  68%|██████▊   | 73/107 [00:31<00:10,  3.32batch/s, batch_idx=54, gpu=0, loss=0.408, v_num=9sg5v24z]
# Epoch 6:  69%|██████▉   | 74/107 [00:32<00:10,  3.24batch/s, batch_idx=54, gpu=0, loss=0.408, v_num=9sg5v24z]
# Epoch 6:  70%|███████   | 75/107 [00:32<00:08,  3.89batch/s, batch_idx=54, gpu=0, loss=0.408, v_num=9sg5v24z]
# Epoch 6:  71%|███████   | 76/107 [00:32<00:07,  4.31batch/s, batch_idx=54, gpu=0, loss=0.408, v_num=9sg5v24z]
# Epoch 6:  72%|███████▏  | 77/107 [00:32<00:06,  4.34batch/s, batch_idx=54, gpu=0, loss=0.408, v_num=9sg5v24z]
# Epoch 6:  73%|███████▎  | 78/107 [00:33<00:10,  2.81batch/s, batch_idx=54, gpu=0, loss=0.408, v_num=9sg5v24z]
# Epoch 6:  74%|███████▍  | 79/107 [00:33<00:08,  3.44batch/s, batch_idx=54, gpu=0, loss=0.408, v_num=9sg5v24z]
# Epoch 6:  75%|███████▍  | 80/107 [00:33<00:07,  3.50batch/s, batch_idx=54, gpu=0, loss=0.408, v_num=9sg5v24z]
# Epoch 6:  77%|███████▋  | 82/107 [00:34<00:05,  4.30batch/s, batch_idx=54, gpu=0, loss=0.408, v_num=9sg5v24z]
# Epoch 6:  78%|███████▊  | 83/107 [00:34<00:05,  4.16batch/s, batch_idx=54, gpu=0, loss=0.408, v_num=9sg5v24z]
# Epoch 6:  79%|███████▊  | 84/107 [00:34<00:04,  4.96batch/s, batch_idx=54, gpu=0, loss=0.408, v_num=9sg5v24z]
# Epoch 6:  79%|███████▉  | 85/107 [00:34<00:04,  5.49batch/s, batch_idx=54, gpu=0, loss=0.408, v_num=9sg5v24z]
# Epoch 6:  80%|████████  | 86/107 [00:34<00:03,  5.32batch/s, batch_idx=54, gpu=0, loss=0.408, v_num=9sg5v24z]
# Epoch 6:  81%|████████▏ | 87/107 [00:34<00:03,  5.72batch/s, batch_idx=54, gpu=0, loss=0.408, v_num=9sg5v24z]
# Epoch 6:  82%|████████▏ | 88/107 [00:35<00:02,  6.40batch/s, batch_idx=54, gpu=0, loss=0.408, v_num=9sg5v24z]
# Epoch 6:  83%|████████▎ | 89/107 [00:35<00:03,  5.79batch/s, batch_idx=54, gpu=0, loss=0.408, v_num=9sg5v24z]
# Epoch 6:  84%|████████▍ | 90/107 [00:35<00:03,  4.36batch/s, batch_idx=54, gpu=0, loss=0.408, v_num=9sg5v24z]
# Epoch 6:  85%|████████▌ | 91/107 [00:35<00:03,  5.04batch/s, batch_idx=54, gpu=0, loss=0.408, v_num=9sg5v24z]
# Epoch 6:  86%|████████▌ | 92/107 [00:36<00:04,  3.08batch/s, batch_idx=54, gpu=0, loss=0.408, v_num=9sg5v24z]
# Epoch 6:  87%|████████▋ | 93/107 [00:36<00:03,  3.74batch/s, batch_idx=54, gpu=0, loss=0.408, v_num=9sg5v24z]
# Epoch 6:  88%|████████▊ | 94/107 [00:37<00:04,  2.91batch/s, batch_idx=54, gpu=0, loss=0.408, v_num=9sg5v24z]
# Epoch 6:  89%|████████▉ | 95/107 [00:38<00:09,  1.33batch/s, batch_idx=54, gpu=0, loss=0.408, v_num=9sg5v24z]
# Epoch 6:  90%|████████▉ | 96/107 [00:39<00:06,  1.66batch/s, batch_idx=54, gpu=0, loss=0.408, v_num=9sg5v24z]
# Epoch 6:  91%|█████████ | 97/107 [00:39<00:06,  1.54batch/s, batch_idx=54, gpu=0, loss=0.408, v_num=9sg5v24z]
# Epoch 6:  92%|█████████▏| 98/107 [00:39<00:04,  1.99batch/s, batch_idx=54, gpu=0, loss=0.408, v_num=9sg5v24z]
# Epoch 6:  93%|█████████▎| 99/107 [00:40<00:03,  2.45batch/s, batch_idx=54, gpu=0, loss=0.408, v_num=9sg5v24z]
# Epoch 6:  94%|█████████▍| 101/107 [00:40<00:01,  3.18batch/s, batch_idx=54, gpu=0, loss=0.408, v_num=9sg5v24z]
# Epoch 6:  95%|█████████▌| 102/107 [00:40<00:01,  3.00batch/s, batch_idx=54, gpu=0, loss=0.408, v_num=9sg5v24z]
# Epoch 6:  96%|█████████▋| 103/107 [00:40<00:01,  3.68batch/s, batch_idx=54, gpu=0, loss=0.408, v_num=9sg5v24z]
# Epoch 6:  97%|█████████▋| 104/107 [00:40<00:00,  4.28batch/s, batch_idx=54, gpu=0, loss=0.408, v_num=9sg5v24z]
# Epoch 6:  98%|█████████▊| 105/107 [00:41<00:00,  4.61batch/s, batch_idx=54, gpu=0, loss=0.408, v_num=9sg5v24z]
# Epoch 6: 100%|██████████| 107/107 [00:42<00:00,  4.17batch/s, batch_idx=54, gpu=0, loss=0.408, v_num=9sg5v24z]
# Epoch 7:  51%|█████▏    | 55/107 [00:20<00:15,  3.44batch/s, batch_idx=54, gpu=0, loss=0.384, v_num=9sg5v24z]
# Validating:   0%|          | 0/52 [00:00<?, ?batch/s]
# Epoch 7:  52%|█████▏    | 56/107 [00:22<00:44,  1.13batch/s, batch_idx=54, gpu=0, loss=0.384, v_num=9sg5v24z]
# Epoch 7:  53%|█████▎    | 57/107 [00:25<01:06,  1.33s/batch, batch_idx=54, gpu=0, loss=0.384, v_num=9sg5v24z]
# Epoch 7:  54%|█████▍    | 58/107 [00:25<00:49,  1.01s/batch, batch_idx=54, gpu=0, loss=0.384, v_num=9sg5v24z]
# Epoch 7:  55%|█████▌    | 59/107 [00:26<00:50,  1.04s/batch, batch_idx=54, gpu=0, loss=0.384, v_num=9sg5v24z]
# Epoch 7:  56%|█████▌    | 60/107 [00:26<00:38,  1.23batch/s, batch_idx=54, gpu=0, loss=0.384, v_num=9sg5v24z]
# Epoch 7:  57%|█████▋    | 61/107 [00:27<00:28,  1.63batch/s, batch_idx=54, gpu=0, loss=0.384, v_num=9sg5v24z]
# Epoch 7:  58%|█████▊    | 62/107 [00:29<00:50,  1.11s/batch, batch_idx=54, gpu=0, loss=0.384, v_num=9sg5v24z]
# Epoch 7:  59%|█████▉    | 63/107 [00:29<00:35,  1.23batch/s, batch_idx=54, gpu=0, loss=0.384, v_num=9sg5v24z]
# Epoch 7:  60%|█████▉    | 64/107 [00:29<00:29,  1.48batch/s, batch_idx=54, gpu=0, loss=0.384, v_num=9sg5v24z]
# Epoch 7:  61%|██████    | 65/107 [00:29<00:21,  1.95batch/s, batch_idx=54, gpu=0, loss=0.384, v_num=9sg5v24z]
# Epoch 7:  62%|██████▏   | 66/107 [00:30<00:19,  2.13batch/s, batch_idx=54, gpu=0, loss=0.384, v_num=9sg5v24z]
# Epoch 7:  63%|██████▎   | 67/107 [00:30<00:16,  2.44batch/s, batch_idx=54, gpu=0, loss=0.384, v_num=9sg5v24z]
# Epoch 7:  64%|██████▎   | 68/107 [00:30<00:13,  2.86batch/s, batch_idx=54, gpu=0, loss=0.384, v_num=9sg5v24z]
# Epoch 7:  64%|██████▍   | 69/107 [00:31<00:12,  2.95batch/s, batch_idx=54, gpu=0, loss=0.384, v_num=9sg5v24z]
# Epoch 7:  65%|██████▌   | 70/107 [00:31<00:12,  3.07batch/s, batch_idx=54, gpu=0, loss=0.384, v_num=9sg5v24z]
# Epoch 7:  66%|██████▋   | 71/107 [00:32<00:14,  2.49batch/s, batch_idx=54, gpu=0, loss=0.384, v_num=9sg5v24z]
# Epoch 7:  67%|██████▋   | 72/107 [00:32<00:13,  2.60batch/s, batch_idx=54, gpu=0, loss=0.384, v_num=9sg5v24z]
# Epoch 7:  68%|██████▊   | 73/107 [00:32<00:10,  3.33batch/s, batch_idx=54, gpu=0, loss=0.384, v_num=9sg5v24z]
# Epoch 7:  69%|██████▉   | 74/107 [00:32<00:09,  3.34batch/s, batch_idx=54, gpu=0, loss=0.384, v_num=9sg5v24z]
# Epoch 7:  70%|███████   | 75/107 [00:32<00:07,  4.03batch/s, batch_idx=54, gpu=0, loss=0.384, v_num=9sg5v24z]
# Epoch 7:  71%|███████   | 76/107 [00:33<00:07,  4.19batch/s, batch_idx=54, gpu=0, loss=0.384, v_num=9sg5v24z]
# Epoch 7:  72%|███████▏  | 77/107 [00:33<00:07,  4.15batch/s, batch_idx=54, gpu=0, loss=0.384, v_num=9sg5v24z]
# Epoch 7:  73%|███████▎  | 78/107 [00:33<00:10,  2.81batch/s, batch_idx=54, gpu=0, loss=0.384, v_num=9sg5v24z]
# Epoch 7:  74%|███████▍  | 79/107 [00:34<00:08,  3.32batch/s, batch_idx=54, gpu=0, loss=0.384, v_num=9sg5v24z]
# Epoch 7:  75%|███████▍  | 80/107 [00:34<00:07,  3.38batch/s, batch_idx=54, gpu=0, loss=0.384, v_num=9sg5v24z]
# Epoch 7:  77%|███████▋  | 82/107 [00:34<00:05,  4.21batch/s, batch_idx=54, gpu=0, loss=0.384, v_num=9sg5v24z]
# Epoch 7:  78%|███████▊  | 83/107 [00:34<00:05,  4.16batch/s, batch_idx=54, gpu=0, loss=0.384, v_num=9sg5v24z]
# Epoch 7:  79%|███████▊  | 84/107 [00:35<00:04,  4.82batch/s, batch_idx=54, gpu=0, loss=0.384, v_num=9sg5v24z]
# Epoch 7:  79%|███████▉  | 85/107 [00:35<00:04,  5.06batch/s, batch_idx=54, gpu=0, loss=0.384, v_num=9sg5v24z]
# Epoch 7:  80%|████████  | 86/107 [00:35<00:04,  5.05batch/s, batch_idx=54, gpu=0, loss=0.384, v_num=9sg5v24z]
# Epoch 7:  81%|████████▏ | 87/107 [00:35<00:03,  5.10batch/s, batch_idx=54, gpu=0, loss=0.384, v_num=9sg5v24z]
# Epoch 7:  82%|████████▏ | 88/107 [00:35<00:03,  5.93batch/s, batch_idx=54, gpu=0, loss=0.384, v_num=9sg5v24z]
# Epoch 7:  83%|████████▎ | 89/107 [00:35<00:03,  5.58batch/s, batch_idx=54, gpu=0, loss=0.384, v_num=9sg5v24z]
# Epoch 7:  84%|████████▍ | 90/107 [00:36<00:03,  4.28batch/s, batch_idx=54, gpu=0, loss=0.384, v_num=9sg5v24z]
# Epoch 7:  85%|████████▌ | 91/107 [00:36<00:03,  4.97batch/s, batch_idx=54, gpu=0, loss=0.384, v_num=9sg5v24z]
# Epoch 7:  86%|████████▌ | 92/107 [00:36<00:04,  3.12batch/s, batch_idx=54, gpu=0, loss=0.384, v_num=9sg5v24z]
# Epoch 7:  87%|████████▋ | 93/107 [00:37<00:03,  3.79batch/s, batch_idx=54, gpu=0, loss=0.384, v_num=9sg5v24z]
# Epoch 7:  88%|████████▊ | 94/107 [00:37<00:04,  3.09batch/s, batch_idx=54, gpu=0, loss=0.384, v_num=9sg5v24z]
# Epoch 7:  89%|████████▉ | 95/107 [00:39<00:08,  1.34batch/s, batch_idx=54, gpu=0, loss=0.384, v_num=9sg5v24z]
# Epoch 7:  90%|████████▉ | 96/107 [00:39<00:06,  1.66batch/s, batch_idx=54, gpu=0, loss=0.384, v_num=9sg5v24z]
# Epoch 7:  91%|█████████ | 97/107 [00:40<00:06,  1.53batch/s, batch_idx=54, gpu=0, loss=0.384, v_num=9sg5v24z]
# Epoch 7:  92%|█████████▏| 98/107 [00:40<00:04,  1.98batch/s, batch_idx=54, gpu=0, loss=0.384, v_num=9sg5v24z]
# Epoch 7:  93%|█████████▎| 99/107 [00:40<00:03,  2.43batch/s, batch_idx=54, gpu=0, loss=0.384, v_num=9sg5v24z]
# Epoch 7:  94%|█████████▍| 101/107 [00:40<00:01,  3.15batch/s, batch_idx=54, gpu=0, loss=0.384, v_num=9sg5v24z]
# Epoch 7:  95%|█████████▌| 102/107 [00:41<00:01,  2.99batch/s, batch_idx=54, gpu=0, loss=0.384, v_num=9sg5v24z]
# Epoch 7:  96%|█████████▋| 103/107 [00:41<00:01,  3.66batch/s, batch_idx=54, gpu=0, loss=0.384, v_num=9sg5v24z]
# Epoch 7:  97%|█████████▋| 104/107 [00:41<00:00,  4.24batch/s, batch_idx=54, gpu=0, loss=0.384, v_num=9sg5v24z]
# Epoch 7:  98%|█████████▊| 105/107 [00:41<00:00,  4.58batch/s, batch_idx=54, gpu=0, loss=0.384, v_num=9sg5v24z]
# Epoch 7:  99%|█████████▉| 106/107 [00:42<00:00,  4.11batch/s, batch_idx=54, gpu=0, loss=0.384, v_num=9sg5v24z]
# Epoch 7: 100%|██████████| 107/107 [00:43<00:00,  4.11batch/s, batch_idx=54, gpu=0, loss=0.384, v_num=9sg5v24z]
# Epoch 8:  51%|█████▏    | 55/107 [00:19<00:14,  3.54batch/s, batch_idx=54, gpu=0, loss=0.363, v_num=9sg5v24z]
# Validating:   0%|          | 0/52 [00:00<?, ?batch/s]
# Epoch 8:  52%|█████▏    | 56/107 [00:22<00:47,  1.07batch/s, batch_idx=54, gpu=0, loss=0.363, v_num=9sg5v24z]
# Epoch 8:  53%|█████▎    | 57/107 [00:25<01:13,  1.47s/batch, batch_idx=54, gpu=0, loss=0.363, v_num=9sg5v24z]
# Epoch 8:  54%|█████▍    | 58/107 [00:25<00:54,  1.12s/batch, batch_idx=54, gpu=0, loss=0.363, v_num=9sg5v24z]
# Epoch 8:  55%|█████▌    | 59/107 [00:26<00:48,  1.01s/batch, batch_idx=54, gpu=0, loss=0.363, v_num=9sg5v24z]
# Epoch 8:  56%|█████▌    | 60/107 [00:26<00:37,  1.26batch/s, batch_idx=54, gpu=0, loss=0.363, v_num=9sg5v24z]
# Epoch 8:  57%|█████▋    | 61/107 [00:26<00:27,  1.67batch/s, batch_idx=54, gpu=0, loss=0.363, v_num=9sg5v24z]
# Epoch 8:  58%|█████▊    | 62/107 [00:29<00:52,  1.17s/batch, batch_idx=54, gpu=0, loss=0.363, v_num=9sg5v24z]
# Epoch 8:  59%|█████▉    | 63/107 [00:29<00:37,  1.18batch/s, batch_idx=54, gpu=0, loss=0.363, v_num=9sg5v24z]
# Epoch 8:  60%|█████▉    | 64/107 [00:29<00:30,  1.42batch/s, batch_idx=54, gpu=0, loss=0.363, v_num=9sg5v24z]
# Epoch 8:  61%|██████    | 65/107 [00:29<00:22,  1.86batch/s, batch_idx=54, gpu=0, loss=0.363, v_num=9sg5v24z]
# Epoch 8:  62%|██████▏   | 66/107 [00:30<00:20,  2.04batch/s, batch_idx=54, gpu=0, loss=0.363, v_num=9sg5v24z]
# Epoch 8:  63%|██████▎   | 67/107 [00:30<00:17,  2.34batch/s, batch_idx=54, gpu=0, loss=0.363, v_num=9sg5v24z]
# Epoch 8:  64%|██████▎   | 68/107 [00:30<00:14,  2.75batch/s, batch_idx=54, gpu=0, loss=0.363, v_num=9sg5v24z]
# Epoch 8:  64%|██████▍   | 69/107 [00:30<00:13,  2.79batch/s, batch_idx=54, gpu=0, loss=0.363, v_num=9sg5v24z]
# Epoch 8:  65%|██████▌   | 70/107 [00:31<00:12,  2.90batch/s, batch_idx=54, gpu=0, loss=0.363, v_num=9sg5v24z]
# Epoch 8:  66%|██████▋   | 71/107 [00:31<00:15,  2.25batch/s, batch_idx=54, gpu=0, loss=0.363, v_num=9sg5v24z]
# Epoch 8:  67%|██████▋   | 72/107 [00:32<00:14,  2.37batch/s, batch_idx=54, gpu=0, loss=0.363, v_num=9sg5v24z]
# Epoch 8:  69%|██████▉   | 74/107 [00:32<00:11,  2.81batch/s, batch_idx=54, gpu=0, loss=0.363, v_num=9sg5v24z]
# Epoch 8:  70%|███████   | 75/107 [00:32<00:09,  3.43batch/s, batch_idx=54, gpu=0, loss=0.363, v_num=9sg5v24z]
# Epoch 8:  71%|███████   | 76/107 [00:33<00:08,  3.87batch/s, batch_idx=54, gpu=0, loss=0.363, v_num=9sg5v24z]
# Epoch 8:  72%|███████▏  | 77/107 [00:33<00:07,  3.93batch/s, batch_idx=54, gpu=0, loss=0.363, v_num=9sg5v24z]
# Epoch 8:  73%|███████▎  | 78/107 [00:33<00:10,  2.66batch/s, batch_idx=54, gpu=0, loss=0.363, v_num=9sg5v24z]
# Epoch 8:  74%|███████▍  | 79/107 [00:34<00:08,  3.25batch/s, batch_idx=54, gpu=0, loss=0.363, v_num=9sg5v24z]
# Epoch 8:  75%|███████▍  | 80/107 [00:34<00:08,  3.31batch/s, batch_idx=54, gpu=0, loss=0.363, v_num=9sg5v24z]
# Epoch 8:  77%|███████▋  | 82/107 [00:34<00:06,  4.07batch/s, batch_idx=54, gpu=0, loss=0.363, v_num=9sg5v24z]
# Epoch 8:  78%|███████▊  | 83/107 [00:34<00:06,  3.96batch/s, batch_idx=54, gpu=0, loss=0.363, v_num=9sg5v24z]
# Epoch 8:  79%|███████▊  | 84/107 [00:34<00:04,  4.70batch/s, batch_idx=54, gpu=0, loss=0.363, v_num=9sg5v24z]
# Epoch 8:  79%|███████▉  | 85/107 [00:35<00:04,  5.18batch/s, batch_idx=54, gpu=0, loss=0.363, v_num=9sg5v24z]
# Epoch 8:  80%|████████  | 86/107 [00:35<00:04,  5.01batch/s, batch_idx=54, gpu=0, loss=0.363, v_num=9sg5v24z]
# Epoch 8:  81%|████████▏ | 87/107 [00:35<00:03,  5.40batch/s, batch_idx=54, gpu=0, loss=0.363, v_num=9sg5v24z]
# Epoch 8:  82%|████████▏ | 88/107 [00:35<00:03,  5.80batch/s, batch_idx=54, gpu=0, loss=0.363, v_num=9sg5v24z]
# Epoch 8:  83%|████████▎ | 89/107 [00:35<00:03,  5.03batch/s, batch_idx=54, gpu=0, loss=0.363, v_num=9sg5v24z]
# Epoch 8:  84%|████████▍ | 90/107 [00:36<00:04,  4.14batch/s, batch_idx=54, gpu=0, loss=0.363, v_num=9sg5v24z]
# Epoch 8:  85%|████████▌ | 91/107 [00:36<00:03,  4.88batch/s, batch_idx=54, gpu=0, loss=0.363, v_num=9sg5v24z]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-9152df242794> in <module>
#      10                   early_stop_callback=False, accumulate_grad_batches=8,
#      11                   logger=logger, gpus=1) #, gradient_clip_val=0.5) # amp_level='O2', use_amp=True) <-- for half precision
# ---> 12 trainer.fit(model)
#
# ~/.virtualenvs/tesselate/lib/python3.6/site-packages/pytorch_lightning/trainer/trainer.py in fit(self, model)
#     693
#     694         elif self.single_gpu:
# --> 695             self.single_gpu_train(model)
#     696
#     697         # ON CPU
#
# ~/.virtualenvs/tesselate/lib/python3.6/site-packages/pytorch_lightning/trainer/distrib_parts.py in single_gpu_train(self, model)
#     439             self.optimizers = optimizers
#     440
# --> 441         self.run_pretrain_routine(model)
#     442
#     443     def dp_train(self, model):
#
# ~/.virtualenvs/tesselate/lib/python3.6/site-packages/pytorch_lightning/trainer/trainer.py in run_pretrain_routine(self, model)
#     827
#     828         # CORE TRAINING LOOP
# --> 829         self.train()
#     830
#     831     def test(self, model=None):
#
# ~/.virtualenvs/tesselate/lib/python3.6/site-packages/pytorch_lightning/trainer/training_loop.py in train(self)
#     330             # RUN TNG EPOCH
#     331             # -----------------
# --> 332             self.run_training_epoch()
#     333
#     334             # update LR schedulers
#
# ~/.virtualenvs/tesselate/lib/python3.6/site-packages/pytorch_lightning/trainer/training_loop.py in run_training_epoch(self)
#     400             # fast_dev_run always forces val checking after train batch
#     401             if self.fast_dev_run or should_check_val:
# --> 402                 self.run_evaluation(test=self.testing)
#     403
#     404             # when logs should be saved
#
# ~/.virtualenvs/tesselate/lib/python3.6/site-packages/pytorch_lightning/trainer/evaluation_loop.py in run_evaluation(self, test)
#     303                                      dataloaders,
#     304                                      max_batches,
# --> 305                                      test)
#     306         _, prog_bar_metrics, log_metrics, callback_metrics, _ = self.process_output(
#     307             eval_results)
#
# ~/.virtualenvs/tesselate/lib/python3.6/site-packages/pytorch_lightning/trainer/evaluation_loop.py in evaluate(self, model, dataloaders, max_batches, test)
#     232                                                  batch_idx,
#     233                                                  dataloader_idx,
# --> 234                                                  test)
#     235
#     236                 # track outputs for collation
#
# ~/.virtualenvs/tesselate/lib/python3.6/site-packages/pytorch_lightning/trainer/evaluation_loop.py in evaluation_forward(self, model, batch, batch_idx, dataloader_idx, test)
#     363             output = model.test_step(*args)
#     364         else:
# --> 365             output = model.validation_step(*args)
#     366
#     367         return output
#
# <ipython-input-19-b1865a7c83e7> in validation_step(self, batch, batch_nb)
#     195     def validation_step(self, batch, batch_nb):
#     196         # OPTIONAL
# --> 197         y_hat = self.forward(batch).squeeze()
#     198         y = triu_condense(batch['res_contact'].squeeze())
#     199         weights = triu_condense(batch['res_mask'].squeeze())
#
# <ipython-input-19-b1865a7c83e7> in forward(self, x)
#     133
#     134         for layer in self.atom_attns:
# --> 135                 atom_embed_update = checkpoint(layer, atom_embed_update, atom_adj)
#     136
#     137         res_embed = torch.matmul( x['mem_mat'].squeeze(), atom_embed_update)
#
# ~/.virtualenvs/tesselate/lib/python3.6/site-packages/torch/utils/checkpoint.py in checkpoint(function, *args, **kwargs)
#     153         raise ValueError("Unexpected keyword arguments: " + ",".join(arg for arg in kwargs))
#     154
# --> 155     return CheckpointFunction.apply(function, preserve, *args)
#     156
#     157
#
# /usr/lib/python3.6/traceback.py in format_stack(f, limit)
#     195     if f is None:
#     196         f = sys._getframe().f_back
# --> 197     return format_list(extract_stack(f, limit=limit))
#     198
#     199
#
# /usr/lib/python3.6/traceback.py in format_list(extracted_list)
#      37     whose source text line is not None.
#      38     """
# ---> 39     return StackSummary.from_list(extracted_list).format()
#      40
#      41 #
#
# /usr/lib/python3.6/traceback.py in format(self)
#     418             if count > _RECURSIVE_CUTOFF:
#     419                 continue
# --> 420             row = []
#     421             row.append('  File "{}", line {}, in {}\n'.format(
#     422                 frame.filename, frame.lineno, frame.name))
#
# KeyboardInterrupt:

# %% [markdown]
# # Analysis

# %%
# acts = model.activations
# model.cpu()
for idx, i in enumerate(DataLoader(val_data, shuffle=False, num_workers=30, pin_memory=True)):
    print(idx)

# %%
preds = triu_expand(out).sigmoid()

# %%
f = plot_channels(preds.detach())

# %%
plot_channels(triu_expand(i['res_contact'].squeeze()))

# %%
f

# %%
# Plot the predictions
preds = triu_expand(torch.from_numpy(acts['preds'])).sigmoid()
plot_channels(preds)

# %%
# Plot the true values
plot_channels(x['res_contact'])

# %%
plot_channels(x['res_mask'])

# %% [markdown]
# ## ROC

# %%
plot_curve(torch.from_numpy(acts['preds']).sigmoid(), triu_condense(x['res_contact'].squeeze()), 'ROC')

# %% [markdown]
# ## PRC

# %%
plot_curve(torch.from_numpy(acts['preds']).sigmoid(), triu_condense(x['res_contact'].squeeze()), 'PRC')

# %%
a = 5

# %%
x = train_data[0]

# %%
y = model(x)

# %%
x

# %%
import torch
x = torch.tensor([1., 2., 3.])

# %%
torch.pow(torch.div(x, 2), 5)

# %%
torch.relu(x - 2)

# %%
torch.randn((5, 5, 3)).sum(dim=-1).sum(dim=-1)
